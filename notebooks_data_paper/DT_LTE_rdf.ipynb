# %%
import pandas as pd 
import numpy as np
import os
from subprocess import check_output
import shutil

from rule import *
from amie import *

# %%
root_source_FB = "./../../FB15k_mail/"
root_source_DB = "./../../DB15k_mail/"

store_data_FB = "./../../Data_mail/FB_LTE.tsv"
store_data_DB = "./../../Data_mail/DB_LTE.tsv"

# %% [markdown]
# # FB15K

# %% [markdown]
# ### Prepare the data
#
# As we need a baseline for Amie, we are not going to change the value of anything.

# %%
data = open(root_source_FB+"numericals.txt", "r")

numerical_predicate = set()

for predicate in data:
    numerical_predicate.add(predicate.split("\n")[0])
    
data.close()

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
def write_file(X, f, threshold, comparator):
    f.write(f"<http:{X['Subject']}>\t<http:{X['Predicate']}_LTE_{threshold}>\t<http:/{X['Object']<=comparator}>\n")

# %%
data = open(root_source_FB+"train.txt", "r")
f = open(store_data_FB, "w")

dic_predicate = {}

for line in data:
    line_split = line.split("\n")[0].split("\t")
    if line_split[1] in numerical_predicate:
        line_split[2] = float(line_split[2]) 
        line_split = tuple(line_split)
        if line_split[1] in dic_predicate.keys():
            dic_predicate[line_split[1]].add(line_split)
        else : 
            dic_predicate[line_split[1]] = {line_split}
    else:
        for var in line_split:
            f.write('<http:'+var+'>\t')
        f.write("\n")
    
data.close()
f.close()

# %%
f = open(store_data_FB, "a")

for key in dic_predicate.keys():
    tp_df = pd.DataFrame.from_dict(dic_predicate[key]).rename(columns={0: "Subject", 1: "Predicate", 2: "Object"})
    tp_df_describe = tp_df["Object"].quantile(thresholds)
    for threshold in thresholds: 
        tp_df.apply(write_file, args=(f, threshold, tp_df_describe[threshold]), axis=1)

f.close()

# %% [markdown]
# ### Launch Amie

# %%
res = check_output(f'java -jar ./../amie3.jar {store_data_FB}', shell=True)

res_parsed = parse_amie(res)

# %%
len(res_parsed)
# Out:
# 114199

# %% [markdown]
# ### Clean rules

# %%
res_parsed_clean = res_parsed.copy()
for i in res_parsed:
    if len(i.hypotheses) == 1:
        if (i.hypotheses[0].predicate.split("LTE")[0] == i.conclusion.predicate.split("LTE")[0]) and len(i.hypotheses[0].predicate.split("LTE")) == 2:
            print(i)
            res_parsed_clean.remove(i)
# Out:
# ?a <http:<http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.location.area>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/location.location.area>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.location.area>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/location.location.area>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.location.area>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/location.location.area>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.location.area>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/location.location.area>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.location.area>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/location.location.area>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.location.area>_LTE_0.5> ?b => ?a <http:<http://rdf.freebase.com/ns/location.location.area>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.75> ?b
# ?a <http:<http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75> ?b => ?a <http:<http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.25> ?b
# ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.5> ?b
# ?a <http:<http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.25> ?b => ?a <http:<http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.75> ?b

# %%
len(res_parsed_clean)
# Out:
# 114049

# %% [markdown]
# ### Test the rules through test

# %%
data = open(root_source_FB+"test.txt", "r")
f = open("./../../Data_mail/"+"FB_LTE_test.nt", "w")

dic_predicate = {}

for line in data:
    line_split = line.split("\n")[0].split("\t")
    if line_split[1] in numerical_predicate:
        line_split[2] = float(line_split[2]) 
        line_split = tuple(line_split)
        if line_split[1] in dic_predicate.keys():
            dic_predicate[line_split[1]].add(line_split)
        else : 
            dic_predicate[line_split[1]] = {line_split}
    else:
        for var in line_split:
            f.write('<http:'+var+'>\t')
        f.write("\n")
        
print(dic_predicate)
for key in dic_predicate.keys():
    tp_df = pd.DataFrame.from_dict(dic_predicate[key]).rename(columns={0: "Subject", 1: "Predicate", 2: "Object"})
    tp_df_describe = tp_df["Object"].quantile(thresholds)
    for threshold in thresholds: 
        tp_df.apply(write_file, args=(f, threshold, tp_df_describe[threshold]), axis=1)

data.close()
f.close()
# Out:
# {}

# %% [markdown]
# # DB15K

# %% [markdown]
# ### Prepare the data
#
# As we need a baseline for Amie, we are not going to change the value of anything.

# %%
data = open(root_source_DB+"numericals.txt", "r")

numerical_predicate = set()

for predicate in data:
    numerical_predicate.add(predicate.split("\n")[0])
    
data.close()

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
data = open(root_source_DB+"train.txt", "r")
f = open(store_data_DB, "w")

dic_predicate = {}

for line in data:
    line_split = line.split("\n")[0].split(" ")
    if len(line_split) == 1:
        line_split = line.split("\n")[0].split("\t")
    if line_split[1] in numerical_predicate:
        line_split[2] = float(line_split[2]) 
        line_split = tuple(line_split)
        if line_split[1] in dic_predicate.keys():
            dic_predicate[line_split[1]].add(line_split)
        else : 
            dic_predicate[line_split[1]] = {line_split}
    else:
        f.write(line)
    
data.close()
f.close()

# %%
f = open(store_data_DB, "a")

for key in dic_predicate.keys():
    tp_df = pd.DataFrame.from_dict(dic_predicate[key]).rename(columns={0: "Subject", 1: "Predicate", 2: "Object"})
    tp_df_describe = tp_df["Object"].quantile(thresholds)
    for threshold in thresholds: 
        tp_df.apply(write_file, args=(f, threshold, tp_df_describe[threshold]), axis=1)

f.close()

# %% [markdown]
# ### Launch Amie

# %%
res = check_output(f'java -jar ./../amie3.jar {store_data_DB}', shell=True)

res_parsed = parse_amie(res)

# %%
len(res_parsed)
# Out:
# 80579

# %%
res_parsed
# Out:
# {?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b,
#  ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b,
#  ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationMetroDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/gross>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/extinctionDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/upperAge>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/other>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfGraduateStudents>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/other>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/other>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/assets>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/extinctionDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/dissolutionDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/firstAirDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/extinctionYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/barPassRate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/ranking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/extinctionDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/operatingIncome>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/other>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfDoctoralStudents>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/inseeCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfDoctoralStudents>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/extinctionDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/other>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/assets>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/netIncome>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/barPassRate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/equity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/extinctionYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/assets>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/netIncome>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/budget>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b,
# ...
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/draftYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/other>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/other>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/capacity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/inseeCode>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b,
#  ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/assets>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/netIncome>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/numberOfDoctoralStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/extinctionYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/budget>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/municipalityCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b,
#  ...}

# %% [markdown]
# ### Clean rules

# %%
res_parsed_clean = res_parsed.copy()
for i in res_parsed:
    if len(i.hypotheses) == 1:
        if (i.hypotheses[0].predicate.split("LTE")[0] == i.conclusion.predicate.split("LTE")[0]) and len(i.hypotheses[0].predicate.split("LTE")) == 2:
            print(i)
            res_parsed_clean.remove(i)
# Out:
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b

# %%
len(res_parsed_clean)
# Out:
# 80267
