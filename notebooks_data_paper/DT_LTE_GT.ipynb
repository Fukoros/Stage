# %%
import pandas as pd 
import numpy as np
import os
from subprocess import check_output
import shutil

from rule import *
from amie import *

# %%
root_source_FB = "./../../FB15k_mail/"
root_source_DB = "./../../DB15k_mail/"

store_data_FB = "./../../Data_mail/FB_LTE_GT.tsv"
store_data_DB = "./../../Data_mail/DB_LTE_GT.tsv"

# %% [markdown]
# # FB15K

# %% [markdown]
# ### Prepare the data
#
# As we need a baseline for Amie, we are not going to change the value of anything.

# %%
data = open(root_source_FB+"numericals.txt", "r")

numerical_predicate = set()

for predicate in data:
    numerical_predicate.add(predicate.split("\n")[0])
    
data.close()

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
def write_file(X, f, threshold, comparator):
    f.write(f"{X['Subject']}\t{X['Predicate']}_LTE_{threshold}\t{X['Object']<=comparator}\n")
    f.write(f"{X['Subject']}\t{X['Predicate']}_GT_{threshold}\t{X['Object']>comparator}\n")

# %%
data = open(root_source_FB+"train.txt", "r")
f = open(store_data_FB, "w")

dic_predicate = {}

for line in data:
    line_split = line.split("\n")[0].split("\t")
    if line_split[1] in numerical_predicate:
        line_split[2] = float(line_split[2]) 
        line_split = tuple(line_split)
        if line_split[1] in dic_predicate.keys():
            dic_predicate[line_split[1]].add(line_split)
        else : 
            dic_predicate[line_split[1]] = {line_split}
    else:
        f.write(line)
    
data.close()
f.close()

# %%
f = open(store_data_FB, "a")

for key in dic_predicate.keys():
    tp_df = pd.DataFrame.from_dict(dic_predicate[key]).rename(columns={0: "Subject", 1: "Predicate", 2: "Object"})
    tp_df_describe = tp_df["Object"].quantile(thresholds)
    for threshold in thresholds: 
        tp_df.apply(write_file, args=(f, threshold, tp_df_describe[threshold]), axis=1)

f.close()

# %% [markdown]
# ### Launch Amie

# %%
res = check_output(f'java -jar ./../amie3.jar {store_data_FB}', shell=True)

res_parsed = parse_amie(res)

# %%
len(res_parsed)
# Out:
# 339508

# %%
res_parsed
# Out:
# {?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b & ?b /base/popstra/celebrity/dated./base/popstra/dated/participant ?a => ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b,
#  ?e /location/country/first_level_divisions ?a & ?e <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?b,
#  ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25 ?b & ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25 ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?f <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_GT_0.25 ?b,
#  ?a /location/administrative_division/country ?f & ?f <http://rdf.freebase.com/ns/location.location.area>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_GT_0.75 ?b,
#  ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f & ?f <http://rdf.freebase.com/ns/topic_server.population_number>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.75 ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.atomic_number>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_GT_0.25 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?f <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_GT_0.75 ?b,
#  ?f /location/hud_county_place/place ?a & ?b /location/us_county/hud_county_place ?f => ?a /location/location/partially_containedby ?b,
#  ?a /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?f & ?f <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.5 ?b,
#  ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a & ?e <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25 ?b,
#  ?b /film/film_festival/location ?f & ?a /time/event/locations ?f => ?a /time/event/instance_of_recurring_event ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?b /tv/tv_program_creator/programs_created ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?f /common/topic/webpage./common/webpage/category ?a & ?b /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?f => ?a /common/annotation_category/annotations./common/webpage/topic ?b,
#  ?e /base/popstra/celebrity/vacations_in./base/popstra/vacation_choice/location ?a & ?e <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_GT_0.75 ?b,
#  ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f & ?f <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.25 ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.5 ?b & ?a <http://rdf.freebase.com/ns/location.location.area>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_GT_0.5 ?b,
#  ?e /location/location/people_born_here ?a & ?e <http://rdf.freebase.com/ns/location.location.gns_ufi>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.5 ?b,
#  ?e /military/military_combatant/military_commanders./military/military_command/military_conflict ?a & ?e <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_GT_0.75 ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/honored_for ?a & ?e <http://rdf.freebase.com/ns/organization.organization.date_founded>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_GT_0.25 ?b,
#  ?e /education/educational_institution/subsidiary_or_constituent_schools ?a & ?e <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_GT_0.25 ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?f <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_GT_0.5 ?b,
#  ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?f & ?f <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.25 ?b,
#  ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?f & ?f <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_GT_0.25 ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?f <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.25 ?b,
#  ?e /olympics/olympic_games/participating_countries ?a & ?e <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.5 ?b,
#  ?a /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?f & ?f <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_GT_0.25 ?b,
#  ?e /location/country/first_level_divisions ?a & ?e <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5 ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75 ?b & ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?b,
#  ?e /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?a & ?e <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_GT_0.25 ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_GT_0.75 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?a /music/musical_group/member./music/group_membership/member ?f & ?f <http://rdf.freebase.com/ns/music.artist.active_end>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.25 ?b,
#  ?e /influence/influence_node/peers./influence/peer_relationship/peers ?a & ?e <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.75 ?b,
#  ?a /organization/organization/place_founded ?f & ?f <http://rdf.freebase.com/ns/topic_server.population_number>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.75 ?b,
#  ?e /location/location/containedby ?a & ?e <http://rdf.freebase.com/ns/geography.river.source_elevation>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.75 ?b,
#  ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?f & ?f <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.5 ?b,
#  ?a /location/location/contains ?f & ?f <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25 ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?f <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.5 ?b,
#  ?a /film/film/country ?f & ?f <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.25 ?b,
#  ?a /people/person/parents ?f & ?f <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.25 ?b,
#  ?b /film/person_or_entity_appearing_in_film/films./film/personal_film_appearance/type_of_appearance ?a & ?b /tv/tv_actor/starring_roles./tv/regular_tv_appearance/special_performance_type ?a => ?a /film/personal_film_appearance_type/film_appearances./film/personal_film_appearance/person ?b,
#  ?e /education/fraternity_sorority/colleges_and_universities ?a & ?e /education/fraternity_sorority/colors ?b => ?a /education/educational_institution/colors ?b,
#  ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_GT_0.75 ?b & ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_GT_0.5 ?b,
#  ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.5 ?b & ?a <http://rdf.freebase.com/ns/sports.pro_athlete.career_start>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_GT_0.5 ?b,
#  ?e /base/culturalevent/event/entity_involved ?b & ?e /military/military_conflict/commanders./military/military_command/military_combatant ?a => ?a /location/statistical_region/places_imported_from./location/imports_and_exports/imported_from ?b,
#  ?a /people/person/nationality ?f & ?f <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.5 ?b,
#  ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a & ?e <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75 ?b,
#  ?e /base/popstra/celebrity/vacations_in./base/popstra/vacation_choice/location ?a & ?e <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5 ?b,
#  ?a /people/person/places_lived./people/place_lived/location ?f & ?f <http://rdf.freebase.com/ns/topic_server.population_number>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.25 ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/award_winner ?a & ?e /film/film/sequel ?b => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /geography/river/cities ?a & ?e <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_GT_0.75 ?b,
#  ?a /people/person/employment_history./business/employment_tenure/company ?f & ?f <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.75 ?b,
#  ?b /film/film/genre ?a & ?b /tv/tv_program/genre ?a => ?a /tv/tv_genre/programs ?b,
#  ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?f & ?f <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_GT_0.25 ?b,
#  ?e /olympics/olympic_participating_country/olympics_participated_in ?a & ?e <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_GT_0.25 ?b,
#  ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.5 ?b,
#  ?a /american_football/football_team/historical_roster./american_football/football_historical_roster_position/player ?f & ?b /user/szaijan/fantasy_football/position/player ?f => ?a /american_football/football_team/historical_roster./sports/sports_team_roster/position ?b,
#  ?a /organization/organization/headquarters./location/mailing_address/country ?f & ?f <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.5 ?b,
#  ?a /base/popstra/celebrity/supporter./base/popstra/support/supported_organization ?f & ?f <http://rdf.freebase.com/ns/people.person.height_meters>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_GT_0.25 ?b,
#  ?a /film/film/country ?f & ?f <http://rdf.freebase.com/ns/location.location.area>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.25 ?b,
#  ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5 ?b & ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_GT_0.25 ?b,
#  ?e /music/musical_group/member./music/group_membership/member ?a & ?e <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_GT_0.5 ?b,
#  ?a /sports/sports_team/roster./soccer/football_roster_position/player ?f & ?f <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.25 ?b,
#  ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f & ?f <http://rdf.freebase.com/ns/base.saturdaynightlive.snl_fiver_timer.number_of_appearances>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_GT_0.5 ?b,
#  ?e /olympics/olympic_games/medals_awarded./olympics/olympic_medal_honor/country ?a & ?e <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5 ?b,
#  ?a /award/award_ceremony/awards_presented./award/award_honor/award_winner ?f & ?f <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_GT_0.25 ?b,
#  ?e /basketball/basketball_team/historical_roster./sports/sports_team_roster/player ?a & ?e <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.5 ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/ceremony ?a & ?e <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_GT_0.25 ?b,
#  ?e /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?a & ?e <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.5 ?b,
#  ?e /education/educational_institution/students_graduates./education/education/student ?a & ?e <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.5 ?b,
#  ?a /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?f & ?f <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5 ?b,
#  ?e /music/musical_group/member./music/group_membership/member ?a & ?e <http://rdf.freebase.com/ns/music.artist.active_end>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_GT_0.25 ?b,
#  ?e /people/person/nationality ?a & ?e <http://rdf.freebase.com/ns/people.person.weight_kg>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.25 ?b,
#  ?a /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer ?f & ?f <http://rdf.freebase.com/ns/people.person.weight_kg>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.5 ?b,
#  ?a /base/biblioness/bibs_location/country ?f & ?f <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25 ?b,
#  ?a /business/business_operation/industry ?f & ?f <http://rdf.freebase.com/ns/business.industry.naics_2007>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_GT_0.5 ?b,
#  ?b /film/film/executive_produced_by ?f & ?a /people/person/sibling_s./people/sibling_relationship/sibling ?f => ?a /film/producer/films_executive_produced ?b,
#  ?a /business/employer/employees./business/employment_tenure/person ?f & ?b /film/film/executive_produced_by ?f => ?a /film/production_company/films ?b,
#  ?a /tv/tv_program/original_network./tv/tv_network_duration/network ?f & ?f <http://rdf.freebase.com/ns/broadcast.tv_station.founded>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.25 ?b,
#  ?e /base/locations/continents/countries_within ?a & ?e <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25 ?b,
#  ?e /people/person/spouse_s./people/marriage/location_of_ceremony ?a & ?e <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5 ?b,
#  ?a /location/location/containedby ?f & ?f <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.75 ?b,
#  ?a /award/award_category/winners./award/award_honor/ceremony ?f & ?f <http://rdf.freebase.com/ns/time.event.start_date>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.25 ?b,
#  ?a /people/person/nationality ?f & ?f <http://rdf.freebase.com/ns/location.location.area>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/music.artist.active_start>_GT_0.75 ?b,
#  ?e /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?e <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_GT_0.5 ?b,
#  ?e /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?a & ?e <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_GT_0.5 ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/award ?a & ?e <http://rdf.freebase.com/ns/film.film.initial_release_date>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.75 ?b,
#  ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_GT_0.75 ?b & ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.25 ?b,
#  ?a /film/film/story_by ?f & ?f <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_GT_0.75 ?b,
#  ?a /film/film/story_by ?f & ?f <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_GT_0.25 ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award ?a & ?e <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_GT_0.5 ?b,
#  ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_GT_0.25 ?b & ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.75 ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.5 ?b & ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.25 ?b,
#  ?e /tv/tv_program/recurring_writers./tv/tv_program_writer_relationship/writer ?a & ?e <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.25 ?b,
#  ?a /film/film/runtime./film/film_cut/type_of_film_cut ?f & ?f <http://rdf.freebase.com/ns/law.invention.date_of_invention>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.25 ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?e <http://rdf.freebase.com/ns/music.artist.active_start>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.5 ?b,
#  ?e /government/governmental_jurisdiction/governing_officials./government/government_position_held/office_holder ?a & ?e <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.75 ?b,
#  ?e /location/us_county/county_seat ?a & ?e <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_GT_0.25 ?b,
#  ?e /people/person/nationality ?a & ?e <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.25 ?b,
#  ?e /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer ?a & ?e <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_GT_0.75 ?b,
#  ?a /organization/organization/headquarters./location/mailing_address/country ?f & ?f <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.25 ?b,
#  ?a /government/political_district/representatives./government/government_position_held/legislative_sessions ?f & ?f <http://rdf.freebase.com/ns/government.legislative_session.date_began>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.5 ?b,
#  ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?f & ?f <http://rdf.freebase.com/ns/time.event.end_date>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.5 ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?e <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_GT_0.25 ?b,
#  ?a /base/aareas/schema/administrative_area/administrative_parent ?f & ?f <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5 ?b,
#  ?a /base/popstra/celebrity/eats_at./base/popstra/restaurant_choice/restaurant ?f & ?f <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_GT_0.25 ?b,
#  ?a /location/country/administrative_divisions ?f & ?f <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?f & ?f /film/film/other_crew./film/film_crew_gig/crewmember ?b => ?a /film/film/other_crew./film/film_crew_gig/crewmember ?b,
#  ?e /base/culturalevent/event/entity_involved ?a & ?e <http://rdf.freebase.com/ns/time.event.start_date>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5 ?b,
#  ?e /location/administrative_division/country ?a & ?e <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.75 ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/ceremony ?a & ?e <http://rdf.freebase.com/ns/music.artist.active_end>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_GT_0.5 ?b,
#  ?e /location/country/administrative_divisions ?a & ?e <http://rdf.freebase.com/ns/location.location.area>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.75 ?b,
#  ?a /location/administrative_division/country ?f & ?f <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.25 ?b,
#  ?a /time/event/locations ?f & ?f <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_GT_0.25 ?b,
#  ?e /location/country/administrative_divisions ?a & ?e <http://rdf.freebase.com/ns/location.location.area>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.25 ?b,
#  ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25 ?b & ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.5 ?b,
#  ?a /base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club ?f & ?f <http://rdf.freebase.com/ns/sports.sports_team.founded>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_GT_0.5 ?b,
#  ?e /government/governmental_jurisdiction/governing_officials./government/government_position_held/office_holder ?a & ?e <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.75 ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?e /business/business_operation/industry ?a => ?a /business/industry/companies ?b,
#  ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?f & ?f <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.75 ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?e <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.25 ?b,
#  ?e /film/film/release_date_s./film/film_regional_release_date/film_release_region ?a & ?e <http://rdf.freebase.com/ns/film.film.initial_release_date>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.75 ?b,
#  ?a /film/film/release_date_s./film/film_regional_release_date/film_release_region ?f & ?f <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_GT_0.75 ?b,
#  ?e /tv/tv_network/programs./tv/tv_network_duration/program ?a & ?e <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_GT_0.75 ?b,
#  ?e /olympics/olympic_games/medals_awarded./olympics/olympic_medal_honor/country ?a & ?e <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75 ?b,
#  ?a /location/statistical_region/places_imported_from./location/imports_and_exports/imported_from ?f & ?f <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.25 ?b,
#  ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_GT_0.5 ?b & ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_GT_0.25 ?b,
#  ?a /people/person/place_of_birth ?f & ?f <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.5 ?b,
#  ?e /location/location/containedby ?a & ?e <http://rdf.freebase.com/ns/location.location.area>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.5 ?b,
#  ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25 ?b & ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.75 ?b,
#  ?a /tv/tv_program/spin_offs ?f & ?f <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_GT_0.25 ?b,
#  ?e /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?a & ?e <http://rdf.freebase.com/ns/location.location.area>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.25 ?b,
#  ?e /award/award_nominated_work/award_nominations./award/award_nomination/award_nominee ?a & ?e <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_GT_0.75 ?b,
#  ?e /sports/sports_team/location ?a & ?e <http://rdf.freebase.com/ns/sports.sports_team.founded>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5 ?b,
#  ?e /olympics/olympic_athlete/country./olympics/olympic_athlete_affiliation/country ?a & ?e <http://rdf.freebase.com/ns/tennis.tennis_player.year_turned_pro>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.25 ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?f <http://rdf.freebase.com/ns/people.deceased_person.date_of_burial>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_GT_0.5 ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?f <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.5 ?b,
#  ?a /military/military_conflict/casualties./military/casualties/combatant ?b => ?a /military/military_conflict/combatants./military/military_combatant_group/combatants ?b,
#  ?e /base/biblioness/bibs_location/country ?a & ?e <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_GT_0.25 ?b,
#  ?e /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?a & ?e <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.75 ?b,
#  ?a /tv/tv_actor/starring_roles./tv/regular_tv_appearance/series ?f & ?f <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_GT_0.75 ?b,
#  ?a /film/film/runtime./film/film_cut/film_release_region ?f & ?f <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.5 ?b,
#  ?e /location/country/first_level_divisions ?a & ?e <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?b,
#  ?a /military/military_combatant/force_deployments./military/force_strength/combatant ?f & ?f <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5 ?b,
#  ?e /military/military_combatant/military_commanders./military/military_command/military_conflict ?a & ?e <http://rdf.freebase.com/ns/location.location.area>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_GT_0.25 ?b,
#  ?a /award/award_ceremony/awards_presented./award/award_honor/award_winner ?f & ?f <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.5 ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?e <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/music.artist.active_start>_GT_0.75 ?b,
#  ?e /government/governmental_jurisdiction/governing_officials./government/government_position_held/district_represented ?a & ?e <http://rdf.freebase.com/ns/location.location.area>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.75 ?b,
#  ?e /film/film/runtime./film/film_cut/film_release_region ?a & ?e <http://rdf.freebase.com/ns/film.film.initial_release_date>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.25 ?b,
#  ?a /award/award_ceremony/awards_presented./award/award_honor/award ?f & ?f <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_GT_0.75 ?b,
#  ?a /tv/tv_program/country_of_origin ?f & ?f <http://rdf.freebase.com/ns/location.location.area>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.75 ?b,
#  ?a /influence/influence_node/influenced_by ?f & ?f <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.25 ?b,
#  ?e /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?a & ?e <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.5 ?b,
#  ?a /base/schemastaging/tv_program_extra/regular_dubbing_performances./base/schemastaging/tv_star_dubbing_performance/actor ?f & ?f <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_GT_0.5 ?b,
#  ?b /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?a & ?a /people/person/spouse_s./people/marriage/spouse ?b => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?a /media_common/dedicator/dedications./media_common/dedication/dedicated_to ?f & ?f <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.75 ?b,
#  ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?f & ?f <http://rdf.freebase.com/ns/topic_server.population_number>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.75 ?b,
#  ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?f & ?f <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_GT_0.25 ?b,
#  ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_GT_0.25 ?b & ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.75 ?b,
#  ?a /military/military_conflict/commanders./military/military_command/military_commander ?f & ?f <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_GT_0.75 ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?f <http://rdf.freebase.com/ns/music.artist.active_start>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_GT_0.25 ?b,
#  ?a /tv/tv_program/country_of_origin ?f & ?f <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.5 ?b,
#  ?e /location/location/containedby ?a & ?e <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.25 ?b,
#  ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_GT_0.5 ?b & ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5 ?b,
#  ?a /film/film/distributors./film/film_film_distributor_relationship/region ?f & ?f <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_GT_0.25 ?b,
#  ?e /people/person/places_lived./people/place_lived/location ?a & ?e <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.25 ?b,
#  ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a & ?e <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.75 ?b,
#  ?e /olympics/olympic_games/medals_awarded./olympics/olympic_medal_honor/country ?a & ?e <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.5 ?b,
#  ?e /people/person/parents ?a & ?e <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5 ?b,
#  ?a /base/biblioness/bibs_location/state ?f & ?f <http://rdf.freebase.com/ns/topic_server.population_number>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.25 ?b,
#  ?a /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/source ?f & ?f <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.75 ?b,
#  ?a /time/event/locations ?f & ?f <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.to>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_GT_0.25 ?b,
#  ?a /music/musical_group/member./music/group_membership/member ?f & ?f <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/music.artist.active_start>_GT_0.75 ?b,
#  ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.5 ?b & ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.5 ?b,
#  ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?f & ?f <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_GT_0.75 ?b,
#  ?a /media_common/netflix_title/netflix_genres ?f & ?f <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.25 ?b,
#  ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a & ?e <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25 ?b,
#  ?a /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer ?f & ?f <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5 ?b,
#  ?a /military/military_conflict/casualties./military/casualties/combatant ?f & ?f <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.75 ?b,
#  ?a /tv/tv_program/spun_off_from ?f & ?f <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_GT_0.5 ?b,
#  ?e /tennis/tennis_player/matches_won./tennis/tennis_match/loser ?a & ?e <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_GT_0.75 ?b,
#  ?a <http://rdf.freebase.com/ns/biology.organism_classification.itis_tsn>_GT_0.5 ?f & ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.covalent_radius>_LTE_0.75 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a /people/person/sibling_s./people/sibling_relationship/sibling ?f & ?f <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.5 ?b,
#  ?e /people/person/nationality ?a & ?e <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.25 ?b,
#  ?a /olympics/olympic_participating_country/olympics_participated_in ?f & ?f <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75 ?b,
#  ?e /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?a & ?e <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.75 ?b,
#  ?e /film/film/runtime./film/film_cut/film_release_region ?a & ?e <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25 ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?f & ?f <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_GT_0.75 ?b,
#  ?a /award/award_category/winners./award/award_honor/award_winner ?f & ?f <http://rdf.freebase.com/ns/music.artist.active_end>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.25 ?b,
#  ?e /location/location/events ?a & ?e <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_GT_0.25 ?b,
#  ?a /people/deceased_person/place_of_death ?f & ?f <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.5 ?b,
#  ?e /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?a & ?e <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.25 ?b,
#  ?e /people/person/places_lived./people/place_lived/location ?a & ?e <http://rdf.freebase.com/ns/people.person.weight_kg>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.75 ?b,
#  ?e /base/aareas/schema/administrative_area/capital ?a & ?e <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5 ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?f & ?f <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_GT_0.25 ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?e /business/business_operation/net_profit./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?e /location/location/partially_contains ?a & ?e <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.75 ?b,
#  ?a <http://rdf.freebase.com/ns/people.person.height_meters>_GT_0.5 ?b & ?a <http://rdf.freebase.com/ns/tennis.tennis_player.year_turned_pro>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.75 ?b,
#  ?a /location/hud_county_place/county ?f & ?f <http://rdf.freebase.com/ns/location.location.area>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.25 ?b,
#  ?e /people/cause_of_death/people ?a & ?e <http://rdf.freebase.com/ns/medicine.icd_9_cm_classification.code>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_GT_0.75 ?b,
#  ?e /military/military_combatant/casualties./military/casualties/military_conflict ?a & ?e <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_GT_0.25 ?b,
#  ?a /government/government_office_category/officeholders./government/government_position_held/office_holder ?f & ?f /government/political_appointer/appointees./government/government_position_held/jurisdiction_of_office ?b => ?a /government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office ?b,
#  ?e /geography/river/basin_countries ?a & ?e <http://rdf.freebase.com/ns/geography.river.length>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.5 ?b,
#  ?e /government/politician/government_positions_held./government/government_position_held/district_represented ?a & ?e <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.75 ?b,
#  ?e /military/military_combatant/force_deployments./military/force_strength/military_conflict ?a & ?e <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.25 ?b,
#  ?e /common/topic/webpage./common/webpage/category ?b & ?e /education/educational_institution/students_graduates./education/education/student ?a => ?a /common/topic/webpage./common/webpage/category ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/honored_for ?a & ?e <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_GT_0.25 ?b,
#  ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?f & ?f <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.75 ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/honored_for ?f & ?f <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_GT_0.5 ?b,
#  ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?f & ?f <http://rdf.freebase.com/ns/base.schemastaging.celestial_object_extra.escape_velocity>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_GT_0.75 ?b,
#  ?a /location/administrative_division/second_level_division_of ?f & ?f <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_GT_0.25 ?b,
#  ?e /olympics/olympic_games/participating_countries ?a & ?e <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.5 ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?f <http://rdf.freebase.com/ns/music.artist.active_start>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.75 ?b,
#  ?e /american_football/football_team/current_roster./sports/sports_team_roster/position ?a & ?e /sports/sports_team/roster./american_football/football_historical_roster_position/position_s ?b => ?a /sports/sports_position/players./sports/sports_team_roster/position ?b,
#  ?a /music/artist/origin ?f & ?f <http://rdf.freebase.com/ns/location.location.area>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.75 ?b,
#  ?f /music/artist/track_contributions./music/track_contribution/role ?a & ?b /music/performance_role/track_performances./music/track_contribution/contributor ?f => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?a /base/biblioness/bibs_location/state ?f & ?f <http://rdf.freebase.com/ns/topic_server.population_number>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_GT_0.25 ?b,
# ...
#  ?a /people/person/place_of_birth ?f & ?f <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.25 ?b,
#  ?e /basketball/basketball_player/player_statistics./basketball/basketball_player_stats/team ?a & ?e <http://rdf.freebase.com/ns/sports.pro_athlete.career_start>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_GT_0.75 ?b,
#  ?a /base/aareas/schema/administrative_area/administrative_parent ?f & ?f <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5 ?b,
#  ?a /military/military_conflict/force_strengths./military/force_strength/combatant ?f & ?f <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_GT_0.75 ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /award/award_winner/awards_won./award/award_honor/award_winner ?b => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.25 ?b & ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.75 ?b,
#  ?a /base/popstra/celebrity/shops_at./base/popstra/shopping_choice/company ?f & ?f <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_GT_0.5 ?b,
#  ?e /base/biblioness/bibs_location/country ?a & ?e <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_GT_0.5 ?b,
#  ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?f & ?f <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_GT_0.5 ?b,
#  ?e /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?e <http://rdf.freebase.com/ns/people.person.height_meters>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.5 ?b,
#  ?a /location/hud_county_place/place ?f & ?f <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?f <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_GT_0.75 ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?e <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_GT_0.25 ?b,
#  ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a & ?e <http://rdf.freebase.com/ns/topic_server.population_number>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.5 ?b,
#  ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?f & ?f <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.25 ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?f <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5 ?b,
#  ?a /film/film/music ?f & ?f <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.5 ?b,
#  ?e /tv/tv_network/programs./tv/tv_network_duration/program ?a & ?e <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_GT_0.75 ?b,
#  ?a /music/artist/origin ?f & ?f <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.5 ?b,
#  ?e /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?a & ?e <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5 ?b,
#  ?e /location/administrative_division/first_level_division_of ?a & ?e <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.5 ?b,
#  ?a /music/musical_group/member./music/group_membership/member ?f & ?f <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/music.artist.active_start>_GT_0.25 ?b,
#  ?a /location/statistical_region/places_imported_from./location/imports_and_exports/imported_from ?f & ?f <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5 ?b,
#  ?a <http://rdf.freebase.com/ns/people.person.height_meters>_GT_0.25 ?b & ?a <http://rdf.freebase.com/ns/sports.pro_athlete.career_start>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_GT_0.75 ?b,
#  ?b /base/locations/continents/countries_within ?f & ?a /military/military_combatant/force_deployments./military/force_strength/combatant ?f => ?a /base/locations/countries/continent ?b,
#  ?a /location/administrative_division/country ?f & ?f <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_GT_0.5 ?b,
#  ?a /dataworld/gardening_hint/split_to ?f & ?b /music/performance_role/guest_performances./music/recording_contribution/performance_role ?f => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.75 ?b & ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.25 ?b,
#  ?e /base/popstra/company/shopping_choice./base/popstra/shopping_choice/shopper ?a & ?e <http://rdf.freebase.com/ns/location.location.area>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_GT_0.5 ?b,
#  ?a <http://rdf.freebase.com/ns/location.location.area>_GT_0.75 ?b & ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.25 ?b,
#  ?a /base/popstra/celebrity/vacations_in./base/popstra/vacation_choice/location ?f & ?f <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_GT_0.75 ?b,
#  ?a /military/military_conflict/commanders./military/military_command/military_combatant ?f & ?f <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.5 ?b,
#  ?a /location/country/capital ?f & ?f <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.75 ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?f <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_GT_0.25 ?b,
#  ?e /government/government_agency/jurisdiction ?b & ?e /organization/organization/founders ?a => ?a /people/person/employment_history./business/employment_tenure/company ?b,
#  ?a /film/actor/film./film/performance/film ?f & ?f <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_GT_0.5 ?b,
#  ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.5 ?f & ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.75 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?a /tv/tv_program/program_creator ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/award_nominee ?b,
#  ?e /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?a & ?e <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.5 ?b,
#  ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a & ?e <http://rdf.freebase.com/ns/geography.body_of_water.volume>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_GT_0.75 ?b,
#  ?f /olympics/olympic_games/sports ?a & ?b /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?f => ?a /olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country ?b,
#  ?e /olympics/olympic_participating_country/olympics_participated_in ?a & ?e <http://rdf.freebase.com/ns/location.dated_location.date_dissolved>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_GT_0.25 ?b,
#  ?a /organization/organization_member/member_of./organization/organization_membership/organization ?f & ?f <http://rdf.freebase.com/ns/organization.organization.date_founded>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.25 ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?f <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_GT_0.75 ?b,
#  ?e /location/country/administrative_divisions ?a & ?e <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25 ?b,
#  ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f & ?f <http://rdf.freebase.com/ns/location.location.area>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.5 ?b,
#  ?e /location/country/administrative_divisions ?a & ?e <http://rdf.freebase.com/ns/location.location.area>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25 ?b,
#  ?a /film/film_location/featured_in_films ?f & ?f <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_GT_0.25 ?b,
#  ?a /award/hall_of_fame_inductee/hall_of_fame_inductions./award/hall_of_fame_induction/hall_of_fame ?f & ?f <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_GT_0.25 ?b,
#  ?f /tv/tv_program/languages ?b & ?a /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?f => ?a /people/person/languages ?b,
#  ?a /people/person/children ?f & ?f <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.75 ?b,
#  ?e /location/location/people_born_here ?a & ?e <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.25 ?b,
#  ?a /tv/tv_program/tv_producer./tv/tv_producer_term/producer ?f & ?f <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_GT_0.5 ?b,
#  ?f /baseball/baseball_team/historical_roster./baseball/baseball_historical_roster_position/player ?a & ?b /sports/sport/teams ?f => ?a /sports/pro_athlete/sports_played_professionally./sports/pro_sports_played/sport ?b,
#  ?a /tv/tv_actor/starring_roles./tv/regular_tv_appearance/series ?f & ?f <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.25 ?b,
#  ?a <http://rdf.freebase.com/ns/base.schemastaging.tennis_player_extra.doubles_grand_slams>_GT_0.25 ?b & ?a <http://rdf.freebase.com/ns/people.person.height_meters>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.75 ?b,
#  ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.5 ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?b & ?e /base/biblioness/bibs_location/country ?a => ?a /location/country/first_level_divisions ?b,
#  ?a /award/hall_of_fame_inductee/hall_of_fame_inductions./award/hall_of_fame_induction/hall_of_fame ?f & ?f <http://rdf.freebase.com/ns/architecture.structure.opened>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_GT_0.25 ?b,
#  ?a /military/military_conflict/commanders./military/military_command/military_combatant ?f & ?f <http://rdf.freebase.com/ns/location.location.area>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.5 ?b,
#  ?e /olympics/olympic_games/medals_awarded./olympics/olympic_medal_honor/country ?a & ?e <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_GT_0.75 ?b,
#  ?a /location/administrative_division/country ?f & ?f <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.5 ?b,
#  ?e /music/musical_group/member./music/group_membership/member ?a & ?e <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_GT_0.25 ?b,
#  ?a /location/location/contains ?f & ?f <http://rdf.freebase.com/ns/location.dated_location.date_dissolved>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_GT_0.5 ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?f <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.75 ?b,
#  ?a /location/location/contains ?f & ?f <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_GT_0.75 ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award ?f & ?f <http://rdf.freebase.com/ns/award.award_category.date_discontinued>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.5 ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award ?f & ?f <http://rdf.freebase.com/ns/award.award_category.date_discontinued>_GT_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_GT_0.25 ?b,
#  ?e /ice_hockey/hockey_player/current_team./sports/sports_team_roster/position ?b & ?e /sports/pro_athlete/teams./sports/sports_team_roster/team ?a => ?a /ice_hockey/hockey_team/current_roster./ice_hockey/hockey_roster_position/position ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/ceremony ?a & ?e <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.5 ?b,
#  ?a /tv/tv_program/spun_off_from ?f & ?f <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.25 ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?a & ?e <http://rdf.freebase.com/ns/location.dated_location.date_founded>_GT_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.5 ?b,
#  ?a /olympics/olympic_games/medals_awarded./olympics/olympic_medal_honor/medalist ?f & ?f <http://rdf.freebase.com/ns/tennis.tennis_player.year_turned_pro>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_GT_0.25 ?b,
#  ...}

# %% [markdown]
# ### Clean rules

# %%
res_parsed_clean = res_parsed.copy()
for i in res_parsed:
    if len(i.hypotheses) == 1:
        if (i.hypotheses[0].predicate.split("LTE")[0] == i.conclusion.predicate.split("LTE")[0]) and len(i.hypotheses[0].predicate.split("LTE")) == 2:
            print(i)
            res_parsed_clean.remove(i)
# Out:
# ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.25 ?b
# ?b /location/statistical_region/places_imported_from./location/imports_and_exports/imported_from ?a => ?a /location/statistical_region/places_imported_from./location/imports_and_exports/imported_from ?b
# ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.25 ?b
# ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b
# ?b /location/hud_county_place/place ?a => ?a /location/hud_county_place/place ?b
# ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.25 ?b
# ?b /government/legislative_session/members./government/government_position_held/legislative_sessions ?a => ?a /government/legislative_session/members./government/government_position_held/legislative_sessions ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.5 ?b
# ?b /base/localfood/seasonal_month/produce_available./base/localfood/produce_availability/seasonal_months ?a => ?a /base/localfood/seasonal_month/produce_available./base/localfood/produce_availability/seasonal_months ?b
# ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.25 ?b
# ?b /award/award_category/category_of ?a => ?a /award/award_category/category_of ?b
# ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.5 ?b
# ?b /location/hud_county_place/county ?a => ?a /location/hud_county_place/county ?b
# ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5 ?b
# ?b /location/country/capital ?a => ?a /location/country/capital ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.75 ?b
# ?b /music/performance_role/regular_performances./music/group_membership/role ?a => ?a /music/performance_role/regular_performances./music/group_membership/role ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.5 ?b
# ?b /dataworld/gardening_hint/split_to ?a => ?a /dataworld/gardening_hint/split_to ?b
# ?b /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a => ?a /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?b
# ?b /education/field_of_study/students_majoring./education/education/major_field_of_study ?a => ?a /education/field_of_study/students_majoring./education/education/major_field_of_study ?b
# ?b /people/person/sibling_s./people/sibling_relationship/sibling ?a => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b
# ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.5 ?b
# ?b /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a => ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?b
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.75 ?b
# ?b /award/award/category ?a => ?a /award/award/category ?b
# ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.5 ?b
# ?b /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?a => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b
# ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.75 ?b
# ?b /sports/sports_position/players./sports/sports_team_roster/position ?a => ?a /sports/sports_position/players./sports/sports_team_roster/position ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.75 ?b
# ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a => ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b
# ?b /location/administrative_division/country ?a => ?a /location/administrative_division/country ?b
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75 ?b
# ?b /location/us_county/county_seat ?a => ?a /location/us_county/county_seat ?b
# ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.25 ?b
# ?b /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?a => ?a /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?b
# ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.5 ?b
# ?b /education/educational_institution_campus/educational_institution ?a => ?a /education/educational_institution_campus/educational_institution ?b
# ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?b
# ?b /location/us_county/hud_county_place ?a => ?a /location/us_county/hud_county_place ?b
# ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.25 ?b
# ?b /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?a => ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b
# ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.5 ?b
# ?b /base/popstra/celebrity/dated./base/popstra/dated/participant ?a => ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b
# ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/music.artist.active_start>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.height_meters>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/film.film.initial_release_date>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.heat>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death>_LTE_0.75 ?b
# ?b /award/award_winner/awards_won./award/award_honor/award_winner ?a => ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b
# ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.weight_kg>_LTE_0.25 ?b
# ?b /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?a => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b
# ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.5 ?b
# ?b /music/performance_role/guest_performances./music/recording_contribution/performance_role ?a => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b
# ?b /music/performance_role/track_performances./music/track_contribution/role ?a => ?a /music/performance_role/track_performances./music/track_contribution/role ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_episodes>_LTE_0.25 ?b
# ?b /award/award_winning_work/awards_won./award/award_honor/honored_for ?a => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b
# ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/time.event.start_date>_LTE_0.75 ?b
# ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.5 ?b
# ?b /education/educational_institution/campuses ?a => ?a /education/educational_institution/campuses ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.5 ?b
# ?b /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?a => ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b
# ?b /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?a => ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b
# ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/time.event.end_date>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.number_of_seasons>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/base.popstra.sww_base.interest>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_final_episode>_LTE_0.25 ?b
# ?b /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b
# ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.5 ?b
# ?b /people/person/spouse_s./people/marriage/spouse ?a => ?a /people/person/spouse_s./people/marriage/spouse ?b
# ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.25 ?b => ?a <http://rdf.freebase.com/ns/award.award_category.date_established>_LTE_0.5 ?b
# ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.75 ?b => ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25 ?b
# ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.5 ?b => ?a <http://rdf.freebase.com/ns/people.person.date_of_birth>_LTE_0.75 ?b
# ?b /influence/influence_node/peers./influence/peer_relationship/peers ?a => ?a /influence/influence_node/peers./influence/peer_relationship/peers ?b

# %%
len(res_parsed_clean)
# Out:
# 339322

# %% [markdown]
# # DB15K

# %% [markdown]
# ### Prepare the data
#
# As we need a baseline for Amie, we are not going to change the value of anything.

# %%
data = open(root_source_DB+"numericals.txt", "r")

numerical_predicate = set()

for predicate in data:
    numerical_predicate.add(predicate.split("\n")[0])
    
data.close()

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
data = open(root_source_DB+"train.txt", "r")
f = open(store_data_DB, "w")

dic_predicate = {}

for line in data:
    line_split = line.split("\n")[0].split(" ")
    if len(line_split) == 1:
        line_split = line.split("\n")[0].split("\t")
    if line_split[1] in numerical_predicate:
        line_split[2] = float(line_split[2]) 
        line_split = tuple(line_split)
        if line_split[1] in dic_predicate.keys():
            dic_predicate[line_split[1]].add(line_split)
        else : 
            dic_predicate[line_split[1]] = {line_split}
    else:
        f.write(line)
    
data.close()
f.close()

# %%
f = open(store_data_DB, "a")

for key in dic_predicate.keys():
    tp_df = pd.DataFrame.from_dict(dic_predicate[key]).rename(columns={0: "Subject", 1: "Predicate", 2: "Object"})
    tp_df_describe = tp_df["Object"].quantile(thresholds)
    for threshold in thresholds: 
        tp_df.apply(write_file, args=(f, threshold, tp_df_describe[threshold]), axis=1)

f.close()

# %% [markdown]
# ### Launch Amie

# %%
res = check_output(f'java -jar ./../amie3.jar {store_data_DB}', shell=True)

res_parsed = parse_amie(res)

# %%
len(res_parsed)
# Out:
# 487704

# %%
res_parsed
# Out:
# {?a <http://dbpedia.org/ontology/numberOfStudents>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/other>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/endowment>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b,
#  ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/facultySize>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/postalCode>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/birthDate>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/imdbId>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/birthYear>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfDoctoralStudents>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfSeasons>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/facultySize>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/other>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/imdbId>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/birthDate>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/releaseDate>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaLand>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/serviceStartYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/capacity>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/formationDate>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/ranking>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/other>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/height>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/area>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/postalCode>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/formationYear>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationDate>_GT_0.75 ?b,
#  ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrbanDensity>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/elevation>_GT_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetroDensity>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathYear>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/censusYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaLand>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/postalCode>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/inseeCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b,
#  ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/deathYear>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/facultySize>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/birthDate>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationMetroDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/barPassRate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfStudents>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/facultySize>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b,
#  ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/deathYear>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b,
#  ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/deathDate>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/deathYear>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/postalCode>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/deathDate>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/revenue>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/revenue>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathYear>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetroDensity>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/areaLand>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/censusYear>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/postalCode>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/inseeCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetroDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaWater>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/equity>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfStudents>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaLand>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/postalCode>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/equity>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/operatingIncome>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.25 ?b,
#  ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfEpisodes>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/staff>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaLand>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaLand>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/releaseDate>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/postalCode>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/elevation>_GT_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/facultySize>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfEpisodes>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/endowment>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/staff>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/imdbId>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/birthDate>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/birthYear>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/netIncome>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/upperAge>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetroDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/postalCode>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/postalCode>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/extinctionDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/other>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/censusYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingYear>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/elevation>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/elevation>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b,
# ...
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthDate>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/endowment>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetroDensity>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/height>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/height>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/assets>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/operatingIncome>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/deathYear>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfDoctoralStudents>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/municipalityCode>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/area>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/facultySize>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/endowment>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/barPassRate>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/censusYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/governmentElevation>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/areaWater>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetroDensity>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/birthDate>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/birthDate>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/birthYear>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/releaseDate>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/runtime>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationYear>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/other>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/draftYear>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/height>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/assets>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/birthYear>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfDoctoralStudents>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaLand>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/areaLand>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/postalCode>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/extinctionYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/operatingIncome>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/completionDate>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/distanceToLondon>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/area>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/distanceToLondon>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/gross>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/budget>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_GT_0.25 ?b,
#  ...}

# %% [markdown]
# ### Clean rules

# %%
res_parsed_clean = res_parsed.copy()
for i in res_parsed:
    if len(i.hypotheses) == 1:
        if (i.hypotheses[0].predicate.split("LTE")[0] == i.conclusion.predicate.split("LTE")[0]) and len(i.hypotheses[0].predicate.split("LTE")) == 2:
            print(i)
            res_parsed_clean.remove(i)
# Out:
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.5 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.5 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b

# %%
len(res_parsed_clean)
# Out:
# 487392
