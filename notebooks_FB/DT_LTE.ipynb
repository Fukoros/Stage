# %%
import pandas as pd 
import numpy as np
import os
from subprocess import check_output
import shutil

# %%
root_source = "./../../FB15k-237-num/"
root_store_data = "./../../Data_FB/"

# %%
if not os.path.isdir(root_store_data):
    os.mkdir(root_store_data)
else : 
    shutil.rmtree(root_store_data)
    os.mkdir(root_store_data)

# %%
f = open(root_source+"FB15K_NumericalTriples.txt", "r")
dic_predicate = {}
for line in f:
    line_split = line.split("\n")[0].split("\t")
    line_split[2] = float(line_split[2]) 
    line_split = tuple(line_split)
    if line_split[1] in dic_predicate.keys():
        dic_predicate[line_split[1]].add(line_split)
    else : 
        dic_predicate[line_split[1]] = {line_split}
f.close()

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
def write_file(X, f, threshold, comparator):
    f.write(f"{X['Subject']}\t{X['Predicate']}_LTE_{threshold}\t{X['Object']<comparator}\n")

# %%
f = open(root_store_data+"FB15K_lte.tsv", "w")

for key in dic_predicate.keys():
    tp_df = pd.DataFrame.from_dict(dic_predicate[key]).rename(columns={0: "Subject", 1: "Predicate", 2: "Object"})
    tp_df_describe = tp_df["Object"].quantile(thresholds)
    for threshold in thresholds: 
        tp_df.apply(write_file, args=(f, threshold, tp_df_describe[threshold]), axis=1)

f.close()

# %%
data = open(root_source+"train.txt")
f = open(root_store_data+"FB15K_lte.tsv", "a")

predicate_to_find = set()

for line in data: 
    f.write(line)
    predicate_to_find.add(line.split("\n")[0].split("\t")[1])
    
data.close()
f.close()

# %%
htr = ""
for p in predicate_to_find:
    htr+=p+","
htr = htr[:-1]
print(htr)
# Out:
# /organization/role/leaders./organization/leadership/organization,/award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee,/ice_hockey/hockey_team/current_roster./sports/sports_team_roster/position,/sports/pro_athlete/teams./sports/sports_team_roster/team,/people/person/religion,/film/film/produced_by,/film/actor/film./film/performance/film,/government/politician/government_positions_held./government/government_position_held/legislative_sessions,/base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club,/award/award_winner/awards_won./award/award_honor/award_winner,/film/film_set_designer/film_sets_designed,/location/country/second_level_divisions,/award/award_winning_work/awards_won./award/award_honor/award_winner,/government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office,/film/film_subject/films,/film/film/other_crew./film/film_crew_gig/crewmember,/base/aareas/schema/administrative_area/administrative_area_type,/film/film/featured_film_locations,/award/award_nominee/award_nominations./award/award_nomination/nominated_for,/people/person/sibling_s./people/sibling_relationship/sibling,/education/university/fraternities_and_sororities,/medicine/symptom/symptom_of,/location/location/partially_contains,/people/person/place_of_birth,/tv/tv_program/regular_cast./tv/regular_tv_appearance/actor,/base/popstra/celebrity/breakup./base/popstra/breakup/participant,/education/university/local_tuition./measurement_unit/dated_money_value/currency,/people/deceased_person/place_of_burial,/film/person_or_entity_appearing_in_film/films./film/personal_film_appearance/type_of_appearance,/location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency,/award/award_category/winners./award/award_honor/award_winner,/music/artist/contribution./music/recording_contribution/performance_role,/film/film/runtime./film/film_cut/film_release_region,/sports/sports_team/roster./basketball/basketball_roster_position/position,/tv/tv_program/tv_producer./tv/tv_producer_term/producer_type,/organization/non_profit_organization/registered_with./organization/non_profit_registration/registering_agency,/common/topic/webpage./common/webpage/category,/food/food/nutrients./food/nutrition_fact/nutrient,/education/field_of_study/students_majoring./education/education/major_field_of_study,/dataworld/gardening_hint/split_to,/music/performance_role/guest_performances./music/recording_contribution/performance_role,/sports/sports_team/sport,/film/film/story_by,/base/petbreeds/city_with_dogs/top_breeds./base/petbreeds/dog_city_relationship/dog_breed,/soccer/football_team/current_roster./sports/sports_team_roster/position,/film/director/film,/sports/sports_team/roster./american_football/football_roster_position/position,/business/business_operation/industry,/medicine/disease/notable_people_with_this_condition,/time/event/instance_of_recurring_event,/location/statistical_region/places_exported_to./location/imports_and_exports/exported_to,/location/hud_county_place/place,/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/olympics,/music/instrument/family,/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/contact_category,/broadcast/content/artist,/music/genre/artists,/education/educational_degree/people_with_this_degree./education/education/major_field_of_study,/people/marriage_union_type/unions_of_this_type./people/marriage/location_of_ceremony,/travel/travel_destination/how_to_get_here./travel/transportation/mode_of_transportation,/tv/tv_program/genre,/award/award_category/disciplines_or_subjects,/film/film/film_format,/base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer,/government/governmental_body/members./government/government_position_held/legislative_sessions,/sports/sports_team/roster./american_football/football_histo ...

# %%
def parse_amie(res_rules_raw):    
    rules_per_cv = {}
    cpt = 0
    rules = set()
    for line in res_rules_raw.decode("utf-8").split("\n"):
        if (line != "") and (line[0] == "?"):
            dic = {}
            parts = line.split("\t")

            conclusion_raw = parts[0].split("=>")[1].split("  ")
            conclusion_raw[0] = conclusion_raw[0][1:]
            dic["conclusion"] = Atom(conclusion_raw)

            hypotheses_raw = parts[0].split("=>")[0].split("  ")
            hypotheses = []
            for i in range(0, len(hypotheses_raw)-1, 3):
                hypotheses.append(Atom(hypotheses_raw[i:i+3]))
            dic["hypotheses"] = hypotheses


            rules.add(Rule(dic["hypotheses"], dic["conclusion"], parts[1:]))
    return rules

# %%
class Atom:
    
    def __init__(self, atom_raw):
        self._subject = atom_raw[0]
        self._predicate = atom_raw[1]
        self._objectD = atom_raw[2]
        
    def __hash__(self):
        return hash((self._subject, self._predicate, self._objectD))
    
    def __repr__(self):
        return f"{self.subject} {self.predicate} {self.objectD}"
    
    def __eq__(self, other):
        return self.subject==other.subject and self.predicate==other.predicate and self.objectD==other.objectD
        
    @property
    def subject(self):
        return self._subject
    
    @property
    def predicate(self):
        return self._predicate
    
    @property
    def objectD(self):
        return self._objectD
    
class Rule:
    
    def __init__(self, hypotheses, conclusion, otherRes, fromDict=False):
        if not fromDict:
            if not isinstance(hypotheses, tuple):
                self._hypotheses = tuple(hypotheses)
            else : 
                self._hypotheses = hypotheses
            self._conclusion = conclusion
            self._size_hypotheses = len(hypotheses)
            self._headCoverage = float(otherRes[0])
            self._stdConfidence = float(otherRes[1])
            self._pcaConfidence = float(otherRes[2])
            self._precision_train = None
            self._precision_test = None
        else:
            
            if not isinstance(hypotheses, tuple):
                self._hypotheses = tuple(hypotheses)
            else : 
                self._hypotheses = hypotheses
            self._conclusion = conclusion
            self._size_hypotheses = len(hypotheses)
            self._headCoverage = float(otherRes[0])
            self._stdConfidence = float(otherRes[1])
            self._pcaConfidence = float(otherRes[2])
            self._precision_train = float(otherRes[3])
            self._precision_test = float(otherRes[4])
        
        
    def __hash__(self):
        return hash((self._hypotheses, self._conclusion))
        
    def __repr__(self):
        toWrite=""
        for atom in self.hypotheses:
            toWrite += f"{atom} & "
        toWrite = toWrite[:-3] + " => " 
        toWrite += str(self.conclusion)
        return toWrite

    def __eq__(self, other):
        if not isinstance(other, Rule):
            return False
        return (self.conclusion == other.conclusion) and (set(self.hypotheses) == set(other.hypotheses))
    
    @property
    def hypotheses(self):
        return self._hypotheses
    
    @property
    def conclusion(self):
        return self._conclusion
    
    @property
    def size_hypotheses(self):
        return self._size_hypotheses
    
    @property
    def headCoverage(self):
        return self._headCoverage
    
    @property
    def stdConfidence(self):
        return self._stdConfidence
    
    @property
    def pcaConfidence(self):
        return self._pcaConfidence
    
    @property
    def precision_train(self):
        return self._precision_train
    
    @property
    def precision_test(self):
        return self._precision_test
    
    def setPrecisionTrain(self, precision):
        self._precision_train = precision
    
    def setPrecisionTest(self, precision):
        self._precision_test = precision
        
    def toDict(self):
        return {"hypotheses":self._hypotheses, "conclusion":self._conclusion, "size_hypothese":self._size_hypotheses, "headCoverage":self._headCoverage, "stdConfidence":self._stdConfidence, "pcaConfidence":self._pcaConfidence, "precision_train": self._precision_train, "precision_test":self._precision_test}
    
    def fromDict(row):
        return Rule( row["hypotheses"], row["conclusion"], row.values[2:], True)
            
# Given a feature we will compare it to a threshold      
def limit_by_threshold(X, feature, threshold):
    return X[feature] >= threshold

# Given Amie sets of rules and new parameters, it returns new set of rules describe by these parameters.
def add_parameters(amie_responses, parameters):
    new_responses = {}
    for amie_response in amie_responses:
        for para in parameters:
            
            #Optimizable
            new_response_raw = amie_responses[amie_response].copy()
            new_response = {}
            for r in new_response_raw:
                new_response[r] = new_response_raw[r].toDict()
            new_response = pd.DataFrame.from_dict(new_response, orient="index")
            
            name = amie_response
            for sub_para in para:
                if len(new_response) != 0:
                    new_response = new_response.loc[new_response.apply(func=limit_by_threshold, axis=1, feature=sub_para[0], threshold=sub_para[1])]
                if sub_para[0] == "stdConfidence":
                    name += "\n"+"stdC"+"="+str(sub_para[1])
                elif sub_para[0] == "pcaConfidence":
                    name += "\n"+"pcaC"+"="+str(sub_para[1])
                else :
                    name += "\n"+"hC"+"="+str(sub_para[1])
            new_responses[name] = new_response
    return new_responses


def save_sets_rule(root, set_rules):
    if not path.isdir(root+"/save"):
        os.mkdir(root+"/save")
    else : 
        shutil.rmtree(root+"/save")
        os.mkdir(root+"/save")
    for set_rule in set_rules:
        set_rules[set_rule].to_csv(root+"/save/"+set_rule+".tsv")

# %%
data = f"{root_store_data}'FB15K_lte.tsv'"
res = check_output(f'java -jar ./../amie3.jar -htr {htr} {data}', shell=True)

res_parsed = parse_amie(res)

# %%
res_parsed
# Out:
# {?b /base/aareas/schema/administrative_area/capital ?f & ?a /people/person/places_lived./people/place_lived/location ?f => ?a /people/person/places_lived./people/place_lived/location ?b,
#  ?a /education/educational_institution_campus/educational_institution ?f & ?f /organization/organization/headquarters./location/mailing_address/state_province_region ?b => ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.ionization_energy>_LTE_0.75 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?b /sports/sports_position/players./sports/sports_team_roster/position ?f & ?a /sports/sports_team/roster./american_football/football_historical_roster_position/position_s ?f => ?a /sports/sports_team/roster./american_football/football_roster_position/position ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?a /film/film/story_by ?b => ?a /film/film/produced_by ?b,
#  ?e /influence/influence_node/influenced_by ?b & ?a /people/ethnicity/people ?e => ?a /people/ethnicity/people ?b,
#  ?f /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b & ?a /people/person/spouse_s./people/marriage/location_of_ceremony ?f => ?a /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b,
#  ?e /base/aareas/schema/administrative_area/capital ?b & ?e /location/administrative_division/first_level_division_of ?a => ?a /location/country/second_level_divisions ?b,
#  ?a /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?f & ?b /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?f => ?a /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b,
#  ?f /film/actor/film./film/performance/special_performance_type ?b & ?a /influence/influence_node/influenced_by ?f => ?a /film/actor/film./film/performance/special_performance_type ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/film_production_design_by ?b => ?a /film/film/film_production_design_by ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?a /education/educational_degree/people_with_this_degree./education/education/student ?e => ?a /education/educational_degree/people_with_this_degree./education/education/student ?b,
#  ?e /location/location/contains ?a & ?e /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b => ?a /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b,
#  ?e /film/film/country ?b & ?e /tv/tv_program/country_of_origin ?a => ?a /dataworld/gardening_hint/split_to ?b,
#  ?a /film/film/featured_film_locations ?f & ?f /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?e /music/instrument/family ?a & ?e /music/performance_role/regular_performances./music/group_membership/role ?b => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?e /education/educational_institution/campuses ?a & ?e /education/university/fraternities_and_sororities ?b => ?a /education/university/fraternities_and_sororities ?b,
#  ?a /dataworld/gardening_hint/split_to ?f & ?b /education/educational_institution/campuses ?f => ?a /education/educational_institution/campuses ?b,
#  ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_LTE_0.5 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?e /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?e /organization/organization/headquarters./location/mailing_address/state_province_region ?a => ?a /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_compound.melting_point>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/food.food.energy>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?f /film/film/music ?b & ?a /film/film/prequel ?f => ?a /film/film/edited_by ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?b /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?a => ?a /tv/tv_program/program_creator ?b,
#  ?e /time/event/locations ?a & ?e /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b => ?a /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b,
#  ?a /base/biblioness/bibs_location/country ?f & ?f /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b => ?a /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b,
#  ?e /location/hud_county_place/county ?a & ?e /location/hud_county_place/place ?b => ?a /location/us_county/county_seat ?b,
#  ?e /education/educational_institution/students_graduates./education/education/student ?a & ?e /organization/organization/headquarters./location/mailing_address/citytown ?b => ?a /people/person/place_of_birth ?b,
#  ?f /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b & ?a /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?f => ?a /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b,
#  ?b /film/director/film ?f & ?a /film/film/prequel ?f => ?a /film/film/written_by ?b,
#  ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?f & ?b /location/location/contains ?f => ?a /location/administrative_division/country ?b,
#  ?b /location/location/contains ?f & ?a /people/deceased_person/place_of_death ?f => ?a /people/person/nationality ?b,
#  ?b /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?a & ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?e /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b & ?e /people/person/places_lived./people/place_lived/location ?a => ?a /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b,
#  ?a <http://rdf.freebase.com/ns/base.schemastaging.location_extra.elevation_min>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.5 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc>_LTE_0.5 ?f => ?a /location/location/time_zones ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?f /location/location/contains ?a => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?a <http://rdf.freebase.com/ns/base.lewisandclark.places_eastward.from>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/time.month.number_of_days_in_month>_LTE_0.75 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?a /music/performance_role/regular_performances./music/group_membership/group ?f & ?b /music/performance_role/regular_performances./music/group_membership/group ?f => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?f /organization/organization_founder/organizations_founded ?b & ?a /people/person/spouse_s./people/marriage/spouse ?f => ?a /organization/organization_founder/organizations_founded ?b,
#  ?a /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b => ?a /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?a /broadcast/content/artist ?e & ?e /influence/influence_node/peers./influence/peer_relationship/peers ?b => ?a /broadcast/content/artist ?b,
#  ?b /film/film/story_by ?a => ?a /film/director/film ?b,
#  ?e /people/person/nationality ?b & ?e /people/person/places_lived./people/place_lived/location ?a => ?a /base/biblioness/bibs_location/country ?b,
#  ?f /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization_member/member_of./organization/organization_membership/organization ?f => ?a /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?a /film/actor/film./film/performance/film ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?e /organization/organization/headquarters./location/mailing_address/citytown ?b & ?e /organization/organization/headquarters./location/mailing_address/state_province_region ?a => ?a /location/country/capital ?b,
#  ?a /film/film/film_production_design_by ?b => ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b,
#  ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b => ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b,
#  ?e /tv/tv_program/languages ?b & ?e /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?a => ?a /people/person/languages ?b,
#  ?e /people/person/places_lived./people/place_lived/location ?a & ?e /people/person/places_lived./people/place_lived/location ?b => ?a /location/hud_county_place/place ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?f /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?b /award/award_winner/awards_won./award/award_honor/award_winner ?a => ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b,
#  ?b <http://rdf.freebase.com/ns/architecture.architect.structure_count>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/architecture.architect.structure_count>_LTE_0.75 ?f => ?a /influence/influence_node/peers./influence/peer_relationship/peers ?b,
#  ?a <http://rdf.freebase.com/ns/biology.organism_classification.itis_tsn>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/chemistry.chemical_compound.melting_point>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries>_LTE_0.75 ?f & ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.75 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?b /award/award_winning_work/awards_won./award/award_honor/award ?a => ?a /award/award_category/nominees./award/award_nomination/nominated_for ?b,
#  ?e /base/biblioness/bibs_location/country ?a & ?e /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b => ?a /location/location/contains ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?f /film/person_or_entity_appearing_in_film/films./film/personal_film_appearance/type_of_appearance ?b => ?a /film/person_or_entity_appearing_in_film/films./film/personal_film_appearance/type_of_appearance ?b,
#  ?e /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a => ?a /location/hud_county_place/county ?b,
#  ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries>_LTE_0.75 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?a /location/country/second_level_divisions ?b => ?a /location/location/contains ?b,
#  ?a /education/educational_institution/campuses ?b => ?a /education/educational_institution_campus/educational_institution ?b,
#  ?b /award/award_category/nominees./award/award_nomination/nominated_for ?a => ?a /award/award_winning_work/awards_won./award/award_honor/award ?b,
#  ?e /location/us_county/county_seat ?a & ?e /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?f /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?a => ?a /olympics/olympic_games/participating_countries ?b,
#  ?a /location/country/second_level_divisions ?f & ?f /location/location/contains ?b => ?a /location/country/second_level_divisions ?b,
#  ?f /location/administrative_division/country ?b & ?a /location/location/contains ?f => ?a /location/administrative_division/first_level_division_of ?b,
#  ?b /education/educational_institution/campuses ?f & ?a /education/educational_institution_campus/educational_institution ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?f /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b & ?a /location/hud_county_place/place ?f => ?a /base/biblioness/bibs_location/state ?b,
#  ?e /film/film/music ?a & ?e /film/film/music ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?e /film/actor/dubbing_performances./film/dubbing_performance/language ?b => ?a /people/person/languages ?b,
#  ?a <http://rdf.freebase.com/ns/government.legislative_session.date_ended>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25 ?f => ?a /government/legislative_session/members./government/government_position_held/district_represented ?b,
#  ?b /film/director/film ?a & ?a /film/film/edited_by ?b => ?a /film/film/produced_by ?b,
#  ?b <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/sports.sports_league_draft.year>_LTE_0.75 ?f => ?a /sports/sports_league_draft/picks./sports/sports_league_draft_pick/school ?b,
#  ?f /location/location/adjoin_s./location/adjoining_relationship/adjoins ?b & ?a /time/event/locations ?f => ?a /military/military_conflict/combatants./military/military_combatant_group/combatants ?b,
#  ?b /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries>_LTE_0.25 ?f => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?f & ?b /music/instrument/instrumentalists ?f => ?a /music/artist/contribution./music/recording_contribution/performance_role ?b,
#  ?f /location/hud_county_place/county ?b & ?a /location/hud_county_place/county ?f => ?a /location/hud_county_place/county ?b,
#  ?a /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?f & ?b /sports/sports_position/players./sports/sports_team_roster/position ?f => ?a /sports/sports_position/players./sports/sports_team_roster/position ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?b /award/award_winner/awards_won./award/award_honor/award_winner ?a => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b,
#  ?a <http://rdf.freebase.com/ns/government.legislative_session.date_began>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25 ?f => ?a /government/legislative_session/members./government/government_position_held/district_represented ?b,
#  ?e /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?a & ?e /sports/sports_position/players./sports/sports_team_roster/position ?b => ?a /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.van_der_waals_radius>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.25 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.25 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?e /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b & ?e /film/film/prequel ?a => ?a /film/film/prequel ?b,
#  ?b /location/location/contains ?f & ?f /organization/organization/headquarters./location/mailing_address/country ?a => ?a /location/location/contains ?b,
#  ?f /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b & ?a /organization/organization/headquarters./location/mailing_address/country ?f => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f & ?f /music/group_member/membership./music/group_membership/role ?a => ?a /music/instrument/instrumentalists ?b,
#  ?f /location/hud_county_place/place ?b & ?a /time/event/locations ?f => ?a /time/event/locations ?b,
#  ?b /base/biblioness/bibs_location/country ?a => ?a /location/country/second_level_divisions ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?b & ?e /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?a => ?a /location/administrative_division/country ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_LTE_0.75 ?f => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?f /people/person/employment_history./business/employment_tenure/company ?b => ?a /organization/organization_founder/organizations_founded ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?e /music/group_member/membership./music/group_membership/role ?b => ?a /music/group_member/membership./music/group_membership/role ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?f & ?f /film/film/film_production_design_by ?b => ?a /film/film/film_production_design_by ?b,
#  ?e /music/performance_role/guest_performances./music/recording_contribution/performance_role ?a & ?e /music/performance_role/regular_performances./music/group_membership/role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?e /education/educational_institution/campuses ?a & ?e /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?a /film/film/produced_by ?b => ?a /film/film/story_by ?b,
#  ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_LTE_0.5 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?f /film/director/film ?a & ?b /film/film/produced_by ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/time.month.number_of_days_in_month>_LTE_0.75 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?b /base/popstra/celebrity/dated./base/popstra/dated/participant ?f & ?a /film/film/personal_appearances./film/personal_film_appearance/person ?f => ?a /film/film/personal_appearances./film/personal_film_appearance/person ?b,
#  ?a /location/administrative_division/country ?f & ?f /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b,
#  ?e /base/popstra/celebrity/dated./base/popstra/dated/participant ?a & ?e /people/person/nationality ?b => ?a /people/person/nationality ?b,
#  ?f /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b & ?a /film/film/personal_appearances./film/personal_film_appearance/person ?f => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?e /base/aareas/schema/administrative_area/capital ?a & ?e /base/aareas/schema/administrative_area/capital ?b => ?a /location/us_county/county_seat ?b,
#  ?b /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?a & ?b /location/hud_county_place/county ?a => ?a /location/location/contains ?b,
#  ?b /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /sports/sports_position/players./sports/sports_team_roster/position ?b & ?e /sports/sports_position/players./sports/sports_team_roster/team ?a => ?a /sports/sports_team/roster./american_football/football_roster_position/position ?b,
#  ?f /location/hud_county_place/county ?a & ?b /location/hud_county_place/county ?f => ?a /location/hud_county_place/place ?b,
#  ?b /film/film/written_by ?a => ?a /film/actor/film./film/performance/film ?b,
#  ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?f & ?b /dataworld/gardening_hint/split_to ?f => ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?b,
#  ?e /music/instrument/family ?a & ?b /music/performance_role/regular_performances./music/group_membership/role ?e => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?e /base/biblioness/bibs_location/country ?b & ?e /location/location/contains ?a => ?a /organization/organization/headquarters./location/mailing_address/country ?b,
#  ?f /location/us_county/county_seat ?b & ?a /location/us_county/county_seat ?f => ?a /location/hud_county_place/place ?b,
#  ?a /film/film/featured_film_locations ?f & ?b /location/country/capital ?f => ?a /film/film/distributors./film/film_film_distributor_relationship/region ?b,
#  ?e /base/popstra/celebrity/dated./base/popstra/dated/participant ?a & ?e /people/person/languages ?b => ?a /people/person/languages ?b,
#  ?b /music/performance_role/guest_performances./music/recording_contribution/performance_role ?f & ?f /music/performance_role/track_performances./music/track_contribution/role ?a => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?f /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b & ?a /education/educational_institution/students_graduates./education/education/student ?f => ?a /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.van_der_waals_radius>_LTE_0.75 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?f /film/actor/film./film/performance/film ?a & ?b /film/film/other_crew./film/film_crew_gig/crewmember ?f => ?a /film/film/prequel ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/produced_by ?b => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.25 ?f & ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.75 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?b /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?a => ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b,
#  ?f /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b & ?a /education/educational_institution_campus/educational_institution ?f => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?a /film/film/country ?f & ?f /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?f /location/administrative_division/country ?b & ?a /olympics/olympic_games/participating_countries ?f => ?a /olympics/olympic_games/participating_countries ?b,
#  ?f /location/hud_county_place/place ?b & ?a /music/artist/origin ?f => ?a /music/artist/origin ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?f /organization/organization_founder/organizations_founded ?b => ?a /organization/organization_founder/organizations_founded ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?b & ?e /film/film/prequel ?a => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_LTE_0.25 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?b /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?a => ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b,
#  ?a <http://rdf.freebase.com/ns/biology.organism_classification.itis_tsn>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.atomic_number>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?e /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b => ?a /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b & ?b /award/award_winning_work/awards_won./award/award_honor/award_winner ?a => ?a /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?b,
#  ?e /film/film/distributors./film/film_film_distributor_relationship/region ?a & ?e /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.electronegativity>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/food.food.energy>_LTE_0.25 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_LTE_0.25 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b & ?b /people/person/spouse_s./people/marriage/spouse ?a => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?e /people/person/nationality ?b & ?e /people/person/places_lived./people/place_lived/location ?a => ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?a /award/award_ceremony/awards_presented./award/award_honor/award_winner ?f & ?b /film/film/written_by ?f => ?a /award/award_ceremony/awards_presented./award/award_honor/honored_for ?b,
#  ?a /award/award_category/winners./award/award_honor/award_winner ?f & ?b /award/award_winner/awards_won./award/award_honor/award_winner ?f => ?a /award/award_category/winners./award/award_honor/award_winner ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?f /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?a /award/award_ceremony/awards_presented./award/award_honor/honored_for ?f & ?b /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?f => ?a /award/award_ceremony/awards_presented./award/award_honor/award_winner ?b,
#  ?f /location/location/time_zones ?b & ?a /location/us_county/county_seat ?f => ?a /location/location/time_zones ?b,
#  ?f /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?b /film/film/prequel ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?b /base/aareas/schema/administrative_area/capital ?f & ?a /organization/organization/headquarters./location/mailing_address/citytown ?f => ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?b,
#  ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?b & ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a => ?a /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?b,
#  ?b /award/award_category/winners./award/award_honor/award_winner ?e & ?e /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?a => ?a /award/award_winning_work/awards_won./award/award_honor/award ?b,
#  ?f /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization/place_founded ?f => ?a /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?f /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b => ?a /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /music/artist/track_contributions./music/track_contribution/role ?f => ?a /music/artist/contribution./music/recording_contribution/performance_role ?b,
#  ?e /soccer/football_team/current_roster./sports/sports_team_roster/position ?a & ?e /soccer/football_team/current_roster./sports/sports_team_roster/position ?b => ?a /sports/sports_position/players./sports/sports_team_roster/position ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?b /music/instrument/instrumentalists ?f => ?a /music/group_member/membership./music/group_membership/role ?b,
#  ?e /location/administrative_division/country ?b & ?e /location/administrative_division/first_level_division_of ?a => ?a /location/administrative_division/first_level_division_of ?b,
#  ?a /broadcast/content/artist ?f & ?b /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?f => ?a /broadcast/content/artist ?b,
#  ?b /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?f => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?e /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b & ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a => ?a /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b,
#  ?f /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b & ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?b /film/film/story_by ?f & ?a /film/film/written_by ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /location/location/contains ?b & ?e /location/us_county/county_seat ?a => ?a /location/hud_county_place/place ?b,
#  ?f /education/field_of_study/students_majoring./education/education/student ?b & ?a /tv/tv_program/genre ?f => ?a /tv/tv_program/program_creator ?b,
#  ?f /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b & ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?b <http://rdf.freebase.com/ns/base.schemastaging.celestial_object_extra.escape_velocity>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?f => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?a <http://rdf.freebase.com/ns/government.legislative_session.date_began>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25 ?f => ?a /government/legislative_session/members./government/government_position_held/district_represented ?b,
#  ?b <http://rdf.freebase.com/ns/sports.sports_league_draft.year>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.75 ?f => ?a /sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/draft ?b,
#  ?e /location/hud_county_place/place ?a & ?e /location/hud_county_place/place ?b => ?a /location/us_county/county_seat ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.25 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.75 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?b /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?f & ?a /medicine/disease/notable_people_with_this_condition ?f => ?a /medicine/disease/notable_people_with_this_condition ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?e /film/film/featured_film_locations ?b => ?a /film/film/featured_film_locations ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.ionization_energy>_LTE_0.25 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.75 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?e /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_language ?b & ?e /tv/tv_network/programs./tv/tv_network_duration/program ?a => ?a /tv/tv_program/languages ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?e /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?a => ?a /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?b,
#  ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_LTE_0.75 ?f => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b => ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b,
#  ?b /sports/sports_team/roster./basketball/basketball_roster_position/position ?a => ?a /sports/sports_position/players./sports/sports_team_roster/team ?b,
#  ?e /location/country/second_level_divisions ?a & ?e /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b => ?a /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b,
#  ?a /base/aareas/schema/administrative_area/capital ?f & ?f /location/administrative_division/country ?b => ?a /location/administrative_division/country ?b,
#  ?f /award/award_winning_work/awards_won./award/award_honor/award ?a & ?b /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?f => ?a /award/award_category/winners./award/award_honor/award_winner ?b,
#  ?a /base/aareas/schema/administrative_area/administrative_parent ?f & ?f /base/aareas/schema/administrative_area/capital ?b => ?a /location/us_county/county_seat ?b,
#  ?e /location/location/contains ?a & ?e /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.ionization_energy>_LTE_0.75 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.75 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a /base/aareas/schema/administrative_area/administrative_parent ?f & ?f /location/country/form_of_government ?b => ?a /location/country/form_of_government ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b,
#  ?e /base/aareas/schema/administrative_area/capital ?a & ?e /location/location/time_zones ?b => ?a /location/location/time_zones ?b,
#  ?b /award/award_category/nominees./award/award_nomination/nominated_for ?e & ?e /film/film/story_by ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/award ?b,
#  ?a /business/job_title/people_with_this_title./business/employment_tenure/company ?e & ?e /location/location/contains ?b => ?a /business/job_title/people_with_this_title./business/employment_tenure/company ?b,
#  ?e /location/country/capital ?b & ?a /people/marriage_union_type/unions_of_this_type./people/marriage/location_of_ceremony ?e => ?a /people/marriage_union_type/unions_of_this_type./people/marriage/location_of_ceremony ?b,
#  ?e /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b & ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a => ?a /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b,
#  ?e /education/educational_institution/campuses ?a & ?e /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?a & ?e /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b => ?a /base/biblioness/bibs_location/country ?b,
#  ?e /location/administrative_division/first_level_division_of ?b & ?e /location/country/official_language ?a => ?a /language/human_language/countries_spoken_in ?b,
#  ?a /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?f & ?f /sports/sports_position/players./sports/sports_team_roster/position ?b => ?a /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?b,
#  ?a /location/hud_county_place/place ?f & ?b /location/us_county/county_seat ?f => ?a /location/us_county/county_seat ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.atomic_number>_LTE_0.75 ?f & ?a <http://rdf.freebase.com/ns/food.food.energy>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a => ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b,
#  ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_LTE_0.75 ?f => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?a /organization/organization_founder/organizations_founded ?b => ?a /organization/organization_member/member_of./organization/organization_membership/organization ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries>_LTE_0.75 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?a /base/aareas/schema/administrative_area/administrative_parent ?f & ?f /dataworld/gardening_hint/split_to ?b => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?e /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b & ?e /location/hud_county_place/place ?a => ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b,
#  ?b /film/film/prequel ?f & ?f /film/film/written_by ?a => ?a /film/director/film ?b,
#  ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?f & ?f /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?b /soccer/football_team/current_roster./soccer/football_roster_position/position ?a => ?a /sports/sports_position/players./sports/sports_team_roster/team ?b,
#  ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.25 ?f & ?a <http://rdf.freebase.com/ns/time.month.number_of_days_in_month>_LTE_0.5 ?f => ?a /base/localfood/seasonal_month/produce_available./base/localfood/produce_availability/seasonal_months ?b,
#  ?a /film/film/written_by ?f & ?f /people/person/languages ?b => ?a /film/film/language ?b,
#  ?f /base/popstra/celebrity/dated./base/popstra/dated/participant ?b & ?a /medicine/disease/notable_people_with_this_condition ?f => ?a /medicine/disease/notable_people_with_this_condition ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b & ?a /people/person/spouse_s./people/marriage/spouse ?f => ?a /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?b,
#  ?e /base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club ?b & ?a /soccer/football_player/current_team./sports/sports_team_roster/team ?e => ?a /sports/pro_athlete/teams./sports/sports_team_roster/team ?b,
#  ?e /government/politician/government_positions_held./government/government_position_held/legislative_sessions ?a & ?e /people/person/places_lived./people/place_lived/location ?b => ?a /government/legislative_session/members./government/government_position_held/district_represented ?b,
#  ?b /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a & ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/produced_by ?b => ?a /film/film/executive_produced_by ?b,
#  ?b <http://rdf.freebase.com/ns/location.location.area>_LTE_0.75 ?f & ?a <http://rdf.freebase.com/ns/sports.sports_league_draft.year>_LTE_0.75 ?f => ?a /sports/sports_league_draft/picks./sports/sports_league_draft_pick/school ?b,
#  ?f /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b & ?a /education/educational_institution_campus/educational_institution ?f => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?b /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?a & ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?f & ?b /film/film/written_by ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /film/film_subject/films ?a & ?b /user/jg/default_domain/olympic_games/sports ?e => ?a /olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?f /base/aareas/schema/administrative_area/administrative_parent ?a & ?b /location/location/contains ?f => ?a /location/administrative_division/first_level_division_of ?b,
#  ?e /education/educational_institution/campuses ?a & ?e /education/educational_institution/students_graduates./education/education/major_field_of_study ?b => ?a /education/educational_institution/students_graduates./education/education/major_field_of_study ?b,
#  ?b <http://rdf.freebase.com/ns/base.schemastaging.celestial_object_extra.escape_velocity>_LTE_0.25 ?f & ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.75 ?f => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?f /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization/child./organization/organization_relationship/child ?f => ?a /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b,
#  ?f /base/biblioness/bibs_location/country ?a & ?b /location/hud_county_place/county ?f => ?a /location/country/second_level_divisions ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.75 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?e /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?e /organization/organization_member/member_of./organization/organization_membership/organization ?a => ?a /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b,
# ...
#  ?a /base/aareas/schema/administrative_area/capital ?f & ?f /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b,
#  ?e /award/award_category/category_of ?a & ?e /award/award_category/category_of ?b => ?a /award/award_category/category_of ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?b /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?a => ?a /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /time/event/locations ?f => ?a /time/event/locations ?b,
#  ?e /location/location/contains ?a & ?e /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b,
#  ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_LTE_0.25 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?b /film/film/prequel ?f => ?a /film/actor/film./film/performance/film ?b,
#  ?a <http://rdf.freebase.com/ns/biology.organism_classification.itis_tsn>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.melting_point>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.atomic_number>_LTE_0.75 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.25 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a <http://rdf.freebase.com/ns/base.usnris.nris_listing.significant_year>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/base.usnris.nris_listing.significant_year>_LTE_0.5 ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /film/actor/film./film/performance/film ?a & ?e /people/person/nationality ?b => ?a /film/film/runtime./film/film_cut/film_release_region ?b,
#  ?f /film/film_subject/films ?b & ?a /film/film_subject/films ?f => ?a /film/film_subject/films ?b,
#  ?e /film/film/story_by ?a & ?e /film/film/story_by ?b => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b,
#  ?f /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?b /tv/tv_program/program_creator ?f => ?a /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award ?b & ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?f => ?a /award/award_winning_work/awards_won./award/award_honor/award ?b,
#  ?a /people/person/spouse_s./people/marriage/spouse ?b => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?f & ?f /people/person/spouse_s./people/marriage/type_of_union ?b => ?a /people/person/spouse_s./people/marriage/type_of_union ?b,
#  ?a <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/time.month.number_of_days_in_month>_LTE_0.5 ?f => ?a /base/localfood/seasonal_month/produce_available./base/localfood/produce_availability/seasonal_months ?b,
#  ?e /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?a & ?e /people/person/languages ?b => ?a /film/actor/dubbing_performances./film/dubbing_performance/language ?b,
#  ?a /education/educational_institution_campus/educational_institution ?f & ?b /location/location/contains ?f => ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?e /film/film/release_date_s./film/film_regional_release_date/film_release_region ?b => ?a /film/film/release_date_s./film/film_regional_release_date/film_release_region ?b,
#  ?e /location/country/capital ?a & ?e /travel/travel_destination/how_to_get_here./travel/transportation/mode_of_transportation ?b => ?a /travel/travel_destination/how_to_get_here./travel/transportation/mode_of_transportation ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?a /education/educational_institution/campuses ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b & ?e /people/person/places_lived./people/place_lived/location ?a => ?a /base/biblioness/bibs_location/state ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?f /organization/organization_member/member_of./organization/organization_membership/organization ?b => ?a /organization/organization_member/member_of./organization/organization_membership/organization ?b,
#  ?f /base/biblioness/bibs_location/state ?b & ?a /people/person/spouse_s./people/marriage/location_of_ceremony ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?e /organization/organization/headquarters./location/mailing_address/country ?b & ?e /organization/organization/headquarters./location/mailing_address/state_province_region ?a => ?a /location/administrative_division/country ?b,
#  ?a /music/instrument/family ?f & ?f /music/performance_role/regular_performances./music/group_membership/role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?b <http://rdf.freebase.com/ns/law.invention.date_of_invention>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/tv.tv_program.episode_running_time>_LTE_0.5 ?f => ?a /film/film/release_date_s./film/film_regional_release_date/film_release_distribution_medium ?b,
#  ?f /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization_member/member_of./organization/organization_membership/organization ?f => ?a /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b,
#  ?f /sports/sports_position/players./sports/sports_team_roster/position ?a & ?b /sports/sports_team/roster./basketball/basketball_roster_position/position ?f => ?a /sports/sports_position/players./sports/sports_team_roster/team ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?b /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?f => ?a /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/edited_by ?b => ?a /film/film/other_crew./film/film_crew_gig/crewmember ?b,
#  ?a /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?b => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.ionization_energy>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?b <http://rdf.freebase.com/ns/sports.sports_league_draft.year>_LTE_0.25 ?f & ?a <http://rdf.freebase.com/ns/sports.sports_team.founded>_LTE_0.75 ?f => ?a /sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/draft ?b,
#  ?a /music/instrument/family ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?b /user/ktrueman/default_domain/international_organization/member_states ?a => ?a /organization/organization_member/member_of./organization/organization_membership/organization ?b,
#  ?a /base/americancomedy/celebrity_impressionist/celebrities_impersonated ?f & ?f /people/person/sibling_s./people/sibling_relationship/sibling ?b => ?a /base/americancomedy/celebrity_impressionist/celebrities_impersonated ?b,
#  ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b & ?b /location/location/contains ?a => ?a /base/biblioness/bibs_location/state ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?f /business/business_operation/industry ?b => ?a /business/business_operation/industry ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b => ?a /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b & ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a => ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b,
#  ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events>_LTE_0.5 ?f => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_compound.average_molar_mass>_LTE_0.75 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.75 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?f /base/aareas/schema/administrative_area/administrative_parent ?b & ?a /location/country/second_level_divisions ?f => ?a /location/country/second_level_divisions ?b,
#  ?f /base/aareas/schema/administrative_area/administrative_parent ?b & ?a /base/biblioness/bibs_location/state ?f => ?a /base/biblioness/bibs_location/country ?b,
#  ?a /music/performance_role/track_performances./music/track_contribution/role ?b => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?e /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b & ?e /people/person/spouse_s./people/marriage/location_of_ceremony ?a => ?a /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.electronegativity>_LTE_0.75 ?f & ?a <http://rdf.freebase.com/ns/food.food.energy>_LTE_0.25 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?e /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b & ?e /education/educational_institution/campuses ?a => ?a /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b,
#  ?a /film/film/country ?f & ?f /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?e /education/educational_institution/colors ?b & ?e /education/educational_institution_campus/educational_institution ?a => ?a /education/educational_institution/colors ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?e /award/ranked_item/appears_in_ranked_lists./award/ranking/list ?b => ?a /award/ranked_item/appears_in_ranked_lists./award/ranking/list ?b,
#  ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f & ?f /music/group_member/membership./music/group_membership/role ?b => ?a /music/group_member/membership./music/group_membership/role ?b,
#  ?b /award/award_winning_work/awards_won./award/award_honor/honored_for ?f & ?f /film/film/prequel ?a => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?b /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?f & ?a /medicine/disease/notable_people_with_this_condition ?f => ?a /medicine/disease/notable_people_with_this_condition ?b,
#  ?a /people/person/place_of_birth ?b => ?a /people/person/places_lived./people/place_lived/location ?b,
#  ?e /base/biblioness/bibs_location/state ?a & ?e /location/hud_county_place/county ?b => ?a /location/location/contains ?b,
#  ?b /location/location/contains ?f & ?a /people/person/place_of_birth ?f => ?a /people/person/nationality ?b,
#  ?e /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b & ?e /organization/organization/headquarters./location/mailing_address/citytown ?a => ?a /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b,
#  ?a /education/educational_institution/campuses ?f & ?f /education/educational_institution/students_graduates./education/education/student ?b => ?a /education/educational_institution/students_graduates./education/education/student ?b,
#  ?f /base/aareas/schema/administrative_area/capital ?b & ?a /people/person/places_lived./people/place_lived/location ?f => ?a /people/person/place_of_birth ?b,
#  ?a /people/person/spouse_s./people/marriage/spouse ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?a /people/person/places_lived./people/place_lived/location ?b => ?a /music/artist/origin ?b,
#  ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f & ?f /music/artist/track_contributions./music/track_contribution/role ?b => ?a /music/artist/track_contributions./music/track_contribution/role ?b,
#  ?b /base/biblioness/bibs_location/state ?f & ?f /location/administrative_division/first_level_division_of ?a => ?a /location/country/second_level_divisions ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.electronegativity>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.25 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?b /award/award_category/nominees./award/award_nomination/nominated_for ?e & ?e /film/film/written_by ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/award ?b,
#  ?f /education/educational_institution/colors ?b & ?a /sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/school ?f => ?a /sports/sports_team/colors ?b,
#  ?e /base/biblioness/bibs_location/state ?b & ?a /location/location/contains ?e => ?a /location/location/contains ?b,
#  ?f /location/country/form_of_government ?b & ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /location/country/form_of_government ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?a /music/genre/artists ?e => ?a /music/genre/artists ?b,
#  ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a & ?e /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b => ?a /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?a /location/hud_county_place/county ?f & ?f /location/hud_county_place/place ?b => ?a /location/hud_county_place/place ?b,
#  ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b => ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b,
#  ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5 ?f => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?b /base/aareas/schema/administrative_area/capital ?a & ?b /location/location/contains ?a => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?b /music/performance_role/regular_performances./music/group_membership/role ?a => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?b /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?f & ?f /location/location/contains ?a => ?a /organization/organization/headquarters./location/mailing_address/citytown ?b,
#  ...}
