# %%
import pandas as pd 
import numpy as np
import os
from subprocess import check_output
import shutil

from rule import *
from amie import *

# %%
root_source = "./../../FB15k-237-num/"
store_data = "./../../Data_FB/FB15K_ST.tsv"

# %%
f = open(root_source+"FB15K_NumericalTriples.txt", "r")
dic_predicate = {}
for line in f:
    line_split = line.split("\n")[0].split("\t")
    line_split[2] = float(line_split[2]) 
    line_split = tuple(line_split)
    if line_split[1] in dic_predicate.keys():
        dic_predicate[line_split[1]].add(line_split)
    else : 
        dic_predicate[line_split[1]] = {line_split}
f.close()

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
def give_group(value, groups):
    for i, value_group in enumerate(groups):
        if value < value_group:
            return i
    return i+1

def write_file(X, f, groups):
    f.write(f"{X['Subject']}\t{X['Predicate']}\t{give_group(X['Object'], groups)}\n")

# %%
f = open(store_data, "w")

for key in dic_predicate.keys():
    tp_df = pd.DataFrame.from_dict(dic_predicate[key]).rename(columns={0: "Subject", 1: "Predicate", 2: "Object"})
    tp_df_describe = tp_df["Object"].quantile(thresholds)
    tp_df.apply(write_file, args=(f, tp_df_describe), axis=1)

f.close()

# %%
data = open(root_source+"train.txt", "r")
f = open(store_data, "a")

predicate_to_find = set()

for line in data: 
    f.write(line)
    predicate_to_find.add(line.split("\n")[0].split("\t")[1])
    
data.close()
f.close()

# %%
htr = ""
for p in predicate_to_find:
    htr+=p+","
htr = htr[:-1]
print(htr)
# Out:
# /medicine/symptom/symptom_of,/people/deceased_person/place_of_death,/location/country/form_of_government,/tv/tv_producer/programs_produced./tv/tv_producer_term/program,/base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club,/film/film_subject/films,/organization/organization_founder/organizations_founded,/music/record_label/artist,/film/film/film_production_design_by,/soccer/football_team/current_roster./sports/sports_team_roster/position,/location/statistical_region/places_exported_to./location/imports_and_exports/exported_to,/location/location/time_zones,/education/university/international_tuition./measurement_unit/dated_money_value/currency,/film/film/estimated_budget./measurement_unit/dated_money_value/currency,/organization/organization/child./organization/organization_relationship/child,/award/award_nominee/award_nominations./award/award_nomination/nominated_for,/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/contact_category,/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location,/people/profession/specialization_of,/medicine/disease/notable_people_with_this_condition,/people/person/profession,/location/hud_county_place/place,/music/genre/parent_genre,/award/award_ceremony/awards_presented./award/award_honor/award_winner,/award/award_winning_work/awards_won./award/award_honor/award,/base/petbreeds/city_with_dogs/top_breeds./base/petbreeds/dog_city_relationship/dog_breed,/government/politician/government_positions_held./government/government_position_held/basic_title,/dataworld/gardening_hint/split_to,/sports/sports_league/teams./sports/sports_league_participation/team,/base/marchmadness/ncaa_basketball_tournament/seeds./base/marchmadness/ncaa_tournament_seed/team,/people/person/spouse_s./people/marriage/location_of_ceremony,/sports/sports_team/sport,/education/educational_institution/students_graduates./education/education/major_field_of_study,/common/topic/webpage./common/webpage/category,/film/film/music,/award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee,/base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer,/education/university/fraternities_and_sororities,/music/performance_role/regular_performances./music/group_membership/role,/sports/sports_team/colors,/film/film/cinematography,/music/artist/track_contributions./music/track_contribution/role,/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country,/people/person/employment_history./business/employment_tenure/company,/film/film/production_companies,/tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program,/tv/tv_program/genre,/location/us_county/county_seat,/film/film/distributors./film/film_film_distributor_relationship/region,/organization/role/leaders./organization/leadership/organization,/people/ethnicity/languages_spoken,/medicine/disease/risk_factors,/people/marriage_union_type/unions_of_this_type./people/marriage/location_of_ceremony,/business/business_operation/operating_income./measurement_unit/dated_money_value/currency,/american_football/football_team/current_roster./sports/sports_team_roster/position,/sports/sports_position/players./american_football/football_historical_roster_position/position_s,/award/award_winner/awards_won./award/award_honor/award_winner,/film/film/distributors./film/film_film_distributor_relationship/film_distribution_medium,/award/award_category/winners./award/award_honor/ceremony,/film/film/country,/base/aareas/schema/administrative_area/administrative_area_type,/base/biblioness/bibs_location/state,/business/business_operation/assets./measurement_unit/dated_money_value/currency,/education/educational_institution/students_graduates./education/education/student,/influence/influence_node/influenced_by,/music/performance_role/regular_performances./music/group_membership/grou ...

# %%
res = check_output(f'java -jar ./../amie3.jar -htr {htr} {store_data}', shell=True)

res_parsed = parse_amie(res)

# %%
len(res_parsed)
# Out:
# 8010

# %%
res_parsed
# Out:
# {?e /dataworld/gardening_hint/split_to ?b & ?e /music/performance_role/guest_performances./music/recording_contribution/performance_role ?a => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?a /education/educational_institution_campus/educational_institution ?e & ?e /organization/organization_founder/organizations_founded ?b => ?a /organization/organization_founder/organizations_founded ?b,
#  ?b /location/hud_county_place/county ?f & ?a /people/person/place_of_birth ?f => ?a /people/person/place_of_birth ?b,
#  ?f /people/person/languages ?b & ?a /people/person/spouse_s./people/marriage/spouse ?f => ?a /people/person/languages ?b,
#  ?b /tv/tv_program/program_creator ?a & ?b /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?a => ?a /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?b,
#  ?a /location/country/second_level_divisions ?f & ?f /location/location/contains ?b => ?a /location/country/second_level_divisions ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b => ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b,
#  ?e /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b & ?a /people/ethnicity/geographic_distribution ?e => ?a /people/ethnicity/geographic_distribution ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?b /tv/tv_program/program_creator ?f => ?a /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?b,
#  ?e /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b & ?e /film/film/featured_film_locations ?a => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?e /people/ethnicity/languages_spoken ?b & ?e /people/ethnicity/people ?a => ?a /film/actor/dubbing_performances./film/dubbing_performance/language ?b,
#  ?a /base/biblioness/bibs_location/country ?f & ?b /dataworld/gardening_hint/split_to ?f => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?a /film/actor/film./film/performance/film ?b & ?b /film/film/produced_by ?a => ?a /film/director/film ?b,
#  ?a /film/film/executive_produced_by ?b => ?a /film/film/story_by ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?a /film/film/produced_by ?b => ?a /film/film/edited_by ?b,
#  ?e /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b & ?e /people/deceased_person/place_of_death ?a => ?a /base/biblioness/bibs_location/country ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?f /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b => ?a /location/administrative_division/first_level_division_of ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?a & ?e /base/aareas/schema/administrative_area/administrative_parent ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b & ?e /music/artist/track_contributions./music/track_contribution/role ?a => ?a /music/instrument/instrumentalists ?b,
#  ?f /common/topic/webpage./common/webpage/category ?b & ?a /music/artist/origin ?f => ?a /common/topic/webpage./common/webpage/category ?b,
#  ?b /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?a & ?a /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?b => ?a /sports/sports_position/players./sports/sports_team_roster/position ?b,
#  ?a /military/military_conflict/combatants./military/military_combatant_group/combatants ?f & ?f /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b => ?a /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b,
#  ?f /influence/influence_node/influenced_by ?a & ?b /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?f => ?a /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?b,
#  ?e /music/artist/origin ?a & ?e /people/person/nationality ?b => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?f /people/person/religion ?b => ?a /people/person/religion ?b,
#  ?e /music/artist/origin ?b & ?e /people/person/nationality ?a => ?a /location/location/contains ?b,
#  ?b /music/performance_role/guest_performances./music/recording_contribution/performance_role ?a & ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?e /music/group_member/membership./music/group_membership/group ?b & ?e /people/person/sibling_s./people/sibling_relationship/sibling ?a => ?a /music/group_member/membership./music/group_membership/group ?b,
#  ?b /base/popstra/celebrity/dated./base/popstra/dated/participant ?a & ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a => ?a /people/person/spouse_s./people/marriage/spouse ?b,
#  ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?f & ?b /people/marriage_union_type/unions_of_this_type./people/marriage/location_of_ceremony ?f => ?a /people/person/spouse_s./people/marriage/type_of_union ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?a /organization/role/leaders./organization/leadership/organization ?f => ?a /organization/role/leaders./organization/leadership/organization ?b,
#  ?a /education/educational_institution/campuses ?f & ?f /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b => ?a /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?f /location/administrative_division/country ?b & ?a /people/person/places_lived./people/place_lived/location ?f => ?a /people/person/employment_history./business/employment_tenure/company ?b,
#  ?e /film/film/produced_by ?a & ?e /film/film/production_companies ?b => ?a /people/person/employment_history./business/employment_tenure/company ?b,
#  ?a /film/film/featured_film_locations ?f & ?f /location/administrative_division/country ?b => ?a /film/film/runtime./film/film_cut/film_release_region ?b,
#  ?a /film/film/written_by ?b => ?a /film/film/edited_by ?b,
#  ?e /base/biblioness/bibs_location/state ?b & ?e /location/location/contains ?a => ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?b,
#  ?a /people/deceased_person/place_of_death ?f & ?b /people/marriage_union_type/unions_of_this_type./people/marriage/location_of_ceremony ?f => ?a /people/person/spouse_s./people/marriage/type_of_union ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?a /music/instrument/instrumentalists ?e => ?a /music/instrument/instrumentalists ?b,
#  ?b /education/educational_institution_campus/educational_institution ?f & ?f /organization/organization/headquarters./location/mailing_address/state_province_region ?a => ?a /location/location/contains ?b,
#  ?f /base/biblioness/bibs_location/state ?b & ?a /organization/organization/place_founded ?f => ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?b,
#  ?e /organization/organization/headquarters./location/mailing_address/country ?b & ?e /organization/organization/headquarters./location/mailing_address/state_province_region ?a => ?a /location/administrative_division/country ?b,
#  ?e /base/popstra/celebrity/dated./base/popstra/dated/participant ?a & ?e /film/actor/film./film/performance/special_performance_type ?b => ?a /film/actor/film./film/performance/special_performance_type ?b,
#  ?f /dataworld/gardening_hint/split_to ?a & ?b /education/educational_institution/campuses ?f => ?a /education/educational_institution_campus/educational_institution ?b,
#  ?e /people/person/spouse_s./people/marriage/location_of_ceremony ?b & ?e /people/person/spouse_s./people/marriage/spouse ?a => ?a /people/person/spouse_s./people/marriage/location_of_ceremony ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b & ?b /film/film/edited_by ?a => ?a /film/director/film ?b,
#  ?e /organization/organization_founder/organizations_founded ?b & ?e /people/person/spouse_s./people/marriage/spouse ?a => ?a /organization/organization_founder/organizations_founded ?b,
#  ?b /location/hud_county_place/place ?f & ?a /people/person/places_lived./people/place_lived/location ?f => ?a /people/person/place_of_birth ?b,
#  ?f /base/biblioness/bibs_location/state ?b & ?a /people/person/place_of_birth ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?e /dataworld/gardening_hint/split_to ?b & ?e /music/performance_role/regular_performances./music/group_membership/role ?a => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/film_art_direction_by ?b => ?a /film/film/film_production_design_by ?b,
#  ?f /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization/place_founded ?f => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?b /base/aareas/schema/administrative_area/administrative_parent ?f & ?a /location/location/contains ?f => ?a /location/location/contains ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/award_winner ?a & ?e /film/film/language ?b => ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_language ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/other_crew./film/film_crew_gig/crewmember ?b => ?a /film/film/other_crew./film/film_crew_gig/crewmember ?b,
#  ?f /film/film/country ?b & ?a /film/film_distributor/films_distributed./film/film_film_distributor_relationship/film ?f => ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?a /music/instrument/instrumentalists ?e => ?a /music/performance_role/regular_performances./music/group_membership/group ?b,
#  ?f /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b & ?a /people/person/nationality ?f => ?a /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?f => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?e /base/popstra/celebrity/dated./base/popstra/dated/participant ?a & ?e /film/actor/dubbing_performances./film/dubbing_performance/language ?b => ?a /people/person/languages ?b,
#  ?e /location/administrative_division/country ?a & ?e /location/administrative_division/first_level_division_of ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?b /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?a => ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?b /organization/organization_founder/organizations_founded ?f => ?a /film/film/executive_produced_by ?b,
#  ?e /music/performance_role/guest_performances./music/recording_contribution/performance_role ?a & ?e /music/performance_role/track_performances./music/track_contribution/role ?b => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?a /music/instrument/family ?f & ?f /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?e /base/eating/practicer_of_diet/diet ?b & ?e /influence/influence_node/influenced_by ?a => ?a /base/eating/practicer_of_diet/diet ?b,
#  ?a /base/biblioness/bibs_location/country ?f & ?f /dataworld/gardening_hint/split_to ?b => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?e /dataworld/gardening_hint/split_to ?b & ?e /location/location/contains ?a => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?b /music/performance_role/guest_performances./music/recording_contribution/performance_role ?a & ?a /music/performance_role/track_performances./music/track_contribution/role ?b => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?f /award/award_winner/awards_won./award/award_honor/award_winner ?a => ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b,
#  ?e /award/award_category/winners./award/award_honor/award_winner ?a & ?e /award/award_category/winners./award/award_honor/award_winner ?b => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?f /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?a /base/americancomedy/celebrity_impressionist/celebrities_impersonated ?f => ?a /base/americancomedy/celebrity_impressionist/celebrities_impersonated ?b,
#  ?a /film/film/prequel ?f & ?f /film/film/written_by ?b => ?a /film/film/written_by ?b,
#  ?a /government/political_party/politicians_in_this_party./government/political_party_tenure/politician ?e & ?e /people/person/spouse_s./people/marriage/spouse ?b => ?a /government/political_party/politicians_in_this_party./government/political_party_tenure/politician ?b,
#  ?b /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?a & ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?e /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a & ?e /film/film/film_production_design_by ?b => ?a /film/film/film_art_direction_by ?b,
#  ?a /film/film/edited_by ?f & ?f /people/person/sibling_s./people/sibling_relationship/sibling ?b => ?a /film/film/written_by ?b,
#  ?b /sports/sports_position/players./sports/sports_team_roster/team ?a & ?a /sports/sports_team/roster./american_football/football_roster_position/position ?b => ?a /american_football/football_team/current_roster./sports/sports_team_roster/position ?b,
#  ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f & ?f /film/actor/dubbing_performances./film/dubbing_performance/language ?b => ?a /film/actor/dubbing_performances./film/dubbing_performance/language ?b,
#  ?b /location/location/contains ?f & ?a /location/location/partially_contains ?f => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?f /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization/headquarters./location/mailing_address/citytown ?f => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /film/film/runtime./film/film_cut/film_release_region ?b & ?e /tv/tv_program/country_of_origin ?a => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /award/award_category/category_of ?a & ?e /award/award_category/disciplines_or_subjects ?b => ?a /award/award_category/disciplines_or_subjects ?b,
#  ?f /music/artist/origin ?b & ?a /people/ethnicity/people ?f => ?a /people/ethnicity/geographic_distribution ?b,
#  ?f /film/film/film_production_design_by ?b & ?a /film/film/prequel ?f => ?a /film/film/film_production_design_by ?b,
#  ?a /music/instrument/family ?f & ?f /music/performance_role/regular_performances./music/group_membership/role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?f /location/location/contains ?a & ?b /location/location/contains ?f => ?a /base/biblioness/bibs_location/state ?b,
#  ?b /location/country/second_level_divisions ?f & ?a /people/person/place_of_birth ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?f /base/biblioness/bibs_location/country ?b & ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /location/administrative_division/country ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?a /tv/tv_program/program_creator ?f => ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b,
#  ?e /base/biblioness/bibs_location/state ?b & ?e /location/location/contains ?a => ?a /base/biblioness/bibs_location/state ?b,
#  ?e /common/topic/webpage./common/webpage/category ?b & ?e /education/educational_institution_campus/educational_institution ?a => ?a /common/topic/webpage./common/webpage/category ?b,
#  ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b & ?a /people/person/spouse_s./people/marriage/spouse ?b => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?f /film/film/language ?b & ?a /film/film/prequel ?f => ?a /film/film/language ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?b & ?e /location/country/second_level_divisions ?a => ?a /location/administrative_division/country ?b,
#  ?a /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?a /location/location/contains ?f & ?f /organization/organization/headquarters./location/mailing_address/state_province_region ?b => ?a /location/country/second_level_divisions ?b,
#  ?a <http://rdf.freebase.com/ns/government.legislative_session.date_ended> ?f & ?b <http://rdf.freebase.com/ns/location.geocode.longitude> ?f => ?a /government/legislative_session/members./government/government_position_held/district_represented ?b,
#  ?a /location/administrative_division/first_level_division_of ?f & ?f /location/country/official_language ?b => ?a /location/country/official_language ?b,
#  ?e /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b & ?e /location/us_county/county_seat ?a => ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b,
#  ?e /influence/influence_node/influenced_by ?a & ?e /people/person/languages ?b => ?a /people/person/languages ?b,
#  ?a /people/cause_of_death/people ?f & ?f /people/person/gender ?b => ?a /medicine/disease/risk_factors ?b,
#  ?e /base/biblioness/bibs_location/country ?a & ?e /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b,
#  ?b /base/biblioness/bibs_location/state ?a & ?a /location/location/contains ?b => ?a /base/aareas/schema/administrative_area/capital ?b,
#  ?e /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b & ?e /people/person/nationality ?a => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?e /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?a => ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b,
#  ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b => ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b,
#  ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?f & ?b /location/location/contains ?f => ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/film_format ?b => ?a /film/film/film_format ?b,
#  ?b /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?f & ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?f => ?a /organization/organization/headquarters./location/mailing_address/citytown ?b,
#  ?e /film/film/executive_produced_by ?a & ?e /film/film/written_by ?b => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b,
#  ?f /base/biblioness/bibs_location/country ?b & ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?f => ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?b,
#  ?b /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?a /location/location/contains ?f => ?a /location/location/contains ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b & ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?f => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?e /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b & ?e /people/person/place_of_birth ?a => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?a /award/award_ceremony/awards_presented./award/award_honor/award_winner ?f & ?b /tv/tv_program/program_creator ?f => ?a /award/award_ceremony/awards_presented./award/award_honor/honored_for ?b,
#  ?a /film/film/featured_film_locations ?f & ?f /location/country/official_language ?b => ?a /film/film/language ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?b /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?a => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?f /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization/place_founded ?f => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?a /film/film/produced_by ?b => ?a /film/film/story_by ?b,
#  ?f /government/politician/government_positions_held./government/government_position_held/basic_title ?b & ?a /influence/influence_node/peers./influence/peer_relationship/peers ?f => ?a /government/politician/government_positions_held./government/government_position_held/basic_title ?b,
#  ?a /base/aareas/schema/administrative_area/administrative_parent ?b & ?b /location/location/contains ?a => ?a /base/biblioness/bibs_location/country ?b,
#  ?f /base/popstra/celebrity/dated./base/popstra/dated/participant ?b & ?a /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer ?f => ?a /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer ?b,
#  ?a /base/aareas/schema/administrative_area/capital ?f & ?f /location/hud_county_place/place ?b => ?a /base/aareas/schema/administrative_area/capital ?b,
#  ?f /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b & ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /location/location/contains ?a & ?e /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b & ?e /people/person/spouse_s./people/marriage/location_of_ceremony ?a => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b & ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?a /film/film/distributors./film/film_film_distributor_relationship/region ?f & ?f /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?b => ?a /film/film/release_date_s./film/film_regional_release_date/film_release_region ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award ?a & ?e /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b => ?a /award/award_category/nominees./award/award_nomination/nominated_for ?b,
#  ?e /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?a & ?e /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medal ?b => ?a /olympics/olympic_games/medals_awarded./olympics/olympic_medal_honor/medal ?b,
#  ?e /organization/organization/headquarters./location/mailing_address/citytown ?b & ?e /organization/organization/headquarters./location/mailing_address/state_province_region ?a => ?a /location/location/contains ?b,
#  ?b /organization/organization/child./organization/organization_relationship/child ?f & ?a /organization/role/leaders./organization/leadership/organization ?f => ?a /business/job_title/people_with_this_title./business/employment_tenure/company ?b,
#  ?a /location/country/capital ?f & ?b /location/location/contains ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?f & ?f /people/person/nationality ?b => ?a /film/film/country ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /people/person/nationality ?f => ?a /people/person/nationality ?b,
#  ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f & ?b /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?f => ?a /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /education/educational_institution/students_graduates./education/education/major_field_of_study ?b => ?a /education/educational_institution/students_graduates./education/education/major_field_of_study ?b,
#  ?a /film/film/story_by ?f & ?f /people/person/nationality ?b => ?a /film/film/distributors./film/film_film_distributor_relationship/region ?b,
#  ?b /location/hud_county_place/place ?f & ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?f => ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?b,
#  ?a /base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club ?f & ?b /sports/sports_position/players./sports/sports_team_roster/team ?f => ?a /soccer/football_team/current_roster./sports/sports_team_roster/position ?b,
#  ?b /award/award_winning_work/awards_won./award/award_honor/award_winner ?a & ?b /film/film/written_by ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?f /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b & ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?f & ?f /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?b => ?a /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?b,
#  ?e /education/educational_institution_campus/educational_institution ?a & ?e /education/educational_institution_campus/educational_institution ?b => ?a /education/educational_institution_campus/educational_institution ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b & ?b /film/director/film ?a => ?a /film/film/written_by ?b,
#  ?f /tv/tv_program/languages ?b & ?a /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?f => ?a /people/person/languages ?b,
#  ?e /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b & ?e /organization/organization/child./organization/organization_relationship/child ?a => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?e /education/educational_institution_campus/educational_institution ?a & ?e /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b => ?a /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /influence/influence_node/influenced_by ?b & ?a /people/ethnicity/people ?e => ?a /people/ethnicity/people ?b,
#  ?a /people/person/spouse_s./people/marriage/spouse ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?b /influence/influence_node/peers./influence/peer_relationship/peers ?a => ?a /influence/influence_node/peers./influence/peer_relationship/peers ?b,
#  ?b /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a => ?a /film/film/prequel ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b,
#  ?b /film/film/other_crew./film/film_crew_gig/crewmember ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?e & ?e /film/film/prequel ?b => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a /film/film/distributors./film/film_film_distributor_relationship/region ?f & ?b /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f => ?a /film/film/release_date_s./film/film_regional_release_date/film_release_region ?b,
#  ?e /people/person/religion ?b & ?e /people/person/spouse_s./people/marriage/spouse ?a => ?a /people/person/religion ?b,
#  ?e /film/film/edited_by ?b & ?e /film/film/written_by ?a => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b,
#  ?e /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b & ?e /music/performance_role/track_performances./music/track_contribution/role ?a => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?a /film/film/country ?f & ?f /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?f /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b & ?a /education/educational_institution_campus/educational_institution ?f => ?a /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b,
#  ?f /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b & ?a /education/educational_institution/campuses ?f => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?e /dataworld/gardening_hint/split_to ?b & ?a /music/performance_role/regular_performances./music/group_membership/role ?e => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?f /location/administrative_division/country ?b & ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /location/administrative_division/country ?b,
#  ?b /language/human_language/countries_spoken_in ?a => ?a /location/country/official_language ?b,
#  ?a /music/group_member/membership./music/group_membership/role ?b => ?a /music/artist/track_contributions./music/track_contribution/role ?b,
#  ?e /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?e /organization/organization/child./organization/organization_relationship/child ?a => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?e /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?a & ?e /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b => ?a /base/biblioness/bibs_location/country ?b,
#  ?b /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?a & ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b => ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b,
#  ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?f & ?f /film/person_or_entity_appearing_in_film/films./film/personal_film_appearance/type_of_appearance ?b => ?a /film/person_or_entity_appearing_in_film/films./film/personal_film_appearance/type_of_appearance ?b,
#  ?e /film/director/film ?a & ?e /people/person/nationality ?b => ?a /film/film/distributors./film/film_film_distributor_relationship/region ?b,
#  ?a /base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club ?f & ?b /sports/sports_position/players./sports/sports_team_roster/team ?f => ?a /soccer/football_team/current_roster./soccer/football_roster_position/position ?b,
#  ?b /sports/sports_team/roster./american_football/football_roster_position/position ?a => ?a /sports/sports_position/players./sports/sports_team_roster/team ?b,
#  ?e /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?a & ?e /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?b => ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b,
#  ?b /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?a => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?e /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a & ?e /film/film/executive_produced_by ?b => ?a /film/film/produced_by ?b,
#  ?a /people/ethnicity/people ?f & ?f /people/person/nationality ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?b /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?a => ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b,
#  ?e /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?e /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?b => ?a /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?b,
#  ?a /film/film/runtime./film/film_cut/film_release_region ?f & ?f /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?f /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b & ?a /location/location/contains ?f => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?f /people/person/places_lived./people/place_lived/location ?b & ?a /people/person/sibling_s./people/sibling_relationship/sibling ?f => ?a /music/artist/origin ?b,
#  ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?f & ?b /music/performance_role/guest_performances./music/recording_contribution/performance_role ?f => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?e /film/film/cinematography ?b => ?a /film/film/cinematography ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?e /people/person/nationality ?b => ?a /people/person/nationality ?b,
#  ?b /music/performance_role/regular_performances./music/group_membership/role ?f & ?f /music/performance_role/track_performances./music/track_contribution/role ?a => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?a /education/educational_institution_campus/educational_institution ?f & ?f /organization/organization/child./organization/organization_relationship/child ?b => ?a /organization/organization/child./organization/organization_relationship/child ?b,
#  ?a /award/award_category/nominees./award/award_nomination/nominated_for ?f & ?b /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?f => ?a /award/award_category/winners./award/award_honor/award_winner ?b,
#  ?a /dataworld/gardening_hint/split_to ?f & ?b /location/us_county/county_seat ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?b /location/location/contains ?a => ?a /base/biblioness/bibs_location/country ?b,
#  ?e /dataworld/gardening_hint/split_to ?b & ?e /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?a => ?a /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?f & ?b /film/film/written_by ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?a /education/educational_institution/campuses ?f & ?f /organization/organization_founder/organizations_founded ?b => ?a /organization/organization_founder/organizations_founded ?b,
#  ?e /organization/organization_founder/organizations_founded ?b & ?e /people/person/employment_history./business/employment_tenure/company ?a => ?a /organization/organization/child./organization/organization_relationship/child ?b,
#  ?b /location/hud_county_place/place ?f & ?a /organization/organization/headquarters./location/mailing_address/citytown ?f => ?a /organization/organization/place_founded ?b,
#  ?e /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?b & ?e /film/film_distributor/films_distributed./film/film_film_distributor_relationship/film ?a => ?a /film/film/runtime./film/film_cut/film_release_region ?b,
#  ?a /award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee ?e & ?e /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b => ?a /award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee ?b,
#  ?a /base/aareas/schema/administrative_area/administrative_parent ?f & ?b /location/location/contains ?f => ?a /base/biblioness/bibs_location/country ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?b /base/popstra/celebrity/dated./base/popstra/dated/participant ?a => ?a /people/person/spouse_s./people/marriage/spouse ?b,
#  ?f /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?b /sports/sports_position/players./sports/sports_team_roster/position ?f & ?a /sports/sports_team/roster./basketball/basketball_roster_position/position ?f => ?a /sports/sports_team/roster./basketball/basketball_roster_position/position ?b,
#  ?e /dataworld/gardening_hint/split_to ?b & ?a /olympics/olympic_games/participating_countries ?e => ?a /olympics/olympic_games/participating_countries ?b,
#  ?a /film/director/film ?f & ?b /film/film/prequel ?f => ?a /film/director/film ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?b & ?e /base/biblioness/bibs_location/country ?a => ?a /dataworld/gardening_hint/split_to ?b,
#  ?b /location/us_county/county_seat ?a => ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b,
#  ?b /people/person/spouse_s./people/marriage/spouse ?a => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?e /location/administrative_division/country ?b & ?e /location/country/second_level_divisions ?a => ?a /base/biblioness/bibs_location/country ?b,
#  ?a /film/film/produced_by ?f & ?b /people/person/spouse_s./people/marriage/spouse ?f => ?a /film/film/executive_produced_by ?b,
#  ?b /location/hud_county_place/place ?f & ?a /music/artist/origin ?f => ?a /music/artist/origin ?b,
#  ?a /base/aareas/schema/administrative_area/capital ?f & ?f /location/us_county/county_seat ?b => ?a /base/aareas/schema/administrative_area/capital ?b,
#  ?a /base/aareas/schema/administrative_area/capital ?f & ?b /location/country/second_level_divisions ?f => ?a /location/administrative_division/first_level_division_of ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?b /film/director/film ?f => ?a /film/film/story_by ?b,
#  ?e /base/biblioness/bibs_location/country ?a & ?e /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b => ?a /location/country/second_level_divisions ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?f /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b & ?a /influence/influence_node/peers./influence/peer_relationship/peers ?f => ?a /influence/influence_node/peers./influence/peer_relationship/peers ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?f & ?b /film/film/written_by ?f => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?f /location/administrative_division/country ?a & ?b /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?f => ?a /location/location/contains ?b,
#  ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?f & ?b /music/performance_role/track_performances./music/track_contribution/role ?f => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b => ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?f /film/actor/dubbing_performances./film/dubbing_performance/language ?b => ?a /people/person/languages ?b,
#  ?a /base/aareas/schema/administrative_area/capital ?f & ?f /location/hud_county_place/county ?b => ?a /base/aareas/schema/administrative_area/capital ?b,
#  ?e /people/deceased_person/place_of_burial ?a & ?e /people/person/nationality ?b => ?a /location/administrative_division/first_level_division_of ?b,
#  ?e /base/biblioness/bibs_location/state ?a & ?e /location/hud_county_place/place ?b => ?a /location/location/contains ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?e /film/film/executive_produced_by ?b => ?a /film/film/edited_by ?b,
#  ?e /location/administrative_division/country ?b & ?e /location/location/contains ?a => ?a /base/biblioness/bibs_location/country ?b,
#  ?b /sports/sports_team/roster./american_football/football_historical_roster_position/position_s ?a => ?a /sports/sports_position/players./sports/sports_team_roster/team ?b,
#  ?e /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?a & ?e /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b => ?a /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b,
#  ?b /award/award_category/nominees./award/award_nomination/nominated_for ?e & ?e /film/film/prequel ?a => ?a /award/award_winning_work/awards_won./award/award_honor/award ?b,
#  ?b /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a & ?b /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a => ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b,
#  ?e /film/actor/film./film/performance/film ?b & ?e /film/director/film ?a => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /film/film/country ?b & ?e /film/film/distributors./film/film_film_distributor_relationship/region ?a => ?a /dataworld/gardening_hint/split_to ?b,
#  ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?f & ?b /music/performance_role/regular_performances./music/group_membership/role ?f => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b & ?a /film/film/written_by ?b => ?a /film/film/story_by ?b,
#  ?b /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?a /tv/tv_program/program_creator ?f => ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /people/person/profession ?f => ?a /music/artist/track_contributions./music/track_contribution/role ?b,
#  ?f /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?a & ?b /olympics/olympic_games/participating_countries ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?f /award/award_winning_work/awards_won./award/award_honor/award_winner ?b & ?a /film/film/prequel ?f => ?a /film/film/story_by ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f => ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?e /award/award_winner/awards_won./award/award_honor/award_winner ?b => ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b,
#  ?e /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a & ?e /award/award_winning_work/awards_won./award/award_honor/award_winner ?b => ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b,
#  ?e /dataworld/gardening_hint/split_to ?b & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a => ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b,
#  ?e /people/person/nationality ?b & ?e /people/person/spouse_s./people/marriage/location_of_ceremony ?a => ?a /base/biblioness/bibs_location/country ?b,
# ...
#  ?b /base/aareas/schema/administrative_area/administrative_parent ?f & ?a /location/country/second_level_divisions ?f => ?a /location/country/second_level_divisions ?b,
#  ?e /dataworld/gardening_hint/split_to ?b & ?e /location/location/contains ?a => ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?b,
#  ?a /people/deceased_person/place_of_burial ?f & ?b /people/deceased_person/place_of_burial ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?b /tv/tv_program/program_creator ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a /location/country/capital ?f & ?f /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?b /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?a & ?b /people/person/spouse_s./people/marriage/spouse ?a => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?e /sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/school ?a & ?e /sports/sports_team/roster./american_football/football_roster_position/position ?b => ?a /sports/sports_team/roster./american_football/football_historical_roster_position/position_s ?b,
#  ?f /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b & ?a /location/hud_county_place/place ?f => ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b,
#  ?f /common/topic/webpage./common/webpage/category ?b & ?a /music/record_label/artist ?f => ?a /common/topic/webpage./common/webpage/category ?b,
#  ?b /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?a => ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b,
#  ?e /location/administrative_division/country ?b & ?e /location/country/official_language ?a => ?a /language/human_language/countries_spoken_in ?b,
#  ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b & ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?f /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?b /film/director/film ?f => ?a /film/film/story_by ?b,
#  ?f /film/actor/film./film/performance/special_performance_type ?a & ?b /film/film/music ?f => ?a /film/special_film_performance_type/film_performance_type./film/performance/film ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?f /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?b => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?f /music/performance_role/track_performances./music/track_contribution/role ?a => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?e /music/performance_role/guest_performances./music/recording_contribution/performance_role ?a & ?e /music/performance_role/regular_performances./music/group_membership/role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?e /influence/influence_node/influenced_by ?a & ?e /music/artist/origin ?b => ?a /music/artist/origin ?b,
#  ?a /film/film/story_by ?b & ?a /film/film/written_by ?b => ?a /film/film/executive_produced_by ?b,
#  ?e /film/film_subject/films ?a & ?e /film/film_subject/films ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?f /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?a => ?a /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?b,
#  ?a /film/director/film ?f & ?f /film/film/film_festivals ?b => ?a /film/film/film_festivals ?b,
#  ?e /people/person/employment_history./business/employment_tenure/company ?a & ?e /people/person/nationality ?b => ?a /organization/organization/headquarters./location/mailing_address/country ?b,
#  ?f /film/director/film ?b & ?a /film/film/music ?f => ?a /film/film/prequel ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/distributors./film/film_film_distributor_relationship/region ?b => ?a /film/film/distributors./film/film_film_distributor_relationship/region ?b,
#  ?e /location/administrative_division/country ?b & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a => ?a /base/biblioness/bibs_location/country ?b,
#  ?a /organization/organization_founder/organizations_founded ?f & ?b /people/person/employment_history./business/employment_tenure/company ?f => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /music/instrument/family ?f => ?a /music/instrument/family ?b,
#  ?f /film/director/film ?b & ?a /film/film/executive_produced_by ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /location/hud_county_place/county ?a & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?b => ?a /location/us_county/county_seat ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?b /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f & ?a /military/military_conflict/combatants./military/military_combatant_group/combatants ?f => ?a /military/military_conflict/combatants./military/military_combatant_group/combatants ?b,
#  ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b => ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b,
#  ?b /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?a & ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b => ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b,
#  ?f /base/aareas/schema/administrative_area/capital ?b & ?a /location/country/second_level_divisions ?f => ?a /location/country/capital ?b,
#  ?f /education/educational_institution_campus/educational_institution ?a & ?b /location/location/contains ?f => ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?b,
#  ?f /location/administrative_division/country ?b & ?a /location/administrative_division/first_level_division_of ?f => ?a /location/administrative_division/country ?b,
#  ?f /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization_member/member_of./organization/organization_membership/organization ?f => ?a /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b,
#  ?f /base/biblioness/bibs_location/country ?b & ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?e /film/film_distributor/films_distributed./film/film_film_distributor_relationship/film ?a & ?e /organization/organization/headquarters./location/mailing_address/country ?b => ?a /film/film/distributors./film/film_film_distributor_relationship/region ?b,
#  ?f /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?a /location/country/capital ?b => ?a /location/location/contains ?b,
#  ?a /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer ?f & ?f /people/person/nationality ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?a /base/aareas/schema/administrative_area/capital ?f & ?f /base/biblioness/bibs_location/country ?b => ?a /location/administrative_division/country ?b,
#  ?e /location/administrative_division/country ?b & ?e /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?a => ?a /location/administrative_division/first_level_division_of ?b,
#  ?a /food/food/nutrients./food/nutrition_fact/nutrient ?f & ?b /food/food/nutrients./food/nutrition_fact/nutrient ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?f /location/hud_county_place/place ?a & ?b /location/us_county/county_seat ?f => ?a /location/us_county/county_seat ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b => ?a /film/film/film_art_direction_by ?b,
#  ?e /education/educational_institution/campuses ?a & ?e /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b => ?a /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /people/person/languages ?b & ?e /people/person/places_lived./people/place_lived/location ?a => ?a /location/country/official_language ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b & ?e /award/award_winner/awards_won./award/award_honor/award_winner ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.longitude> ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events> ?f => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded> ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes> ?f => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?e /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b & ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a => ?a /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b,
#  ?a /film/film/personal_appearances./film/personal_film_appearance/person ?f & ?f /people/person/nationality ?b => ?a /film/film/country ?b,
#  ?f /music/instrument/family ?b & ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?f => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.ionization_energy> ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent> ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?e /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?e /education/educational_institution/campuses ?a => ?a /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b,
#  ?b /base/aareas/schema/administrative_area/capital ?f & ?a /location/hud_county_place/place ?f => ?a /base/biblioness/bibs_location/state ?b,
#  ?f /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?a /education/educational_institution_campus/educational_institution ?f => ?a /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b,
#  ?b /tv/tv_network/programs./tv/tv_network_duration/program ?a => ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b,
#  ?e /film/film/country ?b & ?e /tv/tv_program/country_of_origin ?a => ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b,
#  ?f /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization/headquarters./location/mailing_address/country ?f => ?a /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b,
#  ?e /music/artist/track_contributions./music/track_contribution/role ?a & ?e /music/group_member/membership./music/group_membership/role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?f /common/topic/webpage./common/webpage/category ?b & ?a /film/film/featured_film_locations ?f => ?a /common/topic/webpage./common/webpage/category ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.covalent_radius> ?f & ?a <http://rdf.freebase.com/ns/food.food.energy> ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?b /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?a => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?e /people/person/employment_history./business/employment_tenure/company ?b & ?e /people/person/spouse_s./people/marriage/spouse ?a => ?a /organization/organization_founder/organizations_founded ?b,
#  ?f /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?a /education/educational_institution/campuses ?f => ?a /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /location/hud_county_place/county ?a & ?e /location/hud_county_place/county ?b => ?a /location/hud_county_place/place ?b,
#  ?e /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_language ?b & ?e /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?a => ?a /location/country/official_language ?b,
#  ?e /location/administrative_division/country ?a & ?e /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?b /dataworld/gardening_hint/split_to ?a => ?a /education/educational_institution/campuses ?b,
#  ?b /location/location/contains ?f & ?a /organization/organization_founder/organizations_founded ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?a /film/film/film_production_design_by ?b => ?a /film/film/edited_by ?b,
#  ?e /education/educational_institution/colors ?b & ?e /education/educational_institution_campus/educational_institution ?a => ?a /education/educational_institution/colors ?b,
#  ?b /base/aareas/schema/administrative_area/administrative_parent ?f & ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?f => ?a /location/us_county/county_seat ?b,
#  ?e /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a & ?e /film/film/language ?b => ?a /film/film/language ?b,
#  ?e /common/topic/webpage./common/webpage/category ?b & ?e /film/film/featured_film_locations ?a => ?a /common/topic/webpage./common/webpage/category ?b,
#  ?f /film/director/film ?a & ?b /film/film/written_by ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?b /music/artist/contribution./music/recording_contribution/performance_role ?a => ?a /music/instrument/instrumentalists ?b,
#  ?e /common/topic/webpage./common/webpage/category ?b & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a => ?a /common/topic/webpage./common/webpage/category ?b,
#  ...}
