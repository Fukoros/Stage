# %%
import pandas as pd 
import numpy as np
import os
from subprocess import check_output
import shutil

from rule import *
from amie import *

# %%
root_source = "./../../FB15k-237-num/"
store_data = "./../../Data_FB/FB15K_lte.tsv"

# %%
f = open(root_source+"FB15K_NumericalTriples.txt", "r")
dic_predicate = {}
for line in f:
    line_split = line.split("\n")[0].split("\t")
    line_split[2] = float(line_split[2]) 
    line_split = tuple(line_split)
    if line_split[1] in dic_predicate.keys():
        dic_predicate[line_split[1]].add(line_split)
    else : 
        dic_predicate[line_split[1]] = {line_split}
f.close()

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
def write_file(X, f, threshold, comparator):
    f.write(f"{X['Subject']}\t{X['Predicate']}_LTE_{threshold}\t{X['Object']<=comparator}\n")

# %%
f = open(store_data, "w")

for key in dic_predicate.keys():
    tp_df = pd.DataFrame.from_dict(dic_predicate[key]).rename(columns={0: "Subject", 1: "Predicate", 2: "Object"})
    tp_df_describe = tp_df["Object"].quantile(thresholds)
    for threshold in thresholds: 
        tp_df.apply(write_file, args=(f, threshold, tp_df_describe[threshold]), axis=1)

f.close()

# %%
data = open(root_source+"train.txt", "r")
f = open(store_data, "a")

predicate_to_find = set()

for line in data: 
    f.write(line)
    predicate_to_find.add(line.split("\n")[0].split("\t")[1])
    
data.close()
f.close()

# %%
htr = ""
for p in predicate_to_find:
    htr+=p+","
htr = htr[:-1]
#print(htr)

# %%
res = check_output(f'java -jar ./../amie3.jar -htr {htr} {store_data}', shell=True)

res_parsed = parse_amie(res)

# %%
len(res_parsed)
# Out:
# 9244

# %%
res_parsed
# Out:
# {?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f & ?b /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?f => ?a /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?b,
#  ?e /dataworld/gardening_hint/split_to ?b & ?a /education/educational_degree/people_with_this_degree./education/education/major_field_of_study ?e => ?a /education/educational_degree/people_with_this_degree./education/education/major_field_of_study ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?e /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?a => ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b,
#  ?e /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?a & ?e /tv/tv_producer/programs_produced./tv/tv_producer_term/producer_type ?b => ?a /tv/tv_program/tv_producer./tv/tv_producer_term/producer_type ?b,
#  ?a /film/director/film ?f & ?f /film/film/prequel ?b => ?a /film/director/film ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?b => ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b,
#  ?a /education/educational_institution/students_graduates./education/education/student ?f & ?b /education/educational_institution/students_graduates./education/education/student ?f => ?a /education/educational_institution_campus/educational_institution ?b,
#  ?e /people/person/sibling_s./people/sibling_relationship/sibling ?a & ?e /people/person/sibling_s./people/sibling_relationship/sibling ?b => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_compound.average_molar_mass>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.25 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/time.month.number_of_days_in_month>_LTE_0.5 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?f /dataworld/gardening_hint/split_to ?a & ?b /education/educational_institution/campuses ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a & ?e /film/film/story_by ?b => ?a /film/film/executive_produced_by ?b,
#  ?e /common/topic/webpage./common/webpage/category ?b & ?e /organization/organization/child./organization/organization_relationship/child ?a => ?a /common/topic/webpage./common/webpage/category ?b,
#  ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_LTE_0.25 ?f => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?a /film/film_subject/films ?f & ?f /olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country ?b => ?a /olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country ?b,
#  ?e /tv/tv_program/languages ?b & ?e /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?a => ?a /people/person/languages ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?a /music/instrument/instrumentalists ?e => ?a /music/performance_role/regular_performances./music/group_membership/group ?b,
#  ?a /music/instrument/instrumentalists ?f & ?b /music/instrument/instrumentalists ?f => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?a /base/locations/continents/countries_within ?f & ?f /location/location/adjoin_s./location/adjoining_relationship/adjoins ?b => ?a /location/location/contains ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?a /award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee ?e => ?a /award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b,
#  ?a /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b,
#  ?a /business/job_title/people_with_this_title./business/employment_tenure/company ?e & ?e /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b => ?a /government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office ?b,
#  ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries>_LTE_0.75 ?f & ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?e /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?a & ?e /people/person/nationality ?b => ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b,
#  ?b /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a & ?a /film/film/prequel ?b => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?a <http://rdf.freebase.com/ns/base.schemastaging.tennis_player_extra.doubles_grand_slams>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/base.schemastaging.tennis_player_extra.singles_grand_slams>_LTE_0.75 ?f => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?f & ?b /film/film/prequel ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.5 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?b & ?e /location/location/contains ?a => ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?b,
#  ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?b => ?a /education/educational_institution_campus/educational_institution ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.atomic_number>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a /film/film/featured_film_locations ?f & ?f /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b => ?a /film/film/country ?b,
#  ?a /education/educational_institution_campus/educational_institution ?f & ?f /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b,
#  ?b /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/prequel ?a => ?a /film/film/prequel ?b,
#  ?f /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?b /film/film/prequel ?f => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?b /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?f & ?a /olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/olympics ?f => ?a /olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country ?b,
#  ?a /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?b & ?b /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?a => ?a /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?b,
#  ?a /award/award_ceremony/awards_presented./award/award_honor/award_winner ?f & ?b /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?f => ?a /award/award_ceremony/awards_presented./award/award_honor/honored_for ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?f & ?b /film/director/film ?f => ?a /film/film/edited_by ?b,
#  ?b /base/aareas/schema/administrative_area/capital ?a => ?a /base/biblioness/bibs_location/state ?b,
#  ?e /base/biblioness/bibs_location/state ?a & ?e /location/location/contains ?b => ?a /location/location/contains ?b,
#  ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?f /base/aareas/schema/administrative_area/capital ?b & ?a /film/film/featured_film_locations ?f => ?a /film/film/featured_film_locations ?b,
#  ?a /film/film/executive_produced_by ?f & ?f /people/person/nationality ?b => ?a /film/film/country ?b,
#  ?a /education/educational_institution_campus/educational_institution ?f & ?f /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events>_LTE_0.75 ?f => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?e /base/biblioness/bibs_location/country ?b & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?e /location/hud_county_place/place ?b & ?e /location/us_county/county_seat ?a => ?a /location/us_county/county_seat ?b,
#  ?a <http://rdf.freebase.com/ns/biology.organism_classification.itis_tsn>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/chemistry.chemical_compound.average_molar_mass>_LTE_0.75 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a <http://rdf.freebase.com/ns/base.schemastaging.tennis_player_extra.doubles_grand_slams>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/tennis.tennis_player.year_turned_pro>_LTE_0.5 ?f => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?e /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?b /people/person/spouse_s./people/marriage/spouse ?a => ?a /people/person/spouse_s./people/marriage/spouse ?b,
#  ?e /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b & ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a => ?a /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?f /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b,
#  ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a & ?e /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b,
#  ?f /organization/organization_founder/organizations_founded ?b & ?a /people/person/spouse_s./people/marriage/spouse ?f => ?a /organization/organization_founder/organizations_founded ?b,
#  ?e /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?a & ?b /music/instrument/instrumentalists ?e => ?a /music/group_member/membership./music/group_membership/role ?b,
#  ?e /location/administrative_division/country ?b & ?a /olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country ?e => ?a /olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?a /education/educational_institution_campus/educational_institution ?f => ?a /education/educational_institution_campus/educational_institution ?b,
#  ?f /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a & ?b /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f => ?a /film/film/prequel ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?e /film/film/written_by ?b => ?a /film/film/written_by ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f => ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.melting_point>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/food.food.energy>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?f & ?b /film/film/edited_by ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a <http://rdf.freebase.com/ns/government.legislative_session.date_began>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/location.location.area>_LTE_0.5 ?f => ?a /government/legislative_session/members./government/government_position_held/district_represented ?b,
#  ?f /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?b /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?f => ?a /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?b,
#  ?b /location/country/official_language ?a => ?a /language/human_language/countries_spoken_in ?b,
#  ?e /location/administrative_division/country ?a & ?e /location/location/partially_contains ?b => ?a /location/location/partially_contains ?b,
#  ?a /film/actor/film./film/performance/film ?f & ?f /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b => ?a /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc>_LTE_0.75 ?f => ?a /location/location/time_zones ?b,
#  ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b & ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a => ?a /people/person/spouse_s./people/marriage/spouse ?b,
#  ?e /education/educational_institution_campus/educational_institution ?a & ?e /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b => ?a /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /base/popstra/celebrity/dated./base/popstra/dated/participant ?a & ?e /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?b => ?a /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?b,
#  ?b /music/record_label/artist ?a & ?a /people/person/employment_history./business/employment_tenure/company ?b => ?a /organization/organization_founder/organizations_founded ?b,
#  ?e /influence/influence_node/influenced_by ?a & ?e /music/group_member/membership./music/group_membership/role ?b => ?a /music/artist/contribution./music/recording_contribution/performance_role ?b,
#  ?f /film/film/costume_design_by ?b & ?a /film/film/prequel ?f => ?a /film/film/costume_design_by ?b,
#  ?a /base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club ?f & ?b /sports/sports_position/players./sports/sports_team_roster/team ?f => ?a /soccer/football_team/current_roster./sports/sports_team_roster/position ?b,
#  ?b /influence/influence_node/influenced_by ?f & ?f /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?a => ?a /tv/tv_program/program_creator ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.latitude>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries>_LTE_0.5 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?a /influence/influence_node/influenced_by ?f & ?f /people/person/gender ?b => ?a /people/person/gender ?b,
#  ?b /language/human_language/countries_spoken_in ?f & ?a /people/person/nationality ?f => ?a /people/person/languages ?b,
#  ?e /people/person/nationality ?a & ?e /people/person/place_of_birth ?b => ?a /location/location/contains ?b,
#  ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/tv.tv_program.air_date_of_first_episode>_LTE_0.75 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?a <http://rdf.freebase.com/ns/location.location.gns_ufi>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.75 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?a /award/award_ceremony/awards_presented./award/award_honor/award_winner ?f & ?b /film/film/written_by ?f => ?a /award/award_ceremony/awards_presented./award/award_honor/honored_for ?b,
#  ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events>_LTE_0.5 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.atomic_number>_LTE_0.75 ?f & ?a <http://rdf.freebase.com/ns/food.food.energy>_LTE_0.25 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/time.month.number_of_days_in_month>_LTE_0.75 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?f /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization/headquarters./location/mailing_address/country ?f => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?a /education/educational_institution_campus/educational_institution ?f & ?f /location/location/time_zones ?b => ?a /location/location/time_zones ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?b /award/award_winning_work/awards_won./award/award_honor/award_winner ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?a & ?e /people/person/languages ?b => ?a /people/person/languages ?b,
#  ?a /people/ethnicity/people ?e & ?e /people/person/spouse_s./people/marriage/spouse ?b => ?a /people/ethnicity/people ?b,
#  ?a /business/job_title/people_with_this_title./business/employment_tenure/company ?b => ?a /organization/role/leaders./organization/leadership/organization ?b,
#  ?a <http://rdf.freebase.com/ns/location.location.mean_elevation>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.25 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?f /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b & ?a /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?f => ?a /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b,
#  ?f /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b & ?a /organization/organization/headquarters./location/mailing_address/country ?f => ?a /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?b /location/us_county/county_seat ?f & ?a /people/person/places_lived./people/place_lived/location ?f => ?a /people/person/place_of_birth ?b,
#  ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f & ?b /people/person/spouse_s./people/marriage/spouse ?f => ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b,
#  ?a /education/educational_institution_campus/educational_institution ?f & ?f /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b => ?a /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /location/hud_county_place/county ?b & ?e /location/hud_county_place/place ?a => ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b,
#  ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f & ?f /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b => ?a /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b,
#  ?b /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?f & ?a /people/person/sibling_s./people/sibling_relationship/sibling ?f => ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b,
#  ?f /base/aareas/schema/administrative_area/administrative_parent ?b & ?a /organization/organization/place_founded ?f => ?a /organization/organization/headquarters./location/mailing_address/country ?b,
#  ?f /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization_member/member_of./organization/organization_membership/organization ?f => ?a /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /music/artist/origin ?b & ?e /music/group_member/membership./music/group_membership/group ?a => ?a /music/artist/origin ?b,
#  ?a /location/administrative_division/country ?b & ?b /location/location/contains ?a => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /location/administrative_division/first_level_division_of ?f => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?b /film/film/prequel ?f & ?f /film/film/production_companies ?a => ?a /film/film_distributor/films_distributed./film/film_film_distributor_relationship/film ?b,
#  ?b /award/award_category/nominees./award/award_nomination/nominated_for ?f & ?a /film/director/film ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award ?b,
#  ?a /base/locations/continents/countries_within ?f & ?b /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f => ?a /base/locations/continents/countries_within ?b,
#  ?e /location/country/capital ?a & ?e /location/country/capital ?b => ?a /location/us_county/county_seat ?b,
#  ?e /people/person/place_of_birth ?a & ?e /people/person/place_of_birth ?b => ?a /location/us_county/county_seat ?b,
#  ?a /film/film/story_by ?f & ?f /people/person/nationality ?b => ?a /film/film/release_date_s./film/film_regional_release_date/film_release_region ?b,
#  ?a <http://rdf.freebase.com/ns/biology.organism_classification.itis_tsn>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.boiling_point>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?b /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?a /award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee ?f => ?a /award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee ?b,
#  ?f /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?a /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?f => ?a /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?b,
#  ?b /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?f & ?f /location/us_county/county_seat ?a => ?a /location/hud_county_place/place ?b,
#  ?f /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?b /film/director/film ?f => ?a /film/film/written_by ?b,
#  ?a /people/ethnicity/people ?e & ?e /people/person/sibling_s./people/sibling_relationship/sibling ?b => ?a /people/ethnicity/people ?b,
#  ?e /location/hud_county_place/county ?a & ?e /location/us_county/county_seat ?b => ?a /location/hud_county_place/place ?b,
#  ?e /education/educational_institution/campuses ?b & ?e /education/educational_institution_campus/educational_institution ?a => ?a /education/educational_institution_campus/educational_institution ?b,
#  ?f /base/locations/continents/countries_within ?a & ?b /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?f => ?a /organization/organization_member/member_of./organization/organization_membership/organization ?b,
#  ?b /base/aareas/schema/administrative_area/administrative_parent ?a => ?a /base/aareas/schema/administrative_area/capital ?b,
#  ?a <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/time.month.number_of_days_in_month>_LTE_0.75 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?a /education/educational_institution/campuses ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?a /education/educational_institution/campuses ?f & ?f /education/educational_institution/colors ?b => ?a /education/educational_institution/colors ?b,
#  ?b <http://rdf.freebase.com/ns/base.schemastaging.celestial_object_extra.escape_velocity>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/location.country.calling_code>_LTE_0.5 ?f => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f & ?a /music/genre/artists ?f => ?a /music/genre/artists ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries>_LTE_0.75 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?b /award/award_category/winners./award/award_honor/award_winner ?e & ?e /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?a => ?a /award/award_winning_work/awards_won./award/award_honor/award ?b,
#  ?b /award/award_category/winners./award/award_honor/award_winner ?f & ?a /film/film/produced_by ?f => ?a /award/award_winning_work/awards_won./award/award_honor/award ?b,
#  ?b /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f & ?f /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?a => ?a /olympics/olympic_games/participating_countries ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /music/performance_role/regular_performances./music/group_membership/group ?b => ?a /music/performance_role/regular_performances./music/group_membership/group ?b,
#  ?f /location/hud_county_place/place ?b & ?a /location/location/contains ?f => ?a /location/us_county/county_seat ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?f /award/award_winning_work/awards_won./award/award_honor/award_winner ?b => ?a /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b,
#  ?a <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.to>_LTE_0.5 ?f => ?a /location/hud_county_place/place ?b,
#  ?a /award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee ?f & ?f /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b => ?a /award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee ?b,
#  ?b /education/educational_institution/campuses ?f & ?f /education/educational_institution_campus/educational_institution ?a => ?a /education/educational_institution_campus/educational_institution ?b,
#  ?a /film/film/personal_appearances./film/personal_film_appearance/person ?f & ?f /influence/influence_node/influenced_by ?b => ?a /film/film/personal_appearances./film/personal_film_appearance/person ?b,
#  ?e /music/instrument/family ?a & ?e /music/performance_role/track_performances./music/track_contribution/role ?b => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?e /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a & ?e /film/film/country ?b => ?a /film/film/release_date_s./film/film_regional_release_date/film_release_region ?b,
#  ?f /base/biblioness/bibs_location/country ?b & ?a /film/film/featured_film_locations ?f => ?a /film/film/distributors./film/film_film_distributor_relationship/region ?b,
#  ?b /music/performance_role/track_performances./music/track_contribution/role ?a => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?e /education/educational_institution/campuses ?a & ?e /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b => ?a /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /base/aareas/schema/administrative_area/capital ?a & ?e /location/administrative_division/first_level_division_of ?b => ?a /base/biblioness/bibs_location/country ?b,
#  ?b /award/award_winner/awards_won./award/award_honor/award_winner ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?b /music/instrument/family ?f & ?f /music/performance_role/guest_performances./music/recording_contribution/performance_role ?a => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?f & ?f /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?b => ?a /tv/tv_program/country_of_origin ?b,
#  ?e /film/film/film_production_design_by ?b & ?e /film/film/prequel ?a => ?a /film/film/edited_by ?b,
#  ?f /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?a & ?b /location/us_county/county_seat ?f => ?a /base/aareas/schema/administrative_area/capital ?b,
#  ?b /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?b /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f => ?a /film/actor/film./film/performance/film ?b,
#  ?e /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b & ?e /people/person/employment_history./business/employment_tenure/company ?a => ?a /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b,
#  ?a /location/administrative_division/first_level_division_of ?f & ?f /location/country/official_language ?b => ?a /location/country/official_language ?b,
#  ?f /base/biblioness/bibs_location/country ?b & ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?a /language/human_language/countries_spoken_in ?e & ?e /location/location/contains ?b => ?a /language/human_language/countries_spoken_in ?b,
#  ?a /film/film/prequel ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?f /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?b & ?a /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?f => ?a /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b & ?a /film/film/story_by ?f => ?a /film/film/prequel ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b & ?b /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?a => ?a /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?b,
#  ?a /music/instrument/family ?b & ?a /music/performance_role/track_performances./music/track_contribution/role ?b => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?a /business/job_title/people_with_this_title./business/employment_tenure/company ?f & ?b /education/educational_institution/campuses ?f => ?a /organization/role/leaders./organization/leadership/organization ?b,
#  ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries>_LTE_0.25 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?e /education/educational_institution/campuses ?a & ?e /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b,
#  ?e /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b & ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a => ?a /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b,
#  ?e /location/country/capital ?a & ?e /location/location/time_zones ?b => ?a /location/location/time_zones ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.boiling_point>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/food.food.energy>_LTE_0.75 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?b & ?e /film/film/prequel ?a => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.covalent_radius>_LTE_0.25 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a <http://rdf.freebase.com/ns/organization.organization.date_founded>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc>_LTE_0.75 ?f => ?a /location/location/time_zones ?b,
#  ?b /base/biblioness/bibs_location/country ?a => ?a /location/location/contains ?b,
#  ?b /location/hud_county_place/county ?f & ?f /location/hud_county_place/place ?a => ?a /location/us_county/county_seat ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award ?b & ?e /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/award ?b,
#  ?a /base/biblioness/bibs_location/country ?f & ?f /location/statistical_region/religions./location/religion_percentage/religion ?b => ?a /location/statistical_region/religions./location/religion_percentage/religion ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.boiling_point>_LTE_0.75 ?f & ?a <http://rdf.freebase.com/ns/food.food.energy>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?b /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?f & ?a /music/genre/artists ?f => ?a /music/genre/artists ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /award/award_winning_work/awards_won./award/award_honor/award_winner ?b => ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b,
#  ?e /location/hud_county_place/place ?b & ?e /location/us_county/county_seat ?a => ?a /location/hud_county_place/place ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /education/educational_institution/colors ?f => ?a /education/educational_institution/colors ?b,
#  ?e /education/educational_institution_campus/educational_institution ?b & ?e /organization/organization/headquarters./location/mailing_address/state_province_region ?a => ?a /location/location/contains ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.atomic_number>_LTE_0.25 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?b /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?a => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?f /base/biblioness/bibs_location/state ?a & ?b /location/location/contains ?f => ?a /base/biblioness/bibs_location/country ?b,
#  ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a & ?e /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b,
#  ?f /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?a & ?b /location/location/contains ?f => ?a /base/biblioness/bibs_location/country ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award ?b & ?a /tv/tv_program/program_creator ?f => ?a /award/award_winning_work/awards_won./award/award_honor/award ?b,
#  ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?f /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b & ?a /people/person/spouse_s./people/marriage/spouse ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?a /base/biblioness/bibs_location/country ?f & ?f /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b => ?a /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b,
#  ?b /base/popstra/celebrity/dated./base/popstra/dated/participant ?a & ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?b /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?f & ?a /sports/sports_team/roster./american_football/football_historical_roster_position/position_s ?f => ?a /sports/sports_team/roster./american_football/football_historical_roster_position/position_s ?b,
#  ?a /music/instrument/instrumentalists ?f & ?b /music/instrument/instrumentalists ?f => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?b /base/aareas/schema/administrative_area/administrative_parent ?f & ?a /location/country/second_level_divisions ?f => ?a /location/country/second_level_divisions ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award ?a & ?b /film/film/written_by ?f => ?a /award/award_category/nominees./award/award_nomination/nominated_for ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?b & ?e /location/country/second_level_divisions ?a => ?a /base/biblioness/bibs_location/country ?b,
#  ?a /location/country/second_level_divisions ?f & ?b /location/hud_county_place/county ?f => ?a /location/country/second_level_divisions ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?a & ?e /location/location/time_zones ?b => ?a /location/location/time_zones ?b,
#  ?e /education/educational_institution/colors ?b & ?e /education/educational_institution_campus/educational_institution ?a => ?a /education/educational_institution/colors ?b,
#  ?a /location/hud_county_place/place ?f & ?f /travel/travel_destination/how_to_get_here./travel/transportation/mode_of_transportation ?b => ?a /travel/travel_destination/how_to_get_here./travel/transportation/mode_of_transportation ?b,
#  ?a /film/film/edited_by ?f & ?f /people/person/nationality ?b => ?a /film/film/runtime./film/film_cut/film_release_region ?b,
#  ?e /people/ethnicity/geographic_distribution ?b & ?e /people/ethnicity/languages_spoken ?a => ?a /language/human_language/countries_spoken_in ?b,
#  ?e /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b & ?e /organization/organization_member/member_of./organization/organization_membership/organization ?a => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?f /base/aareas/schema/administrative_area/administrative_parent ?b & ?a /people/deceased_person/place_of_death ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?a /film/film/featured_film_locations ?f & ?b /location/location/contains ?f => ?a /film/film/country ?b,
#  ?e /education/educational_institution_campus/educational_institution ?a & ?e /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b => ?a /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?a <http://rdf.freebase.com/ns/location.location.area>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.25 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?b /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?a /location/location/contains ?f => ?a /base/locations/continents/countries_within ?b,
#  ?a /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?b & ?b /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?a => ?a /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?b,
#  ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes>_LTE_0.5 ?f => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?f /location/country/capital ?b & ?a /location/location/contains ?f => ?a /location/country/capital ?b,
#  ?f /base/aareas/schema/administrative_area/administrative_parent ?b & ?a /location/location/contains ?f => ?a /location/country/second_level_divisions ?b,
#  ?b /film/director/film ?a & ?a /film/film/written_by ?b => ?a /film/film/produced_by ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?a /film/film/prequel ?f & ?f /film/film/produced_by ?b => ?a /film/film/story_by ?b,
#  ?a <http://rdf.freebase.com/ns/location.country.iso_numeric>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries>_LTE_0.5 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?f /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a & ?b /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?f => ?a /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?b,
#  ?a /education/educational_institution_campus/educational_institution ?f & ?f /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?f /people/person/profession ?b & ?a /people/person/spouse_s./people/marriage/spouse ?f => ?a /people/person/profession ?b,
#  ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?f & ?f /people/person/languages ?b => ?a /people/person/languages ?b,
#  ?f /education/educational_institution/campuses ?b & ?a /education/educational_institution/campuses ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/award ?a & ?e /film/film/written_by ?b => ?a /award/award_category/winners./award/award_honor/award_winner ?b,
#  ?a /base/aareas/schema/administrative_area/administrative_parent ?f & ?f /location/administrative_division/first_level_division_of ?b => ?a /location/administrative_division/country ?b,
#  ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?f & ?f /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b => ?a /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b,
#  ?e /people/person/place_of_birth ?a & ?e /people/person/places_lived./people/place_lived/location ?b => ?a /location/us_county/county_seat ?b,
#  ?a <http://rdf.freebase.com/ns/biology.organism_classification.itis_tsn>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/chemistry.chemical_compound.density>_LTE_0.75 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?e /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b & ?e /film/film/produced_by ?a => ?a /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?e /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?b => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /education/educational_degree/people_with_this_degree./education/education/major_field_of_study ?b & ?e /education/educational_institution/students_graduates./education/education/major_field_of_study ?a => ?a /education/field_of_study/students_majoring./education/education/major_field_of_study ?b,
#  ?a /base/aareas/schema/administrative_area/administrative_parent ?f & ?f /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b => ?a /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b,
#  ?e /dataworld/gardening_hint/split_to ?b & ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a => ?a /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?b,
#  ?a /film/film/edited_by ?f & ?b /people/person/sibling_s./people/sibling_relationship/sibling ?f => ?a /film/film/edited_by ?b,
#  ?e /education/educational_institution_campus/educational_institution ?a & ?e /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
# ...
#  ?b <http://rdf.freebase.com/ns/law.invention.date_of_invention>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/tv.tv_series_episode.episode_number>_LTE_0.25 ?f => ?a /film/film/distributors./film/film_film_distributor_relationship/film_distribution_medium ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?f /organization/organization_founder/organizations_founded ?b => ?a /people/person/employment_history./business/employment_tenure/company ?b,
#  ?a /location/location/contains ?f & ?f /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?a /award/award_ceremony/awards_presented./award/award_honor/award_winner ?e & ?e /film/director/film ?b => ?a /award/award_ceremony/awards_presented./award/award_honor/honored_for ?b,
#  ?e /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b & ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a => ?a /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b,
#  ?a /location/location/contains ?b => ?a /base/locations/continents/countries_within ?b,
#  ?b /award/award_winning_work/awards_won./award/award_honor/award_winner ?a & ?a /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?b => ?a /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?b,
#  ?a <http://rdf.freebase.com/ns/government.legislative_session.date_ended>_LTE_0.25 ?f & ?b <http://rdf.freebase.com/ns/location.dated_location.date_founded>_LTE_0.25 ?f => ?a /government/legislative_session/members./government/government_position_held/district_represented ?b,
#  ?a <http://rdf.freebase.com/ns/government.legislative_session.date_began>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.25 ?f => ?a /government/legislative_session/members./government/government_position_held/district_represented ?b,
#  ?b /film/director/film ?a & ?a /film/film/written_by ?b => ?a /film/film/personal_appearances./film/personal_film_appearance/person ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?f /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b,
#  ?e /music/instrument/family ?b & ?a /music/performance_role/track_performances./music/track_contribution/role ?e => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?b /location/administrative_division/country ?a & ?a /location/location/contains ?b => ?a /location/country/second_level_divisions ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?b /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f => ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b,
#  ?e /people/person/employment_history./business/employment_tenure/company ?b & ?e /people/person/sibling_s./people/sibling_relationship/sibling ?a => ?a /people/person/employment_history./business/employment_tenure/company ?b,
#  ?a /film/film/release_date_s./film/film_regional_release_date/film_release_region ?f & ?f /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?b /dataworld/gardening_hint/split_to ?a => ?a /education/educational_institution/campuses ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?b /tv/tv_program/program_creator ?f => ?a /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?b,
#  ?a /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer ?f & ?b /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer ?f => ?a /location/hud_county_place/place ?b,
#  ?f /base/biblioness/bibs_location/country ?b & ?a /music/artist/origin ?f => ?a /people/person/nationality ?b,
#  ?a /government/legislative_session/members./government/government_position_held/district_represented ?e & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?b => ?a /government/legislative_session/members./government/government_position_held/district_represented ?b,
#  ?b /award/award_winner/awards_won./award/award_honor/award_winner ?a => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a <http://rdf.freebase.com/ns/base.schemastaging.location_extra.elevation_min>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/time.month.number_of_days_in_month>_LTE_0.5 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?a /film/film/story_by ?f & ?b /film/film/story_by ?f => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b => ?a /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b,
#  ?b <http://rdf.freebase.com/ns/architecture.architect.structure_count>_LTE_0.25 ?f & ?a <http://rdf.freebase.com/ns/architecture.architect.structure_count>_LTE_0.5 ?f => ?a /influence/influence_node/peers./influence/peer_relationship/peers ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?a /education/educational_degree/people_with_this_degree./education/education/major_field_of_study ?f => ?a /education/educational_degree/people_with_this_degree./education/education/major_field_of_study ?b,
#  ?f /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/contact_category ?b & ?a /organization/organization/child./organization/organization_relationship/child ?f => ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/contact_category ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b => ?a /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/country ?b => ?a /organization/organization/headquarters./location/mailing_address/country ?b,
#  ?f /common/topic/webpage./common/webpage/category ?b & ?a /influence/influence_node/influenced_by ?f => ?a /common/topic/webpage./common/webpage/category ?b,
#  ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/country ?b => ?a /film/film/country ?b,
#  ?a /base/biblioness/bibs_location/state ?f & ?b /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?f => ?a /location/us_county/county_seat ?b,
#  ?b /influence/influence_node/influenced_by ?f & ?a /people/ethnicity/people ?f => ?a /people/ethnicity/people ?b,
#  ?e /base/biblioness/bibs_location/country ?b & ?e /location/administrative_division/first_level_division_of ?a => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a & ?e /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b & ?b /people/person/spouse_s./people/marriage/spouse ?a => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/award ?b & ?e /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/award ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.melting_point>_LTE_0.25 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.5 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?e /location/country/capital ?a & ?e /location/country/official_language ?b => ?a /location/country/official_language ?b,
#  ?f /location/administrative_division/country ?b & ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?f => ?a /organization/organization/headquarters./location/mailing_address/country ?b,
#  ?a /dataworld/gardening_hint/split_to ?f & ?f /education/university/fraternities_and_sororities ?b => ?a /education/university/fraternities_and_sororities ?b,
#  ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.5 ?f & ?a <http://rdf.freebase.com/ns/time.month.number_of_days_in_month>_LTE_0.75 ?f => ?a /base/localfood/seasonal_month/produce_available./base/localfood/produce_availability/seasonal_months ?b,
#  ?b /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?a & ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b => ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?e /film/film/language ?b => ?a /film/film/language ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?f & ?f /tv/tv_program/languages ?b => ?a /tv/tv_program/languages ?b,
#  ?a /music/group_member/membership./music/group_membership/group ?f & ?b /music/instrument/instrumentalists ?f => ?a /music/group_member/membership./music/group_membership/role ?b,
#  ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?a /music/instrument/instrumentalists ?e => ?a /music/instrument/instrumentalists ?b,
#  ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries>_LTE_0.75 ?f => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events>_LTE_0.25 ?f & ?a <http://rdf.freebase.com/ns/topic_server.population_number>_LTE_0.5 ?f => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?a /location/hud_county_place/county ?f & ?b /location/hud_county_place/county ?f => ?a /location/us_county/county_seat ?b,
#  ?b <http://rdf.freebase.com/ns/chemistry.chemical_element.covalent_radius>_LTE_0.25 ?f & ?a <http://rdf.freebase.com/ns/food.food.usda_equivalent>_LTE_0.25 ?f => ?a /food/food/nutrients./food/nutrition_fact/nutrient ?b,
#  ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f & ?f /music/artist/track_contributions./music/track_contribution/role ?b => ?a /music/group_member/membership./music/group_membership/role ?b,
#  ?f /base/aareas/schema/administrative_area/administrative_parent ?b & ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?f & ?f /film/film/language ?b => ?a /film/film/language ?b,
#  ?f /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b & ?a /people/person/sibling_s./people/sibling_relationship/sibling ?f => ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b,
#  ?f /music/artist/contribution./music/recording_contribution/performance_role ?a & ?b /music/instrument/instrumentalists ?f => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?a <http://rdf.freebase.com/ns/government.legislative_session.date_ended>_LTE_0.5 ?f & ?b <http://rdf.freebase.com/ns/location.location.area>_LTE_0.75 ?f => ?a /government/legislative_session/members./government/government_position_held/district_represented ?b,
#  ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?e /film/film/release_date_s./film/film_regional_release_date/film_release_region ?b & ?e /film/film/runtime./film/film_cut/film_release_region ?a => ?a /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?b,
#  ?f /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b & ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f => ?a /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b,
#  ?e /organization/organization/headquarters./location/mailing_address/citytown ?a & ?e /organization/organization/headquarters./location/mailing_address/country ?b => ?a /location/administrative_division/country ?b,
#  ?b /base/popstra/celebrity/dated./base/popstra/dated/participant ?a & ?a /people/person/spouse_s./people/marriage/spouse ?b => ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b,
#  ?a /dataworld/gardening_hint/split_to ?b & ?a /music/performance_role/regular_performances./music/group_membership/role ?b => ?a /music/instrument/family ?b,
#  ?a <http://rdf.freebase.com/ns/base.lewisandclark.places_eastward.from>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/time.month.month_number>_LTE_0.5 ?f => ?a /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month ?b,
#  ?f /music/performance_role/regular_performances./music/group_membership/role ?a & ?b /music/performance_role/regular_performances./music/group_membership/role ?f => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?e /organization/organization/place_founded ?a & ?e /organization/organization/place_founded ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?b /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?a /film/film/prequel ?b => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?a /music/performance_role/track_performances./music/track_contribution/role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?b /location/administrative_division/country ?a => ?a /location/administrative_division/country ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.longitude>_LTE_0.75 ?f & ?b <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events>_LTE_0.25 ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?a & ?e /base/aareas/schema/administrative_area/administrative_parent ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?f /music/performance_role/regular_performances./music/group_membership/role ?b & ?a /music/performance_role/track_performances./music/track_contribution/role ?f => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?f /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?a & ?b /olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country ?f => ?a /olympics/olympic_games/sports ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?a /film/film/edited_by ?b => ?a /film/film/film_production_design_by ?b,
#  ...}
