# %%
import pandas as pd 
import numpy as np
import os
from subprocess import check_output
import shutil

# %%
root_source = "./../../FB15k-237-num/"
store_data = "./../../Data_FB/FB15K_baseline.tsv"

# %%
data = open(root_source+"train.txt", "r")
f = open(store_data, "w")

predicate_to_find = set()

for line in data: 
    f.write(line)
    predicate_to_find.add(line.split("\n")[0].split("\t")[1])
    
data.close()
f.close()

# %%
htr = ""
for p in predicate_to_find:
    htr+=p+","
htr = htr[:-1]

# %%
def parse_amie(res_rules_raw):    
    rules_per_cv = {}
    cpt = 0
    rules = set()
    for line in res_rules_raw.decode("utf-8").split("\n"):
        if (line != "") and (line[0] == "?"):
            dic = {}
            parts = line.split("\t")

            conclusion_raw = parts[0].split("=>")[1].split("  ")
            conclusion_raw[0] = conclusion_raw[0][1:]
            dic["conclusion"] = Atom(conclusion_raw)

            hypotheses_raw = parts[0].split("=>")[0].split("  ")
            hypotheses = []
            for i in range(0, len(hypotheses_raw)-1, 3):
                hypotheses.append(Atom(hypotheses_raw[i:i+3]))
            dic["hypotheses"] = hypotheses


            rules.add(Rule(dic["hypotheses"], dic["conclusion"], parts[1:]))
    return rules

# %%
class Atom:
    
    def __init__(self, atom_raw):
        self._subject = atom_raw[0]
        self._predicate = atom_raw[1]
        self._objectD = atom_raw[2]
        
    def __hash__(self):
        return hash((self._subject, self._predicate, self._objectD))
    
    def __repr__(self):
        return f"{self.subject} {self.predicate} {self.objectD}"
    
    def __eq__(self, other):
        return self.subject==other.subject and self.predicate==other.predicate and self.objectD==other.objectD
        
    @property
    def subject(self):
        return self._subject
    
    @property
    def predicate(self):
        return self._predicate
    
    @property
    def objectD(self):
        return self._objectD
    
class Rule:
    
    def __init__(self, hypotheses, conclusion, otherRes, fromDict=False):
        if not fromDict:
            if not isinstance(hypotheses, tuple):
                self._hypotheses = tuple(hypotheses)
            else : 
                self._hypotheses = hypotheses
            self._conclusion = conclusion
            self._size_hypotheses = len(hypotheses)
            self._headCoverage = float(otherRes[0])
            self._stdConfidence = float(otherRes[1])
            self._pcaConfidence = float(otherRes[2])
            self._precision_train = None
            self._precision_test = None
        else:
            
            if not isinstance(hypotheses, tuple):
                self._hypotheses = tuple(hypotheses)
            else : 
                self._hypotheses = hypotheses
            self._conclusion = conclusion
            self._size_hypotheses = len(hypotheses)
            self._headCoverage = float(otherRes[0])
            self._stdConfidence = float(otherRes[1])
            self._pcaConfidence = float(otherRes[2])
            self._precision_train = float(otherRes[3])
            self._precision_test = float(otherRes[4])
        
        
    def __hash__(self):
        return hash((self._hypotheses, self._conclusion))
        
    def __repr__(self):
        toWrite=""
        for atom in self.hypotheses:
            toWrite += f"{atom} & "
        toWrite = toWrite[:-3] + " => " 
        toWrite += str(self.conclusion)
        return toWrite

    def __eq__(self, other):
        if not isinstance(other, Rule):
            return False
        return (self.conclusion == other.conclusion) and (set(self.hypotheses) == set(other.hypotheses))
    
    @property
    def hypotheses(self):
        return self._hypotheses
    
    @property
    def conclusion(self):
        return self._conclusion
    
    @property
    def size_hypotheses(self):
        return self._size_hypotheses
    
    @property
    def headCoverage(self):
        return self._headCoverage
    
    @property
    def stdConfidence(self):
        return self._stdConfidence
    
    @property
    def pcaConfidence(self):
        return self._pcaConfidence
    
    @property
    def precision_train(self):
        return self._precision_train
    
    @property
    def precision_test(self):
        return self._precision_test
    
    def setPrecisionTrain(self, precision):
        self._precision_train = precision
    
    def setPrecisionTest(self, precision):
        self._precision_test = precision
        
    def toDict(self):
        return {"hypotheses":self._hypotheses, "conclusion":self._conclusion, "size_hypothese":self._size_hypotheses, "headCoverage":self._headCoverage, "stdConfidence":self._stdConfidence, "pcaConfidence":self._pcaConfidence, "precision_train": self._precision_train, "precision_test":self._precision_test}
    
    def fromDict(row):
        return Rule( row["hypotheses"], row["conclusion"], row.values[2:], True)
            
# Given a feature we will compare it to a threshold      
def limit_by_threshold(X, feature, threshold):
    return X[feature] >= threshold

# Given Amie sets of rules and new parameters, it returns new set of rules describe by these parameters.
def add_parameters(amie_responses, parameters):
    new_responses = {}
    for amie_response in amie_responses:
        for para in parameters:
            
            #Optimizable
            new_response_raw = amie_responses[amie_response].copy()
            new_response = {}
            for r in new_response_raw:
                new_response[r] = new_response_raw[r].toDict()
            new_response = pd.DataFrame.from_dict(new_response, orient="index")
            
            name = amie_response
            for sub_para in para:
                if len(new_response) != 0:
                    new_response = new_response.loc[new_response.apply(func=limit_by_threshold, axis=1, feature=sub_para[0], threshold=sub_para[1])]
                if sub_para[0] == "stdConfidence":
                    name += "\n"+"stdC"+"="+str(sub_para[1])
                elif sub_para[0] == "pcaConfidence":
                    name += "\n"+"pcaC"+"="+str(sub_para[1])
                else :
                    name += "\n"+"hC"+"="+str(sub_para[1])
            new_responses[name] = new_response
    return new_responses


def save_sets_rule(root, set_rules):
    if not path.isdir(root+"/save"):
        os.mkdir(root+"/save")
    else : 
        shutil.rmtree(root+"/save")
        os.mkdir(root+"/save")
    for set_rule in set_rules:
        set_rules[set_rule].to_csv(root+"/save/"+set_rule+".tsv")

# %%
res = check_output(f'java -jar ./../amie3.jar -htr {htr} {store_data}', shell=True)

res_parsed = parse_amie(res)

# %%
len(res_parsed)
# Out:
# 7909

# %%
res_parsed
# Out:
# {?e /music/artist/track_contributions./music/track_contribution/role ?a & ?e /music/artist/track_contributions./music/track_contribution/role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?e /organization/organization_founder/organizations_founded ?b & ?e /people/person/employment_history./business/employment_tenure/company ?a => ?a /organization/organization/child./organization/organization_relationship/child ?b,
#  ?a /music/group_member/membership./music/group_membership/role ?e & ?e /music/instrument/family ?b => ?a /music/artist/track_contributions./music/track_contribution/role ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/award_winner ?a & ?e /film/film/country ?b => ?a /people/person/nationality ?b,
#  ?e /business/job_title/people_with_this_title./business/employment_tenure/company ?a & ?e /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?b => ?a /american_football/football_team/current_roster./sports/sports_team_roster/position ?b,
#  ?f /location/location/time_zones ?b & ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?f => ?a /location/location/time_zones ?b,
#  ?a /location/administrative_division/first_level_division_of ?f & ?f /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?a /location/location/contains ?f & ?b /location/location/contains ?f => ?a /location/administrative_division/first_level_division_of ?b,
#  ?f /base/biblioness/bibs_location/country ?a & ?b /location/us_county/county_seat ?f => ?a /location/country/second_level_divisions ?b,
#  ?e /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b & ?e /film/film/production_companies ?a => ?a /film/film_distributor/films_distributed./film/film_film_distributor_relationship/film ?b,
#  ?e /base/biblioness/bibs_location/state ?b & ?e /location/location/contains ?a => ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?b,
#  ?e /education/educational_institution/campuses ?a & ?e /organization/organization/headquarters./location/mailing_address/citytown ?b => ?a /organization/organization/headquarters./location/mailing_address/citytown ?b,
#  ?b /education/educational_institution/campuses ?a => ?a /dataworld/gardening_hint/split_to ?b,
#  ?a /location/hud_county_place/place ?f & ?f /travel/travel_destination/how_to_get_here./travel/transportation/mode_of_transportation ?b => ?a /travel/travel_destination/how_to_get_here./travel/transportation/mode_of_transportation ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?e /film/film/other_crew./film/film_crew_gig/crewmember ?b => ?a /film/film/other_crew./film/film_crew_gig/crewmember ?b,
#  ?a /film/film/country ?f & ?f /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b => ?a /film/film/release_date_s./film/film_regional_release_date/film_release_region ?b,
#  ?b /location/hud_county_place/county ?f & ?f /location/location/contains ?a => ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?b,
#  ?a /business/job_title/people_with_this_title./business/employment_tenure/company ?f & ?b /education/educational_institution_campus/educational_institution ?f => ?a /organization/role/leaders./organization/leadership/organization ?b,
#  ?b /award/award_winning_work/awards_won./award/award_honor/honored_for ?f & ?a /film/film_subject/films ?f => ?a /film/film_subject/films ?b,
#  ?a /education/educational_institution/campuses ?f & ?f /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b,
#  ?f /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b & ?a /film/film/personal_appearances./film/personal_film_appearance/person ?f => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?e /music/instrument/family ?a & ?b /music/performance_role/regular_performances./music/group_membership/role ?e => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?a /base/aareas/schema/administrative_area/administrative_parent ?f & ?f /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?e /common/topic/webpage./common/webpage/category ?b & ?e /sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/school ?a => ?a /common/topic/webpage./common/webpage/category ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?f /award/award_winning_work/awards_won./award/award_honor/award ?a => ?a /award/award_category/winners./award/award_honor/award_winner ?b,
#  ?f /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?a & ?b /location/location/contains ?f => ?a /base/biblioness/bibs_location/country ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?a & ?e /location/location/time_zones ?b => ?a /location/location/time_zones ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?a & ?e /base/aareas/schema/administrative_area/administrative_parent ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award ?a & ?e /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?b => ?a /award/award_category/nominees./award/award_nomination/nominated_for ?b,
#  ?e /base/biblioness/bibs_location/country ?b & ?e /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?a => ?a /location/administrative_division/first_level_division_of ?b,
#  ?e /american_football/football_team/current_roster./sports/sports_team_roster/position ?b & ?a /sports/sports_position/players./sports/sports_team_roster/team ?e => ?a /sports/sports_position/players./sports/sports_team_roster/position ?b,
#  ?f /business/job_title/people_with_this_title./business/employment_tenure/company ?a & ?b /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?f => ?a /american_football/football_team/current_roster./sports/sports_team_roster/position ?b,
#  ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b => ?a /base/biblioness/bibs_location/state ?b,
#  ?e /location/hud_county_place/place ?b & ?a /people/marriage_union_type/unions_of_this_type./people/marriage/location_of_ceremony ?e => ?a /people/marriage_union_type/unions_of_this_type./people/marriage/location_of_ceremony ?b,
#  ?b /award/award_category/nominees./award/award_nomination/nominated_for ?f & ?a /film/director/film ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award ?b,
#  ?a /sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/school ?f & ?f /sports/sports_team/roster./american_football/football_roster_position/position ?b => ?a /sports/sports_team/roster./american_football/football_roster_position/position ?b,
#  ?a /education/educational_institution_campus/educational_institution ?f & ?f /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b,
#  ?a /sports/sports_team_location/teams ?f & ?b /sports/sports_team_location/teams ?f => ?a /base/aareas/schema/administrative_area/capital ?b,
#  ?b /location/country/second_level_divisions ?f & ?f /location/location/contains ?a => ?a /organization/organization/headquarters./location/mailing_address/country ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?e /people/person/nationality ?b => ?a /people/person/nationality ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/award_winner ?a & ?e /tv/tv_program/tv_producer./tv/tv_producer_term/producer_type ?b => ?a /tv/tv_producer/programs_produced./tv/tv_producer_term/producer_type ?b,
#  ?e /location/country/capital ?a & ?e /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b => ?a /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?f /tv/tv_program/languages ?b => ?a /film/actor/dubbing_performances./film/dubbing_performance/language ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b => ?a /film/film/music ?b,
#  ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b & ?a /people/person/spouse_s./people/marriage/spouse ?b => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?e /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b & ?e /film/film/written_by ?a => ?a /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b,
#  ?a /film/film/story_by ?b => ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b,
#  ?f /people/person/nationality ?b & ?a /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?f => ?a /film/film/country ?b,
#  ?f /location/location/adjoin_s./location/adjoining_relationship/adjoins ?b & ?a /location/location/contains ?f => ?a /location/us_county/county_seat ?b,
#  ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?b /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?a => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?e /film/actor/film./film/performance/film ?a & ?e /people/person/languages ?b => ?a /film/film/language ?b,
#  ?a /location/country/second_level_divisions ?f & ?b /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /location/country/second_level_divisions ?b,
#  ?e /common/topic/webpage./common/webpage/category ?b & ?e /film/film/music ?a => ?a /common/topic/webpage./common/webpage/category ?b,
#  ?f /music/artist/track_contributions./music/track_contribution/role ?b & ?a /music/instrument/instrumentalists ?f => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?f /olympics/olympic_games/sports ?a & ?b /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?f => ?a /olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country ?b,
#  ?e /location/location/contains ?a & ?e /time/event/locations ?b => ?a /base/biblioness/bibs_location/country ?b,
#  ?b /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?a & ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b => ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b,
#  ?e /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?a & ?e /organization/organization/headquarters./location/mailing_address/country ?b => ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b,
#  ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f & ?f /people/person/languages ?b => ?a /film/actor/dubbing_performances./film/dubbing_performance/language ?b,
#  ?b /location/hud_county_place/county ?f & ?a /location/hud_county_place/place ?f => ?a /location/hud_county_place/county ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?f /music/artist/track_contributions./music/track_contribution/role ?b => ?a /music/artist/track_contributions./music/track_contribution/role ?b,
#  ?f /location/hud_county_place/place ?b & ?a /music/artist/origin ?f => ?a /people/person/place_of_birth ?b,
#  ?f /location/hud_county_place/place ?b & ?a /people/person/places_lived./people/place_lived/location ?f => ?a /people/deceased_person/place_of_death ?b,
#  ?f /base/aareas/schema/administrative_area/administrative_parent ?b & ?a /location/country/second_level_divisions ?f => ?a /location/country/second_level_divisions ?b,
#  ?e /education/educational_institution/campuses ?a & ?e /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b => ?a /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?f /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization/headquarters./location/mailing_address/country ?f => ?a /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b,
#  ?a /people/person/spouse_s./people/marriage/spouse ?b => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?a /film/director/film ?f & ?f /film/film/written_by ?b => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b,
#  ?b /base/biblioness/bibs_location/country ?f & ?f /dataworld/gardening_hint/split_to ?a => ?a /location/location/contains ?b,
#  ?b /base/biblioness/bibs_location/state ?f & ?a /location/location/contains ?f => ?a /location/location/contains ?b,
#  ?b /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?f & ?f /film/film/release_date_s./film/film_regional_release_date/film_release_distribution_medium ?b => ?a /film/film/release_date_s./film/film_regional_release_date/film_release_distribution_medium ?b,
#  ?e /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b & ?a /education/educational_degree/people_with_this_degree./education/education/student ?e => ?a /education/educational_degree/people_with_this_degree./education/education/student ?b,
#  ?a /film/film/music ?b & ?a /film/film/written_by ?b => ?a /film/film/edited_by ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?a & ?e /location/administrative_division/country ?b => ?a /base/biblioness/bibs_location/country ?b,
#  ?a /education/field_of_study/students_majoring./education/education/student ?f & ?b /education/field_of_study/students_majoring./education/education/student ?f => ?a /education/field_of_study/students_majoring./education/education/major_field_of_study ?b,
#  ?b /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?f & ?a /people/person/sibling_s./people/sibling_relationship/sibling ?f => ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?b /film/film/story_by ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /education/educational_institution_campus/educational_institution ?a & ?e /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b => ?a /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b & ?e /people/person/employment_history./business/employment_tenure/company ?a => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?e /base/biblioness/bibs_location/country ?a & ?e /base/biblioness/bibs_location/state ?b => ?a /location/location/contains ?b,
#  ?e /tv/tv_program/country_of_origin ?b & ?e /tv/tv_program/languages ?a => ?a /language/human_language/countries_spoken_in ?b,
#  ?e /tv/tv_network/programs./tv/tv_network_duration/program ?a & ?e /tv/tv_network/programs./tv/tv_network_duration/program ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /dataworld/gardening_hint/split_to ?b & ?e /location/location/contains ?a => ?a /location/administrative_division/first_level_division_of ?b,
#  ?b /location/location/contains ?f & ?a /people/person/spouse_s./people/marriage/location_of_ceremony ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?b /base/aareas/schema/administrative_area/administrative_parent ?f & ?f /base/aareas/schema/administrative_area/capital ?a => ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b,
#  ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f & ?f /music/group_member/membership./music/group_membership/role ?a => ?a /music/instrument/instrumentalists ?b,
#  ?e /film/film/executive_produced_by ?b & ?e /film/film/prequel ?a => ?a /film/film/story_by ?b,
#  ?b /award/award_winning_work/awards_won./award/award_honor/award_winner ?a & ?b /film/film/written_by ?a => ?a /film/director/film ?b,
#  ?a /film/film/country ?f & ?f /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?e /location/administrative_division/country ?b & ?e /location/location/contains ?a => ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?b,
#  ?e /music/instrument/family ?b & ?e /music/performance_role/track_performances./music/track_contribution/role ?a => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?e /location/administrative_division/country ?a & ?e /organization/organization_member/member_of./organization/organization_membership/organization ?b => ?a /organization/organization_member/member_of./organization/organization_membership/organization ?b,
#  ?b /award/award_winning_work/awards_won./award/award_honor/honored_for ?f & ?f /film/film/prequel ?a => ?a /film/film/prequel ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?f /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?b => ?a /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b,
#  ?b /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f & ?a /user/ktrueman/default_domain/international_organization/member_states ?f => ?a /user/ktrueman/default_domain/international_organization/member_states ?b,
#  ?e /location/administrative_division/country ?b & ?e /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?a => ?a /location/administrative_division/country ?b,
#  ?a <http://rdf.freebase.com/ns/topic_server.population_number> ?f & ?b <http://rdf.freebase.com/ns/topic_server.population_number> ?f => ?a /location/us_county/county_seat ?b,
#  ?e /organization/organization/headquarters./location/mailing_address/citytown ?b & ?e /organization/organization/headquarters./location/mailing_address/state_province_region ?a => ?a /location/location/contains ?b,
#  ?f /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization_member/member_of./organization/organization_membership/organization ?f => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?f /music/instrument/instrumentalists ?a => ?a /people/person/profession ?b,
#  ?b /film/film/executive_produced_by ?f & ?a /film/film/written_by ?f => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?e /film/film/film_art_direction_by ?b & ?e /film/film/prequel ?a => ?a /film/film/film_art_direction_by ?b,
#  ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a & ?e /location/location/partially_contains ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b & ?e /location/hud_county_place/place ?a => ?a /location/hud_county_place/county ?b,
#  ?b /location/location/contains ?f & ?a /people/person/place_of_birth ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /music/group_member/membership./music/group_membership/role ?f => ?a /music/group_member/membership./music/group_membership/role ?b,
#  ?a /film/film/written_by ?f & ?b /film/film/written_by ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?a /film/film/release_date_s./film/film_regional_release_date/film_release_region ?f & ?f /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?e /people/person/nationality ?b & ?e /people/person/places_lived./people/place_lived/location ?a => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?f /education/educational_institution/campuses ?b & ?a /education/educational_institution/campuses ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b & ?a /people/person/spouse_s./people/marriage/spouse ?b => ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b,
#  ?a /base/biblioness/bibs_location/country ?b & ?b /location/location/contains ?a => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?a /base/locations/continents/countries_within ?f & ?b /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f => ?a /base/locations/continents/countries_within ?b,
#  ?a /location/location/partially_contains ?f & ?f /location/location/time_zones ?b => ?a /location/location/time_zones ?b,
#  ?b /base/biblioness/bibs_location/state ?a => ?a /location/location/contains ?b,
#  ?e /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?e /people/person/religion ?b => ?a /people/person/religion ?b,
#  ?b /music/instrument/instrumentalists ?a => ?a /music/artist/contribution./music/recording_contribution/performance_role ?b,
#  ?b /award/award_winner/awards_won./award/award_honor/award_winner ?a => ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /education/educational_institution/campuses ?f => ?a /education/educational_institution/campuses ?b,
#  ?e /film/film/prequel ?a & ?e /film/film/written_by ?b => ?a /film/film/written_by ?b,
#  ?f /base/biblioness/bibs_location/state ?b & ?a /location/us_county/county_seat ?f => ?a /base/biblioness/bibs_location/state ?b,
#  ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b & ?b /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?a => ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?b & ?e /location/location/contains ?a => ?a /organization/organization/headquarters./location/mailing_address/country ?b,
#  ?a /olympics/olympic_games/sports ?b => ?a /user/jg/default_domain/olympic_games/sports ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?b /music/instrument/instrumentalists ?f => ?a /music/group_member/membership./music/group_membership/role ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?b /location/location/contains ?f => ?a /location/administrative_division/first_level_division_of ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.latitude> ?f & ?b <http://rdf.freebase.com/ns/location.geocode.latitude> ?f => ?a /location/hud_county_place/place ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?f /people/person/profession ?b => ?a /people/person/profession ?b,
#  ?a /award/award_ceremony/awards_presented./award/award_honor/honored_for ?f & ?b /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f => ?a /award/award_ceremony/awards_presented./award/award_honor/award_winner ?b,
#  ?f /film/film_distributor/films_distributed./film/film_film_distributor_relationship/film ?a & ?b /organization/organization_founder/organizations_founded ?f => ?a /film/film/executive_produced_by ?b,
#  ?e /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?e /people/person/languages ?b => ?a /people/person/languages ?b,
#  ?f /location/hud_foreclosure_area/estimated_number_of_mortgages./measurement_unit/dated_integer/source ?b & ?a /location/location/contains ?f => ?a /location/hud_foreclosure_area/estimated_number_of_mortgages./measurement_unit/dated_integer/source ?b,
#  ?f /base/biblioness/bibs_location/country ?b & ?a /location/hud_county_place/place ?f => ?a /base/biblioness/bibs_location/country ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b & ?b /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?a => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?a /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b,
#  ?f /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization_member/member_of./organization/organization_membership/organization ?f => ?a /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?a /base/culturalevent/event/entity_involved ?f & ?f /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b => ?a /military/military_conflict/combatants./military/military_combatant_group/combatants ?b,
#  ?f /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a & ?b /user/ktrueman/default_domain/international_organization/member_states ?f => ?a /organization/organization_member/member_of./organization/organization_membership/organization ?b,
#  ?a <http://rdf.freebase.com/ns/location.location.area> ?f & ?b <http://rdf.freebase.com/ns/location.location.area> ?f => ?a /education/educational_institution/campuses ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /people/person/profession ?f => ?a /music/artist/track_contributions./music/track_contribution/role ?b,
#  ?f /film/actor/film./film/performance/film ?b & ?a /film/film/produced_by ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /education/educational_institution/campuses ?a & ?e /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b & ?b /film/film/prequel ?a => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?a /music/instrument/family ?b & ?a /music/performance_role/regular_performances./music/group_membership/role ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /location/administrative_division/first_level_division_of ?b,
#  ?f /award/award_winning_work/awards_won./award/award_honor/award_winner ?a & ?b /film/special_film_performance_type/film_performance_type./film/performance/film ?f => ?a /film/actor/film./film/performance/special_performance_type ?b,
#  ?e /education/educational_institution/campuses ?b & ?e /organization/organization/headquarters./location/mailing_address/state_province_region ?a => ?a /location/location/contains ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?b /film/film/edited_by ?f => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?f /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b & ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f => ?a /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b => ?a /people/person/spouse_s./people/marriage/spouse ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?b /film/film/story_by ?f => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?a /base/aareas/schema/administrative_area/capital ?f & ?f /location/hud_county_place/county ?b => ?a /base/aareas/schema/administrative_area/capital ?b,
#  ?a /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b,
#  ?b /music/record_label/artist ?a & ?a /people/person/employment_history./business/employment_tenure/company ?b => ?a /organization/organization_founder/organizations_founded ?b,
#  ?f /people/person/religion ?b & ?a /people/person/sibling_s./people/sibling_relationship/sibling ?f => ?a /people/person/religion ?b,
#  ?f /base/biblioness/bibs_location/country ?b & ?a /people/deceased_person/place_of_death ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?a /film/film/executive_produced_by ?b => ?a /film/film/written_by ?b,
#  ?b /location/location/contains ?f & ?a /location/location/partially_contains ?f => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?e /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?a & ?e /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b => ?a /base/biblioness/bibs_location/country ?b,
#  ?a /music/instrument/family ?b & ?b /music/performance_role/track_performances./music/track_contribution/role ?a => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b => ?a /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b,
#  ?b /film/director/film ?a & ?a /film/film/written_by ?b => ?a /film/film/produced_by ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b => ?a /film/film/story_by ?b,
#  ?e /time/event/locations ?a & ?e /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b => ?a /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b,
#  ?b /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?a & ?a /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?b => ?a /sports/sports_position/players./sports/sports_team_roster/position ?b,
#  ?b /film/film/cinematography ?f & ?a /film/film/produced_by ?f => ?a /film/film/prequel ?b,
#  ?a /film/director/film ?f & ?b /film/film/prequel ?f => ?a /film/director/film ?b,
#  ?e /location/hud_county_place/county ?a & ?e /location/hud_county_place/county ?b => ?a /location/hud_county_place/county ?b,
#  ?a /location/hud_county_place/place ?b => ?a /location/us_county/county_seat ?b,
#  ?a /film/film/edited_by ?f & ?b /film/film/story_by ?f => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?e /film/actor/dubbing_performances./film/dubbing_performance/language ?b => ?a /people/person/languages ?b,
#  ?b /location/location/contains ?f & ?a /organization/organization_founder/organizations_founded ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b & ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b => ?a /people/person/spouse_s./people/marriage/spouse ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?f /people/person/religion ?b => ?a /people/person/religion ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award ?a & ?b /film/film/other_crew./film/film_crew_gig/crewmember ?f => ?a /award/award_category/nominees./award/award_nomination/nominated_for ?b,
#  ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a => ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b,
#  ?b /location/hud_county_place/county ?f & ?a /location/location/contains ?f => ?a /location/location/contains ?b,
#  ?f /organization/organization_founder/organizations_founded ?b & ?a /people/person/sibling_s./people/sibling_relationship/sibling ?f => ?a /organization/organization_founder/organizations_founded ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?a /organization/organization/child./organization/organization_relationship/child ?f => ?a /organization/organization/child./organization/organization_relationship/child ?b,
#  ?e /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b & ?e /people/person/places_lived./people/place_lived/location ?a => ?a /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b,
#  ?a /film/film/story_by ?f & ?b /film/film/story_by ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /film/film/country ?b & ?e /tv/tv_program/languages ?a => ?a /language/human_language/countries_spoken_in ?b,
#  ?e /base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club ?a & ?b /sports/sports_position/players./sports/sports_team_roster/team ?e => ?a /soccer/football_team/current_roster./sports/sports_team_roster/position ?b,
#  ?e /people/ethnicity/languages_spoken ?b & ?e /people/ethnicity/people ?a => ?a /film/actor/dubbing_performances./film/dubbing_performance/language ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.longitude> ?f & ?b <http://rdf.freebase.com/ns/location.geocode.longitude> ?f => ?a /education/educational_institution/campuses ?b,
#  ?a /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?f & ?b /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?e /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b & ?e /people/person/nationality ?a => ?a /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b,
#  ?b /music/instrument/family ?f & ?a /music/performance_role/regular_performances./music/group_membership/role ?f => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?e /base/biblioness/bibs_location/country ?b & ?a /language/human_language/countries_spoken_in ?e => ?a /language/human_language/countries_spoken_in ?b,
#  ?a /influence/influence_node/influenced_by ?f & ?b /music/performance_role/regular_performances./music/group_membership/group ?f => ?a /music/artist/contribution./music/recording_contribution/performance_role ?b,
#  ?f /music/artist/track_contributions./music/track_contribution/role ?a & ?b /music/instrument/instrumentalists ?f => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?f /people/person/languages ?b & ?a /people/person/spouse_s./people/marriage/spouse ?f => ?a /film/actor/dubbing_performances./film/dubbing_performance/language ?b,
#  ?e /education/educational_institution/campuses ?b & ?e /organization/organization/headquarters./location/mailing_address/citytown ?a => ?a /location/location/contains ?b,
#  ?b /location/hud_county_place/county ?a & ?a /location/hud_county_place/county ?b => ?a /location/us_county/county_seat ?b,
#  ?b /location/country/capital ?f & ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /location/administrative_division/country ?b,
#  ?b /sports/sports_team/roster./american_football/football_historical_roster_position/position_s ?a & ?b /sports/sports_team/roster./american_football/football_roster_position/position ?a => ?a /sports/sports_position/players./sports/sports_team_roster/team ?b,
#  ?a /location/location/contains ?f & ?f /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medal ?b => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medal ?b,
#  ?f /music/group_member/membership./music/group_membership/role ?a & ?b /music/instrument/instrumentalists ?f => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?e /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b & ?e /music/performance_role/track_performances./music/track_contribution/role ?a => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?f /people/person/nationality ?b & ?a /people/person/sibling_s./people/sibling_relationship/sibling ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?a /film/film/film_production_design_by ?f & ?f /people/person/nationality ?b => ?a /film/film/country ?b,
#  ?a /film/film/distributors./film/film_film_distributor_relationship/region ?f & ?f /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?b => ?a /film/film/release_date_s./film/film_regional_release_date/film_release_region ?b,
#  ?f /location/hud_county_place/place ?b & ?a /organization/organization/place_founded ?f => ?a /organization/organization/place_founded ?b,
#  ?b /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?f & ?f /location/location/contains ?a => ?a /location/hud_county_place/place ?b,
#  ?e /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b & ?e /music/artist/track_contributions./music/track_contribution/role ?a => ?a /music/instrument/instrumentalists ?b,
#  ?b /base/aareas/schema/administrative_area/administrative_parent ?f & ?f /location/administrative_division/country ?a => ?a /location/country/second_level_divisions ?b,
#  ?a /base/culturalevent/event/entity_involved ?f & ?b /dataworld/gardening_hint/split_to ?f => ?a /base/culturalevent/event/entity_involved ?b,
#  ?a /education/educational_institution/students_graduates./education/education/student ?f & ?f /people/person/nationality ?b => ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?b,
#  ?f /location/hud_county_place/place ?a & ?b /location/location/contains ?f => ?a /location/hud_county_place/county ?b,
#  ?a /dataworld/gardening_hint/split_to ?f & ?b /music/performance_role/track_performances./music/track_contribution/role ?f => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?f /education/educational_institution_campus/educational_institution ?b & ?a /people/person/employment_history./business/employment_tenure/company ?f => ?a /people/person/employment_history./business/employment_tenure/company ?b,
#  ?f /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b & ?a /education/educational_institution/students_graduates./education/education/student ?f => ?a /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b,
#  ?b /olympics/olympic_games/participating_countries ?a => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?e /tv/tv_program/country_of_origin ?a & ?e /tv/tv_program/languages ?b => ?a /location/country/official_language ?b,
#  ?f /film/actor/film./film/performance/film ?a & ?b /film/film/story_by ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?a /music/group_member/membership./music/group_membership/role ?f => ?a /music/group_member/membership./music/group_membership/role ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /location/administrative_division/country ?f => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?e /music/performance_role/guest_performances./music/recording_contribution/performance_role ?a & ?e /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/award_winner ?b & ?e /film/film/written_by ?a => ?a /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b,
#  ?a /ice_hockey/hockey_team/current_roster./sports/sports_team_roster/position ?f & ?f /sports/sports_position/players./sports/sports_team_roster/position ?b => ?a /ice_hockey/hockey_team/current_roster./sports/sports_team_roster/position ?b,
#  ?b /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?a /tv/non_character_role/tv_regular_personal_appearances./tv/tv_regular_personal_appearance/person ?f => ?a /tv/non_character_role/tv_regular_personal_appearances./tv/tv_regular_personal_appearance/person ?b,
#  ?f /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b & ?a /music/artist/origin ?f => ?a /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b,
#  ?a /soccer/football_team/current_roster./soccer/football_roster_position/position ?f & ?b /sports/sports_position/players./sports/sports_team_roster/position ?f => ?a /soccer/football_team/current_roster./soccer/football_roster_position/position ?b,
#  ?e /music/artist/contribution./music/recording_contribution/performance_role ?a & ?e /music/artist/contribution./music/recording_contribution/performance_role ?b => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?a /soccer/football_team/current_roster./sports/sports_team_roster/position ?f & ?f /sports/sports_position/players./sports/sports_team_roster/position ?b => ?a /soccer/football_team/current_roster./sports/sports_team_roster/position ?b,
#  ?a /education/educational_institution/students_graduates./education/education/student ?f & ?b /education/field_of_study/students_majoring./education/education/student ?f => ?a /education/educational_institution/students_graduates./education/education/major_field_of_study ?b,
#  ?f /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?a & ?b /location/us_county/county_seat ?f => ?a /base/aareas/schema/administrative_area/capital ?b,
#  ?f /location/country/form_of_government ?b & ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f => ?a /location/country/form_of_government ?b,
#  ?e /organization/organization/headquarters./location/mailing_address/citytown ?a & ?e /organization/organization/headquarters./location/mailing_address/citytown ?b => ?a /location/hud_county_place/place ?b,
#  ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a & ?e /travel/travel_destination/how_to_get_here./travel/transportation/mode_of_transportation ?b => ?a /travel/travel_destination/how_to_get_here./travel/transportation/mode_of_transportation ?b,
#  ?f /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?a /education/educational_institution_campus/educational_institution ?f => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?f /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer ?a & ?b /location/location/contains ?f => ?a /people/person/nationality ?b,
#  ?e /base/popstra/celebrity/dated./base/popstra/dated/participant ?a & ?e /people/person/spouse_s./people/marriage/location_of_ceremony ?b => ?a /people/person/spouse_s./people/marriage/location_of_ceremony ?b,
#  ?f /film/person_or_entity_appearing_in_film/films./film/personal_film_appearance/type_of_appearance ?b & ?a /people/person/spouse_s./people/marriage/spouse ?f => ?a /film/person_or_entity_appearing_in_film/films./film/personal_film_appearance/type_of_appearance ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?a /education/educational_institution/campuses ?f => ?a /education/educational_institution/campuses ?b,
#  ?e /people/person/languages ?b & ?e /people/person/places_lived./people/place_lived/location ?a => ?a /location/country/official_language ?b,
#  ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b => ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b,
#  ?f /film/film/executive_produced_by ?b & ?a /film/film/prequel ?f => ?a /film/film/produced_by ?b,
#  ?e /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b & ?e /organization/organization/child./organization/organization_relationship/child ?a => ?a /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?e /tv/tv_network/programs./tv/tv_network_duration/program ?b => ?a /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?b,
#  ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b & ?b /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?a => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?a /film/film/produced_by ?b => ?a /film/film/story_by ?b,
#  ?e /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a => ?a /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?b & ?a /sports/sports_team/roster./american_football/football_roster_position/position ?e => ?a /sports/sports_team/roster./american_football/football_roster_position/position ?b,
# ...
#  ?e /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b & ?e /award/award_winner/awards_won./award/award_honor/award_winner ?a => ?a /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?b,
#  ?a /location/country/capital ?f & ?b /location/country/capital ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?e /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_language ?b => ?a /tv/tv_program/languages ?b,
#  ?a /location/location/contains ?b => ?a /base/locations/continents/countries_within ?b,
#  ?a /film/film/country ?f & ?b /language/human_language/countries_spoken_in ?f => ?a /film/film/language ?b,
#  ?e /film/film/language ?a & ?e /tv/tv_program/country_of_origin ?b => ?a /language/human_language/countries_spoken_in ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?e /film/film/costume_design_by ?b => ?a /film/film/costume_design_by ?b,
#  ?b /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/genre ?a => ?a /media_common/netflix_genre/titles ?b,
#  ?b /government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office ?f & ?a /people/person/employment_history./business/employment_tenure/company ?f => ?a /government/politician/government_positions_held./government/government_position_held/basic_title ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?a /tv/non_character_role/tv_regular_personal_appearances./tv/tv_regular_personal_appearance/person ?e => ?a /tv/non_character_role/tv_regular_personal_appearances./tv/tv_regular_personal_appearance/person ?b,
#  ?e /film/director/film ?a & ?e /influence/influence_node/peers./influence/peer_relationship/peers ?b => ?a /film/film/edited_by ?b,
#  ?b /base/popstra/celebrity/dated./base/popstra/dated/participant ?a & ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a => ?a /people/person/spouse_s./people/marriage/spouse ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?f & ?b /film/film/edited_by ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /location/hud_county_place/place ?a & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?b => ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/award_winner ?a & ?e /award/award_winning_work/awards_won./award/award_honor/award_winner ?b => ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b,
#  ?e /music/artist/contribution./music/recording_contribution/performance_role ?a & ?e /music/group_member/membership./music/group_membership/group ?b => ?a /music/performance_role/regular_performances./music/group_membership/group ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?b /user/ktrueman/default_domain/international_organization/member_states ?f => ?a /organization/organization_member/member_of./organization/organization_membership/organization ?b,
#  ?b /ice_hockey/hockey_team/current_roster./sports/sports_team_roster/position ?a => ?a /sports/sports_position/players./sports/sports_team_roster/team ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?f & ?b /film/film/story_by ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b => ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?a /film/film/film_art_direction_by ?f => ?a /film/film/film_production_design_by ?b,
#  ?e /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b & ?e /organization/organization/headquarters./location/mailing_address/citytown ?a => ?a /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b,
#  ?e /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b & ?e /organization/organization/headquarters./location/mailing_address/citytown ?a => ?a /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b,
#  ?a /tv/tv_program/program_creator ?b => ?a /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?b,
#  ?b /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?f & ?a /organization/organization_member/member_of./organization/organization_membership/organization ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?b /music/instrument/family ?f & ?f /music/performance_role/guest_performances./music/recording_contribution/performance_role ?a => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?a /film/film/film_production_design_by ?b => ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b,
#  ?b /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?a /people/ethnicity/geographic_distribution ?f => ?a /people/ethnicity/geographic_distribution ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?b /film/film/film_art_direction_by ?f => ?a /film/film_set_designer/film_sets_designed ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /location/administrative_division/first_level_division_of ?f => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?f & ?f /common/topic/webpage./common/webpage/category ?b => ?a /common/topic/webpage./common/webpage/category ?b,
#  ?e /influence/influence_node/influenced_by ?a & ?e /music/group_member/membership./music/group_membership/role ?b => ?a /music/group_member/membership./music/group_membership/role ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?e /people/person/employment_history./business/employment_tenure/company ?b => ?a /organization/organization_founder/organizations_founded ?b,
#  ?a /base/biblioness/bibs_location/country ?f & ?f /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b,
#  ?f /base/aareas/schema/administrative_area/capital ?b & ?a /people/deceased_person/place_of_death ?f => ?a /people/deceased_person/place_of_death ?b,
#  ?f /people/person/employment_history./business/employment_tenure/company ?b & ?a /people/person/spouse_s./people/marriage/spouse ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?e /film/film/dubbing_performances./film/dubbing_performance/actor ?b & ?e /film/film/prequel ?a => ?a /film/film/dubbing_performances./film/dubbing_performance/actor ?b,
#  ?e /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?e /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b => ?a /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b,
#  ?f /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?e /music/artist/contribution./music/recording_contribution/performance_role ?a & ?e /music/artist/track_contributions./music/track_contribution/role ?b => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?f /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b & ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?f => ?a /music/group_member/membership./music/group_membership/group ?b,
#  ?e /film/film/other_crew./film/film_crew_gig/crewmember ?b & ?e /film/film/prequel ?a => ?a /film/film/other_crew./film/film_crew_gig/crewmember ?b,
#  ?f /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b & ?a /film/film/prequel ?f => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?b /award/award_category/winners./award/award_honor/award_winner ?e & ?e /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a => ?a /award/award_winning_work/awards_won./award/award_honor/award ?b,
#  ?a /film/film/distributors./film/film_film_distributor_relationship/region ?f & ?f /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f & ?f /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b => ?a /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b,
#  ?a /sports/sports_team_location/teams ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/school ?a & ?b /sports/sports_position/players./sports/sports_team_roster/team ?e => ?a /american_football/football_team/current_roster./sports/sports_team_roster/position ?b,
#  ?a /people/deceased_person/place_of_death ?b => ?a /music/artist/origin ?b,
#  ?a /location/location/contains ?f & ?b /location/location/partially_contains ?f => ?a /location/country/second_level_divisions ?b,
#  ?a /location/hud_county_place/county ?f & ?b /location/us_county/county_seat ?f => ?a /location/hud_county_place/county ?b,
#  ?b /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?a & ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b => ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /music/instrument/instrumentalists ?b => ?a /music/instrument/instrumentalists ?b,
#  ?b /people/person/spouse_s./people/marriage/spouse ?a => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?f /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b & ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a /education/educational_institution_campus/educational_institution ?f & ?b /education/educational_institution_campus/educational_institution ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?f & ?b /organization/organization/headquarters./location/mailing_address/state_province_region ?f => ?a /location/location/contains ?b,
#  ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b & ?b /music/performance_role/regular_performances./music/group_membership/role ?a => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?f /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?b => ?a /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /education/educational_degree/people_with_this_degree./education/education/major_field_of_study ?b => ?a /education/educational_degree/people_with_this_degree./education/education/major_field_of_study ?b,
#  ?a /location/location/contains ?f & ?b /location/us_county/county_seat ?f => ?a /location/location/contains ?b,
#  ?a /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?f /people/deceased_person/place_of_burial ?b => ?a /people/deceased_person/place_of_burial ?b,
#  ?a /music/instrument/family ?f & ?f /music/performance_role/regular_performances./music/group_membership/role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?a /business/job_title/people_with_this_title./business/employment_tenure/company ?f & ?b /people/person/employment_history./business/employment_tenure/company ?f => ?a /tv/non_character_role/tv_regular_personal_appearances./tv/tv_regular_personal_appearance/person ?b,
#  ?a /base/aareas/schema/administrative_area/capital ?f & ?f /location/hud_county_place/place ?b => ?a /base/aareas/schema/administrative_area/capital ?b,
#  ?e /location/administrative_division/country ?a & ?e /location/country/form_of_government ?b => ?a /location/country/form_of_government ?b,
#  ?f /location/location/time_zones ?b & ?a /location/us_county/county_seat ?f => ?a /location/location/time_zones ?b,
#  ?f /location/hud_county_place/county ?b & ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b,
#  ?a /award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee ?e & ?e /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b => ?a /award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_area_type ?b & ?e /location/administrative_division/country ?a => ?a /base/aareas/schema/administrative_area/administrative_area_type ?b,
#  ?a /location/hud_county_place/county ?f & ?f /location/hud_county_place/place ?b => ?a /location/hud_county_place/place ?b,
#  ?f /base/aareas/schema/administrative_area/capital ?a & ?b /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?f => ?a /location/us_county/county_seat ?b,
#  ?b /award/award_winning_work/awards_won./award/award_honor/honored_for ?f & ?f /film/film/prequel ?a => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?e /award/ranked_item/appears_in_ranked_lists./award/ranking/list ?b => ?a /award/ranked_item/appears_in_ranked_lists./award/ranking/list ?b,
#  ?f /dataworld/gardening_hint/split_to ?b & ?a /people/person/profession ?f => ?a /people/person/profession ?b,
#  ?e /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b & ?e /film/film/film_art_direction_by ?a => ?a /film/film_set_designer/film_sets_designed ?b,
#  ?a /award/award_category/nominees./award/award_nomination/nominated_for ?e & ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?b => ?a /award/award_category/nominees./award/award_nomination/nominated_for ?b,
#  ?b /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?a & ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?e /film/film/country ?a & ?e /tv/tv_program/country_of_origin ?b => ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b,
#  ?a /film/film/story_by ?f & ?f /people/person/nationality ?b => ?a /film/film/country ?b,
#  ?b /award/award_winner/awards_won./award/award_honor/award_winner ?f & ?a /film/film/edited_by ?f => ?a /film/film/written_by ?b,
#  ...}
