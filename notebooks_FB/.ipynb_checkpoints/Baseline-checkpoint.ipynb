# %%
import pandas as pd 
import numpy as np
import os
from subprocess import check_output
import shutil

from rule import *
from amie import *

# %%
root_source = "./../../FB15k-237-num/"
store_data = "./../../Data_FB/FB15K_baseline.tsv"

# %%
data = open(root_source+"FB15K_NumericalTriples.txt", "r")
f = open(store_data, "w")

dic_predicate = {}
for line in data:
    f.write(line)
data.close()
f.close()

# %%
data = open(root_source+"train.txt", "r")
f = open(store_data, "a")

predicate_to_find = set()

for line in data: 
    f.write(line)
    predicate_to_find.add(line.split("\n")[0].split("\t")[1])
    
data.close()
f.close()

# %%
htr = ""
for p in predicate_to_find:
    htr+=p+","
htr = htr[:-1]

# %%
res = check_output(f'java -jar ./../amie3.jar -htr {htr} {store_data}', shell=True)

res_parsed = parse_amie(res)

# %%
len(res_parsed)
# Out:
# 7909

# %%
res_parsed
# Out:
# {?f /base/aareas/schema/administrative_area/capital ?a & ?b /location/location/contains ?f => ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b,
#  ?b /film/director/film ?a & ?a /film/film/written_by ?b => ?a /film/film/edited_by ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?f & ?f /common/topic/webpage./common/webpage/category ?b => ?a /common/topic/webpage./common/webpage/category ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?b /people/person/employment_history./business/employment_tenure/company ?f => ?a /film/film/executive_produced_by ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/film_art_direction_by ?b => ?a /film/film/film_art_direction_by ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?a /military/military_conflict/combatants./military/military_combatant_group/combatants ?f => ?a /military/military_conflict/combatants./military/military_combatant_group/combatants ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/story_by ?b => ?a /film/film/story_by ?b,
#  ?f /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?b /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?f => ?a /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?b,
#  ?f /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?b /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /location/administrative_division/country ?a & ?e /location/statistical_region/religions./location/religion_percentage/religion ?b => ?a /location/statistical_region/religions./location/religion_percentage/religion ?b,
#  ?a /location/location/contains ?e & ?e /organization/organization/headquarters./location/mailing_address/citytown ?b => ?a /location/hud_county_place/place ?b,
#  ?b /base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club ?f & ?a /sports/sports_position/players./sports/sports_team_roster/team ?f => ?a /sports/sports_position/players./sports/sports_team_roster/team ?b,
#  ?e /location/country/form_of_government ?b & ?e /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?a => ?a /location/country/form_of_government ?b,
#  ?b /film/film/executive_produced_by ?a => ?a /film/director/film ?b,
#  ?f /common/topic/webpage./common/webpage/category ?b & ?a /people/person/spouse_s./people/marriage/location_of_ceremony ?f => ?a /common/topic/webpage./common/webpage/category ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?a /sports/sports_team/colors ?f => ?a /sports/sports_team/colors ?b,
#  ?a /film/film/film_art_direction_by ?f & ?b /film/film/film_art_direction_by ?f => ?a /film/film/prequel ?b,
#  ?b /award/award_category/winners./award/award_honor/award_winner ?e & ?e /award/award_winner/awards_won./award/award_honor/award_winner ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/award ?b,
#  ?f /film/actor/film./film/performance/film ?b & ?a /film/film/written_by ?f => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?a /base/aareas/schema/administrative_area/administrative_parent ?f & ?f /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?a /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?f & ?f /organization/organization_founder/organizations_founded ?b => ?a /organization/organization_founder/organizations_founded ?b,
#  ?a /film/film/distributors./film/film_film_distributor_relationship/region ?f & ?f /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?b /music/performance_role/guest_performances./music/recording_contribution/performance_role ?f & ?a /music/performance_role/regular_performances./music/group_membership/role ?f => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?a /time/event/locations ?f & ?f /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b => ?a /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/award ?a & ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?b => ?a /award/award_category/nominees./award/award_nomination/nominated_for ?b,
#  ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b & ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?a /film/actor/film./film/performance/film ?f & ?b /film/film/prequel ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b & ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a => ?a /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b,
#  ?e /location/location/contains ?a & ?e /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?e /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b & ?e /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?a => ?a /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b,
#  ?a /base/aareas/schema/administrative_area/capital ?f & ?f /location/location/contains ?b => ?a /location/location/contains ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b & ?b /award/award_winning_work/awards_won./award/award_honor/award_winner ?a => ?a /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?b,
#  ?f /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization_member/member_of./organization/organization_membership/organization ?f => ?a /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?b /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?f & ?a /medicine/disease/notable_people_with_this_condition ?f => ?a /medicine/disease/notable_people_with_this_condition ?b,
#  ?a /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?b => ?a /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?b,
#  ?a /broadcast/content/artist ?e & ?e /music/group_member/membership./music/group_membership/group ?b => ?a /broadcast/content/artist ?b,
#  ?a /dataworld/gardening_hint/split_to ?b => ?a /music/instrument/family ?b,
#  ?e /base/biblioness/bibs_location/country ?b & ?e /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?a => ?a /location/administrative_division/first_level_division_of ?b,
#  ?a /film/film/personal_appearances./film/personal_film_appearance/person ?f & ?f /people/person/nationality ?b => ?a /film/film/runtime./film/film_cut/film_release_region ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?b /award/award_winner/awards_won./award/award_honor/award_winner ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?e /people/person/languages ?b => ?a /film/actor/dubbing_performances./film/dubbing_performance/language ?b,
#  ?a /location/country/capital ?f & ?b /location/us_county/county_seat ?f => ?a /location/country/capital ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/distributors./film/film_film_distributor_relationship/region ?b => ?a /film/film/distributors./film/film_film_distributor_relationship/region ?b,
#  ?e /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?a & ?b /olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country ?e => ?a /user/jg/default_domain/olympic_games/sports ?b,
#  ?a /education/educational_degree/people_with_this_degree./education/education/major_field_of_study ?e & ?e /education/field_of_study/students_majoring./education/education/student ?b => ?a /education/educational_degree/people_with_this_degree./education/education/student ?b,
#  ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?b & ?a /film/film/produced_by ?b => ?a /film/film/story_by ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b => ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b,
#  ?a /medicine/symptom/symptom_of ?b => ?a /medicine/disease/risk_factors ?b,
#  ?b /base/popstra/celebrity/dated./base/popstra/dated/participant ?a => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?e /film/film/distributors./film/film_film_distributor_relationship/region ?b & ?e /film/film/prequel ?a => ?a /film/film/distributors./film/film_film_distributor_relationship/region ?b,
#  ?f /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b & ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a /music/instrument/family ?f & ?b /music/instrument/family ?f => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?e /education/educational_institution_campus/educational_institution ?a & ?e /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b => ?a /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /dataworld/gardening_hint/split_to ?b & ?e /music/performance_role/track_performances./music/track_contribution/role ?a => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?e /location/administrative_division/country ?a & ?e /location/administrative_division/first_level_division_of ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b & ?a /broadcast/content/artist ?e => ?a /broadcast/content/artist ?b,
#  ?a /government/legislative_session/members./government/government_position_held/district_represented ?f & ?b /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /government/legislative_session/members./government/government_position_held/district_represented ?b,
#  ?b /location/country/second_level_divisions ?f & ?a /location/location/contains ?f => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?a /people/ethnicity/people ?e & ?e /people/person/sibling_s./people/sibling_relationship/sibling ?b => ?a /people/ethnicity/people ?b,
#  ?f /location/administrative_division/first_level_division_of ?b & ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /location/administrative_division/first_level_division_of ?b,
#  ?e /business/business_operation/industry ?b & ?e /organization/organization/child./organization/organization_relationship/child ?a => ?a /business/business_operation/industry ?b,
#  ?e /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?e /people/person/languages ?b => ?a /people/person/languages ?b,
#  ?f /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b & ?a /people/person/sibling_s./people/sibling_relationship/sibling ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?f /location/hud_county_place/place ?a & ?b /location/location/contains ?f => ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b,
#  ?e /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b & ?e /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?a => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?e /location/administrative_division/first_level_division_of ?b & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?e /base/biblioness/bibs_location/country ?b & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a => ?a /location/administrative_division/first_level_division_of ?b,
#  ?a /location/location/contains ?f & ?f /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b,
#  ?f /location/hud_county_place/place ?b & ?a /location/us_county/county_seat ?f => ?a /location/hud_county_place/county ?b,
#  ?a /film/film/featured_film_locations ?f & ?b /language/human_language/countries_spoken_in ?f => ?a /film/film/language ?b,
#  ?e /people/person/nationality ?b & ?e /people/person/spouse_s./people/marriage/spouse ?a => ?a /people/person/nationality ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?b /film/director/film ?f => ?a /film/film/produced_by ?b,
#  ?f /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b & ?a /influence/influence_node/influenced_by ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?b /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /award/award_winning_work/awards_won./award/award_honor/honored_for ?a => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /film/film/prequel ?a & ?e /film/film/story_by ?b => ?a /film/film/written_by ?b,
#  ?f /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a & ?b /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?e /base/biblioness/bibs_location/state ?b & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a => ?a /base/biblioness/bibs_location/state ?b,
#  ?f /base/biblioness/bibs_location/state ?b & ?a /organization/organization/place_founded ?f => ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award ?b & ?a /people/person/sibling_s./people/sibling_relationship/sibling ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award ?b,
#  ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b & ?b /location/location/contains ?a => ?a /base/biblioness/bibs_location/state ?b,
#  ?e /sports/sports_position/players./sports/sports_team_roster/position ?b & ?e /sports/sports_position/players./sports/sports_team_roster/team ?a => ?a /sports/sports_team/roster./basketball/basketball_roster_position/position ?b,
#  ?b /business/job_title/people_with_this_title./business/employment_tenure/company ?f & ?a /sports/sports_position/players./sports/sports_team_roster/team ?f => ?a /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?b,
#  ?f /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b & ?a /people/person/nationality ?f => ?a /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b,
#  ?a /organization/organization/place_founded ?b => ?a /organization/organization/headquarters./location/mailing_address/citytown ?b,
#  ?f /location/administrative_division/first_level_division_of ?b & ?a /people/person/places_lived./people/place_lived/location ?f => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?e /education/educational_institution/campuses ?a & ?e /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b,
#  ?e /medicine/disease/risk_factors ?b & ?e /people/cause_of_death/people ?a => ?a /people/person/gender ?b,
#  ?f /location/location/adjoin_s./location/adjoining_relationship/adjoins ?b & ?a /organization/organization/headquarters./location/mailing_address/citytown ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award ?b & ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award ?b,
#  ?e /sports/pro_athlete/teams./sports/sports_team_roster/team ?a & ?b /sports/sport/pro_athletes./sports/pro_sports_played/athlete ?e => ?a /sports/sports_team/sport ?b,
#  ?f /base/popstra/celebrity/dated./base/popstra/dated/participant ?b & ?a /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer ?f => ?a /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer ?b,
#  ?a /location/location/contains ?f & ?f /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?a /award/award_category/category_of ?f & ?f /award/award_category/disciplines_or_subjects ?b => ?a /award/award_category/disciplines_or_subjects ?b,
#  ?e /base/aareas/schema/administrative_area/capital ?a & ?e /location/location/contains ?b => ?a /location/us_county/county_seat ?b,
#  ?f /location/hud_county_place/place ?b & ?a /location/hud_county_place/place ?f => ?a /location/hud_county_place/place ?b,
#  ?f /people/person/gender ?b & ?a /people/person/sibling_s./people/sibling_relationship/sibling ?f => ?a /people/person/gender ?b,
#  ?e /film/film/country ?b & ?e /film/film/featured_film_locations ?a => ?a /location/administrative_division/first_level_division_of ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?e /people/person/languages ?b => ?a /film/film/language ?b,
#  ?e /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?a & ?e /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b => ?a /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b => ?a /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b,
#  ?e /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?a & ?e /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?b => ?a /location/hud_county_place/place ?b,
#  ?e /location/location/contains ?a & ?e /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b,
#  ?e /base/aareas/schema/administrative_area/capital ?b & ?e /location/administrative_division/first_level_division_of ?a => ?a /location/country/second_level_divisions ?b,
#  ?e /base/biblioness/bibs_location/country ?a & ?e /location/hud_county_place/county ?b => ?a /location/country/second_level_divisions ?b,
#  ?f /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b & ?a /tv/non_character_role/tv_regular_personal_appearances./tv/tv_regular_personal_appearance/person ?f => ?a /tv/non_character_role/tv_regular_personal_appearances./tv/tv_regular_personal_appearance/person ?b,
#  ?a /award/award_ceremony/awards_presented./award/award_honor/award_winner ?f & ?b /film/film/written_by ?f => ?a /award/award_ceremony/awards_presented./award/award_honor/honored_for ?b,
#  ?e /location/administrative_division/country ?b & ?a /olympics/olympic_games/participating_countries ?e => ?a /olympics/olympic_games/participating_countries ?b,
#  ?f /award/award_winning_work/awards_won./award/award_honor/award_winner ?b & ?a /film/director/film ?f => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b,
#  ?a /film/film/cinematography ?b & ?a /film/film/written_by ?b => ?a /film/film/edited_by ?b,
#  ?a /film/film/prequel ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?b /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?a & ?a /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?b => ?a /sports/sports_position/players./sports/sports_team_roster/position ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?a & ?e /location/administrative_division/country ?b => ?a /base/biblioness/bibs_location/country ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?e /tv/tv_program/country_of_origin ?b => ?a /tv/tv_program/country_of_origin ?b,
#  ?f /dataworld/gardening_hint/split_to ?a & ?b /education/educational_institution/campuses ?f => ?a /education/educational_institution/campuses ?b,
#  ?a /film/actor/film./film/performance/film ?b & ?b /film/film/written_by ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?e /music/artist/contribution./music/recording_contribution/performance_role ?a & ?e /music/group_member/membership./music/group_membership/role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?f /sports/sports_position/players./sports/sports_team_roster/position ?b & ?a /sports/sports_position/players./sports/sports_team_roster/position ?f => ?a /sports/sports_position/players./sports/sports_team_roster/position ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?f /location/location/contains ?a => ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?b,
#  ?f /award/award_winning_work/awards_won./award/award_honor/award_winner ?a & ?b /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /people/ethnicity/languages_spoken ?b => ?a /people/ethnicity/languages_spoken ?b,
#  ?f /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?b & ?a /sports/sports_team/roster./american_football/football_historical_roster_position/position_s ?f => ?a /sports/sports_team/roster./american_football/football_roster_position/position ?b,
#  ?b /location/country/second_level_divisions ?f & ?a /location/hud_county_place/county ?f => ?a /base/biblioness/bibs_location/country ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?f /award/award_winning_work/awards_won./award/award_honor/honored_for ?b => ?a /film/actor/film./film/performance/film ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?a /base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club ?f & ?f /soccer/football_team/current_roster./sports/sports_team_roster/position ?b => ?a /soccer/football_team/current_roster./soccer/football_roster_position/position ?b,
#  ?b /location/administrative_division/country ?a => ?a /location/administrative_division/country ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/executive_produced_by ?b => ?a /film/film/story_by ?b,
#  ?a /location/hud_county_place/county ?f & ?f /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency ?b,
#  ?e /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b & ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a => ?a /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b,
#  ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/country ?b => ?a /film/film/release_date_s./film/film_regional_release_date/film_release_region ?b,
#  ?b /location/us_county/county_seat ?f & ?a /people/person/places_lived./people/place_lived/location ?f => ?a /people/person/places_lived./people/place_lived/location ?b,
#  ?a /location/administrative_division/country ?f & ?f /location/country/official_language ?b => ?a /location/country/official_language ?b,
#  ?e /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?a & ?e /organization/organization_member/member_of./organization/organization_membership/organization ?b => ?a /organization/organization_member/member_of./organization/organization_membership/organization ?b,
#  ?b /education/educational_institution/campuses ?f & ?a /education/educational_institution_campus/educational_institution ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?f /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b & ?a /people/ethnicity/people ?f => ?a /people/ethnicity/geographic_distribution ?b,
#  ?e /organization/organization/headquarters./location/mailing_address/citytown ?a & ?e /organization/organization/headquarters./location/mailing_address/country ?b => ?a /location/administrative_division/country ?b,
#  ?a /film/film/film_art_direction_by ?f & ?f /people/person/nationality ?b => ?a /film/film/country ?b,
#  ?f /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b & ?a /location/location/contains ?f => ?a /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b,
#  ?a /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?f & ?f /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics ?b => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?e /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a & ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?b => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?f /people/person/nationality ?b => ?a /organization/organization/headquarters./location/mailing_address/country ?b,
#  ?a /film/film/music ?f & ?f /people/person/languages ?b => ?a /film/film/language ?b,
#  ?a <http://rdf.freebase.com/ns/location.geocode.latitude> ?f & ?b <http://rdf.freebase.com/ns/location.geocode.latitude> ?f => ?a /location/country/capital ?b,
#  ?a /film/film/prequel ?f & ?f /film/film/production_companies ?b => ?a /film/film/production_companies ?b,
#  ?a <http://rdf.freebase.com/ns/people.deceased_person.date_of_death> ?f & ?b <http://rdf.freebase.com/ns/people.deceased_person.date_of_death> ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?f /award/award_winning_work/awards_won./award/award_honor/award_winner ?a & ?b /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?f => ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b,
#  ?f /business/job_title/people_with_this_title./business/employment_tenure/company ?a & ?b /sports/sports_position/players./sports/sports_team_roster/position ?f => ?a /sports/sports_team/roster./american_football/football_roster_position/position ?b,
#  ?b /education/educational_institution/campuses ?f & ?f /organization/organization/headquarters./location/mailing_address/state_province_region ?a => ?a /location/location/contains ?b,
#  ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b & ?a /people/person/spouse_s./people/marriage/spouse ?b => ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b,
#  ?b /american_football/football_team/current_roster./sports/sports_team_roster/position ?f & ?a /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?f => ?a /sports/sports_position/players./sports/sports_team_roster/team ?b,
#  ?e /education/educational_institution/campuses ?b & ?e /education/educational_institution_campus/educational_institution ?a => ?a /education/educational_institution_campus/educational_institution ?b,
#  ?e /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?a & ?e /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?b => ?a /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program ?b,
#  ?b /base/aareas/schema/administrative_area/capital ?a => ?a /base/biblioness/bibs_location/state ?b,
#  ?a /base/biblioness/bibs_location/country ?b & ?b /location/country/capital ?a => ?a /location/administrative_division/country ?b,
#  ?a /film/film/executive_produced_by ?b => ?a /film/film/personal_appearances./film/personal_film_appearance/person ?b,
#  ?b /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b => ?a /film/film/prequel ?b,
#  ?b /film/actor/film./film/performance/film ?a & ?a /film/film/written_by ?b => ?a /film/film/produced_by ?b,
#  ?e /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b & ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?b /government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office ?f & ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?f => ?a /government/politician/government_positions_held./government/government_position_held/basic_title ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?a /film/film/release_date_s./film/film_regional_release_date/film_release_region ?f => ?a /film/film/runtime./film/film_cut/film_release_region ?b,
#  ?b /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?f & ?a /film/director/film ?f => ?a /film/director/film ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?b & ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b & ?a /award/award_winning_work/awards_won./award/award_honor/award_winner ?f => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?e /music/artist/contribution./music/recording_contribution/performance_role ?b & ?e /music/group_member/membership./music/group_membership/role ?a => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?f /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?f /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b & ?a /location/location/contains ?f => ?a /location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency ?b,
#  ?a /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?e /base/aareas/schema/administrative_area/administrative_parent ?b & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?a /film/film/distributors./film/film_film_distributor_relationship/region ?f & ?f /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?f /olympics/olympic_games/medals_awarded./olympics/olympic_medal_honor/medal ?b & ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?f => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medal ?b,
#  ?a /broadcast/content/artist ?e & ?e /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b => ?a /broadcast/content/artist ?b,
#  ?e /military/military_conflict/combatants./military/military_combatant_group/combatants ?a & ?e /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b => ?a /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy ?b,
#  ?a /film/film/country ?f & ?f /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?b /music/performance_role/guest_performances./music/recording_contribution/performance_role ?a & ?b /music/performance_role/track_performances./music/track_contribution/role ?a => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?e /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?a & ?e /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics ?b,
#  ?e /music/artist/origin ?a & ?e /music/artist/origin ?b => ?a /location/hud_county_place/place ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?f /education/educational_institution/campuses ?a => ?a /education/educational_institution/campuses ?b,
#  ?a /film/film/country ?b => ?a /film/film/runtime./film/film_cut/film_release_region ?b,
#  ?e /influence/influence_node/influenced_by ?b & ?a /tv/non_character_role/tv_regular_personal_appearances./tv/tv_regular_personal_appearance/person ?e => ?a /tv/non_character_role/tv_regular_personal_appearances./tv/tv_regular_personal_appearance/person ?b,
#  ?b /dataworld/gardening_hint/split_to ?f & ?a /user/ktrueman/default_domain/international_organization/member_states ?f => ?a /user/ktrueman/default_domain/international_organization/member_states ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?a /base/biblioness/bibs_location/state ?f & ?f /common/topic/webpage./common/webpage/category ?b => ?a /common/topic/webpage./common/webpage/category ?b,
#  ?e /soccer/football_team/current_roster./soccer/football_roster_position/position ?b & ?e /soccer/football_team/current_roster./sports/sports_team_roster/position ?a => ?a /sports/sports_position/players./sports/sports_team_roster/position ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?f & ?b /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b,
#  ?e /film/film/edited_by ?a & ?e /film/film/produced_by ?b => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b,
#  ?a /sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/school ?f & ?f /sports/sports_team/roster./american_football/football_roster_position/position ?b => ?a /sports/sports_team/roster./american_football/football_roster_position/position ?b,
#  ?e /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a & ?e /film/film/film_festivals ?b => ?a /film/film/film_festivals ?b,
#  ?a /music/artist/track_contributions./music/track_contribution/role ?e & ?e /music/instrument/family ?b => ?a /music/group_member/membership./music/group_membership/role ?b,
#  ?a /dataworld/gardening_hint/split_to ?b & ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b => ?a /music/instrument/family ?b,
#  ?b /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?a => ?a /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?b,
#  ?a /film/actor/dubbing_performances./film/dubbing_performance/language ?b => ?a /people/person/languages ?b,
#  ?b /influence/influence_node/influenced_by ?f & ?a /music/instrument/instrumentalists ?f => ?a /music/instrument/instrumentalists ?b,
#  ?a /location/location/contains ?f & ?b /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?f => ?a /base/locations/continents/countries_within ?b,
#  ?e /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency ?b & ?e /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?a => ?a /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b,
#  ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?e /people/person/place_of_birth ?b => ?a /organization/organization/place_founded ?b,
#  ?e /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b & ?e /award/award_winning_work/awards_won./award/award_honor/award_winner ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a /dataworld/gardening_hint/split_to ?f & ?f /music/instrument/instrumentalists ?b => ?a /music/instrument/instrumentalists ?b,
#  ?e /olympics/olympic_games/medals_awarded./olympics/olympic_medal_honor/medal ?b & ?e /olympics/olympic_games/participating_countries ?a => ?a /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medal ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b & ?b /film/film/produced_by ?a => ?a /film/director/film ?b,
#  ?b /base/popstra/celebrity/dated./base/popstra/dated/participant ?a & ?b /people/person/spouse_s./people/marriage/spouse ?a => ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?b,
#  ?e /music/artist/contribution./music/recording_contribution/performance_role ?a & ?e /music/group_member/membership./music/group_membership/role ?b => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?b /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /location/hud_county_place/place ?b,
#  ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b & ?a /people/person/spouse_s./people/marriage/spouse ?b => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?f /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b & ?a /education/educational_institution_campus/educational_institution ?f => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?a /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?f & ?f /tv/tv_program/languages ?b => ?a /people/person/languages ?b,
#  ?f /base/biblioness/bibs_location/state ?b & ?a /location/us_county/county_seat ?f => ?a /base/biblioness/bibs_location/state ?b,
#  ?e /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b & ?a /music/performance_role/regular_performances./music/group_membership/role ?e => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?e /dataworld/gardening_hint/split_to ?a & ?e /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b => ?a /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?b /location/location/contains ?f => ?a /location/administrative_division/first_level_division_of ?b,
#  ?f /people/person/nationality ?b & ?a /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?f => ?a /film/film/runtime./film/film_cut/film_release_region ?b,
#  ?e /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/contact_category ?b & ?e /education/educational_institution_campus/educational_institution ?a => ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/contact_category ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?b /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f => ?a /award/award_winner/awards_won./award/award_honor/award_winner ?b,
#  ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a & ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b => ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b,
#  ?e /organization/organization/headquarters./location/mailing_address/country ?b & ?e /organization/organization/place_founded ?a => ?a /base/biblioness/bibs_location/country ?b,
#  ?a /location/location/contains ?f & ?f /location/us_county/county_seat ?b => ?a /base/aareas/schema/administrative_area/capital ?b,
#  ?a <http://rdf.freebase.com/ns/topic_server.population_number> ?f & ?b <http://rdf.freebase.com/ns/topic_server.population_number> ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?a /dataworld/gardening_hint/split_to ?f & ?f /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b => ?a /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b,
#  ?e /education/educational_institution/campuses ?a & ?e /education/university/local_tuition./measurement_unit/dated_money_value/currency ?b => ?a /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?f /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization/headquarters./location/mailing_address/citytown ?f => ?a /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b,
#  ?e /music/instrument/family ?a & ?e /music/performance_role/regular_performances./music/group_membership/role ?b => ?a /music/performance_role/track_performances./music/track_contribution/role ?b,
#  ?a /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant ?f & ?f /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b => ?a /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b,
#  ?e /location/administrative_division/country ?a & ?e /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b => ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b,
#  ?f /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?a & ?b /film/director/film ?f => ?a /film/film/executive_produced_by ?b,
#  ?e /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency ?b & ?e /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?a => ?a /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b,
#  ?b /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?a & ?b /film/film_distributor/films_distributed./film/film_film_distributor_relationship/film ?a => ?a /film/film/production_companies ?b,
#  ?a /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer ?f & ?f /people/person/spouse_s./people/marriage/spouse ?b => ?a /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer ?b,
#  ?f /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b & ?a /education/educational_institution/campuses ?f => ?a /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b,
#  ?e /organization/organization/headquarters./location/mailing_address/country ?b & ?e /organization/organization_member/member_of./organization/organization_membership/organization ?a => ?a /organization/organization/headquarters./location/mailing_address/country ?b,
#  ?a /base/popstra/celebrity/dated./base/popstra/dated/participant ?b & ?b /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?a => ?a /base/popstra/celebrity/breakup./base/popstra/breakup/participant ?b,
#  ?a /base/culturalevent/event/entity_involved ?b & ?a /military/military_conflict/combatants./military/military_combatant_group/combatants ?b => ?a /time/event/locations ?b,
#  ?e /base/biblioness/bibs_location/country ?b & ?a /language/human_language/countries_spoken_in ?e => ?a /language/human_language/countries_spoken_in ?b,
#  ?e /film/film/country ?a & ?e /film/film/runtime./film/film_cut/film_release_region ?b => ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b,
#  ?a /base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club ?f & ?f /sports/sports_team/sport ?b => ?a /sports/sports_team/sport ?b,
#  ?b /award/award_category/winners./award/award_honor/award_winner ?f & ?a /film/film/other_crew./film/film_crew_gig/crewmember ?f => ?a /award/award_winning_work/awards_won./award/award_honor/award ?b,
#  ?e /film/film/edited_by ?b & ?e /film/film/produced_by ?a => ?a /people/person/sibling_s./people/sibling_relationship/sibling ?b,
#  ?e /education/educational_institution_campus/educational_institution ?b & ?a /organization/role/leaders./organization/leadership/organization ?e => ?a /business/job_title/people_with_this_title./business/employment_tenure/company ?b,
# ...
#  ?f /location/hud_county_place/county ?b & ?a /location/hud_county_place/county ?f => ?a /location/hud_county_place/county ?b,
#  ?f /dataworld/gardening_hint/split_to ?a & ?b /education/educational_institution_campus/educational_institution ?f => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?a & ?e /location/hud_county_place/place ?b => ?a /location/us_county/county_seat ?b,
#  ?b /base/aareas/schema/administrative_area/administrative_parent ?f & ?f /location/administrative_division/first_level_division_of ?a => ?a /location/country/second_level_divisions ?b,
#  ?e /organization/organization/headquarters./location/mailing_address/country ?b & ?e /organization/organization/place_founded ?a => ?a /location/administrative_division/first_level_division_of ?b,
#  ?e /location/country/official_language ?b & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a => ?a /location/country/official_language ?b,
#  ?e /influence/influence_node/influenced_by ?b & ?a /music/performance_role/regular_performances./music/group_membership/group ?e => ?a /music/performance_role/regular_performances./music/group_membership/group ?b,
#  ?a /base/biblioness/bibs_location/country ?b & ?a /location/administrative_division/country ?b => ?a /base/aareas/schema/administrative_area/administrative_parent ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/award_winner ?a & ?e /film/film/country ?b => ?a /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office ?b,
#  ?b /education/educational_institution/students_graduates./education/education/student ?f & ?f /people/person/nationality ?a => ?a /location/location/contains ?b,
#  ?f /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b & ?a /education/educational_institution_campus/educational_institution ?f => ?a /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b,
#  ?f /location/administrative_division/first_level_division_of ?a & ?b /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /location/location/contains ?b,
#  ?f /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization_member/member_of./organization/organization_membership/organization ?f => ?a /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b,
#  ?a /film/film/production_companies ?f & ?b /organization/organization_founder/organizations_founded ?f => ?a /film/film/produced_by ?b,
#  ?f /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b & ?a /organization/organization_member/member_of./organization/organization_membership/organization ?f => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?f /business/business_operation/revenue./measurement_unit/dated_money_value/currency ?b & ?a /education/educational_institution/campuses ?f => ?a /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b,
#  ?a /base/aareas/schema/administrative_area/administrative_parent ?f & ?b /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?f => ?a /base/aareas/schema/administrative_area/capital ?b,
#  ?f /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?a /education/educational_institution/campuses ?f => ?a /education/university/domestic_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?e /film/film/country ?b & ?e /film/film/distributors./film/film_film_distributor_relationship/region ?a => ?a /dataworld/gardening_hint/split_to ?b,
#  ?e /music/instrument/family ?a & ?e /music/instrument/family ?b => ?a /dataworld/gardening_hint/split_to ?b,
#  ?a /location/hud_county_place/place ?f & ?b /location/hud_county_place/place ?f => ?a /location/us_county/county_seat ?b,
#  ?f /education/educational_institution/campuses ?a & ?b /location/location/contains ?f => ?a /organization/organization/headquarters./location/mailing_address/citytown ?b,
#  ?e /business/job_title/people_with_this_title./business/employment_tenure/company ?a & ?e /sports/sports_position/players./sports/sports_team_roster/position ?b => ?a /sports/sports_team/roster./american_football/football_roster_position/position ?b,
#  ?a /government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office ?e & ?e /location/hud_county_place/place ?b => ?a /government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office ?b,
#  ?f /influence/influence_node/influenced_by ?b & ?a /influence/influence_node/influenced_by ?f => ?a /influence/influence_node/influenced_by ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b => ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b,
#  ?f /base/aareas/schema/administrative_area/administrative_parent ?a & ?b /location/location/contains ?f => ?a /location/administrative_division/first_level_division_of ?b,
#  ?b /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?f /location/location/partially_contains ?a => ?a /dataworld/gardening_hint/split_to ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?b /film/film/written_by ?f => ?a /award/award_nominee/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a /base/popstra/celebrity/friendship./base/popstra/friendship/participant ?b & ?a /celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity ?b => ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b,
#  ?e /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?e /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?b => ?a /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members ?b,
#  ?b /base/popstra/celebrity/dated./base/popstra/dated/participant ?f & ?a /people/ethnicity/people ?f => ?a /people/ethnicity/people ?b,
#  ?b /award/award_winning_work/awards_won./award/award_honor/award_winner ?f & ?a /film/film/written_by ?f => ?a /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for ?b,
#  ?a /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?b & ?b /location/location/contains ?a => ?a /location/hud_county_place/county ?b,
#  ?e /sports/sports_position/players./sports/sports_team_roster/position ?b & ?e /sports/sports_position/players./sports/sports_team_roster/team ?a => ?a /ice_hockey/hockey_team/current_roster./sports/sports_team_roster/position ?b,
#  ?e /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b & ?e /location/location/adjoin_s./location/adjoining_relationship/adjoins ?a => ?a /education/university/international_tuition./measurement_unit/dated_money_value/currency ?b,
#  ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f & ?f /time/event/locations ?b => ?a /location/administrative_division/first_level_division_of ?b,
#  ?f /base/biblioness/bibs_location/state ?b & ?a /organization/organization/headquarters./location/mailing_address/citytown ?f => ?a /organization/organization/headquarters./location/mailing_address/state_province_region ?b,
#  ?a /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?f & ?f /organization/organization_member/member_of./organization/organization_membership/organization ?b => ?a /organization/organization_member/member_of./organization/organization_membership/organization ?b,
#  ?f /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?b & ?a /organization/organization/child./organization/organization_relationship/child ?f => ?a /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location ?b,
#  ?b /film/film/prequel ?a => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?f /business/business_operation/industry ?b & ?a /organization/organization/child./organization/organization_relationship/child ?f => ?a /business/business_operation/industry ?b,
#  ?e /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?e /education/educational_institution_campus/educational_institution ?a => ?a /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b,
#  ?f /film/director/film ?a & ?b /film/film/executive_produced_by ?f => ?a /award/award_winning_work/awards_won./award/award_honor/honored_for ?b,
#  ?e /business/business_operation/assets./measurement_unit/dated_money_value/currency ?b & ?e /education/educational_institution/students_graduates./education/education/student ?a => ?a /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency ?b,
#  ?e /dataworld/gardening_hint/split_to ?b & ?e /education/educational_institution/campuses ?a => ?a /education/educational_institution_campus/educational_institution ?b,
#  ?a /base/culturalevent/event/entity_involved ?f & ?b /military/military_combatant/military_conflicts./military/military_combatant_group/combatants ?f => ?a /military/military_conflict/combatants./military/military_combatant_group/combatants ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?e /film/film/film_production_design_by ?b => ?a /film/film/film_production_design_by ?b,
#  ?f /location/country/capital ?a & ?b /location/country/capital ?f => ?a /location/country/capital ?b,
#  ?a /location/location/contains ?f & ?f /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency ?b => ?a /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency ?b,
#  ?b /sports/sports_position/players./sports/sports_team_roster/team ?a & ?a /sports/sports_team/roster./american_football/football_roster_position/position ?b => ?a /american_football/football_team/current_roster./sports/sports_team_roster/position ?b,
#  ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?f & ?f /music/performance_role/track_performances./music/track_contribution/role ?b => ?a /music/performance_role/regular_performances./music/group_membership/role ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b & ?a /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?f => ?a /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/honored_for ?a & ?e /film/film/distributors./film/film_film_distributor_relationship/film_distribution_medium ?b => ?a /film/film/distributors./film/film_film_distributor_relationship/film_distribution_medium ?b,
#  ?a /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?f & ?f /music/group_member/membership./music/group_membership/role ?b => ?a /music/artist/track_contributions./music/track_contribution/role ?b,
#  ?b /award/award_winner/awards_won./award/award_honor/award_winner ?a & ?b /people/person/spouse_s./people/marriage/spouse ?a => ?a /people/person/spouse_s./people/marriage/spouse ?b,
#  ?a /award/award_category/winners./award/award_honor/award_winner ?e & ?e /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?b => ?a /award/award_category/winners./award/award_honor/award_winner ?b,
#  ?b /location/country/second_level_divisions ?f & ?a /location/location/adjoin_s./location/adjoining_relationship/adjoins ?f => ?a /location/administrative_division/country ?b,
#  ?b /music/artist/track_contributions./music/track_contribution/role ?a & ?b /music/group_member/membership./music/group_membership/role ?a => ?a /music/instrument/instrumentalists ?b,
#  ?b /business/job_title/people_with_this_title./business/employment_tenure/company ?f & ?f /sports/sports_team/roster./american_football/football_roster_position/position ?a => ?a /sports/sports_position/players./sports/sports_team_roster/position ?b,
#  ?e /government/politician/government_positions_held./government/government_position_held/legislative_sessions ?a & ?e /people/person/places_lived./people/place_lived/location ?b => ?a /government/legislative_session/members./government/government_position_held/district_represented ?b,
#  ?b /location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division ?f & ?a /location/location/contains ?f => ?a /base/aareas/schema/administrative_area/capital ?b,
#  ?e /business/business_operation/operating_income./measurement_unit/dated_money_value/currency ?b & ?e /media_common/netflix_genre/titles ?a => ?a /film/film/estimated_budget./measurement_unit/dated_money_value/currency ?b,
#  ?b /soccer/football_player/current_team./sports/sports_team_roster/team ?f & ?f /sports/sports_team/sport ?a => ?a /sports/sport/pro_athletes./sports/pro_sports_played/athlete ?b,
#  ?e /music/artist/track_contributions./music/track_contribution/role ?a & ?b /music/performance_role/regular_performances./music/group_membership/group ?e => ?a /music/performance_role/guest_performances./music/recording_contribution/performance_role ?b,
#  ?f /award/award_nominee/award_nominations./award/award_nomination/award_nominee ?a & ?b /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?f => ?a /tv/tv_producer/programs_produced./tv/tv_producer_term/program ?b,
#  ?a /film/film/prequel ?f & ?f /film/film/written_by ?b => ?a /film/film/edited_by ?b,
#  ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?f & ?f /people/person/sibling_s./people/sibling_relationship/sibling ?b => ?a /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend ?b,
#  ?e /film/film/featured_film_locations ?a & ?e /film/film/runtime./film/film_cut/film_release_region ?b => ?a /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to ?b,
#  ?f /business/job_title/people_with_this_title./business/employment_tenure/company ?a & ?b /sports/sports_position/players./american_football/football_historical_roster_position/position_s ?f => ?a /sports/sports_team/roster./american_football/football_historical_roster_position/position_s ?b,
#  ?b /location/location/contains ?f & ?f /organization/organization/headquarters./location/mailing_address/citytown ?a => ?a /base/biblioness/bibs_location/state ?b,
#  ?e /location/hud_county_place/county ?b & ?a /location/location/contains ?e => ?a /location/location/contains ?b,
#  ?e /organization/organization/headquarters./location/mailing_address/citytown ?a & ?e /organization/organization/headquarters./location/mailing_address/state_province_region ?b => ?a /base/biblioness/bibs_location/state ?b,
#  ?f /film/film/featured_film_locations ?b & ?a /media_common/netflix_genre/titles ?f => ?a /location/country/capital ?b,
#  ?e /award/award_winning_work/awards_won./award/award_honor/award ?b & ?e /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor ?a => ?a /award/award_nominee/award_nominations./award/award_nomination/award ?b,
#  ?f /sports/sports_position/players./sports/sports_team_roster/position ?b & ?a /sports/sports_team/roster./american_football/football_roster_position/position ?f => ?a /american_football/football_team/current_roster./sports/sports_team_roster/position ?b,
#  ...}
