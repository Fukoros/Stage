# %%
import pandas as pd
import numpy as np
import sklearn.tree as tree
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os.path
from os import path
from sklearn.model_selection import KFold
from multiprocessing import Process, Manager
import multiprocessing
from sklearn.metrics import accuracy_score

# %% [markdown]
# # 1° Load data

# %%
data = pd.read_csv("Data/miniloan-decisions-100K.csv")

# %%
data
# Out:
#            name  creditScore  income  loanAmount  monthDuration      rate  \
# 0      John Doe          736  113243      783440            162  0.030005
# 1      John Doe          527  224186     1787385            183  0.054819
# 2      John Doe          460   39954     1733494             75  0.055183
# 3      John Doe          751  219998     1350004             72  0.043400
# 4      John Doe          684   72470     1210944            160  0.037772
# ...         ...          ...     ...         ...            ...       ...
# 99995  John Doe          366   83851     1718571            168  0.053737
# 99996  John Doe          395  184259     1599473             90  0.040564
# 99997  John Doe          674  242620     1099790            260  0.040825
# 99998  John Doe          420  180957     1645870            203  0.049558
# 99999  John Doe          699  102769      665190            244  0.058460
#
#       approval  yearlyReimbursement
# 0        false                70648
# 1        false               173197
# 2        false               328563
# 3        false               255970
# 4        false               115742
# ...        ...                  ...
# 99995    false               174928
# 99996    false               247703
# 99997    false                76557
# 99998    false               143897
# 99999    false                55993
#
# [100000 rows x 8 columns]

# %% [markdown]
# # Ratios

# %%
#['name', 'creditScore', 'income', 'loanAmount', 'monthDuration', 'rate', 'approval', 'yearlyReimbursement']

ratioNames = [("income","yearlyReimbursement"), ("income","loanAmount"), ("loanAmount","rate")]

# %%
def createFeaturesRatio(data):
    if data[data.index[1]] == 0:
        return 2147483647
    return np.round(data[data.index[0]]/data[data.index[1]], decimals=2)

# %%
for ratioName in ratioNames:
    data[f"{ratioName[0]}/{ratioName[1]}"] = data[[ratioName[0], ratioName[1]]].apply(createFeaturesRatio, axis=1)

# %%
data
# Out:
#            name  creditScore  income  loanAmount  monthDuration      rate  \
# 0      John Doe          736  113243      783440            162  0.030005
# 1      John Doe          527  224186     1787385            183  0.054819
# 2      John Doe          460   39954     1733494             75  0.055183
# 3      John Doe          751  219998     1350004             72  0.043400
# 4      John Doe          684   72470     1210944            160  0.037772
# ...         ...          ...     ...         ...            ...       ...
# 99995  John Doe          366   83851     1718571            168  0.053737
# 99996  John Doe          395  184259     1599473             90  0.040564
# 99997  John Doe          674  242620     1099790            260  0.040825
# 99998  John Doe          420  180957     1645870            203  0.049558
# 99999  John Doe          699  102769      665190            244  0.058460
#
#       approval  yearlyReimbursement  income/yearlyReimbursement  \
# 0        false                70648                        1.60
# 1        false               173197                        1.29
# 2        false               328563                        0.12
# 3        false               255970                        0.86
# 4        false               115742                        0.63
# ...        ...                  ...                         ...
# 99995    false               174928                        0.48
# 99996    false               247703                        0.74
# 99997    false                76557                        3.17
# 99998    false               143897                        1.26
# 99999    false                55993                        1.84
#
#        income/loanAmount  loanAmount/rate
# 0                   0.14      26110372.80
# 1                   0.13      32605003.59
# 2                   0.02      31413368.70
# 3                   0.16      31106073.81
# 4                   0.06      32059172.14
# ...                  ...              ...
# 99995               0.05      31981153.44
# 99996               0.12      39430859.20
# 99997               0.22      26938940.88
# 99998               0.11      33211031.24
# 99999               0.15      11378481.46
#
# [100000 rows x 11 columns]

# %% [markdown]
# # 2° Find the best thresholds

# %%
data_raw = data.drop(columns=["name"])
false_data = data_raw[data_raw["approval"] == " false"]
true_data = data_raw[data_raw["approval"] == " true"]
data_equilibrium = true_data.append(false_data.sample(n=len(true_data)))

# %%
# %%time

def returnSplitValue(stringToSplit):
    res = []
    tp = ""
    spliters = [("lt", "< "), ("lte", "<= "), ("gt", "> "), ("gte", ">= ")]
    i=0
    
    while i < len(spliters):
        splited = stringToSplit.split(spliters[i][1]) 
        if len(splited) == 2:
            return  spliters[i][0], float(splited[1])
        i += 1
    print("C'est casse")
    return None 


best_threshold = []
for key in data_equilibrium.keys():
    if key != "approval":
        print("\t\t"+key)
        X = data_equilibrium[[key]]

        Y = data_equilibrium["approval"]

        X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)
        
        model = tree.DecisionTreeClassifier(max_depth=1)
        model.fit(X_train, y_train)    

        print(f"Train Score : {accuracy_score(y_train, model.predict(X_train))}")
        print(f"Test Score : {accuracy_score(y_test, model.predict(X_test))}")
        
        if accuracy_score(y_train, model.predict(X_train)) > 0.8 and accuracy_score(y_test, model.predict(X_test)) > 0.8:
            best_threshold.append((key,)+ returnSplitValue(tree.export_text(model, spacing=1, feature_names=[key]).split("\n")[0]))
print(best_threshold)
# Out:
# 		creditScore
# Train Score : 0.5037392072880549
# Test Score : 0.5026224982746722
# 		income
# Train Score : 0.6431096607519206
# Test Score : 0.6387853692201518
# 		loanAmount
# Train Score : 0.8434631858046094
# Test Score : 0.8481021394064873
# 		monthDuration
# Train Score : 0.6182609286831192
# Test Score : 0.605175983436853
# 		rate
# Train Score : 0.5105717587871371
# Test Score : 0.5075224292615597
# 		yearlyReimbursement
# Train Score : 0.8992453599836835
# Test Score : 0.8984817115251897
# 		income/yearlyReimbursement
# Train Score : 0.9938812971650011
# Test Score : 0.9913733609385783
# 		income/loanAmount
# Train Score : 0.9240261064654294
# Test Score : 0.9256038647342996
# 		loanAmount/rate
# Train Score : 0.8277585151947787
# Test Score : 0.8291235334713596
# [('loanAmount', 'lte', 829730.5), ('yearlyReimbursement', 'lte', 66647.5), ('income/yearlyReimbursement', 'lte', 3.32), ('income/loanAmount', 'lte', 0.24), ('loanAmount/rate', 'lte', 17692737.0)]
# CPU times: user 1.3 s, sys: 0 ns, total: 1.3 s
# Wall time: 1.3 s

# %% [markdown]
# # 3° Create the thresholds

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
def fromColumnToColumnPercent(name, percents):
    res = []
    for i in percents:
        res.extend([name[0]+i]*(len(percents)**(len(name)-1))) 
    return res

# %%
def descriptionDiffThresholds(data, percents):
    thresholds_Dic =  {}
    for column in data.columns:
        serie = data[column]
        thresholds_Dic[column] = serie.quantile(percents)
        
    return pd.DataFrame.from_dict(thresholds_Dic)

# %%
def GTE_prep_df(value, valueToCompareTo):
    return value >= valueToCompareTo

def LTE_prep_df(value, valueToCompareTo):
    return value <= valueToCompareTo

def GT_prep_df(value, valueToCompareTo):
    return value > valueToCompareTo

def LT_prep_df(value, valueToCompareTo):
    return value < valueToCompareTo

# %%
columns = list(data.drop(columns=["name", "approval"]).columns)

booleanDF = pd.DataFrame()

for column, comparator, value in best_threshold:
    if comparator == "lte" or comparator == "gt":
        booleanDF[column+"-GT-"+str(value)] = data[column].map(lambda x : GT_prep_df(x, value))
        booleanDF[column+"-LTE-"+str(value)] = data[column].map(lambda x : LTE_prep_df(x, value))
    else:
        booleanDF[column+"-GTE-"+str(value)] = data[column].map(lambda x : GTE_prep_df(x, value))
        booleanDF[column+"-LT-"+str(value)] = data[column].map(lambda x : LT_prep_df(x, value))
    columns.remove(column)

# %%
# %%time

description = descriptionDiffThresholds(data[columns], thresholds)

for column in columns:
    for i, value in enumerate(thresholds):
        booleanDF[column+"-GTE-"+str(int(value*100))+"%"] = data[column].map(lambda x : GTE_prep_df(x, description[column].values[i]))
        booleanDF[column+"-LTE-"+str(int(value*100))+"%"] = data[column].map(lambda x : LTE_prep_df(x, description[column].values[i]))
# Out:
# CPU times: user 7.03 s, sys: 31.2 ms, total: 7.06 s
# Wall time: 7.04 s

# %%
booleanDF["approval"] = data["approval"].map({' true': True, ' false': False})
booleanDF
# Out:
#        loanAmount-GT-829730.5  loanAmount-LTE-829730.5  \
# 0                       False                     True
# 1                        True                    False
# 2                        True                    False
# 3                        True                    False
# 4                        True                    False
# ...                       ...                      ...
# 99995                    True                    False
# 99996                    True                    False
# 99997                    True                    False
# 99998                    True                    False
# 99999                   False                     True
#
#        yearlyReimbursement-GT-66647.5  yearlyReimbursement-LTE-66647.5  \
# 0                                True                            False
# 1                                True                            False
# 2                                True                            False
# 3                                True                            False
# 4                                True                            False
# ...                               ...                              ...
# 99995                            True                            False
# 99996                            True                            False
# 99997                            True                            False
# 99998                            True                            False
# 99999                           False                             True
#
#        income/yearlyReimbursement-GT-3.32  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 99995                               False
# 99996                               False
# 99997                               False
# 99998                               False
# 99999                               False
#
#        income/yearlyReimbursement-LTE-3.32  income/loanAmount-GT-0.24  \
# 0                                     True                      False
# 1                                     True                      False
# 2                                     True                      False
# 3                                     True                      False
# 4                                     True                      False
# ...                                    ...                        ...
# 99995                                 True                      False
# 99996                                 True                      False
# 99997                                 True                      False
# 99998                                 True                      False
# 99999                                 True                      False
#
#        income/loanAmount-LTE-0.24  loanAmount/rate-GT-17692737.0  \
# 0                            True                           True
# 1                            True                           True
# 2                            True                           True
# 3                            True                           True
# 4                            True                           True
# ...                           ...                            ...
# 99995                        True                           True
# 99996                        True                           True
# 99997                        True                           True
# 99998                        True                           True
# 99999                        True                          False
#
#        loanAmount/rate-LTE-17692737.0  ...  monthDuration-LTE-50%  \
# 0                               False  ...                   True
# 1                               False  ...                  False
# 2                               False  ...                   True
# 3                               False  ...                   True
# 4                               False  ...                   True
# ...                               ...  ...                    ...
# 99995                           False  ...                   True
# 99996                           False  ...                   True
# 99997                           False  ...                  False
# 99998                           False  ...                  False
# 99999                            True  ...                  False
#
#        monthDuration-GTE-75%  monthDuration-LTE-75%  rate-GTE-25%  \
# 0                      False                   True         False
# 1                      False                   True          True
# 2                      False                   True          True
# 3                      False                   True          True
# 4                      False                   True          True
# ...                      ...                    ...           ...
# 99995                  False                   True          True
# 99996                  False                   True          True
# 99997                  False                   True          True
# 99998                  False                   True          True
# 99999                  False                   True          True
#
#        rate-LTE-25%  rate-GTE-50%  rate-LTE-50%  rate-GTE-75%  rate-LTE-75%  \
# 0              True         False          True         False          True
# 1             False          True         False          True         False
# 2             False          True         False          True         False
# 3             False         False          True         False          True
# 4             False         False          True         False          True
# ...             ...           ...           ...           ...           ...
# 99995         False          True         False          True         False
# 99996         False         False          True         False          True
# 99997         False         False          True         False          True
# 99998         False          True         False         False          True
# 99999         False          True         False          True         False
#
#        approval
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 99995     False
# 99996     False
# 99997     False
# 99998     False
# 99999     False
#
# [100000 rows x 35 columns]

# %%
booleanDF.columns
# Out:
# Index(['loanAmount-GT-829730.5', 'loanAmount-LTE-829730.5',
#        'yearlyReimbursement-GT-66647.5', 'yearlyReimbursement-LTE-66647.5',
#        'income/yearlyReimbursement-GT-3.32',
#        'income/yearlyReimbursement-LTE-3.32', 'income/loanAmount-GT-0.24',
#        'income/loanAmount-LTE-0.24', 'loanAmount/rate-GT-17692737.0',
#        'loanAmount/rate-LTE-17692737.0', 'creditScore-GTE-25%',
#        'creditScore-LTE-25%', 'creditScore-GTE-50%', 'creditScore-LTE-50%',
#        'creditScore-GTE-75%', 'creditScore-LTE-75%', 'income-GTE-25%',
#        'income-LTE-25%', 'income-GTE-50%', 'income-LTE-50%', 'income-GTE-75%',
#        'income-LTE-75%', 'monthDuration-GTE-25%', 'monthDuration-LTE-25%',
#        'monthDuration-GTE-50%', 'monthDuration-LTE-50%',
#        'monthDuration-GTE-75%', 'monthDuration-LTE-75%', 'rate-GTE-25%',
#        'rate-LTE-25%', 'rate-GTE-50%', 'rate-LTE-50%', 'rate-GTE-75%',
#        'rate-LTE-75%', 'approval'],
#       dtype='object')

# %% [markdown]
# # 3° Save the best data

# %%
def intToStrIDS(idsInt):
    res = chr(97+idsInt%26)
    idsReducted = int(idsInt/26)
    while idsReducted != 0:
        res = chr(97+(idsReducted-1)%26) + res
        idsReducted = int(idsReducted/26)
    return res

def syntax(subject, predicate, objectD):
    return f"{subject}\t{predicate}\t{objectD} \n"#f"{intToStrIDS(subject)}\t{predicate}\t{objectD} \n"

def formatData(f, idData, data):
    toWrite = ""
    for i in data.index:
        if i != "approval":
            toWrite += syntax(idData, i, data.loc[i])
    if data.loc["approval"]:
        toWrite += syntax(idData, "approval-True", True)
    else:
        toWrite += syntax(idData, "approval-False", False)
    f.write(toWrite)

# %%
f = open("Knowledge_Data.tsv", "w")

booleanDF_to_Save = booleanDF
booleanDF_to_Save["approval"] = data["approval"].map({' true': True, ' false': False})

for idData in booleanDF_to_Save.index:
    formatData(f, idData, booleanDF_to_Save.iloc[idData])
    
f.close()

# %% [markdown]
# ## Save in cross validation

# %%
import shutil

root = "./../data_cv_Tree/"
cv = 3

if not path.isdir(root):
    os.mkdir(root)
else : 
    shutil.rmtree(root)
    os.mkdir(root)
    
booleanDF_to_Save = booleanDF
booleanDF_to_Save["approval"] = data["approval"].map({' true': True, ' false': False})

booleanDF.to_csv("./../data_cv_Tree/dfSave.csv")

kf = KFold(n_splits=cv, shuffle=True, random_state=42)
kf.get_n_splits(booleanDF_to_Save)

cp = 0

for train_index, test_index in kf.split(booleanDF_to_Save):
    
    f = open(root+f"CV_train_{cp}.tsv", "w")

    for idData in train_index:
        formatData(f, idData, booleanDF_to_Save.iloc[idData])

    f.close()
    
    print("Train repartition",booleanDF_to_Save.iloc[train_index]["approval"].value_counts())
    
    f = open(root+f"CV_valid_{cp}.tsv", "w")

    for idData in test_index:
        formatData(f, idData, booleanDF_to_Save.iloc[idData])

    f.close()
    
    f = open(root+f"index_{cp}.tsv", "w")

    f.write(str(train_index[0]))
    for i in range(1,len(train_index)):
        f.write(","+str(train_index[i]))
    f.write("\n")
    f.write(str(test_index[0]))
    for i in range(1,len(test_index)):
        f.write(","+str(test_index[i]))

    f.close()
    
    cp += 1
# Out:
# Train repartition False    52004
# True     14662
# Name: approval, dtype: int64
# Train repartition False    52007
# True     14660
# Name: approval, dtype: int64
# Train repartition False    52081
# True     14586
# Name: approval, dtype: int64

# %% [markdown]
# # 4° Launch Amie

# %%
root = "./../data_cv_tree/"
cv = 3
atom_LIST = [2,3]
minc_LIST = [0,0.3,0.6,0.9]
minhc_LIST = [0, 0.3, 0.6,0.9]

# %%
class Atom:
    
    def __init__(self, atom_raw):
        self._subject = atom_raw[0][1:]
        self._predicate = atom_raw[1]
        self._objectD = atom_raw[2][1:]
        
    def __hash__(self):
        return hash((self._subject, self._predicate, self._objectD))
    
    def __repr__(self):
        return f"{self.subject} {self.predicate} {self.objectD}"
    
    def __eq__(self, other):
        return self.subject==other.subject and self.predicate==other.predicate and self.objectD==other.objectD
        
    @property
    def subject(self):
        return self._subject
    
    @property
    def predicate(self):
        return self._predicate
    
    @property
    def objectD(self):
        return self._objectD
    
class Rule:
    
    def __init__(self, hypotheses, conclusion, otherRes):
        if not isinstance(hypotheses, tuple):
            self._hypotheses = tuple(hypotheses)
        else : 
            self._hypotheses = hypotheses
        self._conclusion = conclusion
        self._headCoverage = float(otherRes[0])
        self._stdConfidence = float(otherRes[1])
        self._pcaConfidence = float(otherRes[2])
        self._precision_train = None
        self._precision_test = None
        
        
    def __hash__(self):
        return hash((self._hypotheses, self._conclusion))
        
    def __repr__(self):
        toWrite=""
        for atom in self.hypotheses:
            toWrite += f"{atom} & "
        toWrite = toWrite[:-3] + " => " 
        toWrite += str(self.conclusion)
        return toWrite

    def __eq__(self, other):
        if not isinstance(other, Rule):
            return False
        return (self.conclusion == other.conclusion) and (set(self.hypotheses) == set(other.hypotheses))
    
    @property
    def hypotheses(self):
        return self._hypotheses
    
    @property
    def conclusion(self):
        return self._conclusion
    
    @property
    def headCoverage(self):
        return self._headCoverage
    
    @property
    def stdConfidence(self):
        return self._stdConfidence
    
    @property
    def pcaConfidence(self):
        return self._pcaConfidence
    
    @property
    def precision_train(self):
        return self._precision_train
    
    @property
    def precision_test(self):
        return self._precision_test
    
    def setPrecisionTrain(self, precision):
        self._precision_train = precision
    
    def setPrecisionTest(self, precision):
        self._precision_test = precision
        
    def toDict(self):
        return {"hypotheses":self._hypotheses, "conclusion":self._conclusion, "headCoverage":self._headCoverage, "stdConfidence":self._stdConfidence, "pcaConfidence":self._pcaConfidence, "precision_train": self._precision_train, "precision_test":self._precision_test}

# %%
# %%capture captured

sep = "-----------------------------"

parameters = []

for i in range(cv):
    for atom in atom_LIST:
        data = f"{root}CV_train_{i}.tsv"
        # !java -jar amie3.jar -htr approval-True,approval-False -maxad $atom $data
        parameters.append(f"CV={i}-A={atom}")
        print(sep)

# %%
#captured.stdout

# %%
rules_per_cv = {}
cpt = 0
for cv_res in captured.stdout.split(sep)[:-1]:
    rules = set()
    for line in cv_res.split("\n"):
        if (line != "") and (line[0] == "?"):
            dic = {}
            parts = line.split("\t")

            conclusion_raw = parts[0].split("=>")[1].split("  ")
            conclusion_raw[0] = conclusion_raw[0][1:]
            dic["conclusion"] = Atom(conclusion_raw)

            hypotheses_raw = parts[0].split("=>")[0].split("  ")
            hypotheses = []
            for i in range(0, len(hypotheses_raw)-1, 3):
                hypotheses.append(Atom(hypotheses_raw[i:i+3]))
            dic["hypotheses"] = hypotheses


            rules.add(Rule(dic["hypotheses"], dic["conclusion"], parts[1:]))
    rules_per_cv[parameters[cpt]] = rules
    cpt+=1

# %%
score_ressemblance = []
for i, para_1 in enumerate(parameters):
    for j, para_2 in enumerate(parameters[i+1:]):
        score_ressemblance.append(len(rules_per_cv[para_1].intersection(rules_per_cv[para_2]))/len(rules_per_cv[para_1].union(rules_per_cv[para_2]))*100)
print(f"We have a mean of {np.round(np.mean(score_ressemblance),3)}")
print(f"We have a std of {np.round(np.std(score_ressemblance),3)}")
# Out:
# We have a mean of 49.911
# We have a std of 37.833

# %% [markdown]
# # Prediction

# %%
# def prediction_right(X, truth):
#     if X["approval"] !=  truth:
#         return "Not an example"
#     else :
#         sum_X = sum(X)
#         return str(sum_X == len(X) or sum_X == 0)
    
def prediction_right(X, truth):
    if truth:
        if sum(X.iloc[:-1]) == len(X)-1:
            return str(X["approval"])
        return "Can't say anything"
    else : 
        if sum(X.iloc[:-1]) == 0:
            return str(not X["approval"])
        return "Can't say anything"

# %%
def computePrecision(rules, df, rules_result, index, cptShared, train_index, test_index):
    print(f"Process n°{index} : Launched")
    
    for cpt, rule in enumerate(rules):  
        columns = [rule.hypotheses[k].predicate for k in range(len(rule.hypotheses))]
        columns.append("approval")

        res = []
        
        try:
            if (rule.conclusion.predicate == "approval-True"):
                res = df[columns].loc[train_index].apply(func=prediction_right, axis=1, truth=True).value_counts()
            else :
                res = df[columns].loc[train_index].apply(func=prediction_right, axis=1, truth=False).value_counts()
        except:
            print(columns)
            print(df)
            
            
        if not "False" in res.index:
            res["False"] = 0
            
        if not "True" in res.index:
            res["True"] = 0
            
        rule.setPrecisionTrain(res["True"] / (res["True"]+res["False"]))

        if (rule.conclusion.predicate == "approval-True"):
            res = df[columns].loc[test_index].apply(func=prediction_right, axis=1, truth=True).value_counts()
        else :
            res = df[columns].loc[test_index].apply(func=prediction_right, axis=1, truth=False).value_counts()
            
        if not "False" in res.index:
            res["False"] = 0
            
        if not "True" in res.index:
            res["True"] = 0

        rule.setPrecisionTest(res["True"] / (res["True"]+res["False"]))
        
        rules_result[str(rule)] = rule
        
        cptShared.value += 1
        if (cptShared.value%100 == 0):
            print(cptShared)
        
    print(f"Process n°{index} : Finished")

# %%
# %%time

from multiprocessing import Process, Manager
import multiprocessing

names = []
rules_per_CV = {}

df = pd.read_csv("./../data_cv_Tree/dfSave.csv", index_col=0)

for para in parameters:
    with Manager() as manager:
        rules = rules_per_cv[para]

        i = 0
        f = open(f"{root}index_{i}.tsv", "r")

        lines = f.readlines()
        train_index = np.array(list(map(int, lines[0].split(","))))
        test_index = np.array(list(map(int, lines[1].split(","))))

        f.close()

        rules_result =  manager.dict()

        cpt_total = manager.Value("d",0)

        processes_to_create = multiprocessing.cpu_count()-3
        processes = list()

        rules_list = list(rules)

        for index in range(processes_to_create):
            x = Process(target=computePrecision, args=(rules_list[int(np.floor(index*len(rules_list)/processes_to_create)): int(np.floor((index+1)*len(rules_list)/processes_to_create))], df, rules_result, index, cpt_total, train_index, test_index))
            processes.append(x)
            x.start()

        for index, process in enumerate(processes):
            process.join()
        
        rules_per_CV[para] = rules_result.copy()
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°2 : Finished
# Process n°7 : Finished
# Process n°5 : Finished
# Process n°10 : Finished
# Process n°0 : Finished
# Process n°3 : Finished
# Process n°8 : Finished
# Process n°12 : Finished
# Process n°6 : Finished
# Process n°1 : Finished
# Process n°9 : Finished
# Process n°11 : Finished
# Process n°4 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 100)
# Value('d', 200)
# Value('d', 300)
# Process n°0 : Finished
# Process n°1 : Finished
# Process n°5 : Finished
# Process n°11 : Finished
# Process n°3 : Finished
# Process n°9 : Finished
# Process n°7 : Finished
# Process n°8 : Finished
# Process n°2 : Finished
# Process n°4 : Finished
# Process n°12 : Finished
# Process n°6 : Finished
# Process n°10 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°2 : Finished
# Process n°5 : FinishedProcess n°0 : Finished
#
# Process n°10 : Finished
# Process n°7 : Finished
# Process n°3 : Finished
# Process n°12 : Finished
# Process n°1 : Finished
# Process n°8 : Finished
# Process n°6 : Finished
# Process n°9 : Finished
# Process n°11 : Finished
# Process n°4 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : LaunchedProcess n°4 : Launched
# Process n°5 : Launched
#
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 100)
# Value('d', 200)
# Value('d', 300)
# Process n°1 : Finished
# Process n°11 : Finished
# Process n°8 : Finished
# Process n°3 : Finished
# Process n°4 : Finished
# Process n°0 : Finished
# Process n°9 : Finished
# Process n°6 : Finished
# Process n°7 : Finished
# Process n°2 : Finished
# Process n°5 : Finished
# Process n°10 : Finished
# Process n°12 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°10 : Finished
# Process n°7 : Finished
# Process n°2 : Finished
# Process n°5 : Finished
# Process n°0 : Finished
# Process n°8 : Finished
# Process n°9 : Finished
# Process n°11 : FinishedProcess n°3 : Finished
#
# Process n°1 : Finished
# Process n°4 : Finished
# Process n°6 : Finished
# Process n°12 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 100)
# Value('d', 200)
# Process n°0 : Finished
# Process n°9 : Finished
# Process n°6 : Finished
# Process n°3 : Finished
# Process n°1 : Finished
# Value('d', 300)
# Process n°5 : Finished
# Process n°10 : Finished
# Process n°8 : Finished
# Process n°11 : Finished
# Process n°4 : Finished
# Process n°2 : Finished
# Process n°12 : Finished
# Process n°7 : Finished
# CPU times: user 344 ms, sys: 2.78 s, total: 3.12 s
# Wall time: 7min 56s

# %% [markdown]
# ### Mean cross

# %%
def mean_rules(rules):
    headCoverage = []
    stdConfidence = []
    pcaConfidence = []
    precision_train = []
    precision_test = []
    for r in rules: 
        headCoverage.append(r.headCoverage)
        stdConfidence.append(r.stdConfidence)
        pcaConfidence.append(r.pcaConfidence)
        precision_train.append(r.precision_train)
        precision_test.append(r.precision_test)
    res = Rule(rules[0].hypotheses, rules[0].conclusion, [np.mean(headCoverage), np.mean(stdConfidence), np.mean(pcaConfidence)])
    res.setPrecisionTrain(np.mean(precision_train))
    res.setPrecisionTest(np.mean(precision_test))
    return res

# %%
rules_per_para = {}

for atom in atom_LIST:
    post_para = f"-A={atom}"
    allRules = set(rules_per_CV[f"CV={0}"+post_para])
    
    for i in range(1,cv):
        allRules = allRules.intersection(set(rules_per_CV[f"CV={i}"+post_para]))
        
    allRulesMean = {}
    for rule in allRules:
        allRulesMean[rule] = mean_rules([rules_per_CV[f"CV={i}"+post_para][rule] for i in range(cv)])
        
    rules_per_para[post_para] = allRulesMean

# %% [markdown]
# ### Add parameters

# %%
def limitByThreshold(X, parameter, threshold):
    return X[parameter] >= threshold

# %%
to_df = {}
for r in rules_per_para["-A=2"]:
    to_df[r] = rules_per_para["-A=2"][r].toDict()
pd.DataFrame.from_dict(to_df, orient="index")
# Out:
#                                                                                    hypotheses  \
# a income/loanAmount-GT-0.24 b => a approval-Fal...           (a income/loanAmount-GT-0.24 b,)
# a creditScore-GTE-50% b => a approval-True b                       (a creditScore-GTE-50% b,)
# a rate-GTE-25% b => a approval-True b                                     (a rate-GTE-25% b,)
# a creditScore-LTE-75% b => a approval-False b                      (a creditScore-LTE-75% b,)
# a monthDuration-GTE-75% b => a approval-False b                  (a monthDuration-GTE-75% b,)
# a income/loanAmount-LTE-0.24 b => a approval-Fa...          (a income/loanAmount-LTE-0.24 b,)
# a income-LTE-50% b => a approval-False b                                (a income-LTE-50% b,)
# a loanAmount-LTE-829730.5 b => a approval-False b              (a loanAmount-LTE-829730.5 b,)
# a monthDuration-LTE-25% b => a approval-False b                  (a monthDuration-LTE-25% b,)
# a income-LTE-25% b => a approval-False b                                (a income-LTE-25% b,)
# a rate-GTE-75% b => a approval-False b                                    (a rate-GTE-75% b,)
# a rate-GTE-75% b => a approval-True b                                     (a rate-GTE-75% b,)
# a rate-GTE-50% b => a approval-False b                                    (a rate-GTE-50% b,)
# a creditScore-LTE-50% b => a approval-True b                       (a creditScore-LTE-50% b,)
# a loanAmount/rate-GT-17692737.0 b => a approval...       (a loanAmount/rate-GT-17692737.0 b,)
# a creditScore-LTE-50% b => a approval-False b                      (a creditScore-LTE-50% b,)
# a loanAmount-GT-829730.5 b => a approval-False b                (a loanAmount-GT-829730.5 b,)
# a creditScore-GTE-75% b => a approval-True b                       (a creditScore-GTE-75% b,)
# a income-GTE-25% b => a approval-False b                                (a income-GTE-25% b,)
# a rate-GTE-25% b => a approval-False b                                    (a rate-GTE-25% b,)
# a monthDuration-GTE-50% b => a approval-False b                  (a monthDuration-GTE-50% b,)
# a monthDuration-GTE-50% b => a approval-True b                   (a monthDuration-GTE-50% b,)
# a income-LTE-75% b => a approval-True b                                 (a income-LTE-75% b,)
# a creditScore-GTE-25% b => a approval-False b                      (a creditScore-GTE-25% b,)
# a income-LTE-75% b => a approval-False b                                (a income-LTE-75% b,)
# a income-GTE-50% b => a approval-False b                                (a income-GTE-50% b,)
# a rate-LTE-75% b => a approval-True b                                     (a rate-LTE-75% b,)
# a yearlyReimbursement-LTE-66647.5 b => a approv...     (a yearlyReimbursement-LTE-66647.5 b,)
# a loanAmount/rate-LTE-17692737.0 b => a approva...      (a loanAmount/rate-LTE-17692737.0 b,)
# a yearlyReimbursement-LTE-66647.5 b => a approv...     (a yearlyReimbursement-LTE-66647.5 b,)
# a creditScore-GTE-50% b => a approval-False b                      (a creditScore-GTE-50% b,)
# a rate-LTE-75% b => a approval-False b                                    (a rate-LTE-75% b,)
# a income-GTE-50% b => a approval-True b                                 (a income-GTE-50% b,)
# a monthDuration-GTE-75% b => a approval-True b                   (a monthDuration-GTE-75% b,)
# a creditScore-GTE-25% b => a approval-True b                       (a creditScore-GTE-25% b,)
# a income-GTE-75% b => a approval-True b                                 (a income-GTE-75% b,)
# a monthDuration-GTE-25% b => a approval-True b                   (a monthDuration-GTE-25% b,)
# a income-GTE-25% b => a approval-True b                                 (a income-GTE-25% b,)
# a income/loanAmount-GT-0.24 b => a approval-True b           (a income/loanAmount-GT-0.24 b,)
# a income-LTE-50% b => a approval-True b                                 (a income-LTE-50% b,)
# a rate-LTE-25% b => a approval-False b                                    (a rate-LTE-25% b,)
# a creditScore-LTE-25% b => a approval-True b                       (a creditScore-LTE-25% b,)
# a monthDuration-GTE-25% b => a approval-False b                  (a monthDuration-GTE-25% b,)
# a rate-LTE-50% b => a approval-True b                                     (a rate-LTE-50% b,)
# a income-GTE-75% b => a approval-False b                                (a income-GTE-75% b,)
# a monthDuration-LTE-75% b => a approval-True b                   (a monthDuration-LTE-75% b,)
# a rate-GTE-50% b => a approval-True b                                     (a rate-GTE-50% b,)
# a monthDuration-LTE-50% b => a approval-False b                  (a monthDuration-LTE-50% b,)
# a loanAmount-LTE-829730.5 b => a approval-True b               (a loanAmount-LTE-829730.5 b,)
# a creditScore-GTE-75% b => a approval-False b                      (a creditScore-GTE-75% b,)
# a monthDuration-LTE-50% b => a approval-True b                   (a monthDuration-LTE-50% b,)
# a rate-LTE-50% b => a approval-False b                                    (a rate-LTE-50% b,)
# a loanAmount/rate-LTE-17692737.0 b => a approva...      (a loanAmount/rate-LTE-17692737.0 b,)
# a income/yearlyReimbursement-GT-3.32 b => a app...  (a income/yearlyReimbursement-GT-3.32 b,)
# a creditScore-LTE-75% b => a approval-True b                       (a creditScore-LTE-75% b,)
# a creditScore-LTE-25% b => a approval-False b                      (a creditScore-LTE-25% b,)
# a income/yearlyReimbursement-GT-3.32 b => a app...  (a income/yearlyReimbursement-GT-3.32 b,)
# a yearlyReimbursement-GT-66647.5 b => a approva...      (a yearlyReimbursement-GT-66647.5 b,)
# a rate-LTE-25% b => a approval-True b                                     (a rate-LTE-25% b,)
# a monthDuration-LTE-75% b => a approval-False b                  (a monthDuration-LTE-75% b,)
#
#                                                             conclusion  \
# a income/loanAmount-GT-0.24 b => a approval-Fal...  a approval-False b
# a creditScore-GTE-50% b => a approval-True b         a approval-True b
# a rate-GTE-25% b => a approval-True b                a approval-True b
# a creditScore-LTE-75% b => a approval-False b       a approval-False b
# a monthDuration-GTE-75% b => a approval-False b     a approval-False b
# a income/loanAmount-LTE-0.24 b => a approval-Fa...  a approval-False b
# a income-LTE-50% b => a approval-False b            a approval-False b
# a loanAmount-LTE-829730.5 b => a approval-False b   a approval-False b
# a monthDuration-LTE-25% b => a approval-False b     a approval-False b
# a income-LTE-25% b => a approval-False b            a approval-False b
# a rate-GTE-75% b => a approval-False b              a approval-False b
# a rate-GTE-75% b => a approval-True b                a approval-True b
# a rate-GTE-50% b => a approval-False b              a approval-False b
# a creditScore-LTE-50% b => a approval-True b         a approval-True b
# a loanAmount/rate-GT-17692737.0 b => a approval...  a approval-False b
# a creditScore-LTE-50% b => a approval-False b       a approval-False b
# a loanAmount-GT-829730.5 b => a approval-False b    a approval-False b
# a creditScore-GTE-75% b => a approval-True b         a approval-True b
# a income-GTE-25% b => a approval-False b            a approval-False b
# a rate-GTE-25% b => a approval-False b              a approval-False b
# a monthDuration-GTE-50% b => a approval-False b     a approval-False b
# a monthDuration-GTE-50% b => a approval-True b       a approval-True b
# a income-LTE-75% b => a approval-True b              a approval-True b
# a creditScore-GTE-25% b => a approval-False b       a approval-False b
# a income-LTE-75% b => a approval-False b            a approval-False b
# a income-GTE-50% b => a approval-False b            a approval-False b
# a rate-LTE-75% b => a approval-True b                a approval-True b
# a yearlyReimbursement-LTE-66647.5 b => a approv...  a approval-False b
# a loanAmount/rate-LTE-17692737.0 b => a approva...   a approval-True b
# a yearlyReimbursement-LTE-66647.5 b => a approv...   a approval-True b
# a creditScore-GTE-50% b => a approval-False b       a approval-False b
# a rate-LTE-75% b => a approval-False b              a approval-False b
# a income-GTE-50% b => a approval-True b              a approval-True b
# a monthDuration-GTE-75% b => a approval-True b       a approval-True b
# a creditScore-GTE-25% b => a approval-True b         a approval-True b
# a income-GTE-75% b => a approval-True b              a approval-True b
# a monthDuration-GTE-25% b => a approval-True b       a approval-True b
# a income-GTE-25% b => a approval-True b              a approval-True b
# a income/loanAmount-GT-0.24 b => a approval-True b   a approval-True b
# a income-LTE-50% b => a approval-True b              a approval-True b
# a rate-LTE-25% b => a approval-False b              a approval-False b
# a creditScore-LTE-25% b => a approval-True b         a approval-True b
# a monthDuration-GTE-25% b => a approval-False b     a approval-False b
# a rate-LTE-50% b => a approval-True b                a approval-True b
# a income-GTE-75% b => a approval-False b            a approval-False b
# a monthDuration-LTE-75% b => a approval-True b       a approval-True b
# a rate-GTE-50% b => a approval-True b                a approval-True b
# a monthDuration-LTE-50% b => a approval-False b     a approval-False b
# a loanAmount-LTE-829730.5 b => a approval-True b     a approval-True b
# a creditScore-GTE-75% b => a approval-False b       a approval-False b
# a monthDuration-LTE-50% b => a approval-True b       a approval-True b
# a rate-LTE-50% b => a approval-False b              a approval-False b
# a loanAmount/rate-LTE-17692737.0 b => a approva...  a approval-False b
# a income/yearlyReimbursement-GT-3.32 b => a app...   a approval-True b
# a creditScore-LTE-75% b => a approval-True b         a approval-True b
# a creditScore-LTE-25% b => a approval-False b       a approval-False b
# a income/yearlyReimbursement-GT-3.32 b => a app...  a approval-False b
# a yearlyReimbursement-GT-66647.5 b => a approva...  a approval-False b
# a rate-LTE-25% b => a approval-True b                a approval-True b
# a monthDuration-LTE-75% b => a approval-False b     a approval-False b
#
#                                                     headCoverage  \
# a income/loanAmount-GT-0.24 b => a approval-Fal...      0.879865
# a creditScore-GTE-50% b => a approval-True b            0.500725
# a rate-GTE-25% b => a approval-True b                   0.735214
# a creditScore-LTE-75% b => a approval-False b           0.248033
# a monthDuration-GTE-75% b => a approval-False b         0.778886
# a income/loanAmount-LTE-0.24 b => a approval-Fa...      0.120135
# a income-LTE-50% b => a approval-False b                0.433065
# a loanAmount-LTE-829730.5 b => a approval-False b       0.734784
# a monthDuration-LTE-25% b => a approval-False b         0.704174
# a income-LTE-25% b => a approval-False b                0.698229
# a rate-GTE-75% b => a approval-False b                  0.747073
# a rate-GTE-75% b => a approval-True b                   0.239590
# a rate-GTE-50% b => a approval-False b                  0.495656
# a creditScore-LTE-50% b => a approval-True b            0.500869
# a loanAmount/rate-GT-17692737.0 b => a approval...      0.254914
# a creditScore-LTE-50% b => a approval-False b           0.498834
# a loanAmount-GT-829730.5 b => a approval-False b        0.265216
# a creditScore-GTE-75% b => a approval-True b            0.253986
# a income-GTE-25% b => a approval-False b                0.301771
# a rate-GTE-25% b => a approval-False b                  0.245842
# a monthDuration-GTE-50% b => a approval-False b         0.547023
# a monthDuration-GTE-50% b => a approval-True b          0.679735
# a income-LTE-75% b => a approval-True b                 0.582767
# a creditScore-GTE-25% b => a approval-False b           0.249417
# a income-LTE-75% b => a approval-False b                0.202957
# a income-GTE-50% b => a approval-False b                0.566935
# a rate-LTE-75% b => a approval-True b                   0.760410
# a yearlyReimbursement-LTE-66647.5 b => a approv...      0.836391
# a loanAmount/rate-LTE-17692737.0 b => a approva...      0.908673
# a yearlyReimbursement-LTE-66647.5 b => a approv...      0.962058
# a creditScore-GTE-50% b => a approval-False b           0.499744
# a rate-LTE-75% b => a approval-False b                  0.252927
# a income-GTE-50% b => a approval-True b                 0.737950
# a monthDuration-GTE-75% b => a approval-True b          0.359981
# a creditScore-GTE-25% b => a approval-True b            0.748970
# a income-GTE-75% b => a approval-True b                 0.417233
# a monthDuration-GTE-25% b => a approval-True b          0.907305
# a income-GTE-25% b => a approval-True b                 0.934043
# a income/loanAmount-GT-0.24 b => a approval-True b      0.966792
# a income-LTE-50% b => a approval-True b                 0.262050
# a rate-LTE-25% b => a approval-False b                  0.754158
# a creditScore-LTE-25% b => a approval-True b            0.253216
# a monthDuration-GTE-25% b => a approval-False b         0.292520
# a rate-LTE-50% b => a approval-True b                   0.515441
# a income-GTE-75% b => a approval-False b                0.797043
# a monthDuration-LTE-75% b => a approval-True b          0.643846
# a rate-GTE-50% b => a approval-True b                   0.484559
# a monthDuration-LTE-50% b => a approval-False b         0.450209
# a loanAmount-LTE-829730.5 b => a approval-True b        0.950122
# a creditScore-GTE-75% b => a approval-False b           0.750121
# a monthDuration-LTE-50% b => a approval-True b          0.323545
# a rate-LTE-50% b => a approval-False b                  0.504344
# a loanAmount/rate-LTE-17692737.0 b => a approva...      0.745086
# a income/yearlyReimbursement-GT-3.32 b => a app...      1.000000
# a creditScore-LTE-75% b => a approval-True b            0.748200
# a creditScore-LTE-25% b => a approval-False b           0.748545
# a income/yearlyReimbursement-GT-3.32 b => a app...      0.985919
# a yearlyReimbursement-GT-66647.5 b => a approva...      0.163609
# a rate-LTE-25% b => a approval-True b                   0.264786
# a monthDuration-LTE-75% b => a approval-False b         0.218628
#
#                                                     stdConfidence  \
# a income/loanAmount-GT-0.24 b => a approval-Fal...        0.68670
# a creditScore-GTE-50% b => a approval-True b              0.10993
# a rate-GTE-25% b => a approval-True b                     0.16141
# a creditScore-LTE-75% b => a approval-False b             0.19358
# a monthDuration-GTE-75% b => a approval-False b           0.60789
# a income/loanAmount-LTE-0.24 b => a approval-Fa...        0.09376
# a income-LTE-50% b => a approval-False b                  0.33799
# a loanAmount-LTE-829730.5 b => a approval-False b         0.57347
# a monthDuration-LTE-25% b => a approval-False b           0.54958
# a income-LTE-25% b => a approval-False b                  0.54494
# a rate-GTE-75% b => a approval-False b                    0.58306
# a rate-GTE-75% b => a approval-True b                     0.05260
# a rate-GTE-50% b => a approval-False b                    0.38684
# a creditScore-LTE-50% b => a approval-True b              0.10996
# a loanAmount/rate-GT-17692737.0 b => a approval...        0.19895
# a creditScore-LTE-50% b => a approval-False b             0.38932
# a loanAmount-GT-829730.5 b => a approval-False b          0.20699
# a creditScore-GTE-75% b => a approval-True b              0.05576
# a income-GTE-25% b => a approval-False b                  0.23552
# a rate-GTE-25% b => a approval-False b                    0.19187
# a monthDuration-GTE-50% b => a approval-False b           0.42693
# a monthDuration-GTE-50% b => a approval-True b            0.14923
# a income-LTE-75% b => a approval-True b                   0.12794
# a creditScore-GTE-25% b => a approval-False b             0.19466
# a income-LTE-75% b => a approval-False b                  0.15840
# a income-GTE-50% b => a approval-False b                  0.44247
# a rate-LTE-75% b => a approval-True b                     0.16694
# a yearlyReimbursement-LTE-66647.5 b => a approv...        0.65277
# a loanAmount/rate-LTE-17692737.0 b => a approva...        0.19949
# a yearlyReimbursement-LTE-66647.5 b => a approv...        0.21121
# a creditScore-GTE-50% b => a approval-False b             0.39003
# a rate-LTE-75% b => a approval-False b                    0.19740
# a income-GTE-50% b => a approval-True b                   0.16201
# a monthDuration-GTE-75% b => a approval-True b            0.07903
# a creditScore-GTE-25% b => a approval-True b              0.16443
# a income-GTE-75% b => a approval-True b                   0.09160
# a monthDuration-GTE-25% b => a approval-True b            0.19919
# a income-GTE-25% b => a approval-True b                   0.20506
# a income/loanAmount-GT-0.24 b => a approval-True b        0.21225
# a income-LTE-50% b => a approval-True b                   0.05753
# a rate-LTE-25% b => a approval-False b                    0.58859
# a creditScore-LTE-25% b => a approval-True b              0.05559
# a monthDuration-GTE-25% b => a approval-False b           0.22830
# a rate-LTE-50% b => a approval-True b                     0.11316
# a income-GTE-75% b => a approval-False b                  0.62206
# a monthDuration-LTE-75% b => a approval-True b            0.14135
# a rate-GTE-50% b => a approval-True b                     0.10638
# a monthDuration-LTE-50% b => a approval-False b           0.35137
# a loanAmount-LTE-829730.5 b => a approval-True b          0.20859
# a creditScore-GTE-75% b => a approval-False b             0.58544
# a monthDuration-LTE-50% b => a approval-True b            0.07103
# a rate-LTE-50% b => a approval-False b                    0.39362
# a loanAmount/rate-LTE-17692737.0 b => a approva...        0.58151
# a income/yearlyReimbursement-GT-3.32 b => a app...        0.21954
# a creditScore-LTE-75% b => a approval-True b              0.16426
# a creditScore-LTE-25% b => a approval-False b             0.58421
# a income/yearlyReimbursement-GT-3.32 b => a app...        0.76947
# a yearlyReimbursement-GT-66647.5 b => a approva...        0.12769
# a rate-LTE-25% b => a approval-True b                     0.05813
# a monthDuration-LTE-75% b => a approval-False b           0.17063
#
#                                                     pcaConfidence  \
# a income/loanAmount-GT-0.24 b => a approval-Fal...       0.879865
# a creditScore-GTE-50% b => a approval-True b             0.500725
# a rate-GTE-25% b => a approval-True b                    0.735214
# a creditScore-LTE-75% b => a approval-False b            0.248033
# a monthDuration-GTE-75% b => a approval-False b          0.778886
# a income/loanAmount-LTE-0.24 b => a approval-Fa...       0.120135
# a income-LTE-50% b => a approval-False b                 0.433065
# a loanAmount-LTE-829730.5 b => a approval-False b        0.734784
# a monthDuration-LTE-25% b => a approval-False b          0.704174
# a income-LTE-25% b => a approval-False b                 0.698229
# a rate-GTE-75% b => a approval-False b                   0.747073
# a rate-GTE-75% b => a approval-True b                    0.239590
# a rate-GTE-50% b => a approval-False b                   0.495656
# a creditScore-LTE-50% b => a approval-True b             0.500869
# a loanAmount/rate-GT-17692737.0 b => a approval...       0.254914
# a creditScore-LTE-50% b => a approval-False b            0.498834
# a loanAmount-GT-829730.5 b => a approval-False b         0.265216
# a creditScore-GTE-75% b => a approval-True b             0.253986
# a income-GTE-25% b => a approval-False b                 0.301771
# a rate-GTE-25% b => a approval-False b                   0.245842
# a monthDuration-GTE-50% b => a approval-False b          0.547023
# a monthDuration-GTE-50% b => a approval-True b           0.679735
# a income-LTE-75% b => a approval-True b                  0.582767
# a creditScore-GTE-25% b => a approval-False b            0.249417
# a income-LTE-75% b => a approval-False b                 0.202957
# a income-GTE-50% b => a approval-False b                 0.566935
# a rate-LTE-75% b => a approval-True b                    0.760410
# a yearlyReimbursement-LTE-66647.5 b => a approv...       0.836391
# a loanAmount/rate-LTE-17692737.0 b => a approva...       0.908673
# a yearlyReimbursement-LTE-66647.5 b => a approv...       0.962058
# a creditScore-GTE-50% b => a approval-False b            0.499744
# a rate-LTE-75% b => a approval-False b                   0.252927
# a income-GTE-50% b => a approval-True b                  0.737950
# a monthDuration-GTE-75% b => a approval-True b           0.359981
# a creditScore-GTE-25% b => a approval-True b             0.748970
# a income-GTE-75% b => a approval-True b                  0.417233
# a monthDuration-GTE-25% b => a approval-True b           0.907305
# a income-GTE-25% b => a approval-True b                  0.934043
# a income/loanAmount-GT-0.24 b => a approval-True b       0.966792
# a income-LTE-50% b => a approval-True b                  0.262050
# a rate-LTE-25% b => a approval-False b                   0.754158
# a creditScore-LTE-25% b => a approval-True b             0.253216
# a monthDuration-GTE-25% b => a approval-False b          0.292520
# a rate-LTE-50% b => a approval-True b                    0.515441
# a income-GTE-75% b => a approval-False b                 0.797043
# a monthDuration-LTE-75% b => a approval-True b           0.643846
# a rate-GTE-50% b => a approval-True b                    0.484559
# a monthDuration-LTE-50% b => a approval-False b          0.450209
# a loanAmount-LTE-829730.5 b => a approval-True b         0.950122
# a creditScore-GTE-75% b => a approval-False b            0.750121
# a monthDuration-LTE-50% b => a approval-True b           0.323545
# a rate-LTE-50% b => a approval-False b                   0.504344
# a loanAmount/rate-LTE-17692737.0 b => a approva...       0.745086
# a income/yearlyReimbursement-GT-3.32 b => a app...       1.000000
# a creditScore-LTE-75% b => a approval-True b             0.748200
# a creditScore-LTE-25% b => a approval-False b            0.748545
# a income/yearlyReimbursement-GT-3.32 b => a app...       0.985919
# a yearlyReimbursement-GT-66647.5 b => a approva...       0.163609
# a rate-LTE-25% b => a approval-True b                    0.264786
# a monthDuration-LTE-75% b => a approval-False b          0.218628
#
#                                                     precision_train  \
# a income/loanAmount-GT-0.24 b => a approval-Fal...         0.989952
# a creditScore-GTE-50% b => a approval-True b               0.219547
# a rate-GTE-25% b => a approval-True b                      0.215399
# a creditScore-LTE-75% b => a approval-False b              0.779499
# a monthDuration-GTE-75% b => a approval-False b            0.811322
# a income/loanAmount-LTE-0.24 b => a approval-Fa...         0.306941
# a income-LTE-50% b => a approval-False b                   0.674500
# a loanAmount-LTE-829730.5 b => a approval-False b          0.981312
# a monthDuration-LTE-25% b => a approval-False b            0.734500
# a income-LTE-25% b => a approval-False b                   0.725691
# a rate-GTE-75% b => a approval-False b                     0.777109
# a rate-GTE-75% b => a approval-True b                      0.211030
# a rate-GTE-50% b => a approval-False b                     0.772995
# a creditScore-LTE-50% b => a approval-True b               0.220145
# a loanAmount/rate-GT-17692737.0 b => a approval...         0.500131
# a creditScore-LTE-50% b => a approval-False b              0.780281
# a loanAmount-GT-829730.5 b => a approval-False b           0.499029
# a creditScore-GTE-75% b => a approval-True b               0.220759
# a income-GTE-25% b => a approval-False b                   0.943088
# a rate-GTE-25% b => a approval-False b                     0.766509
# a monthDuration-GTE-50% b => a approval-False b            0.859169
# a monthDuration-GTE-50% b => a approval-True b             0.298150
# a income-LTE-75% b => a approval-True b                    0.170533
# a creditScore-GTE-25% b => a approval-False b              0.779365
# a income-LTE-75% b => a approval-False b                   0.632880
# a income-GTE-50% b => a approval-False b                   0.885540
# a rate-LTE-75% b => a approval-True b                      0.222891
# a yearlyReimbursement-LTE-66647.5 b => a approv...         0.987091
# a loanAmount/rate-LTE-17692737.0 b => a approva...         0.499869
# a yearlyReimbursement-LTE-66647.5 b => a approv...         0.621812
# a creditScore-GTE-50% b => a approval-False b              0.779680
# a rate-LTE-75% b => a approval-False b                     0.788970
# a income-GTE-50% b => a approval-True b                    0.325500
# a monthDuration-GTE-75% b => a approval-True b             0.313108
# a creditScore-GTE-25% b => a approval-True b               0.219699
# a income-GTE-75% b => a approval-True b                    0.367120
# a monthDuration-GTE-25% b => a approval-True b             0.265045
# a income-GTE-25% b => a approval-True b                    0.274309
# a income/loanAmount-GT-0.24 b => a approval-True b         0.693059
# a income-LTE-50% b => a approval-True b                    0.114460
# a rate-LTE-25% b => a approval-False b                     0.784601
# a creditScore-LTE-25% b => a approval-True b               0.220608
# a monthDuration-GTE-25% b => a approval-False b            0.917050
# a rate-LTE-50% b => a approval-True b                      0.227005
# a income-GTE-75% b => a approval-False b                   0.829467
# a monthDuration-LTE-75% b => a approval-True b             0.189040
# a rate-GTE-50% b => a approval-True b                      0.212827
# a monthDuration-LTE-50% b => a approval-False b            0.701596
# a loanAmount-LTE-829730.5 b => a approval-True b           0.500971
# a creditScore-GTE-75% b => a approval-False b              0.780346
# a monthDuration-LTE-50% b => a approval-True b             0.141456
# a rate-LTE-50% b => a approval-False b                     0.787173
# a loanAmount/rate-LTE-17692737.0 b => a approva...         0.966396
# a income/yearlyReimbursement-GT-3.32 b => a app...         0.953812
# a creditScore-LTE-75% b => a approval-True b               0.219743
# a creditScore-LTE-25% b => a approval-False b              0.780294
# a income/yearlyReimbursement-GT-3.32 b => a app...         1.000000
# a yearlyReimbursement-GT-66647.5 b => a approva...         0.378188
# a rate-LTE-25% b => a approval-True b                      0.233491
# a monthDuration-LTE-75% b => a approval-False b            0.686560
#
#                                                     precision_test
# a income/loanAmount-GT-0.24 b => a approval-Fal...        0.988587
# a creditScore-GTE-50% b => a approval-True b              0.220013
# a rate-GTE-25% b => a approval-True b                     0.214842
# a creditScore-LTE-75% b => a approval-False b             0.774566
# a monthDuration-GTE-75% b => a approval-False b           0.814118
# a income/loanAmount-LTE-0.24 b => a approval-Fa...        0.305289
# a income-LTE-50% b => a approval-False b                  0.678935
# a loanAmount-LTE-829730.5 b => a approval-False b         0.981168
# a monthDuration-LTE-25% b => a approval-False b           0.734019
# a income-LTE-25% b => a approval-False b                  0.728378
# a rate-GTE-75% b => a approval-False b                    0.778023
# a rate-GTE-75% b => a approval-True b                     0.209150
# a rate-GTE-50% b => a approval-False b                    0.775059
# a creditScore-LTE-50% b => a approval-True b              0.218031
# a loanAmount/rate-GT-17692737.0 b => a approval...        0.497690
# a creditScore-LTE-50% b => a approval-False b             0.780510
# a loanAmount-GT-829730.5 b => a approval-False b          0.496143
# a creditScore-GTE-75% b => a approval-True b              0.225558
# a income-GTE-25% b => a approval-False b                  0.940060
# a rate-GTE-25% b => a approval-False b                    0.769435
# a monthDuration-GTE-50% b => a approval-False b           0.857462
# a monthDuration-GTE-50% b => a approval-True b            0.294163
# a income-LTE-75% b => a approval-True b                   0.170693
# a creditScore-GTE-25% b => a approval-False b             0.779342
# a income-LTE-75% b => a approval-False b                  0.635063
# a income-GTE-50% b => a approval-False b                  0.883738
# a rate-LTE-75% b => a approval-True b                     0.221977
# a yearlyReimbursement-LTE-66647.5 b => a approv...        0.988014
# a loanAmount/rate-LTE-17692737.0 b => a approva...        0.502310
# a yearlyReimbursement-LTE-66647.5 b => a approv...        0.626069
# a creditScore-GTE-50% b => a approval-False b             0.782492
# a rate-LTE-75% b => a approval-False b                    0.790850
# a income-GTE-50% b => a approval-True b                   0.321065
# a monthDuration-GTE-75% b => a approval-True b            0.316102
# a creditScore-GTE-25% b => a approval-True b              0.218116
# a income-GTE-75% b => a approval-True b                   0.364937
# a monthDuration-GTE-25% b => a approval-True b            0.265239
# a income-GTE-25% b => a approval-True b                   0.271622
# a income/loanAmount-GT-0.24 b => a approval-True b        0.694711
# a income-LTE-50% b => a approval-True b                   0.116262
# a rate-LTE-25% b => a approval-False b                    0.785158
# a creditScore-LTE-25% b => a approval-True b              0.220987
# a monthDuration-GTE-25% b => a approval-False b           0.920350
# a rate-LTE-50% b => a approval-True b                     0.224941
# a income-GTE-75% b => a approval-False b                  0.829307
# a monthDuration-LTE-75% b => a approval-True b            0.186428
# a rate-GTE-50% b => a approval-True b                     0.212626
# a monthDuration-LTE-50% b => a approval-False b           0.705536
# a loanAmount-LTE-829730.5 b => a approval-True b          0.503857
# a creditScore-GTE-75% b => a approval-False b             0.783498
# a monthDuration-LTE-50% b => a approval-True b            0.143165
# a rate-LTE-50% b => a approval-False b                    0.787374
# a loanAmount/rate-LTE-17692737.0 b => a approva...        0.967215
# a income/yearlyReimbursement-GT-3.32 b => a app...        0.949356
# a creditScore-LTE-75% b => a approval-True b              0.216565
# a creditScore-LTE-25% b => a approval-False b             0.782002
# a income/yearlyReimbursement-GT-3.32 b => a app...        1.000000
# a yearlyReimbursement-GT-66647.5 b => a approva...        0.373931
# a rate-LTE-25% b => a approval-True b                     0.230565
# a monthDuration-LTE-75% b => a approval-False b           0.684160

# %%
def addParameters(amieResponses, parameters):
    new_responses = {}
    for amieResponse in amieResponses:
        for para in parameters:
            
            #Optimizable
            new_response_raw = amieResponses[amieResponse].copy()
            new_response = {}
            for r in new_response_raw:
                new_response[r] = new_response_raw[r].toDict()
            new_response = pd.DataFrame.from_dict(new_response, orient="index")
            
            name = amieResponse[1:]
            for sub_para in para:
                if len(new_response) != 0:
                    new_response = new_response.loc[new_response.apply(func=limitByThreshold, axis=1, parameter=sub_para[0], threshold=sub_para[1])]
                if sub_para[0] == "stdConfidence":
                    name += "\n"+"stdC"+"="+str(sub_para[1])
                else :
                    name += "\n"+"hC"+"="+str(sub_para[1])
            new_responses[name] = new_response
    return new_responses

# %%
new_parameters = []
for minc in minc_LIST:
    for minhc in minhc_LIST:
        new_parameters.append([("stdConfidence", minc), ("headCoverage", minhc)])
print(new_parameters)
# Out:
# [[('stdConfidence', 0), ('headCoverage', 0)], [('stdConfidence', 0), ('headCoverage', 0.3)], [('stdConfidence', 0), ('headCoverage', 0.6)], [('stdConfidence', 0), ('headCoverage', 0.9)], [('stdConfidence', 0.3), ('headCoverage', 0)], [('stdConfidence', 0.3), ('headCoverage', 0.3)], [('stdConfidence', 0.3), ('headCoverage', 0.6)], [('stdConfidence', 0.3), ('headCoverage', 0.9)], [('stdConfidence', 0.6), ('headCoverage', 0)], [('stdConfidence', 0.6), ('headCoverage', 0.3)], [('stdConfidence', 0.6), ('headCoverage', 0.6)], [('stdConfidence', 0.6), ('headCoverage', 0.9)], [('stdConfidence', 0.9), ('headCoverage', 0)], [('stdConfidence', 0.9), ('headCoverage', 0.3)], [('stdConfidence', 0.9), ('headCoverage', 0.6)], [('stdConfidence', 0.9), ('headCoverage', 0.9)]]

# %%
new_dfs = addParameters(rules_per_para, new_parameters)
to_print = pd.DataFrame(data=None, columns=["precision_train", "precision_test"])
for key in new_dfs.keys():
    to_print = to_print.append(new_dfs[key].describe()[["precision_train", "precision_test"]].loc["mean"].rename(key))

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 
to_print.plot(kind="bar", ax=_axs, rot=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Now time to predict stuff

# %%
new_dfs.keys()
# Out:
# dict_keys(['A=2\nstdC=0\nhC=0', 'A=2\nstdC=0\nhC=0.3', 'A=2\nstdC=0\nhC=0.6', 'A=2\nstdC=0\nhC=0.9', 'A=2\nstdC=0.3\nhC=0', 'A=2\nstdC=0.3\nhC=0.3', 'A=2\nstdC=0.3\nhC=0.6', 'A=2\nstdC=0.3\nhC=0.9', 'A=2\nstdC=0.6\nhC=0', 'A=2\nstdC=0.6\nhC=0.3', 'A=2\nstdC=0.6\nhC=0.6', 'A=2\nstdC=0.6\nhC=0.9', 'A=2\nstdC=0.9\nhC=0', 'A=2\nstdC=0.9\nhC=0.3', 'A=2\nstdC=0.9\nhC=0.6', 'A=2\nstdC=0.9\nhC=0.9', 'A=3\nstdC=0\nhC=0', 'A=3\nstdC=0\nhC=0.3', 'A=3\nstdC=0\nhC=0.6', 'A=3\nstdC=0\nhC=0.9', 'A=3\nstdC=0.3\nhC=0', 'A=3\nstdC=0.3\nhC=0.3', 'A=3\nstdC=0.3\nhC=0.6', 'A=3\nstdC=0.3\nhC=0.9', 'A=3\nstdC=0.6\nhC=0', 'A=3\nstdC=0.6\nhC=0.3', 'A=3\nstdC=0.6\nhC=0.6', 'A=3\nstdC=0.6\nhC=0.9', 'A=3\nstdC=0.9\nhC=0', 'A=3\nstdC=0.9\nhC=0.3', 'A=3\nstdC=0.9\nhC=0.6', 'A=3\nstdC=0.9\nhC=0.9'])

# %%
def prepareVote(X, vote, rules_to_predict):
    prediction = []
    for rule in rules_to_predict.values:
        truth = rule[1].predicate == "approval-True"
        if truth: 
            if sum([X[i.predicate] for i in rule[0]]) == len(rule[0]):
                prediction.append("True")
            else:
                prediction.append("I can't say anything")
        else :
            if sum([X[i.predicate] for i in rule[0]]) == 0:
                prediction.append("False")
            else :
                prediction.append("I can't say anything")
    predicts = pd.Series(prediction).value_counts()    
    return vote(predicts)
    
def safe(X, rules_to_predict):
    prediction = []
    
    predicted_approved = False
    
    for rule in rules_to_predict.values:
        truth = rule[1].predicate == "approval-True"
        if truth and not predicted_approved: 
            if sum([X[i.predicate] for i in rule[0]]) == len(rule[0]):
                predicted_approved = True
        else :
            if sum([X[i.predicate] for i in rule[0]]) == 0:
                return "Not Approved"
    if predicted_approved:
        return "Approved"
    else:
        return "Not Approved - No rules was able to say anything"
    

def democracy(predicts):
    if not "False" in predicts:
        if not "Truth" in predicts:
            return "Not Approved - No rules was able to say anything"
        else:
            return "Approved"
    elif not "True" in predicts:
        return "Not Approved"
    else:
        if predicts["True"] < predicts["False"]:
            return "Not Approved"
        else:
            return "Approved"
        
def prepareVote_democracy_proportional(X, vote, rules_to_predict, proportion):
    prediction = []
    for rule in rules_to_predict.values:
        truth = rule[1].predicate == "approval-True"
        if truth: 
            if sum([X[i.predicate] for i in rule[0]]) == len(rule[0]):
                prediction.append("True")
            else:
                prediction.append("I can't say anything")
        else :
            if sum([X[i.predicate] for i in rule[0]]) == 0:
                prediction.append("False")
            else :
                prediction.append("I can't say anything")
    predicts = pd.Series(prediction).value_counts()    
    return vote(predicts, proportion)
        
def democracy_proportional(predicts, proportion):
    if not "False" in predicts:
        if not "Truth" in predicts:
            return "Not Approved - No rules was able to say anything"
        else:
            return "Approved"
    elif not "True" in predicts:
        return "Not Approved"
    else:
        if predicts["True"]*proportion["True"] < predicts["False"]*proportion["False"]:
            return "Not Approved"
        else:
            return "Approved"

def oligarchie(X, rules_to_predict):
    #Rules have to be sorted
    prediction = []
    
    cpt = 0
    while cpt < len(rules_to_predict):
        rule = rules_to_predict.iloc[cpt]
        truth = rule[1].predicate == "approval-True"
        
        if truth: 
            if sum([X[i.predicate] for i in rule[0]]) == len(rule[0]):
                return "Approved"
        else :
            if sum([X[i.predicate] for i in rule[0]]) == 0:
                return "Not Approved"
        cpt += 1
    return "Not Approved - No rules was able to say anything"

# %%
# %%time

def paralel_prediction_res(parameters, index, new_dfs, res_count, res_raw, cpt ):
    print(f"Process n°{index} : Launched")
    for para in parameters:
        rules_to_predict = new_dfs[para]
        
        true = 0
        false = 0

        for rule in rules_to_predict.values:
            if rule[1].predicate ==  "approval-True":
                true += 1
            else:
                false += 1

        proportion = {"True":1-true/(true+false+1), "False":1-false/(true+false+1)}

        final_prediction = df.apply(prepareVote_democracy_proportional, rules_to_predict=rules_to_predict, axis=1, vote=democracy_proportional, proportion=proportion)
        
        cpt.value += 1
        if (cpt.value%10 == 0):
            print(cpt)
            
        res_count[para] = pd.Series(final_prediction).value_counts()
        res_raw[para] = pd.Series(final_prediction).map({"Not Approved - No rules was able to say anything":False, "Not Approved":False, "Approved":True})
    print(f"Process n°{index} : Finished")
    


prediction_per_rules_count = {}
prediction_per_rules_raw = {}

df = pd.read_csv("./../data_cv_Tree/dfSave.csv", index_col=0)

with Manager() as manager:

    processes_to_create = multiprocessing.cpu_count()-3
    processes = list()

    rules_list = list(new_dfs.keys())
    
    res_count = manager.dict()
    res_raw = manager.dict()
    cpt = manager.Value("d",0)

    for index in range(processes_to_create):
        x = Process(target=paralel_prediction_res, args=(rules_list[int(np.floor(index*len(rules_list)/processes_to_create)): int(np.floor((index+1)*len(rules_list)/processes_to_create))], index, new_dfs, res_count, res_raw, cpt))
        processes.append(x)
        x.start()

    for index, process in enumerate(processes):
        process.join()
        
    prediction_per_rules_count = res_count.copy()
    prediction_per_rules_raw = res_raw.copy()
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# <ipython-input-52-98d60353ff16>:65: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   predicts = pd.Series(prediction).value_counts()
# Process n°6 : Launched
# Process n°7 : Launched
# <ipython-input-52-98d60353ff16>:65: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   predicts = pd.Series(prediction).value_counts()
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 10)
# Process n°5 : Finished
# Process n°3 : Finished
# Process n°11 : Finished
# <ipython-input-52-98d60353ff16>:65: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   predicts = pd.Series(prediction).value_counts()
# Process n°1 : Finished
# Process n°4 : Finished
# Value('d', 20)
# Process n°12 : Finished
# Process n°2 : Finished
# Process n°0 : Finished
# Process n°9 : Finished
# Process n°10 : Finished
# Value('d', 30)
# Process n°6 : Finished
# Process n°7 : Finished
# Process n°8 : Finished
# CPU times: user 203 ms, sys: 13.6 s, total: 13.8 s
# Wall time: 11min 6s

# %%
def compare(prediction, ground_truth):
    if len(prediction) != len(ground_truth):
        print("Different size")
        return None
    return sum(np.array(prediction) == np.array(ground_truth))/float(len(ground_truth))

# %%
accuracy_prediction = {}

for key in prediction_per_rules_raw:
    accuracy_prediction[key] = compare(prediction_per_rules_raw[key], df["approval"].values)

accuracy_prediction = pd.DataFrame.from_dict(accuracy_prediction, orient="index", columns=["Accuracy-democracy-propor"])

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 

to_print_1 = pd.DataFrame(accuracy_prediction)
to_print_1.plot(kind="bar", ax=_axs, rot=0)
# Out:
# <AxesSubplot:>

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 

to_print_count = pd.DataFrame.from_dict(prediction_per_rules_count, orient="index")
to_print_count.sort_index().plot(kind="bar", ax=_axs, rot=0)
# Out:
# <AxesSubplot:>

# %%
# %%time

def paralel_prediction_res(parameters, index, new_dfs, res_count, res_raw, cpt ):
    print(f"Process n°{index} : Launched")
    for para in parameters:
        rules_to_predict = new_dfs[para]

        final_prediction = df.apply(prepareVote, rules_to_predict=rules_to_predict, axis=1, vote=democracy)
        
        cpt.value += 1
        if (cpt.value%10 == 0):
            print(cpt)
            
        res_count[para] = pd.Series(final_prediction).value_counts()
        res_raw[para] = pd.Series(final_prediction).map({"Not Approved - No rules was able to say anything":False, "Not Approved":False, "Approved":True})
    print(f"Process n°{index} : Finished")
    


prediction_per_rules_count = {}
prediction_per_rules_raw = {}

df = pd.read_csv("./../data_cv_Tree/dfSave.csv", index_col=0)

with Manager() as manager:

    processes_to_create = multiprocessing.cpu_count()-3
    processes = list()

    rules_list = list(new_dfs.keys())
    
    res_count = manager.dict()
    res_raw = manager.dict()
    cpt = manager.Value("d",0)

    for index in range(processes_to_create):
        x = Process(target=paralel_prediction_res, args=(rules_list[int(np.floor(index*len(rules_list)/processes_to_create)): int(np.floor((index+1)*len(rules_list)/processes_to_create))], index, new_dfs, res_count, res_raw, cpt))
        processes.append(x)
        x.start()

    for index, process in enumerate(processes):
        process.join()
        
    prediction_per_rules_count = res_count.copy()
    prediction_per_rules_raw = res_raw.copy()
    
accuracy_prediction = {}

for key in prediction_per_rules_raw:
    accuracy_prediction[key] = compare(prediction_per_rules_raw[key], df["approval"].values)

accuracy_prediction = pd.DataFrame.from_dict(accuracy_prediction, orient="index", columns=["Accuracy-democracy"])

fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 

to_print_2 = to_print_1.merge(accuracy_prediction, left_index=True, right_index=True)
to_print_2.plot(kind="bar", ax=_axs, rot=0)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# <ipython-input-52-98d60353ff16>:15: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   predicts = pd.Series(prediction).value_counts()
# <ipython-input-52-98d60353ff16>:15: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   predicts = pd.Series(prediction).value_counts()
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 10)
# Process n°5 : Finished
# Process n°3 : Finished
# Process n°11 : Finished
# <ipython-input-52-98d60353ff16>:15: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   predicts = pd.Series(prediction).value_counts()
# Process n°1 : Finished
# Process n°4 : Finished
# Value('d', 20)
# Process n°12 : Finished
# Process n°0 : Finished
# Process n°2 : Finished
# Process n°9 : Finished
# Process n°10 : Finished
# Value('d', 30)
# Process n°6 : Finished
# Process n°8 : Finished
# Process n°7 : Finished
# CPU times: user 7.14 s, sys: 11.2 s, total: 18.4 s
# Wall time: 11min 22s
# <AxesSubplot:>

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 

to_print_count = pd.DataFrame.from_dict(prediction_per_rules_count, orient="index")
to_print_count.sort_index().plot(kind="bar", ax=_axs, rot=0)
# Out:
# <AxesSubplot:>

# %%
# %%time

def paralel_prediction_res(parameters, index, new_dfs, res_count, res_raw, cpt ):
    print(f"Process n°{index} : Launched")
    for para in parameters:
        rules_to_predict = new_dfs[para]
        
        final_prediction = df.apply(safe, rules_to_predict=rules_to_predict, axis=1)
        
        cpt.value += 1
        if (cpt.value%10 == 0):
            print(cpt)
            
        res_count[para] = pd.Series(final_prediction).value_counts()
        res_raw[para] = pd.Series(final_prediction).map({"Not Approved - No rules was able to say anything":False, "Not Approved":False, "Approved":True})
    print(f"Process n°{index} : Finished")
    


prediction_per_rules_count = {}
prediction_per_rules_raw = {}

df = pd.read_csv("./../data_cv_Tree/dfSave.csv", index_col=0)

with Manager() as manager:

    processes_to_create = multiprocessing.cpu_count()-3
    processes = list()

    rules_list = list(new_dfs.keys())
    
    res_count = manager.dict()
    res_raw = manager.dict()
    cpt = manager.Value("d",0)

    for index in range(processes_to_create):
        x = Process(target=paralel_prediction_res, args=(rules_list[int(np.floor(index*len(rules_list)/processes_to_create)): int(np.floor((index+1)*len(rules_list)/processes_to_create))], index, new_dfs, res_count, res_raw, cpt))
        processes.append(x)
        x.start()

    for index, process in enumerate(processes):
        process.join()
        
    prediction_per_rules_count = res_count.copy()
    prediction_per_rules_raw = res_raw.copy()
    
accuracy_prediction = {}

for key in prediction_per_rules_raw:
    accuracy_prediction[key] = compare(prediction_per_rules_raw[key], df["approval"].values)

accuracy_prediction = pd.DataFrame.from_dict(accuracy_prediction, orient="index", columns=["Accuracy-Safe"])

fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 

to_print_3 = to_print_2.merge(accuracy_prediction, left_index=True, right_index=True)
to_print_3.plot(kind="bar", ax=_axs, rot=0)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 10)
# Process n°5 : Finished
# Process n°3 : Finished
# Process n°0 : Finished
# Process n°1 : Finished
# Process n°11 : Finished
# Value('d', 20)
# Process n°4 : Finished
# Process n°2 : Finished
# Process n°12 : Finished
# Process n°9 : Finished
# Process n°6 : Finished
# Value('d', 30)
# Process n°10 : Finished
# Process n°7 : Finished
# Process n°8 : Finished
# CPU times: user 7.28 s, sys: 11.1 s, total: 18.4 s
# Wall time: 1min 12s
# <AxesSubplot:>

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 

to_print_count = pd.DataFrame.from_dict(prediction_per_rules_count, orient="index")
to_print_count.sort_index().plot(kind="bar", ax=_axs, rot=0)
# Out:
# <AxesSubplot:>

# %%
def paralel_prediction_res(parameters, index, new_dfs, res_count, res_raw, cpt ):
    print(f"Process n°{index} : Launched")
    for para in parameters:
        rules_to_predict = new_dfs[para].sort_values(["precision_train", "precision_test"], ascending=False)
        
        true = 0
        false = 0

        for rule in rules_to_predict.values:
            if rule[1].predicate ==  "approval-True":
                true += 1
            else:
                false += 1

        proportion = {"True":1-true/(true+false+1), "False":1-false/(true+false+1)}

        final_prediction = df.apply(oligarchie, rules_to_predict=rules_to_predict, axis=1)
        
        cpt.value += 1
        if (cpt.value%10 == 0):
            print(cpt)
            
        res_count[para] = pd.Series(final_prediction).value_counts()
        res_raw[para] = pd.Series(final_prediction).map({"Not Approved - No rules was able to say anything":False, "Not Approved":False, "Approved":True})
    print(f"Process n°{index} : Finished")

prediction_per_rules_count = {}
prediction_per_rules_raw = {}

df = pd.read_csv("./../data_cv_Tree/dfSave.csv", index_col=0)

with Manager() as manager:

    processes_to_create = multiprocessing.cpu_count()-3
    processes = list()

    rules_list = list(new_dfs.keys())
    
    res_count = manager.dict()
    res_raw = manager.dict()
    cpt = manager.Value("d",0)

    for index in range(processes_to_create):
        x = Process(target=paralel_prediction_res, args=(rules_list[int(np.floor(index*len(rules_list)/processes_to_create)): int(np.floor((index+1)*len(rules_list)/processes_to_create))], index, new_dfs, res_count, res_raw, cpt))
        processes.append(x)
        x.start()

    for index, process in enumerate(processes):
        process.join()
        
    prediction_per_rules_count = res_count.copy()
    prediction_per_rules_raw = res_raw.copy()
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°5 : Finished
# Value('d', 10)
# Process n°3 : Finished
# Process n°1 : Finished
# Process n°0 : Finished
# Process n°11 : Finished
# Process n°4 : Finished
# Value('d', 20)
# Process n°12 : Finished
# Process n°2 : Finished
# Process n°9 : Finished
# Process n°6 : Finished
# Process n°7 : Finished
# Value('d', 30)
# Process n°8 : Finished
# Process n°10 : Finished

# %%
accuracy_prediction = {}

for key in prediction_per_rules_raw:
    accuracy_prediction[key] = compare(prediction_per_rules_raw[key], df["approval"].values)

accuracy_prediction = pd.DataFrame.from_dict(accuracy_prediction, orient="index", columns=["Accuracy-expert"])

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 

to_print_4 = to_print_3.merge(accuracy_prediction, left_index=True, right_index=True)
to_print_4.sort_index().plot(kind="bar", ax=_axs, rot=0)
# Out:
# <AxesSubplot:>

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 

to_print_count = pd.DataFrame.from_dict(prediction_per_rules_count, orient="index")
to_print_count.sort_index().plot(kind="bar", ax=_axs, rot=0)
# Out:
# <AxesSubplot:>
