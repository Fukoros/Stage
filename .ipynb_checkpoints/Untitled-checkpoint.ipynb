# %%
from sklearn.datasets import load_iris
from sklearn import tree
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv("./test/train.csv")

# %%
X = data[data.columns[:-1]].dropna(axis=1)
Y = data[data.columns[-1]]

# %%
le = LabelEncoder()
le.fit(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-19157faf43dd> in <module>
#       1 le = LabelEncoder()
# ----> 2 le.fit(X)
#
# ~\anaconda3\envs\tC\lib\site-packages\sklearn\preprocessing\_label.py in fit(self, y)
#      98         self : returns an instance of self.
#      99         """
# --> 100         y = column_or_1d(y, warn=True)
#     101         self.classes_ = _unique(y)
#     102         return self
#
# ~\anaconda3\envs\tC\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\tC\lib\site-packages\sklearn\utils\validation.py in column_or_1d(y, warn)
#     864     raise ValueError(
#     865         "y should be a 1d array, "
# --> 866         "got an array of shape {} instead.".format(shape))
#     867
#     868
#
# ValueError: y should be a 1d array, got an array of shape (1460, 61) instead.

# %%
for column in X.dtypes:
    if column.value == dtype(""):
        print('hey')
# Out:
#   File "<ipython-input-28-ab75f1449678>", line 2
#     if column.value == dtype("")
#                                 ^
# SyntaxError: invalid syntax

# %%
clf = tree.DecisionTreeClassifier(random_state=0)
iris = load_iris()

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(20,10))

clf = clf.fit(iris.data, iris.target)
tree.plot_tree(clf)
# Out:
# [Text(558.0, 498.3, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(472.15384615384613, 407.70000000000005, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(643.8461538461538, 407.70000000000005, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(343.38461538461536, 317.1, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(171.69230769230768, 226.5, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(85.84615384615384, 135.89999999999998, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(257.53846153846155, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(515.0769230769231, 226.5, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(429.23076923076917, 135.89999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(600.9230769230769, 135.89999999999998, 'X[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(515.0769230769231, 45.299999999999955, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(686.7692307692307, 45.299999999999955, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(944.3076923076923, 317.1, 'X[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(858.4615384615383, 226.5, 'X[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(772.6153846153845, 135.89999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(944.3076923076923, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(1030.1538461538462, 226.5, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(20,10))

clf = clf.fit(X, Y)
tree.plot_tree(clf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-4d9d05fa990b> in <module>
#       1 fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(20,10))
#       2
# ----> 3 clf = clf.fit(X, Y)
#       4 tree.plot_tree(clf)
#
# ~\anaconda3\envs\tC\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     900             sample_weight=sample_weight,
#     901             check_input=check_input,
# --> 902             X_idx_sorted=X_idx_sorted)
#     903         return self
#     904
#
# ~\anaconda3\envs\tC\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     156             X, y = self._validate_data(X, y,
#     157                                        validate_separately=(check_X_params,
# --> 158                                                             check_y_params))
#     159             if issparse(X):
#     160                 X.sort_indices()
#
# ~\anaconda3\envs\tC\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     428                 # :(
#     429                 check_X_params, check_y_params = validate_separately
# --> 430                 X = check_array(X, **check_X_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
#
# ~\anaconda3\envs\tC\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\tC\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\envs\tC\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~\anaconda3\envs\tC\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1779
#    1780     def __array__(self, dtype=None) -> np.ndarray:
# -> 1781         return np.asarray(self._values, dtype=dtype)
#    1782
#    1783     def __array_wrap__(self, result, context=None):
#
# ~\anaconda3\envs\tC\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'RL'
