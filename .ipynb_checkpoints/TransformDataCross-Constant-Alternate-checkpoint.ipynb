# %%
import pandas as pd
import numpy as np
import sklearn.tree as tree
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os.path
from os import path
from sklearn.model_selection import KFold
from multiprocessing import Process, Manager, SimpleQueue
import multiprocessing
import shutil
import sys
import time
from sklearn.metrics import accuracy_score
from rules import *
from vote_CST import *
from cv import *
from precision_CST import *

root = "./../Classic_threshold_with_constant_alternate/"
cv = 3

colors_to_print = ["red",  "blue", "orange",  "violet", "darkgrey", "darkred", "darkblue", "darkorange", "darkviolet", "grey"]

# %% [markdown]
# # 1° Load data

# %%
data = pd.read_csv("Data/miniloan-decisions-100K.csv")

# %%
data
# Out:
#            name  creditScore  income  loanAmount  monthDuration      rate  \
# 0      John Doe          736  113243      783440            162  0.030005
# 1      John Doe          527  224186     1787385            183  0.054819
# 2      John Doe          460   39954     1733494             75  0.055183
# 3      John Doe          751  219998     1350004             72  0.043400
# 4      John Doe          684   72470     1210944            160  0.037772
# ...         ...          ...     ...         ...            ...       ...
# 99995  John Doe          366   83851     1718571            168  0.053737
# 99996  John Doe          395  184259     1599473             90  0.040564
# 99997  John Doe          674  242620     1099790            260  0.040825
# 99998  John Doe          420  180957     1645870            203  0.049558
# 99999  John Doe          699  102769      665190            244  0.058460
#
#       approval  yearlyReimbursement
# 0        false                70648
# 1        false               173197
# 2        false               328563
# 3        false               255970
# 4        false               115742
# ...        ...                  ...
# 99995    false               174928
# 99996    false               247703
# 99997    false                76557
# 99998    false               143897
# 99999    false                55993
#
# [100000 rows x 8 columns]

# %% [markdown]
# # Ratios

# %%
ratio_names = [("income","yearlyReimbursement"), ("income","loanAmount"), ("loanAmount","rate")]

# %%
# Takes two features and will create the ratio f_0/f_1
def create_features_ratio(data):
    if data[data.index[1]] == 0:
        return 2147483647
    return np.round(data[data.index[0]]/data[data.index[1]], decimals=2)

# %%
for ratio_name in ratio_names:
    data[f"{ratio_name[0]}/{ratio_name[1]}"] = data[[ratio_name[0], ratio_name[1]]].apply(create_features_ratio, axis=1)

# %%
data
# Out:
#            name  creditScore  income  loanAmount  monthDuration      rate  \
# 0      John Doe          736  113243      783440            162  0.030005
# 1      John Doe          527  224186     1787385            183  0.054819
# 2      John Doe          460   39954     1733494             75  0.055183
# 3      John Doe          751  219998     1350004             72  0.043400
# 4      John Doe          684   72470     1210944            160  0.037772
# ...         ...          ...     ...         ...            ...       ...
# 99995  John Doe          366   83851     1718571            168  0.053737
# 99996  John Doe          395  184259     1599473             90  0.040564
# 99997  John Doe          674  242620     1099790            260  0.040825
# 99998  John Doe          420  180957     1645870            203  0.049558
# 99999  John Doe          699  102769      665190            244  0.058460
#
#       approval  yearlyReimbursement  income/yearlyReimbursement  \
# 0        false                70648                        1.60
# 1        false               173197                        1.29
# 2        false               328563                        0.12
# 3        false               255970                        0.86
# 4        false               115742                        0.63
# ...        ...                  ...                         ...
# 99995    false               174928                        0.48
# 99996    false               247703                        0.74
# 99997    false                76557                        3.17
# 99998    false               143897                        1.26
# 99999    false                55993                        1.84
#
#        income/loanAmount  loanAmount/rate
# 0                   0.14      26110372.80
# 1                   0.13      32605003.59
# 2                   0.02      31413368.70
# 3                   0.16      31106073.81
# 4                   0.06      32059172.14
# ...                  ...              ...
# 99995               0.05      31981153.44
# 99996               0.12      39430859.20
# 99997               0.22      26938940.88
# 99998               0.11      33211031.24
# 99999               0.15      11378481.46
#
# [100000 rows x 11 columns]

# %% [markdown]
# # 3° Create the thresholds

# %% [markdown]
# Define the thresholds

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
# Takes a dataframe and return the values per percents for each feature
def description_per_thresholds(data, percents):
    thresholds_Dic =  {}
    for column in data.columns:
        serie = data[column]
        thresholds_Dic[column] = serie.quantile(percents)
        
    return pd.DataFrame.from_dict(thresholds_Dic)

# %%
def GTE_prep_df(value, valueToCompareTo):
    return value >= valueToCompareTo

def LTE_prep_df(value, valueToCompareTo):
    return value <= valueToCompareTo

def GT_prep_df(value, valueToCompareTo):
    return value > valueToCompareTo

def LT_prep_df(value, valueToCompareTo):
    return value < valueToCompareTo

# %%
columns_to_compare = ['creditScore', 'income', 'loanAmount', 'monthDuration', 'rate', 'yearlyReimbursement', 'income/yearlyReimbursement']

description = description_per_thresholds(data[columns_to_compare], thresholds)

# %% [markdown]
# Transform the data from integer values to boolean values corresponding to GTE or LTE with the different percents.

# %%
# %%time

booleanDF = pd.DataFrame()

for column in columns_to_compare:
    for i, value in enumerate(thresholds):
        booleanDF[column+"-GTE-"+str(int(value*100))] = data[column].map(lambda x : GTE_prep_df(x, description[column].values[i]))
        booleanDF[column+"-LTE-"+str(int(value*100))] = data[column].map(lambda x : LTE_prep_df(x, description[column].values[i]))
# Out:
# CPU times: user 12.4 s, sys: 46.9 ms, total: 12.4 s
# Wall time: 12.4 s

# %%
booleanDF["approval"] = data["approval"].map({' true': True, ' false': False})
booleanDF
# Out:
#        creditScore-GTE-25  creditScore-LTE-25  creditScore-GTE-50  \
# 0                    True               False                True
# 1                    True               False               False
# 2                    True               False               False
# 3                    True               False                True
# 4                    True               False                True
# ...                   ...                 ...                 ...
# 99995               False                True               False
# 99996               False                True               False
# 99997                True               False                True
# 99998               False                True               False
# 99999                True               False                True
#
#        creditScore-LTE-50  creditScore-GTE-75  creditScore-LTE-75  \
# 0                   False                True               False
# 1                    True               False                True
# 2                    True               False                True
# 3                   False                True               False
# 4                   False               False                True
# ...                   ...                 ...                 ...
# 99995                True               False                True
# 99996                True               False                True
# 99997               False               False                True
# 99998                True               False                True
# 99999               False               False                True
#
#        income-GTE-25  income-LTE-25  income-GTE-50  income-LTE-50  ...  \
# 0               True          False          False           True  ...
# 1               True          False           True          False  ...
# 2              False           True          False           True  ...
# 3               True          False           True          False  ...
# 4              False           True          False           True  ...
# ...              ...            ...            ...            ...  ...
# 99995           True          False          False           True  ...
# 99996           True          False           True          False  ...
# 99997           True          False           True          False  ...
# 99998           True          False           True          False  ...
# 99999           True          False          False           True  ...
#
#        yearlyReimbursement-LTE-50  yearlyReimbursement-GTE-75  \
# 0                            True                       False
# 1                           False                        True
# 2                           False                        True
# 3                           False                        True
# 4                           False                       False
# ...                           ...                         ...
# 99995                       False                        True
# 99996                       False                        True
# 99997                        True                       False
# 99998                       False                       False
# 99999                        True                       False
#
#        yearlyReimbursement-LTE-75  income/yearlyReimbursement-GTE-25  \
# 0                            True                               True
# 1                           False                               True
# 2                           False                              False
# 3                           False                               True
# 4                            True                               True
# ...                           ...                                ...
# 99995                       False                              False
# 99996                       False                               True
# 99997                        True                               True
# 99998                        True                               True
# 99999                        True                               True
#
#        income/yearlyReimbursement-LTE-25  income/yearlyReimbursement-GTE-50  \
# 0                                  False                               True
# 1                                  False                              False
# 2                                   True                              False
# 3                                  False                              False
# 4                                  False                              False
# ...                                  ...                                ...
# 99995                               True                              False
# 99996                              False                              False
# 99997                              False                               True
# 99998                              False                              False
# 99999                              False                               True
#
#        income/yearlyReimbursement-LTE-50  income/yearlyReimbursement-GTE-75  \
# 0                                  False                              False
# 1                                   True                              False
# 2                                   True                              False
# 3                                   True                              False
# 4                                   True                              False
# ...                                  ...                                ...
# 99995                               True                              False
# 99996                               True                              False
# 99997                              False                               True
# 99998                               True                              False
# 99999                              False                              False
#
#        income/yearlyReimbursement-LTE-75  approval
# 0                                   True     False
# 1                                   True     False
# 2                                   True     False
# 3                                   True     False
# 4                                   True     False
# ...                                  ...       ...
# 99995                               True     False
# 99996                               True     False
# 99997                              False     False
# 99998                               True     False
# 99999                               True     False
#
# [100000 rows x 43 columns]

# %% [markdown]
# Create the folder where the data will be stored.

# %%
if not path.isdir(root):
    os.mkdir(root)
else : 
    shutil.rmtree(root)
    os.mkdir(root)

# %%
booleanDF.to_csv(root+"dfSave.csv")

# %% [markdown]
# # 4° Save the best data

# %%
# Transform an integer id to a string id
def int_to_str_id(idsInt):
    res = chr(97+idsInt%26)
    idsReducted = int(idsInt/26)
    while idsReducted != 0:
        res = chr(97+(idsReducted-1)%26) + res
        idsReducted = int(idsReducted/26)
    return res

# Syntax of Amie data
def syntax(subject, predicate, objectD):
    return f"{subject}\t{predicate}\t{objectD} \n" # Integer id
    #return f"{int_to_str_id(subject)}\t{predicate}\t{objectD} \n" #String id

# Create the text for each feature and finally write it to the file
def formatData(f, idData, data):
    toWrite = ""
    for i in data.index:
        toWrite += syntax(idData, i, data.loc[i])
    f.write(toWrite)

# %% [markdown]
# We store the data in the Amie format.

# %%
f = open(root+"Knowledge_Data.tsv", "w")

booleanDF_to_Save = booleanDF
booleanDF_to_Save["approval"] = data["approval"].map({' true': True, ' false': False})

for idData in booleanDF_to_Save.index:
    formatData(f, idData, booleanDF_to_Save.iloc[idData])
    
f.close()

# %% [markdown]
# ## Save in cross validation

# %%
booleanDF_to_Save = booleanDF
booleanDF_to_Save["approval"] = data["approval"].map({' true': True, ' false': False})

kf = KFold(n_splits=cv, shuffle=True, random_state=42)
kf.get_n_splits(booleanDF_to_Save)

cp = 0

for train_index, test_index in kf.split(booleanDF_to_Save):
    
    f = open(root+f"CV_train_{cp}.tsv", "w")

    for idData in train_index:
        formatData(f, idData, booleanDF_to_Save.iloc[idData])

    f.close()
    
    print("Train repartition :\n",booleanDF_to_Save.iloc[train_index]["approval"].value_counts())
    
    f = open(root+f"CV_valid_{cp}.tsv", "w")

    for idData in test_index:
        formatData(f, idData, booleanDF_to_Save.iloc[idData])

    f.close()
    
    f = open(root+f"index_{cp}.tsv", "w")

    f.write(str(train_index[0]))
    for i in range(1,len(train_index)):
        f.write(","+str(train_index[i]))
    f.write("\n")
    f.write(str(test_index[0]))
    for i in range(1,len(test_index)):
        f.write(","+str(test_index[i]))

    f.close()
    
    cp += 1
# Out:
# Train repartition :
#  False    52004
# True     14662
# Name: approval, dtype: int64
# Train repartition :
#  False    52007
# True     14660
# Name: approval, dtype: int64
# Train repartition :
#  False    52081
# True     14586
# Name: approval, dtype: int64

# %% [markdown]
# # 5° Launch Amie

# %% [markdown]
# Describe the parameters.

# %%
atom_LIST = [2, 3]
minc_LIST = [0, 0.4, 0.8]
minhc_LIST = [0, 0.4, 0.8]

# %% [markdown]
# Launch Amie.

# %%
# %%time
# %%capture --no-stderr captured 

sep = "-----------------------------"

parameters = []

for i in range(cv):
    for atom in atom_LIST:
        sys.stderr.write(f"{atom}\n")
        data = f"{root}CV_train_{i}.tsv"
        start = time.time()
        # !java -jar amie3.jar -const -htr approval -maxad $atom $data
        parameters.append(f"CV={i}-A={atom}")
        done = time.time()
        elapsed = done - start
        sys.stderr.write("Time "+str(elapsed/60)+" m\n")
        print(sep)
# Out:
# 2
# Time 35.707601217428845 m
# 2
# Time 34.04706681569417 m
# 2
# CPU times: user 46.9 ms, sys: 188 ms, total: 234 ms
# Wall time: 1h 45min 29s
# Time 35.73367882172267 m

# %%
#captured.stdout

# %% [markdown]
# Transform the raw output into sets of rules.

# %%
rules_per_cv = {}
cpt = 0
for cv_res in captured.stdout.split(sep)[:-1]:
    rules = set()
    for line in cv_res.split("\n"):
        if (line != "") and (line[0] == "?"):
            dic = {}
            parts = line.split("\t")

            conclusion_raw = parts[0].split("=>")[1].split("  ")
            conclusion_raw[0] = conclusion_raw[0][1:]
            dic["conclusion"] = Atom(conclusion_raw)

            hypotheses_raw = parts[0].split("=>")[0].split("  ")
            hypotheses = []
            for i in range(0, len(hypotheses_raw)-1, 3):
                hypotheses.append(Atom(hypotheses_raw[i:i+3]))
            dic["hypotheses"] = hypotheses


            rules.add(Rule(dic["hypotheses"], dic["conclusion"], parts[1:]))
    rules_per_cv[parameters[cpt]] = rules
    cpt+=1

# %% [markdown]
# Retrieve the indexes for each CV.

# %%
indexes = retrieve_indexes(root, cv)
df = pd.read_csv(root+"dfSave.csv")

# %% [markdown]
# # 5° Precision

# %%
# %%time

rules_per_para = run_precision(root, indexes, parameters, rules_per_cv)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 100)
# Process n°1 : Finished
# Process n°4 : Finished
# Process n°8 : Finished
# Process n°0 : Finished
# Process n°3 : Finished
# Process n°9 : Finished
# Process n°11 : Finished
# Process n°6 : Finished
# Process n°5 : Finished
# Process n°7 : Finished
# Process n°10 : Finished
# Process n°2 : Finished
# Process n°12 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : LaunchedProcess n°5 : Launched
#
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 100)
# Process n°0 : Finished
# Process n°1 : Finished
# Process n°3 : Finished
# Process n°6 : Finished
# Process n°8 : Finished
# Process n°9 : Finished
# Process n°4 : Finished
# Process n°11 : Finished
# Process n°5 : Finished
# Process n°7 : Finished
# Process n°2 : Finished
# Process n°12 : Finished
# Process n°10 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 100)
# Process n°1 : Finished
# Process n°11 : Finished
# Process n°8 : Finished
# Process n°9 : Finished
# Process n°0 : Finished
# Process n°3 : Finished
# Process n°6 : Finished
# Process n°4 : Finished
# Process n°2 : Finished
# Process n°7 : Finished
# Process n°10 : Finished
# Process n°12 : Finished
# Process n°5 : Finished
# CPU times: user 359 ms, sys: 1.58 s, total: 1.94 s
# Wall time: 5min 15s

# %% [markdown]
# ### Add parameters

# %% [markdown]
# Describe the combinaison of these new parameters.

# %%
new_parameters = []
for minc in minc_LIST:
    for minhc in minhc_LIST:
        new_parameters.append([("stdConfidence", minc), ("headCoverage", minhc)])
print(new_parameters)
# Out:
# [[('stdConfidence', 0), ('headCoverage', 0)], [('stdConfidence', 0), ('headCoverage', 0.4)], [('stdConfidence', 0.4), ('headCoverage', 0)], [('stdConfidence', 0.4), ('headCoverage', 0.4)]]

# %% [markdown]
# Create the DataFrames corresponding to these parameters.

# %%
new_dfs = add_parameters(rules_per_para, new_parameters)

# %% [markdown]
# Print the precision for each parameters.

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 
to_print, to_print_std = mean_and_std_precision(new_dfs, cv)

to_print.plot.bar(ax=_axs, rot=0, yerr=to_print_std, yerr=[0,1])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 6° Prediction

# %%
to_print_save =  []
to_print_std_save = []

# %%
# %%time

# prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy_proportional, indexes, True)
prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy, indexes, True)

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "Demo")
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

max_possible = bestScorePossible(prediction_per_rules_count)
print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : LaunchedProcess n°11 : Launched
#
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°1 : Finished
# Process n°9 : Finished
# Process n°5 : Finished
# Process n°3 : Finished
# Process n°11 : Finished
# Process n°7 : Finished
# Process n°2 : Finished
# Process n°10 : Finished
# Process n°6 : Finished
# Value('d', 10)
# Process n°8 : Finished
# Process n°0 : Finished
# Process n°4 : Finished
# 12
# CPU times: user 2.98 s, sys: 2.28 s, total: 5.27 s
# Wall time: 4min 57s

# %%
# %%time

# prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy, indexes, True)
prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, safe, indexes, True)

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "Safe")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°7 : Finished
# Process n°5 : Finished
# Process n°1 : Finished
# Process n°3 : Finished
# Process n°2 : Finished
# Process n°6 : Finished
# Process n°9 : Finished
# Process n°10 : Finished
# Process n°11 : Finished
# Value('d', 10)
# Process n°0 : Finished
# Process n°4 : Finished
# Process n°8 : Finished
# 12
# CPU times: user 2.97 s, sys: 734 ms, total: 3.7 s
# Wall time: 18.7 s

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["precision_train", "precision_test"], [False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-precision")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°4 : Finished
# Process n°5 : Finished
# Process n°0 : Finished
# Process n°2 : Finished
# Process n°1 : Finished
# Process n°9 : Finished
# Process n°3 : Finished
# Process n°7 : Finished
# Process n°10 : Finished
# Value('d', 10)
# Process n°8 : Finished
# Process n°11 : Finished
# Process n°6 : Finished
# 12
# CPU times: user 2.98 s, sys: 766 ms, total: 3.75 s
# Wall time: 22.7 s

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["headCoverage", "precision_train", "precision_test"], [True, False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-coverage")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°0 : Finished
# Process n°1 : Finished
# Process n°3 : Finished
# Process n°2 : Finished
# Process n°5 : Finished
# Process n°7 : Finished
# Process n°6 : Finished
# Process n°4 : Finished
# Process n°9 : Finished
# Value('d', 10)
# Process n°8 : Finished
# Process n°10 : Finished
# Process n°11 : Finished
# 12
# CPU times: user 2.95 s, sys: 719 ms, total: 3.67 s
# Wall time: 22.7 s

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["size_hypothese", "precision_train", "precision_test"], [False, False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-length")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°0 : Finished
# Process n°1 : Finished
# Process n°4 : Finished
# Process n°5 : Finished
# Process n°8 : Finished
# Process n°3 : Finished
# Process n°9 : Finished
# Process n°7 : Finished
# Value('d', 10)
# Process n°10 : Finished
# Process n°6 : Finished
# Process n°11 : Finished
# Process n°2 : Finished
# 12
# CPU times: user 3.05 s, sys: 750 ms, total: 3.8 s
# Wall time: 23.1 s

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 187 entries, ?a yearlyReimbursement-GTE-75 True => ?a approval False to ?a income-LTE-25 True => ?a approval False
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   hypotheses       187 non-null    object
#  1   conclusion       187 non-null    object
#  2   size_hypothese   187 non-null    int64
#  3   headCoverage     187 non-null    float64
#  4   stdConfidence    187 non-null    float64
#  5   pcaConfidence    187 non-null    float64
#  6   precision_train  187 non-null    float64
#  7   precision_test   187 non-null    float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 13.1+ KB

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0'].describe()
# Out:
#        size_hypothese  headCoverage  stdConfidence  pcaConfidence  \
# count           187.0    187.000000     187.000000     187.000000
# mean              1.0      0.335266       0.558398       0.558398
# std               0.0      0.211553       0.272735       0.272735
# min               1.0      0.030150       0.106471       0.106471
# 25%               1.0      0.164462       0.292666       0.292666
# 50%               1.0      0.280458       0.562354       0.562354
# 75%               1.0      0.517138       0.780056       0.780056
# max               1.0      0.968815       1.000000       1.000000
#
#        precision_train  precision_test
# count       187.000000      187.000000
# mean          0.502173        0.502179
# std           0.191011        0.191764
# min           0.030150        0.030569
# 25%           0.359569        0.359273
# 50%           0.500255        0.502400
# 75%           0.639471        0.639737
# max           0.968815        0.968441

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0']
# Out:
#                                                                                       hypotheses  \
# ?a yearlyReimbursement-GTE-75 True => ?a approv...         (?a yearlyReimbursement-GTE-75 True,)
# ?a yearlyReimbursement-GTE-50 ?b => ?a approval ?b           (?a yearlyReimbursement-GTE-50 ?b,)
# ?a income/yearlyReimbursement-LTE-25 True => ?a...  (?a income/yearlyReimbursement-LTE-25 True,)
# ?a yearlyReimbursement-GTE-25 ?b => ?a approval ?b           (?a yearlyReimbursement-GTE-25 ?b,)
# ?a monthDuration-GTE-75 False => ?a approval False              (?a monthDuration-GTE-75 False,)
# ...                                                                                          ...
# ?a loanAmount-GTE-75 False => ?a approval False                    (?a loanAmount-GTE-75 False,)
# ?a income-LTE-25 False => ?a approval True                             (?a income-LTE-25 False,)
# ?a income-GTE-25 True => ?a approval False                              (?a income-GTE-25 True,)
# ?a rate-GTE-50 True => ?a approval False                                  (?a rate-GTE-50 True,)
# ?a income-LTE-25 True => ?a approval False                              (?a income-LTE-25 True,)
#
#                                                            conclusion  \
# ?a yearlyReimbursement-GTE-75 True => ?a approv...  ?a approval False
# ?a yearlyReimbursement-GTE-50 ?b => ?a approval ?b     ?a approval ?b
# ?a income/yearlyReimbursement-LTE-25 True => ?a...  ?a approval False
# ?a yearlyReimbursement-GTE-25 ?b => ?a approval ?b     ?a approval ?b
# ?a monthDuration-GTE-75 False => ?a approval False  ?a approval False
# ...                                                               ...
# ?a loanAmount-GTE-75 False => ?a approval False     ?a approval False
# ?a income-LTE-25 False => ?a approval True           ?a approval True
# ?a income-GTE-25 True => ?a approval False          ?a approval False
# ?a rate-GTE-50 True => ?a approval False            ?a approval False
# ?a income-LTE-25 True => ?a approval False          ?a approval False
#
#                                                     size_hypothese  \
# ?a yearlyReimbursement-GTE-75 True => ?a approv...               1
# ?a yearlyReimbursement-GTE-50 ?b => ?a approval ?b               1
# ?a income/yearlyReimbursement-LTE-25 True => ?a...               1
# ?a yearlyReimbursement-GTE-25 ?b => ?a approval ?b               1
# ?a monthDuration-GTE-75 False => ?a approval False               1
# ...                                                            ...
# ?a loanAmount-GTE-75 False => ?a approval False                  1
# ?a income-LTE-25 False => ?a approval True                       1
# ?a income-GTE-25 True => ?a approval False                       1
# ?a rate-GTE-50 True => ?a approval False                         1
# ?a income-LTE-25 True => ?a approval False                       1
#
#                                                     headCoverage  \
# ?a yearlyReimbursement-GTE-75 True => ?a approv...      0.248987
# ?a yearlyReimbursement-GTE-50 ?b => ?a approval ?b      0.281688
# ?a income/yearlyReimbursement-LTE-25 True => ?a...      0.252243
# ?a yearlyReimbursement-GTE-25 ?b => ?a approval ?b      0.106471
# ?a monthDuration-GTE-75 False => ?a approval False      0.607536
# ...                                                          ...
# ?a loanAmount-GTE-75 False => ?a approval False         0.531545
# ?a income-LTE-25 False => ?a approval True              0.205697
# ?a income-GTE-25 True => ?a approval False              0.544175
# ?a rate-GTE-50 True => ?a approval False                0.392689
# ?a income-LTE-25 True => ?a approval False              0.235892
#
#                                                     stdConfidence  \
# ?a yearlyReimbursement-GTE-75 True => ?a approv...       1.000000
# ?a yearlyReimbursement-GTE-50 ?b => ?a approval ?b       0.281688
# ?a income/yearlyReimbursement-LTE-25 True => ?a...       1.000000
# ?a yearlyReimbursement-GTE-25 ?b => ?a approval ?b       0.106471
# ?a monthDuration-GTE-75 False => ?a approval False       0.811322
# ...                                                           ...
# ?a loanAmount-GTE-75 False => ?a approval False          0.707334
# ?a income-LTE-25 False => ?a approval True               0.274309
# ?a income-GTE-25 True => ?a approval False               0.725691
# ?a rate-GTE-50 True => ?a approval False                 0.787173
# ?a income-LTE-25 True => ?a approval False               0.943088
#
#                                                     pcaConfidence  \
# ?a yearlyReimbursement-GTE-75 True => ?a approv...       1.000000
# ?a yearlyReimbursement-GTE-50 ?b => ?a approval ?b       0.281688
# ?a income/yearlyReimbursement-LTE-25 True => ?a...       1.000000
# ?a yearlyReimbursement-GTE-25 ?b => ?a approval ?b       0.106471
# ?a monthDuration-GTE-75 False => ?a approval False       0.811322
# ...                                                           ...
# ?a loanAmount-GTE-75 False => ?a approval False          0.707334
# ?a income-LTE-25 False => ?a approval True               0.274309
# ?a income-GTE-25 True => ?a approval False               0.725691
# ?a rate-GTE-50 True => ?a approval False                 0.787173
# ?a income-LTE-25 True => ?a approval False               0.943088
#
#                                                     precision_train  \
# ?a yearlyReimbursement-GTE-75 True => ?a approv...         0.531080
# ?a yearlyReimbursement-GTE-50 ?b => ?a approval ?b         0.281688
# ?a income/yearlyReimbursement-LTE-25 True => ?a...         0.527825
# ?a yearlyReimbursement-GTE-25 ?b => ?a approval ?b         0.106471
# ?a monthDuration-GTE-75 False => ?a approval False         0.686182
# ...                                                             ...
# ?a loanAmount-GTE-75 False => ?a approval False            0.531545
# ?a income-LTE-25 False => ?a approval True                 0.558411
# ?a income-GTE-25 True => ?a approval False                 0.441589
# ?a rate-GTE-50 True => ?a approval False                   0.493550
# ?a income-LTE-25 True => ?a approval False                 0.558411
#
#                                                     precision_test
# ?a yearlyReimbursement-GTE-75 True => ?a approv...        0.529219
# ?a yearlyReimbursement-GTE-50 ?b => ?a approval ?b        0.278004
# ?a income/yearlyReimbursement-LTE-25 True => ?a...        0.527119
# ?a yearlyReimbursement-GTE-25 ?b => ?a approval ?b        0.105118
# ?a monthDuration-GTE-75 False => ?a approval False        0.688396
# ...                                                            ...
# ?a loanAmount-GTE-75 False => ?a approval False           0.528289
# ?a income-LTE-25 False => ?a approval True                0.561439
# ?a income-GTE-25 True => ?a approval False                0.438561
# ?a rate-GTE-50 True => ?a approval False                  0.492560
# ?a income-LTE-25 True => ?a approval False                0.561439
#
# [187 rows x 8 columns]
