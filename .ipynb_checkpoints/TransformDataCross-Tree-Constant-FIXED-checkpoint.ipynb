# %%
import pandas as pd
import numpy as np
import sklearn.tree as tree
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os.path
from os import path
from sklearn.model_selection import KFold
from multiprocessing import Process, Manager, SimpleQueue
import multiprocessing
import shutil
import sys
import time
from sklearn.metrics import accuracy_score
from rules import *
from vote_CST import *
from cv import *
from precision_CST import *

root = "./../Tree_threshold_with_constant/"
cv = 3

colors_to_print = ["red",  "blue", "orange",  "violet", "darkgrey", "darkred", "darkblue", "darkorange", "darkviolet", "grey"]

# %% [markdown]
# # 1° Load data

# %%
data = pd.read_csv("Data/miniloan-decisions-100K.csv")

# %%
data
# Out:
#            name  creditScore  income  loanAmount  monthDuration      rate  \
# 0      John Doe          736  113243      783440            162  0.030005
# 1      John Doe          527  224186     1787385            183  0.054819
# 2      John Doe          460   39954     1733494             75  0.055183
# 3      John Doe          751  219998     1350004             72  0.043400
# 4      John Doe          684   72470     1210944            160  0.037772
# ...         ...          ...     ...         ...            ...       ...
# 99995  John Doe          366   83851     1718571            168  0.053737
# 99996  John Doe          395  184259     1599473             90  0.040564
# 99997  John Doe          674  242620     1099790            260  0.040825
# 99998  John Doe          420  180957     1645870            203  0.049558
# 99999  John Doe          699  102769      665190            244  0.058460
#
#       approval  yearlyReimbursement
# 0        false                70648
# 1        false               173197
# 2        false               328563
# 3        false               255970
# 4        false               115742
# ...        ...                  ...
# 99995    false               174928
# 99996    false               247703
# 99997    false                76557
# 99998    false               143897
# 99999    false                55993
#
# [100000 rows x 8 columns]

# %% [markdown]
# # Ratios

# %%
ratio_names = [("income","yearlyReimbursement"), ("income","loanAmount"), ("loanAmount","rate")]

# %%
# Takes two features and will create the ratio f_0/f_1
def create_features_ratio(data):
    if data[data.index[1]] == 0:
        return 2147483647
    return np.round(data[data.index[0]]/data[data.index[1]], decimals=2)

# %%
for ratio_name in ratio_names:
    data[f"{ratio_name[0]}/{ratio_name[1]}"] = data[[ratio_name[0], ratio_name[1]]].apply(create_features_ratio, axis=1)

# %%
data
# Out:
#            name  creditScore  income  loanAmount  monthDuration      rate  \
# 0      John Doe          736  113243      783440            162  0.030005
# 1      John Doe          527  224186     1787385            183  0.054819
# 2      John Doe          460   39954     1733494             75  0.055183
# 3      John Doe          751  219998     1350004             72  0.043400
# 4      John Doe          684   72470     1210944            160  0.037772
# ...         ...          ...     ...         ...            ...       ...
# 99995  John Doe          366   83851     1718571            168  0.053737
# 99996  John Doe          395  184259     1599473             90  0.040564
# 99997  John Doe          674  242620     1099790            260  0.040825
# 99998  John Doe          420  180957     1645870            203  0.049558
# 99999  John Doe          699  102769      665190            244  0.058460
#
#       approval  yearlyReimbursement  income/yearlyReimbursement  \
# 0        false                70648                        1.60
# 1        false               173197                        1.29
# 2        false               328563                        0.12
# 3        false               255970                        0.86
# 4        false               115742                        0.63
# ...        ...                  ...                         ...
# 99995    false               174928                        0.48
# 99996    false               247703                        0.74
# 99997    false                76557                        3.17
# 99998    false               143897                        1.26
# 99999    false                55993                        1.84
#
#        income/loanAmount  loanAmount/rate
# 0                   0.14      26110372.80
# 1                   0.13      32605003.59
# 2                   0.02      31413368.70
# 3                   0.16      31106073.81
# 4                   0.06      32059172.14
# ...                  ...              ...
# 99995               0.05      31981153.44
# 99996               0.12      39430859.20
# 99997               0.22      26938940.88
# 99998               0.11      33211031.24
# 99999               0.15      11378481.46
#
# [100000 rows x 11 columns]

# %% [markdown]
# # 2° Find the best thresholds

# %%
data_raw = data.drop(columns=["name"])
false_data = data_raw[data_raw["approval"] == " false"]
true_data = data_raw[data_raw["approval"] == " true"]
data_equilibrium = true_data.append(false_data.sample(n=len(true_data)))

# %%
# %%time

def returnSplitValue(stringToSplit):
    res = []
    tp = ""
    spliters = [("lt", "< "), ("lte", "<= "), ("gt", "> "), ("gte", ">= ")]
    i=0
    
    while i < len(spliters):
        splited = stringToSplit.split(spliters[i][1]) 
        if len(splited) == 2:
            return  spliters[i][0], float(splited[1])
        i += 1
    print("C'est casse")
    return None 


best_threshold = []
for key in data_equilibrium.keys():
    if key != "approval":
        print("\t\t"+key)
        X = data_equilibrium[[key]]

        Y = data_equilibrium["approval"]

        X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)
        
        model = tree.DecisionTreeClassifier(max_depth=1)
        model.fit(X_train, y_train)    

        print(f"Train Score : {accuracy_score(y_train, model.predict(X_train))}")
        print(f"Test Score : {accuracy_score(y_test, model.predict(X_test))}")
        
        if accuracy_score(y_train, model.predict(X_train)) > 0.8 and accuracy_score(y_test, model.predict(X_test)) > 0.8:
            best_threshold.append((key,)+ returnSplitValue(tree.export_text(model, spacing=1, feature_names=[key]).split("\n")[0]))
print(best_threshold)
# Out:
# 		creditScore
# Train Score : 0.5037732000815827
# Test Score : 0.5015873015873016
# 		income
# Train Score : 0.6428037256101706
# Test Score : 0.6399585921325052
# 		loanAmount
# Train Score : 0.8387381875042491
# Test Score : 0.8413388543823327
# 		monthDuration
# Train Score : 0.6122781970222313
# Test Score : 0.6084195997239475
# 		rate
# Train Score : 0.5143449588687198
# Test Score : 0.512008281573499
# 		yearlyReimbursement
# Train Score : 0.8964579509144062
# Test Score : 0.8993098688750862
# 		income/yearlyReimbursement
# Train Score : 0.9932354340879733
# Test Score : 0.9937888198757764
# 		income/loanAmount
# Train Score : 0.924671969542457
# Test Score : 0.9189095928226363
# 		loanAmount/rate
# Train Score : 0.8268747025630566
# Test Score : 0.8240165631469979
# [('loanAmount', 'lte', 845901.0), ('yearlyReimbursement', 'lte', 68872.0), ('income/yearlyReimbursement', 'lte', 3.33), ('income/loanAmount', 'lte', 0.24), ('loanAmount/rate', 'lte', 16619675.5)]
# CPU times: user 1.27 s, sys: 15.6 ms, total: 1.28 s
# Wall time: 1.28 s

# %% [markdown]
# # 3° Create the thresholds

# %% [markdown]
# Define the thresholds

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
# Takes a dataframe and return the values per percents for each feature
def description_per_thresholds(data, percents):
    thresholds_Dic =  {}
    for column in data.columns:
        serie = data[column]
        thresholds_Dic[column] = serie.quantile(percents)
        
    return pd.DataFrame.from_dict(thresholds_Dic)

# %%
def GTE_prep_df(value, valueToCompareTo):
    return value >= valueToCompareTo

def LTE_prep_df(value, valueToCompareTo):
    return value <= valueToCompareTo

def GT_prep_df(value, valueToCompareTo):
    return value > valueToCompareTo

def LT_prep_df(value, valueToCompareTo):
    return value < valueToCompareTo

# %%
columns = list(data.drop(columns=["name", "approval"]).columns)

booleanDF = pd.DataFrame()

for column, comparator, value in best_threshold:
    if comparator == "lte" or comparator == "gt":
#         booleanDF[column+"-GT-"+str(value)] = data[column].map(lambda x : GT_prep_df(x, value))
        booleanDF[column+"-LTE-"+str(value)] = data[column].map(lambda x : LTE_prep_df(x, value))
    else:
        booleanDF[column+"-GTE-"+str(value)] = data[column].map(lambda x : GTE_prep_df(x, value))
#         booleanDF[column+"-LT-"+str(value)] = data[column].map(lambda x : LT_prep_df(x, value))
    columns.remove(column)

# %%
description = description_per_thresholds(data[columns], thresholds)

# %% [markdown]
# Transform the data from integer values to boolean values corresponding to GTE or LTE with the different percents.

# %%
# %%time

for column in columns:
    for i, value in enumerate(thresholds):
        booleanDF[column+"-GTE-"+str(int(value*100))] = data[column].map(lambda x : GTE_prep_df(x, description[column].values[i]))
#         booleanDF[column+"-LTE-"+str(int(value*100))] = data[column].map(lambda x : LTE_prep_df(x, description[column].values[i]))
# Out:
# CPU times: user 3.45 s, sys: 15.6 ms, total: 3.47 s
# Wall time: 3.47 s

# %%
booleanDF["approval"] = data["approval"].map({' true': True, ' false': False})
booleanDF
# Out:
#        loanAmount-LTE-820905.0  yearlyReimbursement-LTE-63704.5  \
# 0                         True                            False
# 1                        False                            False
# 2                        False                            False
# 3                        False                            False
# 4                        False                            False
# ...                        ...                              ...
# 99995                    False                            False
# 99996                    False                            False
# 99997                    False                            False
# 99998                    False                            False
# 99999                     True                             True
#
#        income/yearlyReimbursement-LTE-3.33  income/loanAmount-LTE-0.24  \
# 0                                     True                        True
# 1                                     True                        True
# 2                                     True                        True
# 3                                     True                        True
# 4                                     True                        True
# ...                                    ...                         ...
# 99995                                 True                        True
# 99996                                 True                        True
# 99997                                 True                        True
# 99998                                 True                        True
# 99999                                 True                        True
#
#        loanAmount/rate-LTE-16170496.0  creditScore-GTE-25  creditScore-GTE-50  \
# 0                               False                True                True
# 1                               False                True               False
# 2                               False                True               False
# 3                               False                True                True
# 4                               False                True                True
# ...                               ...                 ...                 ...
# 99995                           False               False               False
# 99996                           False               False               False
# 99997                           False                True                True
# 99998                           False               False               False
# 99999                            True                True                True
#
#        creditScore-GTE-75  income-GTE-25  income-GTE-50  income-GTE-75  \
# 0                    True           True          False          False
# 1                   False           True           True          False
# 2                   False          False          False          False
# 3                    True           True           True          False
# 4                   False          False          False          False
# ...                   ...            ...            ...            ...
# 99995               False           True          False          False
# 99996               False           True           True          False
# 99997               False           True           True           True
# 99998               False           True           True          False
# 99999               False           True          False          False
#
#        monthDuration-GTE-25  monthDuration-GTE-50  monthDuration-GTE-75  \
# 0                      True                 False                 False
# 1                      True                  True                 False
# 2                     False                 False                 False
# 3                     False                 False                 False
# 4                      True                 False                 False
# ...                     ...                   ...                   ...
# 99995                  True                 False                 False
# 99996                  True                 False                 False
# 99997                  True                  True                 False
# 99998                  True                  True                 False
# 99999                  True                  True                 False
#
#        rate-GTE-25  rate-GTE-50  rate-GTE-75  approval
# 0            False        False        False     False
# 1             True         True         True     False
# 2             True         True         True     False
# 3             True        False        False     False
# 4             True        False        False     False
# ...            ...          ...          ...       ...
# 99995         True         True         True     False
# 99996         True        False        False     False
# 99997         True        False        False     False
# 99998         True         True        False     False
# 99999         True         True         True     False
#
# [100000 rows x 18 columns]

# %% [markdown]
# Create the folder where the data will be stored.

# %%
if not path.isdir(root):
    os.mkdir(root)
else : 
    shutil.rmtree(root)
    os.mkdir(root)

# %%
booleanDF.to_csv(root+"dfSave.csv")

# %% [markdown]
# # 4° Save the best data

# %%
# Transform an integer id to a string id
def int_to_str_id(idsInt):
    res = chr(97+idsInt%26)
    idsReducted = int(idsInt/26)
    while idsReducted != 0:
        res = chr(97+(idsReducted-1)%26) + res
        idsReducted = int(idsReducted/26)
    return res

# Syntax of Amie data
def syntax(subject, predicate, objectD):
    return f"{subject}\t{predicate}\t{objectD} \n" # Integer id
    #return f"{int_to_str_id(subject)}\t{predicate}\t{objectD} \n" #String id

# Create the text for each feature and finally write it to the file
def formatData(f, idData, data):
    toWrite = ""
    for i in data.index:
        toWrite += syntax(idData, i, data.loc[i])
    f.write(toWrite)

# %% [markdown]
# We store the data in the Amie format.

# %%
f = open(root+"Knowledge_Data.tsv", "w")

booleanDF_to_Save = booleanDF
booleanDF_to_Save["approval"] = data["approval"].map({' true': True, ' false': False})

for idData in booleanDF_to_Save.index:
    formatData(f, idData, booleanDF_to_Save.iloc[idData])
    
f.close()

# %% [markdown]
# ## Save in cross validation

# %%
booleanDF_to_Save = booleanDF
booleanDF_to_Save["approval"] = data["approval"].map({' true': True, ' false': False})

kf = KFold(n_splits=cv, shuffle=True, random_state=42)
kf.get_n_splits(booleanDF_to_Save)

cp = 0

for train_index, test_index in kf.split(booleanDF_to_Save):
    
    f = open(root+f"CV_train_{cp}.tsv", "w")

    for idData in train_index:
        formatData(f, idData, booleanDF_to_Save.iloc[idData])

    f.close()
    
    print("Train repartition :\n",booleanDF_to_Save.iloc[train_index]["approval"].value_counts())
    
    f = open(root+f"CV_valid_{cp}.tsv", "w")

    for idData in test_index:
        formatData(f, idData, booleanDF_to_Save.iloc[idData])

    f.close()
    
    f = open(root+f"index_{cp}.tsv", "w")

    f.write(str(train_index[0]))
    for i in range(1,len(train_index)):
        f.write(","+str(train_index[i]))
    f.write("\n")
    f.write(str(test_index[0]))
    for i in range(1,len(test_index)):
        f.write(","+str(test_index[i]))

    f.close()
    
    cp += 1
# Out:
# Train repartition :
#  False    52004
# True     14662
# Name: approval, dtype: int64
# Train repartition :
#  False    52007
# True     14660
# Name: approval, dtype: int64
# Train repartition :
#  False    52081
# True     14586
# Name: approval, dtype: int64

# %% [markdown]
# # 5° Launch Amie

# %% [markdown]
# Describe the parameters.

# %%
atom_LIST = [2, 3]
minc_LIST = [0, 0.4, 0.8]
minhc_LIST = [0, 0.4, 0.8]

# %% [markdown]
# Launch Amie.

# %%
# %%time
# %%capture --no-stderr captured 

sep = "-----------------------------"

parameters = []

for i in range(cv):
    for atom in atom_LIST:
        sys.stderr.write(f"{atom}\n")
        data = f"{root}CV_train_{i}.tsv"
        start = time.time()
        # !java -jar amie3.jar -const -htr approval -maxad $atom $data
        parameters.append(f"CV={i}-A={atom}")
        done = time.time()
        elapsed = done - start
        sys.stderr.write("Time "+str(elapsed/60)+" m\n")
        print(sep)
# Out:
# 2

# %%
#captured.stdout

# %% [markdown]
# Transform the raw output into sets of rules.

# %%
rules_per_cv = {}
cpt = 0
for cv_res in captured.stdout.split(sep)[:-1]:
    rules = set()
    for line in cv_res.split("\n"):
        if (line != "") and (line[0] == "?"):
            dic = {}
            parts = line.split("\t")

            conclusion_raw = parts[0].split("=>")[1].split("  ")
            conclusion_raw[0] = conclusion_raw[0][1:]
            dic["conclusion"] = Atom(conclusion_raw)

            hypotheses_raw = parts[0].split("=>")[0].split("  ")
            hypotheses = []
            for i in range(0, len(hypotheses_raw)-1, 3):
                hypotheses.append(Atom(hypotheses_raw[i:i+3]))
            dic["hypotheses"] = hypotheses


            rules.add(Rule(dic["hypotheses"], dic["conclusion"], parts[1:]))
    rules_per_cv[parameters[cpt]] = rules
    cpt+=1

# %% [markdown]
# Retrieve the indexes for each CV.

# %%
indexes = retrieve_indexes(root, cv)
df = pd.read_csv(root+"dfSave.csv")

# %% [markdown]
# # 5° Precision

# %%
# %%time

rules_per_para = run_precision(root, indexes, parameters, rules_per_cv)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°0 : Finished
# Process n°6 : Finished
# Process n°2 : Finished
# Process n°4 : Finished
# Process n°3 : Finished
# Process n°12 : Finished
# Process n°9 : Finished
# Process n°1 : Finished
# Process n°8 : Finished
# Process n°5 : Finished
# Process n°7 : Finished
# Process n°11 : Finished
# Process n°10 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
#
# Process n°9 : LaunchedProcess n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°0 : Finished
# Process n°6 : Finished
# Process n°3 : Finished
# Process n°12 : Finished
# Process n°5 : Finished
# Process n°10 : Finished
# Process n°9 : Finished
# Process n°2 : Finished
# Process n°7 : Finished
# Process n°8 : Finished
# Process n°4 : Finished
# Process n°1 : Finished
# Process n°11 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : LaunchedProcess n°4 : Launched
#
# Process n°5 : LaunchedProcess n°6 : Launched
#
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°0 : Finished
# Process n°6 : Finished
# Process n°1 : Finished
# Process n°9 : FinishedProcess n°4 : Finished
#
# Process n°2 : Finished
# Process n°3 : Finished
# Process n°5 : Finished
# Process n°12 : Finished
# Process n°10 : Finished
# Process n°7 : Finished
# Process n°8 : Finished
# Process n°11 : Finished
# CPU times: user 156 ms, sys: 1.78 s, total: 1.94 s
# Wall time: 1min 56s

# %% [markdown]
# ### Add parameters

# %% [markdown]
# Describe the combinaison of these new parameters.

# %%
new_parameters = []
for minc in minc_LIST:
    for minhc in minhc_LIST:
        new_parameters.append([("stdConfidence", minc), ("headCoverage", minhc)])
print(new_parameters)
# Out:
# [[('stdConfidence', 0), ('headCoverage', 0)], [('stdConfidence', 0), ('headCoverage', 0.4)], [('stdConfidence', 0.4), ('headCoverage', 0)], [('stdConfidence', 0.4), ('headCoverage', 0.4)]]

# %% [markdown]
# Create the DataFrames corresponding to these parameters.

# %%
new_dfs = add_parameters(rules_per_para, new_parameters)

# %% [markdown]
# Print the precision for each parameters.

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 
to_print, to_print_std = mean_and_std_precision(new_dfs, cv)

to_print.plot.bar(ax=_axs, rot=0, yerr=to_print_std, ylim=[0,1])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 6° Prediction

# %%
to_print_save =  []
to_print_std_save = []

# %%
# %%time

# prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy_proportional, indexes, True)
prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy, indexes, True)

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "Demo")
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

max_possible = bestScorePossible(prediction_per_rules_count)
print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°5 : Finished
# Process n°7 : Finished
# Process n°1 : Finished
# Process n°9 : Finished
# Process n°3 : Finished
# Process n°11 : Finished
# Process n°6 : Finished
# Process n°2 : Finished
# Process n°10 : Finished
# Value('d', 10)
# Process n°0 : Finished
# Process n°8 : Finished
# Process n°4 : Finished
# 12
# CPU times: user 2.88 s, sys: 703 ms, total: 3.58 s
# Wall time: 2min 41s

# %%
# %%time

# prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy, indexes, True)
prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, safe, indexes, True)

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "Safe")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°1 : Finished
# Process n°10 : Finished
# Process n°5 : Finished
# Process n°2 : Finished
# Process n°6 : Finished
# Process n°3 : Finished
# Process n°7 : Finished
# Process n°8 : Finished
# Value('d', 10)
# Process n°0 : Finished
# Process n°9 : Finished
# Process n°4 : Finished
# Process n°11 : Finished
# 12
# CPU times: user 2.8 s, sys: 703 ms, total: 3.5 s
# Wall time: 16.6 s

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["precision_train", "precision_test"], [False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-precision")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°0 : Finished
# Process n°7 : Finished
# Process n°4 : Finished
# Process n°1 : Finished
# Process n°3 : Finished
# Process n°6 : Finished
# Process n°2 : Finished
# Process n°9 : Finished
# Value('d', 10)
# Process n°11 : Finished
# Process n°10 : Finished
# Process n°5 : Finished
# Process n°8 : Finished
# 12
# CPU times: user 2.89 s, sys: 766 ms, total: 3.66 s
# Wall time: 22.7 s

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["headCoverage", "precision_train", "precision_test"], [True, False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-coverage")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°4 : Finished
# Process n°0 : Finished
# Process n°2 : Finished
# Process n°3 : Finished
# Process n°7 : Finished
# Process n°8 : Finished
# Process n°6 : Finished
# Process n°5 : Finished
# Value('d', 10)
# Process n°10 : Finished
# Process n°9 : Finished
# Process n°11 : Finished
#
# 12
# CPU times: user 2.81 s, sys: 781 ms, total: 3.59 s
# Wall time: 24.8 s

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["size_hypothese", "precision_train", "precision_test"], [False, False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-length")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : LaunchedProcess n°6 : Launched
#
# Process n°7 : Launched
# Process n°8 : LaunchedProcess n°9 : Launched
#
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°1 : Finished
# Process n°3 : Finished
# Process n°2 : Finished
# Process n°9 : Finished
# Process n°5 : Finished
# Process n°8 : Finished
# Process n°0 : Finished
# Process n°7 : Finished
# Process n°4 : Finished
# Value('d', 10)
# Process n°6 : Finished
# Process n°10 : Finished
# Process n°11 : Finished
# 12
# CPU times: user 2.84 s, sys: 719 ms, total: 3.56 s
# Wall time: 22 s

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76 entries, ?a income-GTE-25 True => ?a approval False to ?a creditScore-GTE-50 False => ?a approval False
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   hypotheses       76 non-null     object
#  1   conclusion       76 non-null     object
#  2   size_hypothese   76 non-null     int64
#  3   headCoverage     76 non-null     float64
#  4   stdConfidence    76 non-null     float64
#  5   pcaConfidence    76 non-null     float64
#  6   precision_train  76 non-null     float64
#  7   precision_test   76 non-null     float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 5.3+ KB

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0'].describe()
# Out:
#        size_hypothese  headCoverage  stdConfidence  pcaConfidence  \
# count            76.0     76.000000      76.000000      76.000000
# mean              1.0      0.340588       0.562019       0.562019
# std               0.0      0.229879       0.271337       0.271337
# min               1.0      0.052636       0.101281       0.101281
# 25%               1.0      0.160832       0.292190       0.292190
# 50%               1.0      0.223525       0.634398       0.634398
# 75%               1.0      0.575770       0.780373       0.780373
# max               1.0      0.871239       0.999903       0.999903
#
#        precision_train  precision_test
# count        76.000000       76.000000
# mean          0.546444        0.547244
# std           0.203413        0.204411
# min           0.010155        0.011100
# 25%           0.426574        0.429321
# 50%           0.577086        0.574309
# 75%           0.686182        0.688396
# max           0.871239        0.875412

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0']
# Out:
#                                                                                          hypotheses  \
# ?a income-GTE-25 True => ?a approval False                                 (?a income-GTE-25 True,)
# ?a income-GTE-75 True => ?a approval False                                 (?a income-GTE-75 True,)
# ?a loanAmount-LTE-820905.0 ?b => ?a approval ?b                    (?a loanAmount-LTE-820905.0 ?b,)
# ?a rate-GTE-75 True => ?a approval False                                     (?a rate-GTE-75 True,)
# ?a creditScore-GTE-75 ?b => ?a approval ?b                              (?a creditScore-GTE-75 ?b,)
# ...                                                                                             ...
# ?a income/yearlyReimbursement-LTE-3.33 False =>...  (?a income/yearlyReimbursement-LTE-3.33 False,)
# ?a creditScore-GTE-50 False => ?a approval True                      (?a creditScore-GTE-50 False,)
# ?a monthDuration-GTE-25 False => ?a approval False                 (?a monthDuration-GTE-25 False,)
# ?a creditScore-GTE-25 False => ?a approval False                     (?a creditScore-GTE-25 False,)
# ?a creditScore-GTE-50 False => ?a approval False                     (?a creditScore-GTE-50 False,)
#
#                                                            conclusion  \
# ?a income-GTE-25 True => ?a approval False          ?a approval False
# ?a income-GTE-75 True => ?a approval False          ?a approval False
# ?a loanAmount-LTE-820905.0 ?b => ?a approval ?b        ?a approval ?b
# ?a rate-GTE-75 True => ?a approval False            ?a approval False
# ?a creditScore-GTE-75 ?b => ?a approval ?b             ?a approval ?b
# ...                                                               ...
# ?a income/yearlyReimbursement-LTE-3.33 False =>...   ?a approval True
# ?a creditScore-GTE-50 False => ?a approval True      ?a approval True
# ?a monthDuration-GTE-25 False => ?a approval False  ?a approval False
# ?a creditScore-GTE-25 False => ?a approval False    ?a approval False
# ?a creditScore-GTE-50 False => ?a approval False    ?a approval False
#
#                                                     size_hypothese  \
# ?a income-GTE-25 True => ?a approval False                       1
# ?a income-GTE-75 True => ?a approval False                       1
# ?a loanAmount-LTE-820905.0 ?b => ?a approval ?b                  1
# ?a rate-GTE-75 True => ?a approval False                         1
# ?a creditScore-GTE-75 ?b => ?a approval ?b                       1
# ...                                                            ...
# ?a income/yearlyReimbursement-LTE-3.33 False =>...               1
# ?a creditScore-GTE-50 False => ?a approval True                  1
# ?a monthDuration-GTE-25 False => ?a approval False               1
# ?a creditScore-GTE-25 False => ?a approval False                 1
# ?a creditScore-GTE-50 False => ?a approval False                 1
#
#                                                     headCoverage  \
# ?a income-GTE-25 True => ?a approval False              0.544175
# ?a income-GTE-75 True => ?a approval False              0.159032
# ?a loanAmount-LTE-820905.0 ?b => ?a approval ?b         0.783743
# ?a rate-GTE-75 True => ?a approval False                0.196787
# ?a creditScore-GTE-75 ?b => ?a approval ?b              0.639471
# ...                                                          ...
# ?a income/yearlyReimbursement-LTE-3.33 False =>...      0.219857
# ?a creditScore-GTE-50 False => ?a approval True         0.109816
# ?a monthDuration-GTE-25 False => ?a approval False      0.227192
# ?a creditScore-GTE-25 False => ?a approval False        0.193982
# ?a creditScore-GTE-50 False => ?a approval False        0.388624
#
#                                                     stdConfidence  \
# ?a income-GTE-25 True => ?a approval False               0.725691
# ?a income-GTE-75 True => ?a approval False               0.632880
# ?a loanAmount-LTE-820905.0 ?b => ?a approval ?b          0.783743
# ?a rate-GTE-75 True => ?a approval False                 0.788970
# ?a creditScore-GTE-75 ?b => ?a approval ?b               0.639471
# ...                                                           ...
# ?a income/yearlyReimbursement-LTE-3.33 False =>...       0.956162
# ?a creditScore-GTE-50 False => ?a approval True          0.220320
# ?a monthDuration-GTE-25 False => ?a approval False       0.917050
# ?a creditScore-GTE-25 False => ?a approval False         0.779365
# ?a creditScore-GTE-50 False => ?a approval False         0.779680
#
#                                                     pcaConfidence  \
# ?a income-GTE-25 True => ?a approval False               0.725691
# ?a income-GTE-75 True => ?a approval False               0.632880
# ?a loanAmount-LTE-820905.0 ?b => ?a approval ?b          0.783743
# ?a rate-GTE-75 True => ?a approval False                 0.788970
# ?a creditScore-GTE-75 ?b => ?a approval ?b               0.639471
# ...                                                           ...
# ?a income/yearlyReimbursement-LTE-3.33 False =>...       0.956162
# ?a creditScore-GTE-50 False => ?a approval True          0.220320
# ?a monthDuration-GTE-25 False => ?a approval False       0.917050
# ?a creditScore-GTE-25 False => ?a approval False         0.779365
# ?a creditScore-GTE-50 False => ?a approval False         0.779680
#
#                                                     precision_train  \
# ?a income-GTE-25 True => ?a approval False                 0.441589
# ?a income-GTE-75 True => ?a approval False                 0.713287
# ?a loanAmount-LTE-820905.0 ?b => ?a approval ?b            0.783743
# ?a rate-GTE-75 True => ?a approval False                   0.635916
# ?a creditScore-GTE-75 ?b => ?a approval ?b                 0.639471
# ...                                                             ...
# ?a income/yearlyReimbursement-LTE-3.33 False =>...         0.010155
# ?a creditScore-GTE-50 False => ?a approval True            0.498740
# ?a monthDuration-GTE-25 False => ?a approval False         0.426574
# ?a creditScore-GTE-25 False => ?a approval False           0.358999
# ?a creditScore-GTE-50 False => ?a approval False           0.498740
#
#                                                     precision_test
# ?a income-GTE-25 True => ?a approval False                0.438561
# ?a income-GTE-75 True => ?a approval False                0.714406
# ?a loanAmount-LTE-820905.0 ?b => ?a approval ?b           0.787244
# ?a rate-GTE-75 True => ?a approval False                  0.635147
# ?a creditScore-GTE-75 ?b => ?a approval ?b                0.644657
# ...                                                            ...
# ?a income/yearlyReimbursement-LTE-3.33 False =>...        0.011100
# ?a creditScore-GTE-50 False => ?a approval True           0.502400
# ?a monthDuration-GTE-25 False => ?a approval False        0.429321
# ?a creditScore-GTE-25 False => ?a approval False          0.359273
# ?a creditScore-GTE-50 False => ?a approval False          0.502400
#
# [76 rows x 8 columns]
