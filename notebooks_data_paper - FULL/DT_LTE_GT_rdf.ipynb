# %%
import pandas as pd 
import numpy as np
import os
from subprocess import check_output
import shutil
import rdflib
from multiprocessing import Process, Manager, Queue
import multiprocessing

from rule import *
from amie import *
from experiment import *

# %%
root_source_FB = "./../../FB15k_mail/"
root_source_DB = "./../../DB15k_mail/"

root_data_FB = "./../../Data_mail/FB_LTE_GT_"
root_data_DB = "./../../Data_mail/DB_LTE_GT_"

# %% [markdown]
# # FB15K

# %% [markdown]
# ### Prepare the data
#
# As we need a baseline for Amie, we are not going to change the value of anything.

# %%
data = open(root_source_FB+"numericals.txt", "r")

numerical_predicate = set()

for predicate in data:
    numerical_predicate.add(predicate.split("\n")[0])
    
data.close()

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
def write_file(X, f, threshold, comparator):
    f.write(f"<http:{X['Subject']}>\t{X['Predicate'][:-1]}_LTE_{threshold}>\t<http:/{X['Object']<=comparator}>\n")
    f.write(f"<http:{X['Subject']}>\t{X['Predicate'][:-1]}_GT_{threshold}>\t<http:/{X['Object']>comparator}>\n")

# %%
data = open(root_source_FB+"train.txt", "r")
f = open(root_data_FB+"train.tsv", "w")

dic_predicate = {}

for line in data:
    line_split = line.split("\n")[0].split("\t")
    if line_split[1] in numerical_predicate:
        line_split[2] = float(line_split[2]) 
        line_split = tuple(line_split)
        if line_split[1] in dic_predicate.keys():
            dic_predicate[line_split[1]].add(line_split)
        else : 
            dic_predicate[line_split[1]] = {line_split}
    else:
        for var in line_split:
            f.write('<http:'+var+'>\t')
        f.write("\n")
    
data.close()
f.close()

# %%
f = open(root_data_FB+"train.tsv", "a")

for key in dic_predicate.keys():
    tp_df = pd.DataFrame.from_dict(dic_predicate[key]).rename(columns={0: "Subject", 1: "Predicate", 2: "Object"})
    tp_df_describe = tp_df["Object"].quantile(thresholds)
    for threshold in thresholds: 
        tp_df.apply(write_file, args=(f, threshold, tp_df_describe[threshold]), axis=1)

f.close()

# %% [markdown]
# ### Launch Amie

# %%
res = check_output(f'java -jar ./../amie3.jar {root_data_FB+"train.tsv"}', shell=True)

res_parsed = parse_amie(res)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-35c58594d97f> in <module>
# ----> 1 res = check_output(f'java -jar ./../amie3.jar {root_data_FB+"train.tsv"}', shell=True)
#       2
#       3 res_parsed = parse_amie(res)
#
# ~/anaconda3/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     413         kwargs['input'] = empty
#     414
# --> 415     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416                **kwargs).stdout
#     417
#
# ~/anaconda3/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     493     with Popen(*popenargs, **kwargs) as process:
#     494         try:
# --> 495             stdout, stderr = process.communicate(input, timeout=timeout)
#     496         except TimeoutExpired as exc:
#     497             process.kill()
#
# ~/anaconda3/lib/python3.8/subprocess.py in communicate(self, input, timeout)
#    1013                 self._stdin_write(input)
#    1014             elif self.stdout:
# -> 1015                 stdout = self.stdout.read()
#    1016                 self.stdout.close()
#    1017             elif self.stderr:
#
# KeyboardInterrupt:

# %%
len(res_parsed)

# %%
# res_parsed

# %% [markdown]
# ### Clean rules

# %%
res_parsed_clean = res_parsed.copy()
for i in res_parsed:
    if len(i.hypotheses) == 1:
        if (i.hypotheses[0].predicate.split("LTE")[0] == i.conclusion.predicate.split("LTE")[0]) and len(i.hypotheses[0].predicate.split("LTE")) == 2:
#             print(i)
            res_parsed_clean.remove(i)

# %%
len(res_parsed_clean)

# %% [markdown]
# ### Number of numericals in the rules

# %%
num_f = open("LTE_GT_num_rules.txt", "w")
symb_f = open("LTE_GT_symb_rules.txt", "w")

def predicate_is_numerical(atom, numerical_predicate):
    return "LTE" in atom.predicate or "GT" in atom.predicate or atom.objectD.isdigit()

rule_with_numerical_in_hyp = 0
rule_with_numerical_in_conc = 0
rule_with_numerical = 0

for rule in res_parsed:
    num = False
    for hyp in rule.hypotheses:
        if predicate_is_numerical(hyp, numerical_predicate):
            rule_with_numerical_in_hyp+=1
            num = True
            break
    if predicate_is_numerical(rule.conclusion, numerical_predicate):
        rule_with_numerical_in_conc+=1
        num=True
    if num:
        rule_with_numerical += 1
        num_f.write(str(rule)+"\n")
    else:
        symb_f.write(str(rule)+"\n")
    
print("Rule with numerical : ", rule_with_numerical)
print("Rule without numerical : ", len(res_parsed) - rule_with_numerical)
print("Rule with numerical in hypotheses : ", rule_with_numerical_in_hyp)
print("Rule with numerical in conclusion : ", rule_with_numerical_in_conc)

num_f.close()
symb_f.close()

# %% [markdown]
# ### Test the rules through test

# %%
data = open(root_data_FB+"train.tsv", "r")
f = open(root_data_FB+"train_rdflib.nt", "w")

for line in data:
    f.write(line.split("\n")[0]+" . \n")

data.close()
f.close()

# %%
data = open(root_source_FB+"test.txt", "r")

set_instances_to_predict = set()

for line in data:
    line_splited = line.split("\n")[0].split("\t")
    for i in range(len(line_splited)):
        line_splited[i] = "<http:"+line_splited[i]+">"
    set_instances_to_predict.add(tuple(line_splited))
        
data.close()

# %%
print(len(set_instances_to_predict))

# %%
rules_associated_to_query = {}

for rule in res_parsed:
    if rule.conclusion.predicate in rules_associated_to_query.keys():
        rules_associated_to_query[rule.conclusion.predicate].add(rule)
    else:
        rules_associated_to_query[rule.conclusion.predicate] = set()
        rules_associated_to_query[rule.conclusion.predicate].add(rule)

# %%
g = rdflib.Graph()
g.parse(root_data_FB+"train_rdflib.nt")

# %%
def print_rules_nicely(rule):
    toprint = ""
    for hyp in rule.hypotheses:
        toprint += hyp.predicate+" & "
    toprint = toprint[:-2]
    toprint += "=>"+rule.conclusion.predicate
    print(toprint)

# %%
# %%time

def predict_instance(name, g, queue, prediction_per_instance_man, rules_associated_to_query, cpt, total_length, print_advancment):
    
    print(f"Process n°{name} : Launched")
    
    while not queue.empty():
        
        instance = queue.get()
        
        dict_tp = {}
        
        if instance[1] in rules_associated_to_query.keys():
            for rule in rules_associated_to_query[instance[1]]:
                try:
                    qres = g.query(create_query(rule, instance[2]))

                    set_res = set()
                    bool_res = False
                    for row in qres:
                        bool_res = True
                        set_res.add(str(row.a))

                    if bool_res:
                        dict_tp[rule] = set_res
            
                except:
                    print(create_query(rule, instance[2]))
                    
            prediction_per_instance_man[instance] = dict_tp
            
        else:
            prediction_per_instance_man[instance] = {}
        
        cpt.value += 1
        if (cpt.value/total_length > print_advancment.value):
            print(print_advancment.value*100, "%")
            print_advancment.value+=0.1
        
    print(f"Process n°{name} : Finished")   
    
q = Queue()
prediction_per_instance = {}

for instance in list(set_instances_to_predict):
    q.put(instance)

size_queue = q.qsize()

print("Queue finished")

with Manager() as manager:

    processes_to_create = multiprocessing.cpu_count()-1
    processes = list()

    prediction_per_instance_man = manager.dict()
    cpt = manager.Value("cpt",0)
    print_advancment = manager.Value("print_advancment",0)

    for name in range(processes_to_create):
        x = Process(target=predict_instance, args=(name, g, q, prediction_per_instance_man, rules_associated_to_query, cpt, size_queue, print_advancment))
        processes.append(x)
        x.start()
        
    for index, process in enumerate(processes):
        process.join()
    
    print("copy")
    
    df_prediction = {}
    
    cpt = 0
    advcement = 0.1
    total_length = len(prediction_per_instance_man)
    
    del g

    for prediction_instance in prediction_per_instance_man:
        df_rules = {}
        cpt += 1
        for rule in prediction_per_instance_man[prediction_instance]:
            df_rules[rule] = [set(prediction_per_instance_man[prediction_instance][rule]), rule.stdConfidence, rule.pcaConfidence]
        df_prediction[prediction_instance] = pd.DataFrame.from_dict(df_rules, orient="index", columns=["Prediction", "Std Confidence", "Pca Confidence"])
        
        if (cpt/total_length > advcement):
            print(advcement *100, "%")
            advcement+=0.1
        
    print("----- Democracy -----")
    hit_at(df_prediction, democracy, 1)
    hit_at(df_prediction, democracy, 5)
    hit_at(df_prediction, democracy, 10)
    hit_at(df_prediction, democracy, 1000)

    print("----- Expert -----")
    hit_at(df_prediction, expert, 1)
    hit_at(df_prediction, expert, 5)
    hit_at(df_prediction, expert, 10)
    hit_at(df_prediction, expert, 1000)

# %%
# %%time

def predict_instance(name, g, instances, prediction_per_instance_man, rules_associated_to_query, cpt, total_length, print_advancment):
    
    print(f"Process n°{name} : Launched")
    
    for instance in instances:
        
        dict_tp = {}
        if instance[1] in rules_associated_to_query.keys():
            for rule in rules_associated_to_query[instance[1]]:
                try:
                    qres = g.query(create_query(rule, instance[2]))
                    tp = create_query(rule, instance[2])
                    if ("LTE"  in tp) or ("GT" in tp):
                        print(tp)

                    set_res = set()
                    bool_res = False
                    for row in qres:
                        bool_res = True
                        set_res.add(str(row.a))

                    if bool_res:
                        dict_tp[rule] = set_res
            
                except:
                    print(create_query(rule, instance[2]))
                    
            prediction_per_instance_man[instance] = dict_tp
            
        else:
            prediction_per_instance_man[instance] = {}
        
        cpt.value += 1
        if (cpt.value/total_length > print_advancment.value):
            print(cpt)
            print_advancment.value+=0.1
        
    print(f"Process n°{name} : Finished")

prediction_per_instance_test = {}

size_queue = len(list(set_instances_to_predict)[:100])

with Manager() as manager:

    processes_to_create = 1#multiprocessing.cpu_count()-3
    processes = list()

    prediction_per_instance_man = manager.dict()
    cpt = manager.Value("cpt",0)
    print_advancment = manager.Value("print_advancment",0)
    
    instances_list = list(set_instances_to_predict)[:100]

    for name in range(processes_to_create):
        x = Process(target=predict_instance, args=(name, g, instances_list[int(np.floor(name*len(instances_list)/processes_to_create)): int(np.floor((name+1)*len(instances_list)/processes_to_create))], 
                                                   prediction_per_instance_man, rules_associated_to_query, cpt, size_queue, print_advancment))
        processes.append(x)
        x.start()
        
    for index, process in enumerate(processes):
        process.join()

    prediction_per_instance_test = prediction_per_instance_man.copy()
# Out:
# Process n°0 : Launched
# Value('cpt', 1)
# Value('cpt', 11)
# Value('cpt', 21)
# Value('cpt', 31)
# Value('cpt', 41)
# Value('cpt', 51)
# Value('cpt', 61)
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.gns_ufi_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.gns_ufi_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.gns_ufi_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.gns_ufi_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.gns_ufi_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.gns_ufi_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.75> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.gns_ufi_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.gns_ufi_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.gns_ufi_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.gns_ufi_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.gns_ufi_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/base.lewisandclark.places_westward.from_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.gns_ufi_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_GT_0.5> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.5> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/time.time_zone.offset_from_uct_LTE_0.75> ?f .
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.country.iso_numeric_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.location.area_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0mwjk> <http://rdf.freebase.com/ns/organization.organization.date_founded_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/time.time_zone.dst_offset_from_utc_LTE_0.25> ?f .
# }
# Value('cpt', 71)
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0dq16> <http://rdf.freebase.com/ns/base.schemastaging.location_extra.elevation_max_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/location.fr_department.code_insee_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0dq16> <http://rdf.freebase.com/ns/base.schemastaging.location_extra.elevation_max_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/location.fr_department.code_insee_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0dq16> <http://rdf.freebase.com/ns/base.schemastaging.location_extra.elevation_max_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/location.fr_department.code_insee_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0dq16> <http://rdf.freebase.com/ns/base.schemastaging.location_extra.elevation_max_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/location.fr_department.code_insee_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0dq16> <http://rdf.freebase.com/ns/base.schemastaging.location_extra.elevation_max_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/location.fr_department.code_insee_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/0dq16> <http://rdf.freebase.com/ns/base.schemastaging.location_extra.elevation_max_LTE_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/location.fr_department.code_insee_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.latitude_LTE_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_LTE_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved_GT_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved_LTE_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.iso_numeric_GT_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ...
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.iso_numeric_LTE_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.iso_numeric_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_GT_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_GT_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_LTE_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.latitude_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved_GT_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.iso_numeric_LTE_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_LTE_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_GT_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved_LTE_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.5> ?f .
# ?a <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_LTE_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_LTE_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/topic_server.population_number_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude_LTE_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_GT_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved_GT_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded_LTE_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_founded_GT_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.longitude_GT_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.geocode.latitude_GT_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.calling_code_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.iso_numeric_GT_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.iso_numeric_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_LTE_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.iso_numeric_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_LTE_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_LTE_0.25> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_GT_0.75> ?f .
# ?a <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.location.area_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved_LTE_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_athletes_LTE_0.5> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_GT_0.25> ?f .
# ?a <http://rdf.freebase.com/ns/topic_server.population_number_GT_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.dated_location.date_dissolved_GT_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_GT_0.75> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.calling_code_GT_0.5> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_countries_LTE_0.25> ?f .
# }
#
#     SELECT DISTINCT ?a
#     WHERE {
# ?a <http://rdf.freebase.com/ns/location.country.iso_numeric_GT_0.75> ?f .
# <http:/m/06sks6> <http://rdf.freebase.com/ns/olympics.olympic_games.number_of_events_LTE_0.25> ?f .
# }
# Value('cpt', 80)
# Value('cpt', 90)
# Value('cpt', 100)
# Process n°0 : Finished
# CPU times: user 734 ms, sys: 2.34 s, total: 3.08 s
# Wall time: 1min 50s

# %% [markdown]
# # DB15K

# %% [markdown]
# ### Prepare the data
#
# As we need a baseline for Amie, we are not going to change the value of anything.

# %%
data = open(root_source_DB+"numericals.txt", "r")

numerical_predicate = set()

for predicate in data:
    numerical_predicate.add(predicate.split("\n")[0])
    
data.close()

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
data = open(root_source_DB+"train.txt", "r")
f = open(store_data_DB, "w")

dic_predicate = {}

for line in data:
    line_split = line.split("\n")[0].split(" ")
    if len(line_split) == 1:
        line_split = line.split("\n")[0].split("\t")
    if line_split[1] in numerical_predicate:
        line_split[2] = float(line_split[2]) 
        line_split = tuple(line_split)
        if line_split[1] in dic_predicate.keys():
            dic_predicate[line_split[1]].add(line_split)
        else : 
            dic_predicate[line_split[1]] = {line_split}
    else:
        f.write(line)
    
data.close()
f.close()

# %%
f = open(store_data_DB, "a")

for key in dic_predicate.keys():
    tp_df = pd.DataFrame.from_dict(dic_predicate[key]).rename(columns={0: "Subject", 1: "Predicate", 2: "Object"})
    tp_df_describe = tp_df["Object"].quantile(thresholds)
    for threshold in thresholds: 
        tp_df.apply(write_file, args=(f, threshold, tp_df_describe[threshold]), axis=1)

f.close()

# %% [markdown]
# ### Launch Amie

# %%
res = check_output(f'java -jar ./../amie3.jar {store_data_DB}', shell=True)

res_parsed = parse_amie(res)

# %%
len(res_parsed)
# Out:
# 487704

# %%
res_parsed
# Out:
# {?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/extinctionDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/elevation>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/runtime>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/imdbId>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/assets>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/equity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingYear>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/netIncome>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/area>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/postalCode>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/postalCode>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/censusYear>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/deathDate>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetroDensity>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/areaWater>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaLand>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/facultySize>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/deathDate>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaLand>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/formationDate>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/imdbId>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/formationDate>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/gross>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/imdbId>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/facultySize>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/numberOfStudents>_GT_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/deathYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaWater>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/endowment>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfStudents>_GT_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/staff>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/birthDate>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/budget>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/gross>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationYear>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/formationDate>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/netIncome>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/formationDate>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/operatingIncome>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/revenue>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/distanceToLondon>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/openingDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/operatingIncome>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/formationDate>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/imdbId>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/postalCode>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfDoctoralStudents>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/budget>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/budget>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/endowment>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/netIncome>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/facultySize>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfEpisodes>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfDoctoralStudents>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaLand>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaLand>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/birthDate>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/revenue>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/postalCode>_GT_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/facultySize>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/endowment>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/postalCode>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/postalCode>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrbanDensity>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaWater>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaWater>_GT_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/birthYear>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/censusYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaWater>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/assets>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetroDensity>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/area>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/assets>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/censusYear>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathYear>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaLand>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/elevation>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetroDensity>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingYear>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrbanDensity>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/censusYear>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/censusYear>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/completionDate>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/releaseDate>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/endowment>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.75 ?b,
# ...
#  ?a <http://dbpedia.org/ontology/foundingYear>_GT_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/area>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/areaCode>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/staff>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/formationDate>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/formationDate>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaCode>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetroDensity>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingYear>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/formationYear>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/area>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/censusYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/foundingYear>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/birthYear>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/gross>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/imdbId>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/budget>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.25 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/censusYear>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaCode>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/foundingYear>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingYear>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/birthDate>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotalRanking>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/capacity>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/birthYear>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/facultySize>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/completionDate>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/area>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/inseeCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_GT_0.5 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/populationUrban>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b & ?a <http://dbpedia.org/ontology/populationMetroDensity>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/foundingDate>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_GT_0.75 ?b & ?a <http://dbpedia.org/ontology/utcOffset>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_GT_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/birthYear>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b,
#  ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/censusYear>_GT_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/activeYearsStartYear>_GT_0.25 ?b & ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/staff>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b & ?a <http://dbpedia.org/ontology/populationAsOf>_GT_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_GT_0.5 ?b,
#  ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_GT_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b & ?a <http://dbpedia.org/ontology/censusYear>_GT_0.75 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b,
#  ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b & ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b,
#  ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.5 ?b & ?a <http://dbpedia.org/ontology/maximumElevation>_GT_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_GT_0.75 ?b,
#  ...}

# %% [markdown]
# ### Clean rules

# %%
res_parsed_clean = res_parsed.copy()
for i in res_parsed:
    if len(i.hypotheses) == 1:
        if (i.hypotheses[0].predicate.split("LTE")[0] == i.conclusion.predicate.split("LTE")[0]) and len(i.hypotheses[0].predicate.split("LTE")) == 2:
            print(i)
            res_parsed_clean.remove(i)
# Out:
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfPostgraduateStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.5 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/endowment>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/endowment>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/area>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/area>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaTotal>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/deathDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/ethnicGroupsInYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfEpisodes>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationDensity>_LTE_0.5 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/utcOffset>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationUrban>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/deathYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/capacity>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/capacity>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaWater>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/minimumElevation>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#lat>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/budget>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/budget>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaCode>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationAsOf>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/activeYearsEndYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfUndergraduateStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/gross>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/gross>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/staff>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/staff>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthYear>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/areaUrban>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/releaseDate>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/activeYearsStartYear>_LTE_0.25 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.5 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/areaLand>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/formationYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/birthDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/formationDate>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/height>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/height>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/facultySize>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/populationTotalRanking>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/year>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/year>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfSeasons>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/completionDate>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/maximumElevation>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/foundingYear>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/populationTotal>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/populationMetro>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/numberOfStudents>_LTE_0.5 ?b
# ?a <http://dbpedia.org/ontology/elevation>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/elevation>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/runtime>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/runtime>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.75 ?b => ?a <http://dbpedia.org/ontology/numberOfEmployees>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/imdbId>_LTE_0.75 ?b
# ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.25 ?b => ?a <http://www.w3.org/2003/01/geo/wgs84_pos#long>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/censusYear>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/areaMetro>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/percentageOfAreaWater>_LTE_0.75 ?b
# ?a <http://dbpedia.org/ontology/revenue>_LTE_0.5 ?b => ?a <http://dbpedia.org/ontology/revenue>_LTE_0.25 ?b
# ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.25 ?b => ?a <http://dbpedia.org/ontology/postalCode>_LTE_0.5 ?b

# %%
len(res_parsed_clean)
# Out:
# 487392

# %% [markdown]
# ### Number of numericals in the rules

# %%
def predicate_is_numerical(atom):
    return "LTE" in atom.predicate or "GT" in atom.predicate or atom.objectD.isdigit()

rule_with_numerical_in_hyp = 0
rule_with_numerical_in_conc = 0
rule_with_numerical = 0

for rule in res_parsed_clean:
    num = False
    for hyp in rule.hypotheses:
        if predicate_is_numerical(hyp):
            rule_with_numerical_in_hyp+=1
            num = True
            break
    if predicate_is_numerical(rule.conclusion):
        rule_with_numerical_in_conc+=1
        num=True
    if num:
        rule_with_numerical += 1
    
print("Rule with numerical : ", rule_with_numerical)
print("Rule without numerical : ", len(res_parsed_clean) - rule_with_numerical)
print("Rule with numerical in hypotheses : ", rule_with_numerical_in_hyp)
print("Rule with numerical in conclusion : ", rule_with_numerical_in_conc)
# Out:
# Rule with numerical :  487392
# Rule without numerical :  0
# Rule with numerical in hypotheses :  487392
# Rule with numerical in conclusion :  487392
