# %%
import pandas as pd
import numpy as np
import sklearn.tree as tree
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os.path
from os import path
from sklearn.model_selection import KFold
from multiprocessing import Process, Manager, SimpleQueue
import multiprocessing
import shutil
import sys
import time
from sklearn.metrics import accuracy_score
from rules import *
from vote import *
from save_amie_data import *
from precision import *
from amie import *

root = "./../../ST_constant/"
cv = 3

colors_to_print = ["red",  "blue", "orange",  "violet", "darkgrey", "darkred", "darkblue", "darkorange", "darkviolet", "grey"]

# %% [markdown]
# # 1° Load data

# %%
data = pd.read_csv("./../Data/miniloan-decisions-100K.csv")

# %%
data
# Out:
#            name  creditScore  income  loanAmount  monthDuration      rate  \
# 0      John Doe          736  113243      783440            162  0.030005
# 1      John Doe          527  224186     1787385            183  0.054819
# 2      John Doe          460   39954     1733494             75  0.055183
# 3      John Doe          751  219998     1350004             72  0.043400
# 4      John Doe          684   72470     1210944            160  0.037772
# ...         ...          ...     ...         ...            ...       ...
# 99995  John Doe          366   83851     1718571            168  0.053737
# 99996  John Doe          395  184259     1599473             90  0.040564
# 99997  John Doe          674  242620     1099790            260  0.040825
# 99998  John Doe          420  180957     1645870            203  0.049558
# 99999  John Doe          699  102769      665190            244  0.058460
#
#       approval  yearlyReimbursement
# 0        false                70648
# 1        false               173197
# 2        false               328563
# 3        false               255970
# 4        false               115742
# ...        ...                  ...
# 99995    false               174928
# 99996    false               247703
# 99997    false                76557
# 99998    false               143897
# 99999    false                55993
#
# [100000 rows x 8 columns]

# %% [markdown]
# # Ratios

# %%
ratio_names = [("income","yearlyReimbursement"), ("income","loanAmount"), ("loanAmount","rate")]

# %%
# Takes two features and will create the ratio f_0/f_1
def create_features_ratio(data):
    if data[data.index[1]] == 0:
        return 2147483647
    return np.round(data[data.index[0]]/data[data.index[1]], decimals=2)

# %%
for ratio_name in ratio_names:
    data[f"{ratio_name[0]}/{ratio_name[1]}"] = data[[ratio_name[0], ratio_name[1]]].apply(create_features_ratio, axis=1)

# %%
data
# Out:
#            name  creditScore  income  loanAmount  monthDuration      rate  \
# 0      John Doe          736  113243      783440            162  0.030005
# 1      John Doe          527  224186     1787385            183  0.054819
# 2      John Doe          460   39954     1733494             75  0.055183
# 3      John Doe          751  219998     1350004             72  0.043400
# 4      John Doe          684   72470     1210944            160  0.037772
# ...         ...          ...     ...         ...            ...       ...
# 99995  John Doe          366   83851     1718571            168  0.053737
# 99996  John Doe          395  184259     1599473             90  0.040564
# 99997  John Doe          674  242620     1099790            260  0.040825
# 99998  John Doe          420  180957     1645870            203  0.049558
# 99999  John Doe          699  102769      665190            244  0.058460
#
#       approval  yearlyReimbursement  income/yearlyReimbursement  \
# 0        false                70648                        1.60
# 1        false               173197                        1.29
# 2        false               328563                        0.12
# 3        false               255970                        0.86
# 4        false               115742                        0.63
# ...        ...                  ...                         ...
# 99995    false               174928                        0.48
# 99996    false               247703                        0.74
# 99997    false                76557                        3.17
# 99998    false               143897                        1.26
# 99999    false                55993                        1.84
#
#        income/loanAmount  loanAmount/rate
# 0                   0.14      26110372.80
# 1                   0.13      32605003.59
# 2                   0.02      31413368.70
# 3                   0.16      31106073.81
# 4                   0.06      32059172.14
# ...                  ...              ...
# 99995               0.05      31981153.44
# 99996               0.12      39430859.20
# 99997               0.22      26938940.88
# 99998               0.11      33211031.24
# 99999               0.15      11378481.46
#
# [100000 rows x 11 columns]

# %% [markdown]
# # 3° Create the thresholds

# %% [markdown]
# Define the thresholds

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = [(str(i) for i in range(len(thresholds)))]

# %%
# Takes a dataframe and return the values per percents for each feature
def description_per_thresholds(data, percents):
    thresholds_Dic =  {}
    for column in data.columns:
        serie = data[column]
        thresholds_Dic[column] = serie.quantile(percents)
        
    return pd.DataFrame.from_dict(thresholds_Dic)

# %%
columns_to_compare = ['creditScore', 'income', 'loanAmount', 'monthDuration', 'rate', 'yearlyReimbursement', 'income/yearlyReimbursement']

description = description_per_thresholds(data[columns_to_compare], thresholds)
description = description.set_index(np.arange(len(description)))

# %% [markdown]
# Transform the data from integer values to boolean values corresponding to GTE or LTE with the different percents.

# %%
def attribute_group(value, description):
    for i, index in enumerate(description.index):
        if value <= description[index]:
            return i 
    return i+1

# %%
# %%time

groupsDF = pd.DataFrame()

for column in columns_to_compare:
    groupsDF[column] = data[column].map(lambda x : attribute_group(x, description[column]))
# Out:
# CPU times: user 9.12 s, sys: 46.9 ms, total: 9.17 s
# Wall time: 9.17 s

# %%
groupsDF["approval"] = data["approval"].map({' true': True, ' false': False})
groupsDF
# Out:
#        creditScore  income  loanAmount  monthDuration  rate  \
# 0                3       1           1              1     0
# 1                1       2           3              2     3
# 2                1       0           3              0     3
# 3                3       2           2              0     1
# 4                2       0           2              1     1
# ...            ...     ...         ...            ...   ...
# 99995            0       1           3              1     3
# 99996            0       2           3              0     1
# 99997            2       3           2              2     1
# 99998            0       2           3              2     2
# 99999            2       1           1              2     3
#
#        yearlyReimbursement  income/yearlyReimbursement  approval
# 0                        1                           2     False
# 1                        3                           1     False
# 2                        3                           0     False
# 3                        3                           1     False
# 4                        2                           1     False
# ...                    ...                         ...       ...
# 99995                    3                           0     False
# 99996                    3                           1     False
# 99997                    1                           3     False
# 99998                    2                           1     False
# 99999                    1                           2     False
#
# [100000 rows x 8 columns]

# %% [markdown]
# Create the folder where the data will be stored.

# %%
if not path.isdir(root):
    os.mkdir(root)
    os.mkdir(root+"/Save_raw")
else : 
    shutil.rmtree(root)
    os.mkdir(root)
    os.mkdir(root+"/Save_raw")

# %%
groupsDF.to_csv(root+"dfSave.csv")

# %% [markdown]
# # 4° Save the best data

# %% [markdown]
# We store the data in the Amie format.

# %%
save_all_data(root, groupsDF, integer=False)

# %% [markdown]
# ## Save in cross validation

# %%
save_CV(root, groupsDF, cv, integer=False)
# Out:
# Train repartition :
#  False    52004
# True     14662
# Name: approval, dtype: int64
# Train repartition :
#  False    52007
# True     14660
# Name: approval, dtype: int64
# Train repartition :
#  False    52081
# True     14586
# Name: approval, dtype: int64

# %% [markdown]
# ### Save description to retrieve the groups

# %%
description.to_csv(root+"description.csv")
description
# Out:
#    creditScore    income  loanAmount  monthDuration      rate  \
# 0        439.0   75050.5   498531.50           90.0  0.037479
# 1        576.0  149826.0  1000959.00          179.0  0.045058
# 2        713.0  225287.5  1501814.25          269.0  0.052568
#
#    yearlyReimbursement  income/yearlyReimbursement
# 0             49162.50                        0.53
# 1             98902.00                        1.37
# 2            166595.25                        3.05

# %% [markdown]
# # 5° Launch Amie

# %% [markdown]
# Describe the parameters.

# %%
atom_LIST = [2, 3]
minc_LIST = [0, 0.4, 0.8]
minhc_LIST = [0, 0.2, 0.4]

# %% [markdown]
# Launch Amie.

# %%
# %%time

res_rules_raw = run_amie(atom_LIST, root, cv, const=True)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°6 : FinishedProcess n°7 : Launched
#
# Process n°8 : LaunchedProcess n°7 : Finished
#
# Process n°8 : FinishedProcess n°9 : Launched
#
# Process n°9 : FinishedProcess n°10 : Launched
#
# Process n°10 : FinishedProcess n°11 : Launched
#
# Process n°11 : Finished
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°4 : Finished
# Process n°2 : Finished
# Process n°0 : Finished
# Process n°5 : Finished
# Process n°3 : Finished
# Process n°1 : Finished
# CPU times: user 46.9 ms, sys: 531 ms, total: 578 ms
# Wall time: 35min 19s

# %% [markdown]
# ### Save raw results

# %%
for i in res_rules_raw:
    f = open(root+"Save_raw/"+i+".txt", "w")
    f.write(res_rules_raw[i].decode())
    f.close()

# %% [markdown]
# ### Read raw results

# %%
res_rules_raw = {}
for a in atom_LIST:
    for i in range(cv):
        f = open(root+"Save_raw/"+f"CV={i}-A={a}"+".txt", "r")
        res_rules_raw[f"CV={i}-A={a}"] = f.read().encode()
        f.close()

# %% [markdown]
# Transform the raw output into sets of rules.

# %%
rules_per_cv = parse_amie(res_rules_raw)

# %% [markdown]
# Retrieve the indexes for each CV.

# %%
indexes = retrieve_indexes(root, cv)
df = pd.read_csv(root+"dfSave.csv")

# %%
description = pd.read_csv(root+"description.csv", index_col=0)

# %% [markdown]
# # 5° Precision

# %%
# %%time

rules_per_para = run_precision(root, indexes, rules_per_cv)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : LaunchedProcess n°4 : Launched
# Process n°5 : Launched
#
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°0 : Finished
# Process n°2 : Finished
# Process n°5 : Finished
# Process n°7 : Finished
# Process n°10 : Finished
# Process n°4 : Finished
# Process n°6 : Finished
# Process n°1 : Finished
# Process n°3 : Finished
# Process n°12 : Finished
# Process n°9 : FinishedProcess n°8 : Finished
#
# Process n°11 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : LaunchedProcess n°4 : Launched
#
# Process n°5 : LaunchedProcess n°6 : Launched
#
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : LaunchedProcess n°10 : Launched
#
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°0 : Finished
# Process n°2 : Finished
# Process n°5 : Finished
# Process n°7 : Finished
# Process n°10 : Finished
# Process n°1 : Finished
# Process n°3 : Finished
# Process n°4 : Finished
# Process n°6 : Finished
# Process n°8 : Finished
# Process n°9 : Finished
# Process n°11 : Finished
# Process n°12 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : LaunchedProcess n°7 : Launched
#
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°0 : Finished
# Process n°2 : Finished
# Process n°5 : Finished
# Process n°7 : Finished
# Process n°10 : Finished
# Process n°3 : Finished
# Process n°1 : Finished
# Process n°4 : Finished
# Process n°8 : Finished
# Process n°11 : Finished
# Process n°6 : Finished
# Process n°12 : Finished
# Process n°9 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 100)
# Process n°7 : Finished
# Process n°10 : Finished
# Process n°9 : Finished
# Process n°4 : Finished
# Process n°2 : Finished
# Process n°0 : Finished
# Process n°6 : Finished
# Process n°5 : Finished
# Process n°8 : Finished
# Process n°1 : Finished
# Process n°3 : Finished
# Process n°11 : Finished
# Process n°12 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 100)
# Process n°7 : Finished
# Process n°9 : Finished
# Process n°4 : Finished
# Process n°10 : Finished
# Process n°8 : Finished
# Process n°0 : Finished
# Process n°11 : Finished
# Process n°1 : Finished
# Process n°2 : Finished
# Process n°5 : Finished
# Process n°6 : Finished
# Process n°3 : Finished
# Process n°12 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : LaunchedProcess n°6 : Launched
# Process n°7 : Launched
#
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 100)
# Process n°7 : Finished
# Process n°9 : Finished
# Process n°3 : Finished
# Process n°10 : Finished
# Process n°1 : Finished
# Process n°0 : Finished
# Process n°4 : Finished
# Process n°5 : Finished
# Process n°8 : Finished
# Process n°11 : Finished
# Process n°6 : Finished
# Process n°12 : Finished
# Process n°2 : Finished
# CPU times: user 172 ms, sys: 2.88 s, total: 3.05 s
# Wall time: 2min 6s

# %% [markdown]
# ### Add parameters

# %% [markdown]
# Describe the combinaison of these new parameters.

# %%
new_parameters = []
for minc in minc_LIST:
    for minhc in minhc_LIST:
        new_parameters.append([("stdConfidence", minc), ("headCoverage", minhc)])
print(new_parameters)
# Out:
# [[('stdConfidence', 0), ('headCoverage', 0)], [('stdConfidence', 0), ('headCoverage', 0.2)], [('stdConfidence', 0), ('headCoverage', 0.4)], [('stdConfidence', 0.4), ('headCoverage', 0)], [('stdConfidence', 0.4), ('headCoverage', 0.2)], [('stdConfidence', 0.4), ('headCoverage', 0.4)], [('stdConfidence', 0.8), ('headCoverage', 0)], [('stdConfidence', 0.8), ('headCoverage', 0.2)], [('stdConfidence', 0.8), ('headCoverage', 0.4)]]

# %% [markdown]
# Create the DataFrames corresponding to these parameters.

# %%
new_dfs = add_parameters(rules_per_para, new_parameters)

# %% [markdown]
# Print the precision for each parameters.

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 
to_print, to_print_std = mean_and_std_precision(new_dfs, cv)

to_print.plot.bar(ax=_axs, rot=0, yerr=to_print_std, ylim=[0,1])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 6° Prediction

# %%
to_print_save =  []
to_print_std_save = []

# %%
# %%time

# prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy_proportional, indexes, True)
prediction_per_rules_count, prediction_per_rules_raw, rules_used = prediction_test(root, cv, new_dfs, democracy, indexes, True)

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "Demo", cv)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

max_possible = bestScorePossible(prediction_per_rules_count, cv)
print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 10)
# Value('d', 20)
# Value('d', 30)
# Value('d', 40)
# Process n°3 : Finished
# Process n°7 : Finished
# Process n°6 : Finished
# Process n°4 : Finished
# Process n°12 : Finished
# Process n°1 : Finished
# Process n°10 : Finished
# Process n°0 : Finished
# Value('d', 50)
# Process n°8 : Finished
# Process n°2 : Finished
# Process n°11 : Finished
# Process n°9 : Finished
# Process n°5 : Finished
# 54
# CPU times: user 12.3 s, sys: 39.6 s, total: 51.8 s
# Wall time: 11min 54s

# %%
# %%time

# prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy, indexes, True)
prediction_per_rules_count, prediction_per_rules_raw, rules_used = prediction_test(root, cv, new_dfs, safe, indexes, True)

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "Safe", cv)
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 10)
# Value('d', 20)
# Value('d', 30)
# Value('d', 40)
# Process n°4 : Finished
# Process n°11 : Finished
# Process n°2 : Finished
# Process n°3 : Finished
# Process n°12 : Finished
# Process n°10 : Finished
# Process n°1 : Finished
# Process n°9 : Finished
# Value('d', 50)
# Process n°0 : Finished
# Process n°6 : Finished
# Process n°5 : Finished
# Process n°8 : Finished
# Process n°7 : Finished
# 54
# CPU times: user 12.1 s, sys: 39.7 s, total: 51.8 s
# Wall time: 2min 3s

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw, rules_used = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["precision_train", "precision_test"], [False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-precision", cv)
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 10)
# Value('d', 20)
# Value('d', 30)
# Value('d', 40)
# Process n°3 : Finished
# Process n°5 : Finished
# Process n°1 : Finished
# Process n°7 : Finished
# Process n°9 : Finished
# Process n°12 : Finished
# Process n°0 : Finished
# Process n°6 : Finished
# Value('d', 50)
# Process n°10 : Finished
# Process n°4 : Finished
# Process n°11 : Finished
# Process n°8 : Finished
# Process n°2 : Finished
# 54
# CPU times: user 12.1 s, sys: 39.4 s, total: 51.5 s
# Wall time: 5min 6s

# %%
rules_used
# Out:
# {'CV=0-A=2\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=2\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=2\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=2\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=2\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=2\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=2\nstdC=0\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a yearlyReimbursement 2 => ?a approval False           16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a loanAmount 3 => ?a approval False                    16549
#   Name: 1, dtype: int64,
#   'test': ?a yearlyReimbursement 2 => ?a approval False           8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a loanAmount 3 => ?a approval False                    8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=1-A=2\nstdC=0\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a yearlyReimbursement 2 => ?a approval False           16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a loanAmount 3 => ?a approval False                    16549
#   Name: 1, dtype: int64,
#   'test': ?a yearlyReimbursement 2 => ?a approval False           8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a loanAmount 3 => ?a approval False                    8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=1-A=2\nstdC=0.4\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a yearlyReimbursement 2 => ?a approval False           16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a loanAmount 3 => ?a approval False                    16549
#   Name: 1, dtype: int64,
#   'test': ?a yearlyReimbursement 2 => ?a approval False           8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a loanAmount 3 => ?a approval False                    8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a yearlyReimbursement 2 => ?a approval False           16685
#   ?a loanAmount 3 => ?a approval False                    16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a yearlyReimbursement 2 => ?a approval False           8319
#   ?a loanAmount 3 => ?a approval False                    8233
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a yearlyReimbursement 2 => ?a approval False           16685
#   ?a loanAmount 3 => ?a approval False                    16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a yearlyReimbursement 2 => ?a approval False           8319
#   ?a loanAmount 3 => ?a approval False                    8233
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0.8\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a yearlyReimbursement 2 => ?a approval False           16685
#   ?a loanAmount 3 => ?a approval False                    16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a yearlyReimbursement 2 => ?a approval False           8319
#   ?a loanAmount 3 => ?a approval False                    8233
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0.8\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a yearlyReimbursement 2 => ?a approval False           16685
#   ?a loanAmount 3 => ?a approval False                    16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a yearlyReimbursement 2 => ?a approval False           8319
#   ?a loanAmount 3 => ?a approval False                    8233
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0.4\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a yearlyReimbursement 2 => ?a approval False           16685
#   ?a loanAmount 3 => ?a approval False                    16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a yearlyReimbursement 2 => ?a approval False           8319
#   ?a loanAmount 3 => ?a approval False                    8233
#   Name: 1, dtype: int64},
#  'CV=1-A=2\nstdC=0.4\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a yearlyReimbursement 2 => ?a approval False           16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a loanAmount 3 => ?a approval False                    16549
#   Name: 1, dtype: int64,
#   'test': ?a yearlyReimbursement 2 => ?a approval False           8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a loanAmount 3 => ?a approval False                    8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0.4\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a yearlyReimbursement 2 => ?a approval False           16685
#   ?a loanAmount 3 => ?a approval False                    16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a yearlyReimbursement 2 => ?a approval False           8319
#   ?a loanAmount 3 => ?a approval False                    8233
#   Name: 1, dtype: int64},
#  'CV=1-A=2\nstdC=0.8\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a yearlyReimbursement 2 => ?a approval False           16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a loanAmount 3 => ?a approval False                    16549
#   Name: 1, dtype: int64,
#   'test': ?a yearlyReimbursement 2 => ?a approval False           8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a loanAmount 3 => ?a approval False                    8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=1-A=2\nstdC=0.8\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a yearlyReimbursement 2 => ?a approval False           16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a loanAmount 3 => ?a approval False                    16549
#   Name: 1, dtype: int64,
#   'test': ?a yearlyReimbursement 2 => ?a approval False           8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a loanAmount 3 => ?a approval False                    8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=2-A=2\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=2-A=2\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=3\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=2-A=2\nstdC=0\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a yearlyReimbursement 2 => ?a approval False           16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a yearlyReimbursement 2 => ?a approval False           8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=3\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=2-A=2\nstdC=0\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a yearlyReimbursement 2 => ?a approval False           16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a yearlyReimbursement 2 => ?a approval False           8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0.4\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a yearlyReimbursement 2 => ?a approval False           16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a yearlyReimbursement 2 => ?a approval False           8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0.8\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a yearlyReimbursement 2 => ?a approval False           16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a yearlyReimbursement 2 => ?a approval False           8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0.4\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a yearlyReimbursement 2 => ?a approval False           16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a yearlyReimbursement 2 => ?a approval False           8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0.8\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a yearlyReimbursement 2 => ?a approval False           16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a yearlyReimbursement 2 => ?a approval False           8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=3\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=3\nstdC=0\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a loanAmount 2 => ?a approval False                    16685
#   ?a yearlyReimbursement 3 => ?a approval False           16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a loanAmount 2 => ?a approval False                    8319
#   ?a yearlyReimbursement 3 => ?a approval False           8233
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=3\nstdC=0.4\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a loanAmount 2 => ?a approval False                    16685
#   ?a yearlyReimbursement 3 => ?a approval False           16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a loanAmount 2 => ?a approval False                    8319
#   ?a yearlyReimbursement 3 => ?a approval False           8233
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0.8\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a loanAmount 2 => ?a approval False                    16685
#   ?a yearlyReimbursement 3 => ?a approval False           16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a loanAmount 2 => ?a approval False                    8319
#   ?a yearlyReimbursement 3 => ?a approval False           8233
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=3\nstdC=0\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a income/yearlyReimbursement 2 => ?a approval False    16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a yearlyReimbursement 3 => ?a approval False           16549
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 2 => ?a approval False    8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a yearlyReimbursement 3 => ?a approval False           8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0\nhC=0': {'train': ?a loanAmount 2 => ?a approval False                                        12613
#   ?a yearlyReimbursement 3 => ?a approval False                               12532
#   ?a income/yearlyReimbursement 1 => ?a approval False                        12472
#   ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    12410
#   ?a income/yearlyReimbursement 0 => ?a approval False                         8378
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4136
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                  4125
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    6317
#   ?a income/yearlyReimbursement 1 => ?a approval False                        6246
#   ?a loanAmount 2 => ?a approval False                                        6213
#   ?a yearlyReimbursement 3 => ?a approval False                               6188
#   ?a income/yearlyReimbursement 0 => ?a approval False                        4207
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                 2083
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2080
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0.4\nhC=0': {'train': ?a loanAmount 2 => ?a approval False                                        12613
#   ?a yearlyReimbursement 3 => ?a approval False                               12532
#   ?a income/yearlyReimbursement 1 => ?a approval False                        12472
#   ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    12410
#   ?a income/yearlyReimbursement 0 => ?a approval False                         8378
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4136
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                  4125
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    6317
#   ?a income/yearlyReimbursement 1 => ?a approval False                        6246
#   ?a loanAmount 2 => ?a approval False                                        6213
#   ?a yearlyReimbursement 3 => ?a approval False                               6188
#   ?a income/yearlyReimbursement 0 => ?a approval False                        4207
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                 2083
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2080
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=3\nstdC=0.8\nhC=0': {'train': ?a loanAmount 2 => ?a approval False                                        12613
#   ?a yearlyReimbursement 3 => ?a approval False                               12532
#   ?a income/yearlyReimbursement 1 => ?a approval False                        12472
#   ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    12410
#   ?a income/yearlyReimbursement 0 => ?a approval False                         8378
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4136
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                  4125
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    6317
#   ?a income/yearlyReimbursement 1 => ?a approval False                        6246
#   ?a loanAmount 2 => ?a approval False                                        6213
#   ?a yearlyReimbursement 3 => ?a approval False                               6188
#   ?a income/yearlyReimbursement 0 => ?a approval False                        4207
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                 2083
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2080
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=3\nstdC=0\nhC=0': {'train': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    16649
#   ?a income/yearlyReimbursement 2 => ?a approval False                        12497
#   ?a yearlyReimbursement 3 => ?a approval False                               12479
#   ?a income/yearlyReimbursement 1 => ?a approval False                        12458
#   ?a income/yearlyReimbursement 0 => ?a approval False                         8429
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4155
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    8286
#   ?a income/yearlyReimbursement 2 => ?a approval False                        6329
#   ?a income/yearlyReimbursement 1 => ?a approval False                        6260
#   ?a yearlyReimbursement 3 => ?a approval False                               6241
#   ?a income/yearlyReimbursement 0 => ?a approval False                        4156
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2061
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0.4\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a income/yearlyReimbursement 2 => ?a approval False    16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a yearlyReimbursement 3 => ?a approval False           16549
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 2 => ?a approval False    8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a yearlyReimbursement 3 => ?a approval False           8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0.8\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a income/yearlyReimbursement 2 => ?a approval False    16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a yearlyReimbursement 3 => ?a approval False           16549
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 2 => ?a approval False    8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a yearlyReimbursement 3 => ?a approval False           8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0.4\nhC=0': {'train': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    16649
#   ?a income/yearlyReimbursement 2 => ?a approval False                        12497
#   ?a yearlyReimbursement 3 => ?a approval False                               12479
#   ?a income/yearlyReimbursement 1 => ?a approval False                        12458
#   ?a income/yearlyReimbursement 0 => ?a approval False                         8429
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4155
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    8286
#   ?a income/yearlyReimbursement 2 => ?a approval False                        6329
#   ?a income/yearlyReimbursement 1 => ?a approval False                        6260
#   ?a yearlyReimbursement 3 => ?a approval False                               6241
#   ?a income/yearlyReimbursement 0 => ?a approval False                        4156
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2061
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a loanAmount 2 => ?a approval False                    16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a loanAmount 2 => ?a approval False                    8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0.8\nhC=0': {'train': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    16649
#   ?a income/yearlyReimbursement 2 => ?a approval False                        12497
#   ?a yearlyReimbursement 3 => ?a approval False                               12479
#   ?a income/yearlyReimbursement 1 => ?a approval False                        12458
#   ?a income/yearlyReimbursement 0 => ?a approval False                         8429
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4155
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    8286
#   ?a income/yearlyReimbursement 2 => ?a approval False                        6329
#   ?a income/yearlyReimbursement 1 => ?a approval False                        6260
#   ?a yearlyReimbursement 3 => ?a approval False                               6241
#   ?a income/yearlyReimbursement 0 => ?a approval False                        4156
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2061
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.4\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a loanAmount 2 => ?a approval False                    16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a loanAmount 2 => ?a approval False                    8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0\nhC=0': {'train': ?a loanAmount 2 => ?a approval False                                        16674
#   ?a loanAmount 3 => ?a approval False                                        16570
#   ?a income/yearlyReimbursement 1 => ?a approval False                        12506
#   ?a income/yearlyReimbursement 0 => ?a approval False                         8363
#   ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False     4288
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4141
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                  4125
#   Name: 1, dtype: int64,
#   'test': ?a loanAmount 2 => ?a approval False                                        8330
#   ?a loanAmount 3 => ?a approval False                                        8316
#   ?a income/yearlyReimbursement 1 => ?a approval False                        6212
#   ?a income/yearlyReimbursement 0 => ?a approval False                        4222
#   ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    2095
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                 2083
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2075
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.4\nhC=0': {'train': ?a loanAmount 2 => ?a approval False                                        16674
#   ?a loanAmount 3 => ?a approval False                                        16570
#   ?a income/yearlyReimbursement 1 => ?a approval False                        12506
#   ?a income/yearlyReimbursement 0 => ?a approval False                         8363
#   ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False     4288
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4141
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                  4125
#   Name: 1, dtype: int64,
#   'test': ?a loanAmount 2 => ?a approval False                                        8330
#   ?a loanAmount 3 => ?a approval False                                        8316
#   ?a income/yearlyReimbursement 1 => ?a approval False                        6212
#   ?a income/yearlyReimbursement 0 => ?a approval False                        4222
#   ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    2095
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                 2083
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2075
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.8\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a loanAmount 2 => ?a approval False                    16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a loanAmount 2 => ?a approval False                    8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.8\nhC=0': {'train': ?a loanAmount 2 => ?a approval False                                        16674
#   ?a loanAmount 3 => ?a approval False                                        16570
#   ?a income/yearlyReimbursement 1 => ?a approval False                        12506
#   ?a income/yearlyReimbursement 0 => ?a approval False                         8363
#   ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False     4288
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4141
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                  4125
#   Name: 1, dtype: int64,
#   'test': ?a loanAmount 2 => ?a approval False                                        8330
#   ?a loanAmount 3 => ?a approval False                                        8316
#   ?a income/yearlyReimbursement 1 => ?a approval False                        6212
#   ?a income/yearlyReimbursement 0 => ?a approval False                        4222
#   ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    2095
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                 2083
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2075
#   Name: 1, dtype: int64}}

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw, rules_used = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["headCoverage", "precision_train", "precision_test"], [True, False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-coverage", cv)
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : LaunchedProcess n°3 : Launched
#
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 10)
# Value('d', 20)
# Value('d', 30)
# Value('d', 40)
# Process n°12 : Finished
# Process n°9 : Finished
# Process n°11 : Finished
# Process n°8 : Finished
# Process n°3 : Finished
# Process n°7 : Finished
# Process n°0 : Finished
# Process n°10 : Finished
# Value('d', 50)
# Process n°1 : Finished
# Process n°6 : Finished
# Process n°2 : Finished
# Process n°4 : Finished
# Process n°5 : Finished
# 54
# CPU times: user 12.1 s, sys: 39.4 s, total: 51.5 s
# Wall time: 9min 29s

# %%
rules_used
# Out:
# {'CV=0-A=2\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=2\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=2\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=2\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=2\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=2\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=2\nstdC=0.4\nhC=0': {'train': ?a loanAmount 0 => ?a approval True     16845
#   ?a income 2 => ?a approval False        16649
#   ?a loanAmount 1 => ?a approval False    16624
#   ?a income 3 => ?a approval False        16549
#   Name: 1, dtype: int64,
#   'test': ?a income 2 => ?a approval False        8355
#   ?a loanAmount 0 => ?a approval True     8339
#   ?a income 3 => ?a approval False        8337
#   ?a loanAmount 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0.4\nhC=0': {'train': ?a loanAmount 0 => ?a approval True     16731
#   ?a income 2 => ?a approval False        16685
#   ?a income 3 => ?a approval False        16653
#   ?a loanAmount 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a loanAmount 0 => ?a approval True     8453
#   ?a loanAmount 1 => ?a approval False    8329
#   ?a income 2 => ?a approval False        8319
#   ?a income 3 => ?a approval False        8233
#   Name: 1, dtype: int64},
#  'CV=1-A=2\nstdC=0\nhC=0.2': {'train': ?a monthDuration 0 => ?a approval False                 16845
#   ?a income/yearlyReimbursement 2 => ?a approval False    16649
#   ?a income 1 => ?a approval False                        16624
#   ?a income/yearlyReimbursement 3 => ?a approval True     16549
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 2 => ?a approval False    8355
#   ?a monthDuration 0 => ?a approval False                 8339
#   ?a income/yearlyReimbursement 3 => ?a approval True     8337
#   ?a income 1 => ?a approval False                        8302
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0\nhC=0.2': {'train': ?a monthDuration 0 => ?a approval False                16731
#   ?a yearlyReimbursement 2 => ?a approval False          16685
#   ?a income/yearlyReimbursement 3 => ?a approval True    16653
#   ?a income 1 => ?a approval False                       16597
#   Name: 1, dtype: int64,
#   'test': ?a monthDuration 0 => ?a approval False                8453
#   ?a income 1 => ?a approval False                       8329
#   ?a yearlyReimbursement 2 => ?a approval False          8319
#   ?a income/yearlyReimbursement 3 => ?a approval True    8233
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0.8\nhC=0.2': {'train': ?a monthDuration 0 => ?a approval False                16731
#   ?a yearlyReimbursement 2 => ?a approval False          16685
#   ?a income/yearlyReimbursement 3 => ?a approval True    16653
#   ?a income 1 => ?a approval False                       16597
#   Name: 1, dtype: int64,
#   'test': ?a monthDuration 0 => ?a approval False                8453
#   ?a income 1 => ?a approval False                       8329
#   ?a yearlyReimbursement 2 => ?a approval False          8319
#   ?a income/yearlyReimbursement 3 => ?a approval True    8233
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0.4\nhC=0.2': {'train': ?a monthDuration 0 => ?a approval False                16731
#   ?a yearlyReimbursement 2 => ?a approval False          16685
#   ?a income/yearlyReimbursement 3 => ?a approval True    16653
#   ?a income 1 => ?a approval False                       16597
#   Name: 1, dtype: int64,
#   'test': ?a monthDuration 0 => ?a approval False                8453
#   ?a income 1 => ?a approval False                       8329
#   ?a yearlyReimbursement 2 => ?a approval False          8319
#   ?a income/yearlyReimbursement 3 => ?a approval True    8233
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=2\nstdC=0.4\nhC=0.2': {'train': ?a monthDuration 0 => ?a approval False                 16845
#   ?a income/yearlyReimbursement 2 => ?a approval False    16649
#   ?a income 1 => ?a approval False                        16624
#   ?a income/yearlyReimbursement 3 => ?a approval True     16549
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 2 => ?a approval False    8355
#   ?a monthDuration 0 => ?a approval False                 8339
#   ?a income/yearlyReimbursement 3 => ?a approval True     8337
#   ?a income 1 => ?a approval False                        8302
#   Name: 1, dtype: int64},
#  'CV=1-A=2\nstdC=0.8\nhC=0': {'train': ?a monthDuration 0 => ?a approval False                 16845
#   ?a income/yearlyReimbursement 2 => ?a approval False    16649
#   ?a income 1 => ?a approval False                        16624
#   ?a income/yearlyReimbursement 3 => ?a approval True     16549
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 2 => ?a approval False    8355
#   ?a monthDuration 0 => ?a approval False                 8339
#   ?a income/yearlyReimbursement 3 => ?a approval True     8337
#   ?a income 1 => ?a approval False                        8302
#   Name: 1, dtype: int64},
#  'CV=1-A=2\nstdC=0\nhC=0': {'train': ?a creditScore 0 => ?a approval True                    16845
#   ?a rate 2 => ?a approval True                           16649
#   ?a yearlyReimbursement 1 => ?a approval True            16624
#   ?a income/yearlyReimbursement 3 => ?a approval False    16549
#   Name: 1, dtype: int64,
#   'test': ?a rate 2 => ?a approval True                           8355
#   ?a creditScore 0 => ?a approval True                    8339
#   ?a income/yearlyReimbursement 3 => ?a approval False    8337
#   ?a yearlyReimbursement 1 => ?a approval True            8302
#   Name: 1, dtype: int64},
#  'CV=1-A=2\nstdC=0.8\nhC=0.2': {'train': ?a monthDuration 0 => ?a approval False                 16845
#   ?a income/yearlyReimbursement 2 => ?a approval False    16649
#   ?a income 1 => ?a approval False                        16624
#   ?a income/yearlyReimbursement 3 => ?a approval True     16549
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 2 => ?a approval False    8355
#   ?a monthDuration 0 => ?a approval False                 8339
#   ?a income/yearlyReimbursement 3 => ?a approval True     8337
#   ?a income 1 => ?a approval False                        8302
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=2\nstdC=0.8\nhC=0': {'train': ?a monthDuration 0 => ?a approval False                16731
#   ?a yearlyReimbursement 2 => ?a approval False          16685
#   ?a income/yearlyReimbursement 3 => ?a approval True    16653
#   ?a monthDuration 1 => ?a approval False                16597
#   Name: 1, dtype: int64,
#   'test': ?a monthDuration 0 => ?a approval False                8453
#   ?a monthDuration 1 => ?a approval False                8329
#   ?a yearlyReimbursement 2 => ?a approval False          8319
#   ?a income/yearlyReimbursement 3 => ?a approval True    8233
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0\nhC=0': {'train': ?a creditScore 0 => ?a approval True                    16731
#   ?a rate 2 => ?a approval True                           16685
#   ?a income/yearlyReimbursement 3 => ?a approval False    16653
#   ?a yearlyReimbursement 1 => ?a approval True            16597
#   Name: 1, dtype: int64,
#   'test': ?a creditScore 0 => ?a approval True                    8453
#   ?a yearlyReimbursement 1 => ?a approval True            8329
#   ?a rate 2 => ?a approval True                           8319
#   ?a income/yearlyReimbursement 3 => ?a approval False    8233
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=3\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=3\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=3\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=2-A=2\nstdC=0\nhC=0': {'train': ?a creditScore 0 => ?a approval True                    16792
#   ?a creditScore 2 => ?a approval True                    16674
#   ?a yearlyReimbursement 1 => ?a approval True            16631
#   ?a income/yearlyReimbursement 3 => ?a approval False    16570
#   Name: 1, dtype: int64,
#   'test': ?a creditScore 0 => ?a approval True                    8392
#   ?a creditScore 2 => ?a approval True                    8330
#   ?a income/yearlyReimbursement 3 => ?a approval False    8316
#   ?a yearlyReimbursement 1 => ?a approval True            8295
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0\nhC=0.2': {'train': ?a monthDuration 0 => ?a approval False                 16792
#   ?a income/yearlyReimbursement 2 => ?a approval False    16674
#   ?a income 1 => ?a approval False                        16631
#   ?a income/yearlyReimbursement 3 => ?a approval True     16570
#   Name: 1, dtype: int64,
#   'test': ?a monthDuration 0 => ?a approval False                 8392
#   ?a income/yearlyReimbursement 2 => ?a approval False    8330
#   ?a income/yearlyReimbursement 3 => ?a approval True     8316
#   ?a income 1 => ?a approval False                        8295
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0.4\nhC=0': {'train': ?a loanAmount 0 => ?a approval True     16792
#   ?a income 2 => ?a approval False        16674
#   ?a loanAmount 1 => ?a approval False    16631
#   ?a income 3 => ?a approval False        16570
#   Name: 1, dtype: int64,
#   'test': ?a loanAmount 0 => ?a approval True     8392
#   ?a income 2 => ?a approval False        8330
#   ?a income 3 => ?a approval False        8316
#   ?a loanAmount 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=2-A=2\nstdC=0.4\nhC=0.2': {'train': ?a monthDuration 0 => ?a approval False                 16792
#   ?a income/yearlyReimbursement 2 => ?a approval False    16674
#   ?a income 1 => ?a approval False                        16631
#   ?a income/yearlyReimbursement 3 => ?a approval True     16570
#   Name: 1, dtype: int64,
#   'test': ?a monthDuration 0 => ?a approval False                 8392
#   ?a income/yearlyReimbursement 2 => ?a approval False    8330
#   ?a income/yearlyReimbursement 3 => ?a approval True     8316
#   ?a income 1 => ?a approval False                        8295
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0.8\nhC=0': {'train': ?a monthDuration 0 => ?a approval False                 16792
#   ?a income/yearlyReimbursement 2 => ?a approval False    16674
#   ?a income 1 => ?a approval False                        16631
#   ?a income/yearlyReimbursement 3 => ?a approval True     16570
#   Name: 1, dtype: int64,
#   'test': ?a monthDuration 0 => ?a approval False                 8392
#   ?a income/yearlyReimbursement 2 => ?a approval False    8330
#   ?a income/yearlyReimbursement 3 => ?a approval True     8316
#   ?a income 1 => ?a approval False                        8295
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0.8\nhC=0.2': {'train': ?a monthDuration 0 => ?a approval False                 16792
#   ?a income/yearlyReimbursement 2 => ?a approval False    16674
#   ?a income 1 => ?a approval False                        16631
#   ?a income/yearlyReimbursement 3 => ?a approval True     16570
#   Name: 1, dtype: int64,
#   'test': ?a monthDuration 0 => ?a approval False                 8392
#   ?a income/yearlyReimbursement 2 => ?a approval False    8330
#   ?a income/yearlyReimbursement 3 => ?a approval True     8316
#   ?a income 1 => ?a approval False                        8295
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=3\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=3\nstdC=0\nhC=0.2': {'train': ?a rate ?d & ?a yearlyReimbursement ?d => ?a approval False    16535
#   ?a yearlyReimbursement 2 => ?a approval False                  12613
#   ?a income/yearlyReimbursement 3 => ?a approval True            12532
#   ?a monthDuration 0 => ?a approval False                        12514
#   ?a income 1 => ?a approval False                               12472
#   Name: 1, dtype: int64,
#   'test': ?a rate ?d & ?a yearlyReimbursement ?d => ?a approval False    8400
#   ?a monthDuration 0 => ?a approval False                        6287
#   ?a income 1 => ?a approval False                               6246
#   ?a yearlyReimbursement 2 => ?a approval False                  6213
#   ?a income/yearlyReimbursement 3 => ?a approval True            6188
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0.8\nhC=0.2': {'train': ?a income/yearlyReimbursement 3 => ?a approval True            16653
#   ?a income 1 => ?a approval False                               16597
#   ?a yearlyReimbursement 2 => ?a approval False                  12613
#   ?a monthDuration 0 => ?a approval False                        12514
#   ?a loanAmount ?d & ?a monthDuration ?d => ?a approval False     8289
#   Name: 1, dtype: int64,
#   'test': ?a income 1 => ?a approval False                               8329
#   ?a income/yearlyReimbursement 3 => ?a approval True            8233
#   ?a monthDuration 0 => ?a approval False                        6287
#   ?a yearlyReimbursement 2 => ?a approval False                  6213
#   ?a loanAmount ?d & ?a monthDuration ?d => ?a approval False    4272
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0.4\nhC=0.2': {'train': ?a rate ?d & ?a yearlyReimbursement ?d => ?a approval False    16535
#   ?a yearlyReimbursement 2 => ?a approval False                  12613
#   ?a income/yearlyReimbursement 3 => ?a approval True            12532
#   ?a monthDuration 0 => ?a approval False                        12514
#   ?a income 1 => ?a approval False                               12472
#   Name: 1, dtype: int64,
#   'test': ?a rate ?d & ?a yearlyReimbursement ?d => ?a approval False    8400
#   ?a monthDuration 0 => ?a approval False                        6287
#   ?a income 1 => ?a approval False                               6246
#   ?a yearlyReimbursement 2 => ?a approval False                  6213
#   ?a income/yearlyReimbursement 3 => ?a approval True            6188
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=3\nstdC=0\nhC=0.2': {'train': ?a income 1 => ?a approval False                               16624
#   ?a monthDuration 0 => ?a approval False                        12584
#   ?a income/yearlyReimbursement 2 => ?a approval False           12497
#   ?a rate ?d & ?a yearlyReimbursement ?d => ?a approval False    12483
#   ?a income/yearlyReimbursement 3 => ?a approval True            12479
#   Name: 1, dtype: int64,
#   'test': ?a income 1 => ?a approval False                               8302
#   ?a income/yearlyReimbursement 2 => ?a approval False           6329
#   ?a rate ?d & ?a yearlyReimbursement ?d => ?a approval False    6244
#   ?a income/yearlyReimbursement 3 => ?a approval True            6241
#   ?a monthDuration 0 => ?a approval False                        6217
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=3\nstdC=0.8\nhC=0.2': {'train': ?a income 1 => ?a approval False                               16624
#   ?a income/yearlyReimbursement 3 => ?a approval True            16549
#   ?a monthDuration 0 => ?a approval False                        12584
#   ?a income/yearlyReimbursement 2 => ?a approval False           12497
#   ?a loanAmount ?d & ?a monthDuration ?d => ?a approval False     8413
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 3 => ?a approval True            8337
#   ?a income 1 => ?a approval False                               8302
#   ?a income/yearlyReimbursement 2 => ?a approval False           6329
#   ?a monthDuration 0 => ?a approval False                        6217
#   ?a loanAmount ?d & ?a monthDuration ?d => ?a approval False    4148
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0.4\nhC=0.2': {'train': ?a income 1 => ?a approval False                               16624
#   ?a monthDuration 0 => ?a approval False                        12584
#   ?a income/yearlyReimbursement 2 => ?a approval False           12497
#   ?a rate ?d & ?a yearlyReimbursement ?d => ?a approval False    12483
#   ?a income/yearlyReimbursement 3 => ?a approval True            12479
#   Name: 1, dtype: int64,
#   'test': ?a income 1 => ?a approval False                               8302
#   ?a income/yearlyReimbursement 2 => ?a approval False           6329
#   ?a rate ?d & ?a yearlyReimbursement ?d => ?a approval False    6244
#   ?a income/yearlyReimbursement 3 => ?a approval True            6241
#   ?a monthDuration 0 => ?a approval False                        6217
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=2-A=3\nstdC=0\nhC=0.2': {'train': ?a income 1 => ?a approval False                               16631
#   ?a rate ?d & ?a yearlyReimbursement ?d => ?a approval False    12561
#   ?a income/yearlyReimbursement 2 => ?a approval False           12542
#   ?a monthDuration 0 => ?a approval False                        12504
#   ?a income/yearlyReimbursement 3 => ?a approval True            12429
#   Name: 1, dtype: int64,
#   'test': ?a income 1 => ?a approval False                               8295
#   ?a monthDuration 0 => ?a approval False                        6297
#   ?a income/yearlyReimbursement 3 => ?a approval True            6291
#   ?a income/yearlyReimbursement 2 => ?a approval False           6284
#   ?a rate ?d & ?a yearlyReimbursement ?d => ?a approval False    6166
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.4\nhC=0.2': {'train': ?a income 1 => ?a approval False                               16631
#   ?a rate ?d & ?a yearlyReimbursement ?d => ?a approval False    12561
#   ?a income/yearlyReimbursement 2 => ?a approval False           12542
#   ?a monthDuration 0 => ?a approval False                        12504
#   ?a income/yearlyReimbursement 3 => ?a approval True            12429
#   Name: 1, dtype: int64,
#   'test': ?a income 1 => ?a approval False                               8295
#   ?a monthDuration 0 => ?a approval False                        6297
#   ?a income/yearlyReimbursement 3 => ?a approval True            6291
#   ?a income/yearlyReimbursement 2 => ?a approval False           6284
#   ?a rate ?d & ?a yearlyReimbursement ?d => ?a approval False    6166
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0\nhC=0': {'train': ?a creditScore 2 & ?a rate 3 => ?a approval True                       4283
#   ?a creditScore 3 & ?a rate 1 => ?a approval True                       4250
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True      4227
#   ?a monthDuration ?d & ?a yearlyReimbursement ?d => ?a approval True    4217
#   ?a loanAmount 1 & ?a rate 0 => ?a approval True                        4189
#   ?a income/yearlyReimbursement 3 => ?a approval False                   4181
#   ?a creditScore 2 & ?a rate 0 => ?a approval True                       4168
#   ?a creditScore 2 & ?a loanAmount 1 => ?a approval True                 4162
#   ?a creditScore 1 & ?a rate 2 => ?a approval True                       4162
#   ?a creditScore 0 & ?a rate 2 => ?a approval True                       4151
#   ?a creditScore 0 & ?a loanAmount 1 => ?a approval True                 4136
#   ?a creditScore 1 & ?a rate 1 => ?a approval True                       4125
#   ?a creditScore 1 & ?a monthDuration 3 => ?a approval True              4121
#   ?a creditScore 3 & ?a monthDuration 3 => ?a approval True              4121
#   ?a creditScore 3 & ?a rate 0 => ?a approval True                       4101
#   ?a monthDuration 2 & ?a rate 2 => ?a approval True                     4072
#   Name: 1, dtype: int64,
#   'test': ?a monthDuration ?d & ?a yearlyReimbursement ?d => ?a approval True    2166
#   ?a creditScore 0 & ?a rate 2 => ?a approval True                       2155
#   ?a monthDuration 2 & ?a rate 2 => ?a approval True                     2106
#   ?a creditScore 1 & ?a rate 2 => ?a approval True                       2099
#   ?a creditScore 2 & ?a rate 3 => ?a approval True                       2097
#   ?a loanAmount 1 & ?a rate 0 => ?a approval True                        2093
#   ?a creditScore 2 & ?a loanAmount 1 => ?a approval True                 2090
#   ?a creditScore 1 & ?a rate 1 => ?a approval True                       2083
#   ?a creditScore 0 & ?a loanAmount 1 => ?a approval True                 2080
#   ?a creditScore 3 & ?a rate 1 => ?a approval True                       2074
#   ?a income/yearlyReimbursement 3 => ?a approval False                   2074
#   ?a creditScore 1 & ?a monthDuration 3 => ?a approval True              2054
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True      2052
#   ?a creditScore 3 & ?a monthDuration 3 => ?a approval True              2045
#   ?a creditScore 3 & ?a rate 0 => ?a approval True                       2040
#   ?a creditScore 2 & ?a rate 0 => ?a approval True                       2026
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.8\nhC=0.2': {'train': ?a income 1 => ?a approval False                               16631
#   ?a income/yearlyReimbursement 3 => ?a approval True            16570
#   ?a income/yearlyReimbursement 2 => ?a approval False           12542
#   ?a monthDuration 0 => ?a approval False                        12504
#   ?a loanAmount ?d & ?a monthDuration ?d => ?a approval False     8420
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 3 => ?a approval True            8316
#   ?a income 1 => ?a approval False                               8295
#   ?a monthDuration 0 => ?a approval False                        6297
#   ?a income/yearlyReimbursement 2 => ?a approval False           6284
#   ?a loanAmount ?d & ?a monthDuration ?d => ?a approval False    4141
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0.4\nhC=0': {'train': ?a income 2 & ?a monthDuration 3 => ?a approval True                 4283
#   ?a income 3 & ?a yearlyReimbursement 1 => ?a approval True           4250
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True    4227
#   ?a loanAmount 0 & ?a rate 0 => ?a approval True                      4217
#   ?a creditScore 1 & ?a loanAmount 0 => ?a approval True               4189
#   ?a income 3 & ?a monthDuration 2 => ?a approval True                 4181
#   ?a rate 2 & ?a yearlyReimbursement 0 => ?a approval True             4168
#   ?a creditScore 2 & ?a rate 1 => ?a approval False                    4162
#   ?a monthDuration 1 & ?a rate 2 => ?a approval False                  4162
#   ?a loanAmount 0 & ?a monthDuration 2 => ?a approval True             4151
#   ?a loanAmount 0 & ?a rate 1 => ?a approval True                      4136
#   ?a monthDuration 1 & ?a rate 1 => ?a approval False                  4125
#   ?a income 3 & ?a monthDuration 3 => ?a approval True                 4121
#   ?a loanAmount 1 & ?a monthDuration 3 => ?a approval True             4121
#   ?a creditScore 3 & ?a loanAmount 0 => ?a approval True               4101
#   ?a creditScore 2 & ?a rate 2 => ?a approval False                    4072
#   Name: 1, dtype: int64,
#   'test': ?a loanAmount 0 & ?a rate 0 => ?a approval True                      2166
#   ?a loanAmount 0 & ?a monthDuration 2 => ?a approval True             2155
#   ?a creditScore 2 & ?a rate 2 => ?a approval False                    2106
#   ?a monthDuration 1 & ?a rate 2 => ?a approval False                  2099
#   ?a income 2 & ?a monthDuration 3 => ?a approval True                 2097
#   ?a creditScore 1 & ?a loanAmount 0 => ?a approval True               2093
#   ?a creditScore 2 & ?a rate 1 => ?a approval False                    2090
#   ?a monthDuration 1 & ?a rate 1 => ?a approval False                  2083
#   ?a loanAmount 0 & ?a rate 1 => ?a approval True                      2080
#   ?a income 3 & ?a monthDuration 2 => ?a approval True                 2074
#   ?a income 3 & ?a yearlyReimbursement 1 => ?a approval True           2074
#   ?a loanAmount 1 & ?a monthDuration 3 => ?a approval True             2054
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True    2052
#   ?a income 3 & ?a monthDuration 3 => ?a approval True                 2045
#   ?a creditScore 3 & ?a loanAmount 0 => ?a approval True               2040
#   ?a rate 2 & ?a yearlyReimbursement 0 => ?a approval True             2026
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0\nhC=0': {'train': ?a loanAmount ?d & ?a monthDuration ?d => ?a approval True           4261
#   ?a creditScore 2 & ?a rate 3 => ?a approval True                     4259
#   ?a loanAmount 0 & ?a monthDuration 2 => ?a approval True             4223
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True    4206
#   ?a creditScore 1 & ?a rate 2 => ?a approval True                     4197
#   ?a creditScore 3 & ?a rate 1 => ?a approval True                     4194
#   ?a loanAmount 1 & ?a rate 1 => ?a approval True                      4166
#   ?a creditScore 0 & ?a rate 1 => ?a approval True                     4155
#   ?a creditScore 3 & ?a income 2 => ?a approval True                   4152
#   ?a creditScore 2 & ?a income 2 => ?a approval True                   4152
#   ?a loanAmount 1 & ?a rate 0 => ?a approval True                      4149
#   ?a creditScore 3 & ?a rate 0 => ?a approval True                     4133
#   ?a income 2 & ?a rate 0 => ?a approval True                          4119
#   ?a creditScore 2 & ?a loanAmount 1 => ?a approval True               4119
#   ?a creditScore 1 & ?a monthDuration 3 => ?a approval True            4112
#   ?a creditScore 3 & ?a monthDuration 3 => ?a approval True            4070
#   Name: 1, dtype: int64,
#   'test': ?a loanAmount 1 & ?a rate 0 => ?a approval True                      2133
#   ?a creditScore 2 & ?a loanAmount 1 => ?a approval True               2133
#   ?a creditScore 3 & ?a rate 1 => ?a approval True                     2130
#   ?a loanAmount ?d & ?a monthDuration ?d => ?a approval True           2122
#   ?a creditScore 2 & ?a rate 3 => ?a approval True                     2121
#   ?a creditScore 3 & ?a income 2 => ?a approval True                   2103
#   ?a creditScore 3 & ?a monthDuration 3 => ?a approval True            2096
#   ?a loanAmount 0 & ?a monthDuration 2 => ?a approval True             2083
#   ?a income 2 & ?a rate 0 => ?a approval True                          2075
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True    2073
#   ?a creditScore 1 & ?a rate 2 => ?a approval True                     2064
#   ?a creditScore 1 & ?a monthDuration 3 => ?a approval True            2063
#   ?a creditScore 0 & ?a rate 1 => ?a approval True                     2061
#   ?a loanAmount 1 & ?a rate 1 => ?a approval True                      2042
#   ?a creditScore 2 & ?a income 2 => ?a approval True                   2026
#   ?a creditScore 3 & ?a rate 0 => ?a approval True                     2008
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0.4\nhC=0': {'train': ?a loanAmount 0 & ?a rate 0 => ?a approval True                      4261
#   ?a income 2 & ?a monthDuration 3 => ?a approval True                 4259
#   ?a loanAmount 0 & ?a monthDuration 2 => ?a approval True             4223
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True    4206
#   ?a monthDuration 1 & ?a rate 2 => ?a approval False                  4197
#   ?a income 3 & ?a yearlyReimbursement 1 => ?a approval True           4194
#   ?a creditScore 1 & ?a monthDuration 1 => ?a approval False           4166
#   ?a loanAmount 0 & ?a rate 1 => ?a approval True                      4155
#   ?a creditScore 2 & ?a rate 2 => ?a approval False                    4152
#   ?a income 3 & ?a monthDuration 2 => ?a approval True                 4152
#   ?a monthDuration 1 & ?a yearlyReimbursement 0 => ?a approval True    4149
#   ?a creditScore 3 & ?a loanAmount 0 => ?a approval True               4133
#   ?a creditScore 2 & ?a rate 1 => ?a approval False                    4119
#   ?a creditScore 2 & ?a loanAmount 0 => ?a approval True               4119
#   ?a loanAmount 1 & ?a monthDuration 3 => ?a approval True             4112
#   ?a income 3 & ?a monthDuration 3 => ?a approval True                 4070
#   Name: 1, dtype: int64,
#   'test': ?a creditScore 2 & ?a rate 1 => ?a approval False                    2133
#   ?a monthDuration 1 & ?a yearlyReimbursement 0 => ?a approval True    2133
#   ?a income 3 & ?a yearlyReimbursement 1 => ?a approval True           2130
#   ?a loanAmount 0 & ?a rate 0 => ?a approval True                      2122
#   ?a income 2 & ?a monthDuration 3 => ?a approval True                 2121
#   ?a income 3 & ?a monthDuration 2 => ?a approval True                 2103
#   ?a income 3 & ?a monthDuration 3 => ?a approval True                 2096
#   ?a loanAmount 0 & ?a monthDuration 2 => ?a approval True             2083
#   ?a creditScore 2 & ?a loanAmount 0 => ?a approval True               2075
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True    2073
#   ?a monthDuration 1 & ?a rate 2 => ?a approval False                  2064
#   ?a loanAmount 1 & ?a monthDuration 3 => ?a approval True             2063
#   ?a loanAmount 0 & ?a rate 1 => ?a approval True                      2061
#   ?a creditScore 1 & ?a monthDuration 1 => ?a approval False           2042
#   ?a creditScore 2 & ?a rate 2 => ?a approval False                    2026
#   ?a creditScore 3 & ?a loanAmount 0 => ?a approval True               2008
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0\nhC=0': {'train': ?a loanAmount ?d & ?a monthDuration ?d => ?a approval True           8413
#   ?a creditScore 0 & ?a rate 2 => ?a approval True                     4238
#   ?a loanAmount 1 & ?a rate 0 => ?a approval True                      4226
#   ?a monthDuration 2 & ?a rate 1 => ?a approval True                   4223
#   ?a income 2 & ?a monthDuration 3 => ?a approval True                 4218
#   ?a creditScore 3 & ?a loanAmount 1 => ?a approval True               4204
#   ?a creditScore 3 & ?a income 2 => ?a approval True                   4177
#   ?a creditScore 1 & ?a rate 2 => ?a approval True                     4163
#   ?a creditScore 0 & ?a rate 1 => ?a approval True                     4141
#   ?a creditScore 3 & ?a monthDuration 3 => ?a approval True            4141
#   ?a monthDuration 2 & ?a rate 2 => ?a approval True                   4132
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True    4125
#   ?a creditScore 1 & ?a monthDuration 3 => ?a approval True            4117
#   ?a creditScore 2 & ?a rate 0 => ?a approval True                     4101
#   ?a creditScore 3 & ?a rate 0 => ?a approval True                     4048
#   Name: 1, dtype: int64,
#   'test': ?a loanAmount ?d & ?a monthDuration ?d => ?a approval True           4178
#   ?a income 2 & ?a monthDuration 3 => ?a approval True                 2162
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True    2154
#   ?a creditScore 3 & ?a loanAmount 1 => ?a approval True               2120
#   ?a creditScore 1 & ?a rate 2 => ?a approval True                     2098
#   ?a creditScore 3 & ?a rate 0 => ?a approval True                     2093
#   ?a creditScore 2 & ?a rate 0 => ?a approval True                     2093
#   ?a creditScore 3 & ?a income 2 => ?a approval True                   2078
#   ?a creditScore 0 & ?a rate 1 => ?a approval True                     2075
#   ?a creditScore 0 & ?a rate 2 => ?a approval True                     2068
#   ?a creditScore 1 & ?a monthDuration 3 => ?a approval True            2058
#   ?a loanAmount 1 & ?a rate 0 => ?a approval True                      2056
#   ?a monthDuration 2 & ?a rate 2 => ?a approval True                   2046
#   ?a monthDuration 2 & ?a rate 1 => ?a approval True                   2029
#   ?a creditScore 3 & ?a monthDuration 3 => ?a approval True            2025
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.4\nhC=0': {'train': ?a creditScore 0 & ?a loanAmount 0 => ?a approval True               4288
#   ?a loanAmount 0 & ?a rate 2 => ?a approval True                      4238
#   ?a monthDuration 1 & ?a yearlyReimbursement 0 => ?a approval True    4226
#   ?a creditScore 2 & ?a rate 1 => ?a approval False                    4223
#   ?a income 2 & ?a monthDuration 3 => ?a approval True                 4218
#   ?a income 3 & ?a yearlyReimbursement 1 => ?a approval True           4204
#   ?a income 3 & ?a monthDuration 2 => ?a approval True                 4177
#   ?a monthDuration 1 & ?a rate 2 => ?a approval False                  4163
#   ?a income 3 & ?a monthDuration 3 => ?a approval True                 4141
#   ?a loanAmount 0 & ?a monthDuration 1 => ?a approval True             4141
#   ?a creditScore 2 & ?a rate 2 => ?a approval False                    4132
#   ?a creditScore 1 & ?a rate 1 => ?a approval False                    4125
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True    4125
#   ?a loanAmount 1 & ?a monthDuration 3 => ?a approval True             4117
#   ?a rate 2 & ?a yearlyReimbursement 0 => ?a approval True             4101
#   ?a creditScore 3 & ?a loanAmount 0 => ?a approval True               4048
#   Name: 1, dtype: int64,
#   'test': ?a income 2 & ?a monthDuration 3 => ?a approval True                 2162
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True    2154
#   ?a income 3 & ?a yearlyReimbursement 1 => ?a approval True           2120
#   ?a monthDuration 1 & ?a rate 2 => ?a approval False                  2098
#   ?a creditScore 0 & ?a loanAmount 0 => ?a approval True               2095
#   ?a rate 2 & ?a yearlyReimbursement 0 => ?a approval True             2093
#   ?a creditScore 3 & ?a loanAmount 0 => ?a approval True               2093
#   ?a creditScore 1 & ?a rate 1 => ?a approval False                    2083
#   ?a income 3 & ?a monthDuration 2 => ?a approval True                 2078
#   ?a loanAmount 0 & ?a monthDuration 1 => ?a approval True             2075
#   ?a loanAmount 0 & ?a rate 2 => ?a approval True                      2068
#   ?a loanAmount 1 & ?a monthDuration 3 => ?a approval True             2058
#   ?a monthDuration 1 & ?a yearlyReimbursement 0 => ?a approval True    2056
#   ?a creditScore 2 & ?a rate 2 => ?a approval False                    2046
#   ?a creditScore 2 & ?a rate 1 => ?a approval False                    2029
#   ?a income 3 & ?a monthDuration 3 => ?a approval True                 2025
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0.8\nhC=0': {'train': ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           4283
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    4250
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True           4227
#   ?a creditScore 0 & ?a monthDuration 0 => ?a approval False                  4217
#   ?a income 1 & ?a monthDuration 0 => ?a approval False                       4189
#   ?a income/yearlyReimbursement 3 & ?a rate 2 => ?a approval True             4181
#   ?a income 2 & ?a loanAmount 0 => ?a approval True                           4168
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                 4162
#   ?a monthDuration 1 & ?a rate 2 => ?a approval False                         4162
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                         4151
#   ?a creditScore 0 & ?a income 1 => ?a approval False                         4136
#   ?a monthDuration 1 & ?a rate 1 => ?a approval False                         4125
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           4121
#   ?a income/yearlyReimbursement 3 & ?a rate 3 => ?a approval True             4121
#   ?a income 3 & ?a loanAmount 0 => ?a approval True                           4101
#   ?a monthDuration ?d & ?a yearlyReimbursement ?d => ?a approval False        4072
#   Name: 1, dtype: int64,
#   'test': ?a creditScore 0 & ?a monthDuration 0 => ?a approval False                  2166
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                         2155
#   ?a monthDuration ?d & ?a yearlyReimbursement ?d => ?a approval False        2106
#   ?a monthDuration 1 & ?a rate 2 => ?a approval False                         2099
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           2097
#   ?a income 1 & ?a monthDuration 0 => ?a approval False                       2093
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                 2090
#   ?a monthDuration 1 & ?a rate 1 => ?a approval False                         2083
#   ?a creditScore 0 & ?a income 1 => ?a approval False                         2080
#   ?a income/yearlyReimbursement 3 & ?a rate 2 => ?a approval True             2074
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    2074
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           2054
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True           2052
#   ?a income/yearlyReimbursement 3 & ?a rate 3 => ?a approval True             2045
#   ?a income 3 & ?a loanAmount 0 => ?a approval True                           2040
#   ?a income 2 & ?a loanAmount 0 => ?a approval True                           2026
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0.8\nhC=0': {'train': ?a income 0 & ?a monthDuration 0 => ?a approval False                       4261
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           4259
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                         4223
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True           4206
#   ?a monthDuration 1 & ?a rate 2 => ?a approval False                         4197
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    4194
#   ?a income 1 & ?a monthDuration 1 => ?a approval False                       4166
#   ?a creditScore 0 & ?a yearlyReimbursement 1 => ?a approval False            4155
#   ?a income/yearlyReimbursement 3 & ?a rate 2 => ?a approval True             4152
#   ?a monthDuration ?d & ?a yearlyReimbursement ?d => ?a approval False        4152
#   ?a creditScore 1 & ?a monthDuration 0 => ?a approval False                  4149
#   ?a income 3 & ?a loanAmount 0 => ?a approval True                           4133
#   ?a creditScore 2 & ?a income 1 => ?a approval False                         4119
#   ?a income 2 & ?a loanAmount 0 => ?a approval True                           4119
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           4112
#   ?a income/yearlyReimbursement 3 & ?a rate 3 => ?a approval True             4070
#   Name: 1, dtype: int64,
#   'test': ?a creditScore 2 & ?a income 1 => ?a approval False                         2133
#   ?a creditScore 1 & ?a monthDuration 0 => ?a approval False                  2133
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    2130
#   ?a income 0 & ?a monthDuration 0 => ?a approval False                       2122
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           2121
#   ?a income/yearlyReimbursement 3 & ?a rate 2 => ?a approval True             2103
#   ?a income/yearlyReimbursement 3 & ?a rate 3 => ?a approval True             2096
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                         2083
#   ?a income 2 & ?a loanAmount 0 => ?a approval True                           2075
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True           2073
#   ?a monthDuration 1 & ?a rate 2 => ?a approval False                         2064
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           2063
#   ?a creditScore 0 & ?a yearlyReimbursement 1 => ?a approval False            2061
#   ?a income 1 & ?a monthDuration 1 => ?a approval False                       2042
#   ?a monthDuration ?d & ?a yearlyReimbursement ?d => ?a approval False        2026
#   ?a income 3 & ?a loanAmount 0 => ?a approval True                           2008
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.8\nhC=0': {'train': ?a income 0 & ?a monthDuration 0 => ?a approval False                       4288
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                         4238
#   ?a income 1 & ?a monthDuration 0 => ?a approval False                       4226
#   ?a creditScore 2 & ?a monthDuration 1 => ?a approval False                  4223
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           4218
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    4204
#   ?a income/yearlyReimbursement 3 & ?a rate 2 => ?a approval True             4177
#   ?a income 1 & ?a rate 2 => ?a approval False                                4163
#   ?a income/yearlyReimbursement 3 & ?a rate 3 => ?a approval True             4141
#   ?a monthDuration 0 & ?a rate 1 => ?a approval False                         4141
#   ?a creditScore 2 & ?a rate 2 => ?a approval False                           4132
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True           4125
#   ?a monthDuration 1 & ?a rate 1 => ?a approval False                         4125
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           4117
#   ?a income 2 & ?a loanAmount 0 => ?a approval True                           4101
#   ?a income 3 & ?a loanAmount 0 => ?a approval True                           4048
#   Name: 1, dtype: int64,
#   'test': ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           2162
#   ?a income 0 & ?a income/yearlyReimbursement 3 => ?a approval True           2154
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    2120
#   ?a income 1 & ?a rate 2 => ?a approval False                                2098
#   ?a income 0 & ?a monthDuration 0 => ?a approval False                       2095
#   ?a income 3 & ?a loanAmount 0 => ?a approval True                           2093
#   ?a income 2 & ?a loanAmount 0 => ?a approval True                           2093
#   ?a monthDuration 1 & ?a rate 1 => ?a approval False                         2083
#   ?a income/yearlyReimbursement 3 & ?a rate 2 => ?a approval True             2078
#   ?a monthDuration 0 & ?a rate 1 => ?a approval False                         2075
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                         2068
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           2058
#   ?a income 1 & ?a monthDuration 0 => ?a approval False                       2056
#   ?a creditScore 2 & ?a rate 2 => ?a approval False                           2046
#   ?a creditScore 2 & ?a monthDuration 1 => ?a approval False                  2029
#   ?a income/yearlyReimbursement 3 & ?a rate 3 => ?a approval True             2025
#   Name: 1, dtype: int64}}

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw, rules_used = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["size_hypothese", "precision_train", "precision_test"], [False, False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-length", cv)
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : LaunchedProcess n°11 : Launched
#
# Process n°12 : Launched
# Value('d', 10)
# Value('d', 20)
# Value('d', 30)
# Value('d', 40)
# Process n°0 : Finished
# Process n°8 : Finished
# Process n°5 : Finished
# Process n°3 : Finished
# Process n°7 : Finished
# Process n°9 : Finished
# Process n°11 : Finished
# Process n°4 : Finished
# Value('d', 50)
# Process n°12 : Finished
# Process n°1 : Finished
# Process n°6 : Finished
# Process n°10 : Finished
# Process n°2 : Finished
# 54
# CPU times: user 12.1 s, sys: 39 s, total: 51.2 s
# Wall time: 9min 20s

# %%
rules_used
# Out:
# {'CV=0-A=2\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=2\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=2\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=2\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=2\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=2\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=2\nstdC=0\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a yearlyReimbursement 2 => ?a approval False           16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a loanAmount 3 => ?a approval False                    16549
#   Name: 1, dtype: int64,
#   'test': ?a yearlyReimbursement 2 => ?a approval False           8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a loanAmount 3 => ?a approval False                    8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=1-A=2\nstdC=0\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a yearlyReimbursement 2 => ?a approval False           16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a loanAmount 3 => ?a approval False                    16549
#   Name: 1, dtype: int64,
#   'test': ?a yearlyReimbursement 2 => ?a approval False           8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a loanAmount 3 => ?a approval False                    8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=1-A=2\nstdC=0.4\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a yearlyReimbursement 2 => ?a approval False           16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a loanAmount 3 => ?a approval False                    16549
#   Name: 1, dtype: int64,
#   'test': ?a yearlyReimbursement 2 => ?a approval False           8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a loanAmount 3 => ?a approval False                    8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a yearlyReimbursement 2 => ?a approval False           16685
#   ?a loanAmount 3 => ?a approval False                    16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a yearlyReimbursement 2 => ?a approval False           8319
#   ?a loanAmount 3 => ?a approval False                    8233
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0.4\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a yearlyReimbursement 2 => ?a approval False           16685
#   ?a loanAmount 3 => ?a approval False                    16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a yearlyReimbursement 2 => ?a approval False           8319
#   ?a loanAmount 3 => ?a approval False                    8233
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a yearlyReimbursement 2 => ?a approval False           16685
#   ?a loanAmount 3 => ?a approval False                    16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a yearlyReimbursement 2 => ?a approval False           8319
#   ?a loanAmount 3 => ?a approval False                    8233
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0.8\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a yearlyReimbursement 2 => ?a approval False           16685
#   ?a loanAmount 3 => ?a approval False                    16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a yearlyReimbursement 2 => ?a approval False           8319
#   ?a loanAmount 3 => ?a approval False                    8233
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0.4\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a yearlyReimbursement 2 => ?a approval False           16685
#   ?a loanAmount 3 => ?a approval False                    16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a yearlyReimbursement 2 => ?a approval False           8319
#   ?a loanAmount 3 => ?a approval False                    8233
#   Name: 1, dtype: int64},
#  'CV=0-A=2\nstdC=0.8\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16731
#   ?a yearlyReimbursement 2 => ?a approval False           16685
#   ?a loanAmount 3 => ?a approval False                    16653
#   ?a income/yearlyReimbursement 1 => ?a approval False    16597
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8453
#   ?a income/yearlyReimbursement 1 => ?a approval False    8329
#   ?a yearlyReimbursement 2 => ?a approval False           8319
#   ?a loanAmount 3 => ?a approval False                    8233
#   Name: 1, dtype: int64},
#  'CV=1-A=2\nstdC=0.4\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a yearlyReimbursement 2 => ?a approval False           16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a loanAmount 3 => ?a approval False                    16549
#   Name: 1, dtype: int64,
#   'test': ?a yearlyReimbursement 2 => ?a approval False           8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a loanAmount 3 => ?a approval False                    8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=1-A=2\nstdC=0.8\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a yearlyReimbursement 2 => ?a approval False           16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a loanAmount 3 => ?a approval False                    16549
#   Name: 1, dtype: int64,
#   'test': ?a yearlyReimbursement 2 => ?a approval False           8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a loanAmount 3 => ?a approval False                    8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=2\nstdC=0.8\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16845
#   ?a yearlyReimbursement 2 => ?a approval False           16649
#   ?a income/yearlyReimbursement 1 => ?a approval False    16624
#   ?a loanAmount 3 => ?a approval False                    16549
#   Name: 1, dtype: int64,
#   'test': ?a yearlyReimbursement 2 => ?a approval False           8355
#   ?a income/yearlyReimbursement 0 => ?a approval False    8339
#   ?a loanAmount 3 => ?a approval False                    8337
#   ?a income/yearlyReimbursement 1 => ?a approval False    8302
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=2-A=2\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=3\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=2-A=2\nstdC=0\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a yearlyReimbursement 2 => ?a approval False           16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a yearlyReimbursement 2 => ?a approval False           8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=3\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=2-A=2\nstdC=0\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a yearlyReimbursement 2 => ?a approval False           16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a yearlyReimbursement 2 => ?a approval False           8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0.4\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a yearlyReimbursement 2 => ?a approval False           16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a yearlyReimbursement 2 => ?a approval False           8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0.4\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a yearlyReimbursement 2 => ?a approval False           16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a yearlyReimbursement 2 => ?a approval False           8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0.8\nhC=0.2': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a yearlyReimbursement 2 => ?a approval False           16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a yearlyReimbursement 2 => ?a approval False           8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=2-A=2\nstdC=0.8\nhC=0': {'train': ?a income/yearlyReimbursement 0 => ?a approval False    16792
#   ?a yearlyReimbursement 2 => ?a approval False           16674
#   ?a income/yearlyReimbursement 1 => ?a approval False    16631
#   ?a loanAmount 3 => ?a approval False                    16570
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement 0 => ?a approval False    8392
#   ?a yearlyReimbursement 2 => ?a approval False           8330
#   ?a loanAmount 3 => ?a approval False                    8316
#   ?a income/yearlyReimbursement 1 => ?a approval False    8295
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=3\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=3\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=0-A=3\nstdC=0.8\nhC=0.2': {'train': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    16535
#   ?a loanAmount 2 => ?a approval False                             12613
#   ?a yearlyReimbursement 3 => ?a approval False                    12532
#   ?a income/yearlyReimbursement 0 => ?a approval False             12514
#   ?a income/yearlyReimbursement 1 => ?a approval False             12472
#   Name: 1, dtype: int64,
#   'test': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    8400
#   ?a income/yearlyReimbursement 0 => ?a approval False             6287
#   ?a income/yearlyReimbursement 1 => ?a approval False             6246
#   ?a loanAmount 2 => ?a approval False                             6213
#   ?a yearlyReimbursement 3 => ?a approval False                    6188
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0\nhC=0.2': {'train': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    16535
#   ?a loanAmount 2 => ?a approval False                             12613
#   ?a yearlyReimbursement 3 => ?a approval False                    12532
#   ?a income/yearlyReimbursement 0 => ?a approval False             12514
#   ?a income/yearlyReimbursement 1 => ?a approval False             12472
#   Name: 1, dtype: int64,
#   'test': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    8400
#   ?a income/yearlyReimbursement 0 => ?a approval False             6287
#   ?a income/yearlyReimbursement 1 => ?a approval False             6246
#   ?a loanAmount 2 => ?a approval False                             6213
#   ?a yearlyReimbursement 3 => ?a approval False                    6188
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0.8\nhC=0.2': {'train': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    16649
#   ?a income/yearlyReimbursement 0 => ?a approval False             12584
#   ?a income/yearlyReimbursement 2 => ?a approval False             12497
#   ?a yearlyReimbursement 3 => ?a approval False                    12479
#   ?a income/yearlyReimbursement 1 => ?a approval False             12458
#   Name: 1, dtype: int64,
#   'test': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    8286
#   ?a income/yearlyReimbursement 2 => ?a approval False             6329
#   ?a income/yearlyReimbursement 1 => ?a approval False             6260
#   ?a yearlyReimbursement 3 => ?a approval False                    6241
#   ?a income/yearlyReimbursement 0 => ?a approval False             6217
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0.4\nhC=0.2': {'train': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    16535
#   ?a loanAmount 2 => ?a approval False                             12613
#   ?a yearlyReimbursement 3 => ?a approval False                    12532
#   ?a income/yearlyReimbursement 0 => ?a approval False             12514
#   ?a income/yearlyReimbursement 1 => ?a approval False             12472
#   Name: 1, dtype: int64,
#   'test': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    8400
#   ?a income/yearlyReimbursement 0 => ?a approval False             6287
#   ?a income/yearlyReimbursement 1 => ?a approval False             6246
#   ?a loanAmount 2 => ?a approval False                             6213
#   ?a yearlyReimbursement 3 => ?a approval False                    6188
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=2-A=3\nstdC=0.4\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=1-A=3\nstdC=0\nhC=0.2': {'train': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    16649
#   ?a income/yearlyReimbursement 0 => ?a approval False             12584
#   ?a income/yearlyReimbursement 2 => ?a approval False             12497
#   ?a yearlyReimbursement 3 => ?a approval False                    12479
#   ?a income/yearlyReimbursement 1 => ?a approval False             12458
#   Name: 1, dtype: int64,
#   'test': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    8286
#   ?a income/yearlyReimbursement 2 => ?a approval False             6329
#   ?a income/yearlyReimbursement 1 => ?a approval False             6260
#   ?a yearlyReimbursement 3 => ?a approval False                    6241
#   ?a income/yearlyReimbursement 0 => ?a approval False             6217
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0.4\nhC=0.2': {'train': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    16649
#   ?a income/yearlyReimbursement 0 => ?a approval False             12584
#   ?a income/yearlyReimbursement 2 => ?a approval False             12497
#   ?a yearlyReimbursement 3 => ?a approval False                    12479
#   ?a income/yearlyReimbursement 1 => ?a approval False             12458
#   Name: 1, dtype: int64,
#   'test': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    8286
#   ?a income/yearlyReimbursement 2 => ?a approval False             6329
#   ?a income/yearlyReimbursement 1 => ?a approval False             6260
#   ?a yearlyReimbursement 3 => ?a approval False                    6241
#   ?a income/yearlyReimbursement 0 => ?a approval False             6217
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.8\nhC=0.4': {'train': Series([], Name: 1, dtype: int64),
#   'test': Series([], Name: 1, dtype: int64)},
#  'CV=2-A=3\nstdC=0\nhC=0.2': {'train': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    16686
#   ?a loanAmount 2 => ?a approval False                             12542
#   ?a income/yearlyReimbursement 1 => ?a approval False             12506
#   ?a income/yearlyReimbursement 0 => ?a approval False             12504
#   ?a loanAmount 3 => ?a approval False                             12429
#   Name: 1, dtype: int64,
#   'test': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    8249
#   ?a income/yearlyReimbursement 0 => ?a approval False             6297
#   ?a loanAmount 3 => ?a approval False                             6291
#   ?a loanAmount 2 => ?a approval False                             6284
#   ?a income/yearlyReimbursement 1 => ?a approval False             6212
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.8\nhC=0.2': {'train': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    16686
#   ?a loanAmount 2 => ?a approval False                             12542
#   ?a income/yearlyReimbursement 1 => ?a approval False             12506
#   ?a income/yearlyReimbursement 0 => ?a approval False             12504
#   ?a loanAmount 3 => ?a approval False                             12429
#   Name: 1, dtype: int64,
#   'test': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    8249
#   ?a income/yearlyReimbursement 0 => ?a approval False             6297
#   ?a loanAmount 3 => ?a approval False                             6291
#   ?a loanAmount 2 => ?a approval False                             6284
#   ?a income/yearlyReimbursement 1 => ?a approval False             6212
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0\nhC=0': {'train': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    16649
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True            4259
#   ?a income 0 & ?a rate 2 => ?a approval False                                 4223
#   ?a income 0 & ?a rate 3 => ?a approval False                                 4206
#   ?a income 1 & ?a rate 2 => ?a approval False                                 4197
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True     4194
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4155
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True     4152
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                    4149
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                   4133
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                  4119
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                   4119
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True            4112
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    8286
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                 2133
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                   2133
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    2130
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           2121
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True    2103
#   ?a income 0 & ?a rate 2 => ?a approval False                                2083
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                  2075
#   ?a income 0 & ?a rate 3 => ?a approval False                                2073
#   ?a income 1 & ?a rate 2 => ?a approval False                                2064
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           2063
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2061
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                  2008
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0\nhC=0': {'train': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    12410
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True            4283
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True     4250
#   ?a income 0 & ?a rate 3 => ?a approval False                                 4227
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                    4189
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True     4181
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                   4168
#   ?a income 1 & ?a rate 2 => ?a approval False                                 4162
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                  4162
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                          4151
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4136
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                  4125
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True            4121
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                   4101
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    6317
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                         2155
#   ?a income 1 & ?a rate 2 => ?a approval False                                2099
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           2097
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                   2093
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                 2090
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                 2083
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2080
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    2074
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True    2074
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           2054
#   ?a income 0 & ?a rate 3 => ?a approval False                                2052
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                  2040
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                  2026
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0.4\nhC=0': {'train': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    12410
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True            4283
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True     4250
#   ?a income 0 & ?a rate 3 => ?a approval False                                 4227
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                    4189
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True     4181
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                   4168
#   ?a income 1 & ?a rate 2 => ?a approval False                                 4162
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                  4162
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                          4151
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4136
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                  4125
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True            4121
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                   4101
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    6317
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                         2155
#   ?a income 1 & ?a rate 2 => ?a approval False                                2099
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           2097
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                   2093
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                 2090
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                 2083
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2080
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    2074
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True    2074
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           2054
#   ?a income 0 & ?a rate 3 => ?a approval False                                2052
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                  2040
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                  2026
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.4\nhC=0.2': {'train': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    16686
#   ?a loanAmount 2 => ?a approval False                             12542
#   ?a income/yearlyReimbursement 1 => ?a approval False             12506
#   ?a income/yearlyReimbursement 0 => ?a approval False             12504
#   ?a loanAmount 3 => ?a approval False                             12429
#   Name: 1, dtype: int64,
#   'test': ?a income ?d & ?a yearlyReimbursement ?d => ?a approval False    8249
#   ?a income/yearlyReimbursement 0 => ?a approval False             6297
#   ?a loanAmount 3 => ?a approval False                             6291
#   ?a loanAmount 2 => ?a approval False                             6284
#   ?a income/yearlyReimbursement 1 => ?a approval False             6212
#   Name: 1, dtype: int64},
#  'CV=0-A=3\nstdC=0.8\nhC=0': {'train': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    12410
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True            4283
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True     4250
#   ?a income 0 & ?a rate 3 => ?a approval False                                 4227
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                    4189
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True     4181
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                   4168
#   ?a income 1 & ?a rate 2 => ?a approval False                                 4162
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                  4162
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                          4151
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4136
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                  4125
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True            4121
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                   4101
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    6317
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                         2155
#   ?a income 1 & ?a rate 2 => ?a approval False                                2099
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           2097
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                   2093
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                 2090
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                 2083
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2080
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    2074
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True    2074
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           2054
#   ?a income 0 & ?a rate 3 => ?a approval False                                2052
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                  2040
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                  2026
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0.4\nhC=0': {'train': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    16649
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True            4259
#   ?a income 0 & ?a rate 2 => ?a approval False                                 4223
#   ?a income 0 & ?a rate 3 => ?a approval False                                 4206
#   ?a income 1 & ?a rate 2 => ?a approval False                                 4197
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True     4194
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4155
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True     4152
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                    4149
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                   4133
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                  4119
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                   4119
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True            4112
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    8286
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                 2133
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                   2133
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    2130
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           2121
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True    2103
#   ?a income 0 & ?a rate 2 => ?a approval False                                2083
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                  2075
#   ?a income 0 & ?a rate 3 => ?a approval False                                2073
#   ?a income 1 & ?a rate 2 => ?a approval False                                2064
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           2063
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2061
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                  2008
#   Name: 1, dtype: int64},
#  'CV=1-A=3\nstdC=0.8\nhC=0': {'train': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    16649
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True            4259
#   ?a income 0 & ?a rate 2 => ?a approval False                                 4223
#   ?a income 0 & ?a rate 3 => ?a approval False                                 4206
#   ?a income 1 & ?a rate 2 => ?a approval False                                 4197
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True     4194
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4155
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True     4152
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                    4149
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                   4133
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                  4119
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                   4119
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True            4112
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    8286
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                 2133
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                   2133
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    2130
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           2121
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True    2103
#   ?a income 0 & ?a rate 2 => ?a approval False                                2083
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                  2075
#   ?a income 0 & ?a rate 3 => ?a approval False                                2073
#   ?a income 1 & ?a rate 2 => ?a approval False                                2064
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           2063
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2061
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                  2008
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0\nhC=0': {'train': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    12561
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                          4238
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                    4226
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                  4223
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True            4218
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True     4204
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True     4177
#   ?a income 1 & ?a rate 2 => ?a approval False                                 4163
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4141
#   ?a income 0 & ?a rate 3 => ?a approval False                                 4125
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                  4125
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True            4117
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                   4101
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                   4048
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    6166
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           2162
#   ?a income 0 & ?a rate 3 => ?a approval False                                2154
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    2120
#   ?a income 1 & ?a rate 2 => ?a approval False                                2098
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                  2093
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                  2093
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                 2083
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True    2078
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2075
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                         2068
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           2058
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                   2056
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                 2029
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.4\nhC=0': {'train': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    12561
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                          4238
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                    4226
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                  4223
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True            4218
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True     4204
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True     4177
#   ?a income 1 & ?a rate 2 => ?a approval False                                 4163
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4141
#   ?a income 0 & ?a rate 3 => ?a approval False                                 4125
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                  4125
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True            4117
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                   4101
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                   4048
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    6166
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           2162
#   ?a income 0 & ?a rate 3 => ?a approval False                                2154
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    2120
#   ?a income 1 & ?a rate 2 => ?a approval False                                2098
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                  2093
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                  2093
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                 2083
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True    2078
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2075
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                         2068
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           2058
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                   2056
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                 2029
#   Name: 1, dtype: int64},
#  'CV=2-A=3\nstdC=0.8\nhC=0': {'train': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    12561
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                          4238
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                    4226
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                  4223
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True            4218
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True     4204
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True     4177
#   ?a income 1 & ?a rate 2 => ?a approval False                                 4163
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                  4141
#   ?a income 0 & ?a rate 3 => ?a approval False                                 4125
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                  4125
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True            4117
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                   4101
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                   4048
#   Name: 1, dtype: int64,
#   'test': ?a income/yearlyReimbursement ?d & ?a loanAmount ?d => ?a approval False    6166
#   ?a income 2 & ?a income/yearlyReimbursement 3 => ?a approval True           2162
#   ?a income 0 & ?a rate 3 => ?a approval False                                2154
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 1 => ?a approval True    2120
#   ?a income 1 & ?a rate 2 => ?a approval False                                2098
#   ?a income 2 & ?a yearlyReimbursement 0 => ?a approval True                  2093
#   ?a income 3 & ?a yearlyReimbursement 0 => ?a approval True                  2093
#   ?a income 1 & ?a yearlyReimbursement 1 => ?a approval False                 2083
#   ?a income/yearlyReimbursement 3 & ?a monthDuration 2 => ?a approval True    2078
#   ?a income 0 & ?a yearlyReimbursement 1 => ?a approval False                 2075
#   ?a monthDuration 0 & ?a rate 2 => ?a approval False                         2068
#   ?a income 1 & ?a income/yearlyReimbursement 3 => ?a approval True           2058
#   ?a loanAmount 1 & ?a monthDuration 0 => ?a approval False                   2056
#   ?a income 2 & ?a yearlyReimbursement 1 => ?a approval False                 2029
#   Name: 1, dtype: int64}}

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47 entries, ?a rate 2 => ?a approval False to ?a rate 3 => ?a approval True
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   hypotheses       47 non-null     object
#  1   conclusion       47 non-null     object
#  2   size_hypothese   47 non-null     int64
#  3   headCoverage     47 non-null     float64
#  4   stdConfidence    47 non-null     float64
#  5   pcaConfidence    47 non-null     float64
#  6   precision_train  47 non-null     float64
#  7   precision_test   47 non-null     float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 3.3+ KB

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0'].describe()
# Out:
#        size_hypothese  headCoverage  stdConfidence  pcaConfidence  \
# count            47.0     47.000000      47.000000      47.000000
# mean              1.0      0.148186       0.592752       0.592752
# std               0.0      0.077972       0.312187       0.312187
# min               1.0      0.030150       0.120561       0.120561
# 25%               1.0      0.058156       0.231804       0.231804
# 50%               1.0      0.180317       0.716588       0.716588
# 75%               1.0      0.203305       0.814245       0.814245
# max               1.0      0.252243       1.000000       1.000000
#
#        precision_train  precision_test
# count        47.000000       47.000000
# mean          0.592752        0.592776
# std           0.312187        0.312399
# min           0.120561        0.122609
# 25%           0.231804        0.231422
# 50%           0.716588        0.726912
# 75%           0.814245        0.809525
# max           1.000000        1.000000

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0'].sort_values("precision_train", ascending=False)
# Out:
#                                                                             hypotheses  \
# ?a loanAmount 3 => ?a approval False                                (?a loanAmount 3,)
# ?a income/yearlyReimbursement 2 => ?a approval ...  (?a income/yearlyReimbursement 2,)
# ?a income/yearlyReimbursement 0 => ?a approval ...  (?a income/yearlyReimbursement 0,)
# ?a income/yearlyReimbursement 1 => ?a approval ...  (?a income/yearlyReimbursement 1,)
# ?a yearlyReimbursement 3 => ?a approval False              (?a yearlyReimbursement 3,)
# ?a yearlyReimbursement 2 => ?a approval False              (?a yearlyReimbursement 2,)
# ?a loanAmount 2 => ?a approval False                                (?a loanAmount 2,)
# ?a income 0 => ?a approval False                                        (?a income 0,)
# ?a monthDuration 0 => ?a approval False                          (?a monthDuration 0,)
# ?a income/yearlyReimbursement 3 => ?a approval ...  (?a income/yearlyReimbursement 3,)
# ?a yearlyReimbursement 1 => ?a approval False              (?a yearlyReimbursement 1,)
# ?a income 1 => ?a approval False                                        (?a income 1,)
# ?a monthDuration 1 => ?a approval False                          (?a monthDuration 1,)
# ?a rate 3 => ?a approval False                                            (?a rate 3,)
# ?a rate 2 => ?a approval False                                            (?a rate 2,)
# ?a creditScore 2 => ?a approval False                              (?a creditScore 2,)
# ?a creditScore 1 => ?a approval False                              (?a creditScore 1,)
# ?a creditScore 3 => ?a approval False                              (?a creditScore 3,)
# ?a rate 1 => ?a approval False                                            (?a rate 1,)
# ?a creditScore 0 => ?a approval False                              (?a creditScore 0,)
# ?a loanAmount 1 => ?a approval False                                (?a loanAmount 1,)
# ?a rate 0 => ?a approval False                                            (?a rate 0,)
# ?a yearlyReimbursement 0 => ?a approval True               (?a yearlyReimbursement 0,)
# ?a income 2 => ?a approval False                                        (?a income 2,)
# ?a monthDuration 2 => ?a approval False                          (?a monthDuration 2,)
# ?a monthDuration 3 => ?a approval False                          (?a monthDuration 3,)
# ?a loanAmount 0 => ?a approval True                                 (?a loanAmount 0,)
# ?a income 3 => ?a approval False                                        (?a income 3,)
# ?a income 3 => ?a approval True                                         (?a income 3,)
# ?a loanAmount 0 => ?a approval False                                (?a loanAmount 0,)
# ?a monthDuration 3 => ?a approval True                           (?a monthDuration 3,)
# ?a monthDuration 2 => ?a approval True                           (?a monthDuration 2,)
# ?a income 2 => ?a approval True                                         (?a income 2,)
# ?a yearlyReimbursement 0 => ?a approval False              (?a yearlyReimbursement 0,)
# ?a rate 0 => ?a approval True                                             (?a rate 0,)
# ?a loanAmount 1 => ?a approval True                                 (?a loanAmount 1,)
# ?a creditScore 0 => ?a approval True                               (?a creditScore 0,)
# ?a rate 1 => ?a approval True                                             (?a rate 1,)
# ?a creditScore 3 => ?a approval True                               (?a creditScore 3,)
# ?a creditScore 1 => ?a approval True                               (?a creditScore 1,)
# ?a creditScore 2 => ?a approval True                               (?a creditScore 2,)
# ?a rate 2 => ?a approval True                                             (?a rate 2,)
# ?a rate 3 => ?a approval True                                             (?a rate 3,)
# ?a monthDuration 1 => ?a approval True                           (?a monthDuration 1,)
# ?a income 1 => ?a approval True                                         (?a income 1,)
# ?a yearlyReimbursement 1 => ?a approval True               (?a yearlyReimbursement 1,)
# ?a income/yearlyReimbursement 3 => ?a approval ...  (?a income/yearlyReimbursement 3,)
#
#                                                            conclusion  \
# ?a loanAmount 3 => ?a approval False                ?a approval False
# ?a income/yearlyReimbursement 2 => ?a approval ...  ?a approval False
# ?a income/yearlyReimbursement 0 => ?a approval ...  ?a approval False
# ?a income/yearlyReimbursement 1 => ?a approval ...  ?a approval False
# ?a yearlyReimbursement 3 => ?a approval False       ?a approval False
# ?a yearlyReimbursement 2 => ?a approval False       ?a approval False
# ?a loanAmount 2 => ?a approval False                ?a approval False
# ?a income 0 => ?a approval False                    ?a approval False
# ?a monthDuration 0 => ?a approval False             ?a approval False
# ?a income/yearlyReimbursement 3 => ?a approval ...   ?a approval True
# ?a yearlyReimbursement 1 => ?a approval False       ?a approval False
# ?a income 1 => ?a approval False                    ?a approval False
# ?a monthDuration 1 => ?a approval False             ?a approval False
# ?a rate 3 => ?a approval False                      ?a approval False
# ?a rate 2 => ?a approval False                      ?a approval False
# ?a creditScore 2 => ?a approval False               ?a approval False
# ?a creditScore 1 => ?a approval False               ?a approval False
# ?a creditScore 3 => ?a approval False               ?a approval False
# ?a rate 1 => ?a approval False                      ?a approval False
# ?a creditScore 0 => ?a approval False               ?a approval False
# ?a loanAmount 1 => ?a approval False                ?a approval False
# ?a rate 0 => ?a approval False                      ?a approval False
# ?a yearlyReimbursement 0 => ?a approval True         ?a approval True
# ?a income 2 => ?a approval False                    ?a approval False
# ?a monthDuration 2 => ?a approval False             ?a approval False
# ?a monthDuration 3 => ?a approval False             ?a approval False
# ?a loanAmount 0 => ?a approval True                  ?a approval True
# ?a income 3 => ?a approval False                    ?a approval False
# ?a income 3 => ?a approval True                      ?a approval True
# ?a loanAmount 0 => ?a approval False                ?a approval False
# ?a monthDuration 3 => ?a approval True               ?a approval True
# ?a monthDuration 2 => ?a approval True               ?a approval True
# ?a income 2 => ?a approval True                      ?a approval True
# ?a yearlyReimbursement 0 => ?a approval False       ?a approval False
# ?a rate 0 => ?a approval True                        ?a approval True
# ?a loanAmount 1 => ?a approval True                  ?a approval True
# ?a creditScore 0 => ?a approval True                 ?a approval True
# ?a rate 1 => ?a approval True                        ?a approval True
# ?a creditScore 3 => ?a approval True                 ?a approval True
# ?a creditScore 1 => ?a approval True                 ?a approval True
# ?a creditScore 2 => ?a approval True                 ?a approval True
# ?a rate 2 => ?a approval True                        ?a approval True
# ?a rate 3 => ?a approval True                        ?a approval True
# ?a monthDuration 1 => ?a approval True               ?a approval True
# ?a income 1 => ?a approval True                      ?a approval True
# ?a yearlyReimbursement 1 => ?a approval True         ?a approval True
# ?a income/yearlyReimbursement 3 => ?a approval ...  ?a approval False
#
#                                                     size_hypothese  \
# ?a loanAmount 3 => ?a approval False                             1
# ?a income/yearlyReimbursement 2 => ?a approval ...               1
# ?a income/yearlyReimbursement 0 => ?a approval ...               1
# ?a income/yearlyReimbursement 1 => ?a approval ...               1
# ?a yearlyReimbursement 3 => ?a approval False                    1
# ?a yearlyReimbursement 2 => ?a approval False                    1
# ?a loanAmount 2 => ?a approval False                             1
# ?a income 0 => ?a approval False                                 1
# ?a monthDuration 0 => ?a approval False                          1
# ?a income/yearlyReimbursement 3 => ?a approval ...               1
# ?a yearlyReimbursement 1 => ?a approval False                    1
# ?a income 1 => ?a approval False                                 1
# ?a monthDuration 1 => ?a approval False                          1
# ?a rate 3 => ?a approval False                                   1
# ?a rate 2 => ?a approval False                                   1
# ?a creditScore 2 => ?a approval False                            1
# ?a creditScore 1 => ?a approval False                            1
# ?a creditScore 3 => ?a approval False                            1
# ?a rate 1 => ?a approval False                                   1
# ?a creditScore 0 => ?a approval False                            1
# ?a loanAmount 1 => ?a approval False                             1
# ?a rate 0 => ?a approval False                                   1
# ?a yearlyReimbursement 0 => ?a approval True                     1
# ?a income 2 => ?a approval False                                 1
# ?a monthDuration 2 => ?a approval False                          1
# ?a monthDuration 3 => ?a approval False                          1
# ?a loanAmount 0 => ?a approval True                              1
# ?a income 3 => ?a approval False                                 1
# ?a income 3 => ?a approval True                                  1
# ?a loanAmount 0 => ?a approval False                             1
# ?a monthDuration 3 => ?a approval True                           1
# ?a monthDuration 2 => ?a approval True                           1
# ?a income 2 => ?a approval True                                  1
# ?a yearlyReimbursement 0 => ?a approval False                    1
# ?a rate 0 => ?a approval True                                    1
# ?a loanAmount 1 => ?a approval True                              1
# ?a creditScore 0 => ?a approval True                             1
# ?a rate 1 => ?a approval True                                    1
# ?a creditScore 3 => ?a approval True                             1
# ?a creditScore 1 => ?a approval True                             1
# ?a creditScore 2 => ?a approval True                             1
# ?a rate 2 => ?a approval True                                    1
# ?a rate 3 => ?a approval True                                    1
# ?a monthDuration 1 => ?a approval True                           1
# ?a income 1 => ?a approval True                                  1
# ?a yearlyReimbursement 1 => ?a approval True                     1
# ?a income/yearlyReimbursement 3 => ?a approval ...               1
#
#                                                     headCoverage  \
# ?a loanAmount 3 => ?a approval False                    0.248522
# ?a income/yearlyReimbursement 2 => ?a approval ...      0.250308
# ?a income/yearlyReimbursement 0 => ?a approval ...      0.252243
# ?a income/yearlyReimbursement 1 => ?a approval ...      0.247367
# ?a yearlyReimbursement 3 => ?a approval False           0.248987
# ?a yearlyReimbursement 2 => ?a approval False           0.249392
# ?a loanAmount 2 => ?a approval False                    0.249812
# ?a income 0 => ?a approval False                        0.235892
# ?a monthDuration 0 => ?a approval False                 0.229727
# ?a income/yearlyReimbursement 3 => ?a approval ...      0.219932
# ?a yearlyReimbursement 1 => ?a approval False           0.212702
# ?a income 1 => ?a approval False                        0.207077
# ?a monthDuration 1 => ?a approval False                 0.199532
# ?a rate 3 => ?a approval False                          0.196787
# ?a rate 2 => ?a approval False                          0.195902
# ?a creditScore 2 => ?a approval False                   0.195482
# ?a creditScore 1 => ?a approval False                   0.194267
# ?a creditScore 3 => ?a approval False                   0.194717
# ?a rate 1 => ?a approval False                          0.195332
# ?a creditScore 0 => ?a approval False                   0.195602
# ?a loanAmount 1 => ?a approval False                    0.193412
# ?a rate 0 => ?a approval False                          0.192047
# ?a yearlyReimbursement 0 => ?a approval True            0.182447
# ?a income 2 => ?a approval False                        0.178067
# ?a monthDuration 2 => ?a approval False                 0.180317
# ?a monthDuration 3 => ?a approval False                 0.170492
# ?a loanAmount 0 => ?a approval True                     0.162122
# ?a income 3 => ?a approval False                        0.159032
# ?a income 3 => ?a approval True                         0.092251
# ?a loanAmount 0 => ?a approval False                    0.088321
# ?a monthDuration 3 => ?a approval True                  0.077836
# ?a monthDuration 2 => ?a approval True                  0.071371
# ?a income 2 => ?a approval True                         0.070426
# ?a yearlyReimbursement 0 => ?a approval False           0.068986
# ?a rate 0 => ?a approval True                           0.058501
# ?a loanAmount 1 => ?a approval True                     0.057811
# ?a creditScore 0 => ?a approval True                    0.055366
# ?a rate 1 => ?a approval True                           0.055261
# ?a creditScore 3 => ?a approval True                    0.055081
# ?a creditScore 1 => ?a approval True                    0.054691
# ?a creditScore 2 => ?a approval True                    0.054796
# ?a rate 2 => ?a approval True                           0.053536
# ?a rate 3 => ?a approval True                           0.052636
# ?a monthDuration 1 => ?a approval True                  0.049725
# ?a income 1 => ?a approval True                         0.043020
# ?a yearlyReimbursement 1 => ?a approval True            0.037485
# ?a income/yearlyReimbursement 3 => ?a approval ...      0.030150
#
#                                                     stdConfidence  \
# ?a loanAmount 3 => ?a approval False                     1.000000
# ?a income/yearlyReimbursement 2 => ?a approval ...       1.000000
# ?a income/yearlyReimbursement 0 => ?a approval ...       1.000000
# ?a income/yearlyReimbursement 1 => ?a approval ...       1.000000
# ?a yearlyReimbursement 3 => ?a approval False            1.000000
# ?a yearlyReimbursement 2 => ?a approval False            1.000000
# ?a loanAmount 2 => ?a approval False                     1.000000
# ?a income 0 => ?a approval False                         0.943088
# ?a monthDuration 0 => ?a approval False                  0.916243
# ?a income/yearlyReimbursement 3 => ?a approval ...       0.879439
# ?a yearlyReimbursement 1 => ?a approval False            0.850171
# ?a income 1 => ?a approval False                         0.827985
# ?a monthDuration 1 => ?a approval False                  0.800506
# ?a rate 3 => ?a approval False                           0.788970
# ?a rate 2 => ?a approval False                           0.785375
# ?a creditScore 2 => ?a approval False                    0.781061
# ?a creditScore 1 => ?a approval False                    0.780322
# ?a creditScore 3 => ?a approval False                    0.779499
# ?a rate 1 => ?a approval False                           0.779480
# ?a creditScore 0 => ?a approval False                    0.779392
# ?a loanAmount 1 => ?a approval False                     0.769883
# ?a rate 0 => ?a approval False                           0.766509
# ?a yearlyReimbursement 0 => ?a approval True             0.725629
# ?a income 2 => ?a approval False                         0.716588
# ?a monthDuration 2 => ?a approval False                  0.716431
# ?a monthDuration 3 => ?a approval False                  0.686560
# ?a loanAmount 0 => ?a approval True                      0.647341
# ?a income 3 => ?a approval False                         0.632880
# ?a income 3 => ?a approval True                          0.367120
# ?a loanAmount 0 => ?a approval False                     0.352659
# ?a monthDuration 3 => ?a approval True                   0.313440
# ?a monthDuration 2 => ?a approval True                   0.283569
# ?a income 2 => ?a approval True                          0.283412
# ?a yearlyReimbursement 0 => ?a approval False            0.274371
# ?a rate 0 => ?a approval True                            0.233491
# ?a loanAmount 1 => ?a approval True                      0.230117
# ?a creditScore 0 => ?a approval True                     0.220608
# ?a rate 1 => ?a approval True                            0.220520
# ?a creditScore 3 => ?a approval True                     0.220501
# ?a creditScore 1 => ?a approval True                     0.219678
# ?a creditScore 2 => ?a approval True                     0.218939
# ?a rate 2 => ?a approval True                            0.214625
# ?a rate 3 => ?a approval True                            0.211030
# ?a monthDuration 1 => ?a approval True                   0.199494
# ?a income 1 => ?a approval True                          0.172015
# ?a yearlyReimbursement 1 => ?a approval True             0.149829
# ?a income/yearlyReimbursement 3 => ?a approval ...       0.120561
#
#                                                     pcaConfidence  \
# ?a loanAmount 3 => ?a approval False                     1.000000
# ?a income/yearlyReimbursement 2 => ?a approval ...       1.000000
# ?a income/yearlyReimbursement 0 => ?a approval ...       1.000000
# ?a income/yearlyReimbursement 1 => ?a approval ...       1.000000
# ?a yearlyReimbursement 3 => ?a approval False            1.000000
# ?a yearlyReimbursement 2 => ?a approval False            1.000000
# ?a loanAmount 2 => ?a approval False                     1.000000
# ?a income 0 => ?a approval False                         0.943088
# ?a monthDuration 0 => ?a approval False                  0.916243
# ?a income/yearlyReimbursement 3 => ?a approval ...       0.879439
# ?a yearlyReimbursement 1 => ?a approval False            0.850171
# ?a income 1 => ?a approval False                         0.827985
# ?a monthDuration 1 => ?a approval False                  0.800506
# ?a rate 3 => ?a approval False                           0.788970
# ?a rate 2 => ?a approval False                           0.785375
# ?a creditScore 2 => ?a approval False                    0.781061
# ?a creditScore 1 => ?a approval False                    0.780322
# ?a creditScore 3 => ?a approval False                    0.779499
# ?a rate 1 => ?a approval False                           0.779480
# ?a creditScore 0 => ?a approval False                    0.779392
# ?a loanAmount 1 => ?a approval False                     0.769883
# ?a rate 0 => ?a approval False                           0.766509
# ?a yearlyReimbursement 0 => ?a approval True             0.725629
# ?a income 2 => ?a approval False                         0.716588
# ?a monthDuration 2 => ?a approval False                  0.716431
# ?a monthDuration 3 => ?a approval False                  0.686560
# ?a loanAmount 0 => ?a approval True                      0.647341
# ?a income 3 => ?a approval False                         0.632880
# ?a income 3 => ?a approval True                          0.367120
# ?a loanAmount 0 => ?a approval False                     0.352659
# ?a monthDuration 3 => ?a approval True                   0.313440
# ?a monthDuration 2 => ?a approval True                   0.283569
# ?a income 2 => ?a approval True                          0.283412
# ?a yearlyReimbursement 0 => ?a approval False            0.274371
# ?a rate 0 => ?a approval True                            0.233491
# ?a loanAmount 1 => ?a approval True                      0.230117
# ?a creditScore 0 => ?a approval True                     0.220608
# ?a rate 1 => ?a approval True                            0.220520
# ?a creditScore 3 => ?a approval True                     0.220501
# ?a creditScore 1 => ?a approval True                     0.219678
# ?a creditScore 2 => ?a approval True                     0.218939
# ?a rate 2 => ?a approval True                            0.214625
# ?a rate 3 => ?a approval True                            0.211030
# ?a monthDuration 1 => ?a approval True                   0.199494
# ?a income 1 => ?a approval True                          0.172015
# ?a yearlyReimbursement 1 => ?a approval True             0.149829
# ?a income/yearlyReimbursement 3 => ?a approval ...       0.120561
#
#                                                     precision_train  \
# ?a loanAmount 3 => ?a approval False                       1.000000
# ?a income/yearlyReimbursement 2 => ?a approval ...         1.000000
# ?a income/yearlyReimbursement 0 => ?a approval ...         1.000000
# ?a income/yearlyReimbursement 1 => ?a approval ...         1.000000
# ?a yearlyReimbursement 3 => ?a approval False              1.000000
# ?a yearlyReimbursement 2 => ?a approval False              1.000000
# ?a loanAmount 2 => ?a approval False                       1.000000
# ?a income 0 => ?a approval False                           0.943088
# ?a monthDuration 0 => ?a approval False                    0.916243
# ?a income/yearlyReimbursement 3 => ?a approval ...         0.879439
# ?a yearlyReimbursement 1 => ?a approval False              0.850171
# ?a income 1 => ?a approval False                           0.827985
# ?a monthDuration 1 => ?a approval False                    0.800506
# ?a rate 3 => ?a approval False                             0.788970
# ?a rate 2 => ?a approval False                             0.785375
# ?a creditScore 2 => ?a approval False                      0.781061
# ?a creditScore 1 => ?a approval False                      0.780322
# ?a creditScore 3 => ?a approval False                      0.779499
# ?a rate 1 => ?a approval False                             0.779480
# ?a creditScore 0 => ?a approval False                      0.779392
# ?a loanAmount 1 => ?a approval False                       0.769883
# ?a rate 0 => ?a approval False                             0.766509
# ?a yearlyReimbursement 0 => ?a approval True               0.725629
# ?a income 2 => ?a approval False                           0.716588
# ?a monthDuration 2 => ?a approval False                    0.716431
# ?a monthDuration 3 => ?a approval False                    0.686560
# ?a loanAmount 0 => ?a approval True                        0.647341
# ?a income 3 => ?a approval False                           0.632880
# ?a income 3 => ?a approval True                            0.367120
# ?a loanAmount 0 => ?a approval False                       0.352659
# ?a monthDuration 3 => ?a approval True                     0.313440
# ?a monthDuration 2 => ?a approval True                     0.283569
# ?a income 2 => ?a approval True                            0.283412
# ?a yearlyReimbursement 0 => ?a approval False              0.274371
# ?a rate 0 => ?a approval True                              0.233491
# ?a loanAmount 1 => ?a approval True                        0.230117
# ?a creditScore 0 => ?a approval True                       0.220608
# ?a rate 1 => ?a approval True                              0.220520
# ?a creditScore 3 => ?a approval True                       0.220501
# ?a creditScore 1 => ?a approval True                       0.219678
# ?a creditScore 2 => ?a approval True                       0.218939
# ?a rate 2 => ?a approval True                              0.214625
# ?a rate 3 => ?a approval True                              0.211030
# ?a monthDuration 1 => ?a approval True                     0.199494
# ?a income 1 => ?a approval True                            0.172015
# ?a yearlyReimbursement 1 => ?a approval True               0.149829
# ?a income/yearlyReimbursement 3 => ?a approval ...         0.120561
#
#                                                     precision_test
# ?a loanAmount 3 => ?a approval False                      1.000000
# ?a income/yearlyReimbursement 2 => ?a approval ...        1.000000
# ?a income/yearlyReimbursement 0 => ?a approval ...        1.000000
# ?a income/yearlyReimbursement 1 => ?a approval ...        1.000000
# ?a yearlyReimbursement 3 => ?a approval False             1.000000
# ?a yearlyReimbursement 2 => ?a approval False             1.000000
# ?a loanAmount 2 => ?a approval False                      1.000000
# ?a income 0 => ?a approval False                          0.940060
# ?a monthDuration 0 => ?a approval False                   0.920426
# ?a income/yearlyReimbursement 3 => ?a approval ...        0.877391
# ?a yearlyReimbursement 1 => ?a approval False             0.846293
# ?a income 1 => ?a approval False                          0.827429
# ?a monthDuration 1 => ?a approval False                   0.791621
# ?a rate 3 => ?a approval False                            0.790850
# ?a rate 2 => ?a approval False                            0.783897
# ?a creditScore 2 => ?a approval False                     0.786393
# ?a creditScore 1 => ?a approval False                     0.784968
# ?a creditScore 3 => ?a approval False                     0.774566
# ?a rate 1 => ?a approval False                            0.780685
# ?a creditScore 0 => ?a approval False                     0.779013
# ?a loanAmount 1 => ?a approval False                      0.767721
# ?a rate 0 => ?a approval False                            0.769435
# ?a yearlyReimbursement 0 => ?a approval True              0.729910
# ?a income 2 => ?a approval False                          0.721840
# ?a monthDuration 2 => ?a approval False                   0.726912
# ?a monthDuration 3 => ?a approval False                   0.684160
# ?a loanAmount 0 => ?a approval True                       0.647278
# ?a income 3 => ?a approval False                          0.635063
# ?a income 3 => ?a approval True                           0.364937
# ?a loanAmount 0 => ?a approval False                      0.352722
# ?a monthDuration 3 => ?a approval True                    0.315840
# ?a monthDuration 2 => ?a approval True                    0.273088
# ?a income 2 => ?a approval True                           0.278160
# ?a yearlyReimbursement 0 => ?a approval False             0.270090
# ?a rate 0 => ?a approval True                             0.230565
# ?a loanAmount 1 => ?a approval True                       0.232279
# ?a creditScore 0 => ?a approval True                      0.220987
# ?a rate 1 => ?a approval True                             0.219315
# ?a creditScore 3 => ?a approval True                      0.225434
# ?a creditScore 1 => ?a approval True                      0.215032
# ?a creditScore 2 => ?a approval True                      0.213607
# ?a rate 2 => ?a approval True                             0.216103
# ?a rate 3 => ?a approval True                             0.209150
# ?a monthDuration 1 => ?a approval True                    0.208379
# ?a income 1 => ?a approval True                           0.172571
# ?a yearlyReimbursement 1 => ?a approval True              0.153707
# ?a income/yearlyReimbursement 3 => ?a approval ...        0.122609
