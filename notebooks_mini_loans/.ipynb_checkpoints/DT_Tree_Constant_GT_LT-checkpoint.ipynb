# %%
import pandas as pd
import numpy as np
import sklearn.tree as tree
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os.path
from os import path
from multiprocessing import Process, Manager, SimpleQueue
import multiprocessing
import shutil
import sys
import time
from sklearn.metrics import accuracy_score
from rules import *
from vote import *
from save_amie_data import *
from precision import *
from amie import *

root = "./../../DT_Tree_Constant_GT_LT/"
cv = 3

colors_to_print = ["red",  "blue", "orange",  "violet", "darkgrey", "darkred", "darkblue", "darkorange", "darkviolet", "grey"]

# %% [markdown]
# # 1° Load data

# %%
data = pd.read_csv("./../Data/miniloan-decisions-100K.csv")

# %%
data
# Out:
#            name  creditScore  income  loanAmount  monthDuration      rate  \
# 0      John Doe          736  113243      783440            162  0.030005
# 1      John Doe          527  224186     1787385            183  0.054819
# 2      John Doe          460   39954     1733494             75  0.055183
# 3      John Doe          751  219998     1350004             72  0.043400
# 4      John Doe          684   72470     1210944            160  0.037772
# ...         ...          ...     ...         ...            ...       ...
# 99995  John Doe          366   83851     1718571            168  0.053737
# 99996  John Doe          395  184259     1599473             90  0.040564
# 99997  John Doe          674  242620     1099790            260  0.040825
# 99998  John Doe          420  180957     1645870            203  0.049558
# 99999  John Doe          699  102769      665190            244  0.058460
#
#       approval  yearlyReimbursement
# 0        false                70648
# 1        false               173197
# 2        false               328563
# 3        false               255970
# 4        false               115742
# ...        ...                  ...
# 99995    false               174928
# 99996    false               247703
# 99997    false                76557
# 99998    false               143897
# 99999    false                55993
#
# [100000 rows x 8 columns]

# %% [markdown]
# # Ratios

# %%
ratio_names = [("income","yearlyReimbursement"), ("income","loanAmount"), ("loanAmount","rate")]

# %%
# Takes two features and will create the ratio f_0/f_1
def create_features_ratio(data):
    if data[data.index[1]] == 0:
        return 2147483647
    return np.round(data[data.index[0]]/data[data.index[1]], decimals=2)

# %%
for ratio_name in ratio_names:
    data[f"{ratio_name[0]}/{ratio_name[1]}"] = data[[ratio_name[0], ratio_name[1]]].apply(create_features_ratio, axis=1)

# %%
data
# Out:
#            name  creditScore  income  loanAmount  monthDuration      rate  \
# 0      John Doe          736  113243      783440            162  0.030005
# 1      John Doe          527  224186     1787385            183  0.054819
# 2      John Doe          460   39954     1733494             75  0.055183
# 3      John Doe          751  219998     1350004             72  0.043400
# 4      John Doe          684   72470     1210944            160  0.037772
# ...         ...          ...     ...         ...            ...       ...
# 99995  John Doe          366   83851     1718571            168  0.053737
# 99996  John Doe          395  184259     1599473             90  0.040564
# 99997  John Doe          674  242620     1099790            260  0.040825
# 99998  John Doe          420  180957     1645870            203  0.049558
# 99999  John Doe          699  102769      665190            244  0.058460
#
#       approval  yearlyReimbursement  income/yearlyReimbursement  \
# 0        false                70648                        1.60
# 1        false               173197                        1.29
# 2        false               328563                        0.12
# 3        false               255970                        0.86
# 4        false               115742                        0.63
# ...        ...                  ...                         ...
# 99995    false               174928                        0.48
# 99996    false               247703                        0.74
# 99997    false                76557                        3.17
# 99998    false               143897                        1.26
# 99999    false                55993                        1.84
#
#        income/loanAmount  loanAmount/rate
# 0                   0.14      26110372.80
# 1                   0.13      32605003.59
# 2                   0.02      31413368.70
# 3                   0.16      31106073.81
# 4                   0.06      32059172.14
# ...                  ...              ...
# 99995               0.05      31981153.44
# 99996               0.12      39430859.20
# 99997               0.22      26938940.88
# 99998               0.11      33211031.24
# 99999               0.15      11378481.46
#
# [100000 rows x 11 columns]

# %% [markdown]
# # 2° Find the best thresholds

# %%
data_raw = data.drop(columns=["name"])
false_data = data_raw[data_raw["approval"] == " false"]
true_data = data_raw[data_raw["approval"] == " true"]
data_equilibrium = true_data.append(false_data.sample(n=len(true_data)))

# %%
# %%time

def returnSplitValue(stringToSplit):
    res = []
    tp = ""
    spliters = [("lt", "< "), ("lte", "<= "), ("gt", "> "), ("gte", ">= ")]
    i=0
    
    while i < len(spliters):
        splited = stringToSplit.split(spliters[i][1]) 
        if len(splited) == 2:
            return  spliters[i][0], float(splited[1])
        i += 1
    print("C'est casse")
    return None 


best_threshold = []
for key in data_equilibrium.keys():
    if key != "approval":
        print("\t\t"+key)
        X = data_equilibrium[[key]]

        Y = data_equilibrium["approval"]

        X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)
        
        model = tree.DecisionTreeClassifier(max_depth=1)
        model.fit(X_train, y_train)    

        print(f"Train Score : {accuracy_score(y_train, model.predict(X_train))}")
        print(f"Test Score : {accuracy_score(y_test, model.predict(X_test))}")
        
        if accuracy_score(y_train, model.predict(X_train)) > 0.8 and accuracy_score(y_test, model.predict(X_test)) > 0.8:
            best_threshold.append((key,)+ returnSplitValue(tree.export_text(model, spacing=1, feature_names=[key]).split("\n")[0]))
print(best_threshold)
# Out:
# 		creditScore
# Train Score : 0.5044530559521382
# Test Score : 0.5018633540372671
# 		income
# Train Score : 0.6472907743558366
# Test Score : 0.637336093857833
# 		loanAmount
# Train Score : 0.8439390849139983
# Test Score : 0.8448585231193927
# 		monthDuration
# Train Score : 0.6129580528927867
# Test Score : 0.6164941338854383
# 		rate
# Train Score : 0.5123393840505813
# Test Score : 0.5102829537612147
# 		yearlyReimbursement
# Train Score : 0.8988374464613502
# Test Score : 0.9026915113871635
# 		income/yearlyReimbursement
# Train Score : 0.9935413692297232
# Test Score : 0.9933057280883368
# 		income/loanAmount
# Train Score : 0.9271874362635122
# Test Score : 0.9189786059351277
# 		loanAmount/rate
# Train Score : 0.8272146304983343
# Test Score : 0.8276742581090407
# [('loanAmount', 'lte', 814085.5), ('yearlyReimbursement', 'lte', 66274.0), ('income/yearlyReimbursement', 'lte', 3.33), ('income/loanAmount', 'lte', 0.25), ('loanAmount/rate', 'lte', 17942690.0)]
# CPU times: user 1.3 s, sys: 15.6 ms, total: 1.31 s
# Wall time: 1.3 s

# %% [markdown]
# # 3° Create the thresholds

# %% [markdown]
# Define the thresholds

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
# Takes a dataframe and return the values per percents for each feature
def description_per_thresholds(data, percents):
    thresholds_Dic =  {}
    for column in data.columns:
        serie = data[column]
        thresholds_Dic[column] = serie.quantile(percents)
        
    return pd.DataFrame.from_dict(thresholds_Dic)

# %%
def GTE_prep_df(value, valueToCompareTo):
    return value >= valueToCompareTo

def LTE_prep_df(value, valueToCompareTo):
    return value <= valueToCompareTo

def GT_prep_df(value, valueToCompareTo):
    return value > valueToCompareTo

def LT_prep_df(value, valueToCompareTo):
    return value < valueToCompareTo

# %%
columns = list(data.drop(columns=["name", "approval"]).columns)

booleanDF = pd.DataFrame()

for column, comparator, value in best_threshold:
    if comparator == "lte" or comparator == "gt":
        booleanDF[column+"-GT-"+str(value)] = data[column].map(lambda x : GT_prep_df(x, value))
        booleanDF[column+"-LTE-"+str(value)] = data[column].map(lambda x : LTE_prep_df(x, value))
    else:
        booleanDF[column+"-GTE-"+str(value)] = data[column].map(lambda x : GTE_prep_df(x, value))
        booleanDF[column+"-LT-"+str(value)] = data[column].map(lambda x : LT_prep_df(x, value))
    columns.remove(column)

# %%
description = description_per_thresholds(data[columns], thresholds)

# %% [markdown]
# Transform the data from integer values to boolean values corresponding to GTE or LTE with the different percents.

# %%
# %%time

for column in columns:
    for i, value in enumerate(thresholds):
        booleanDF[column+"-GTE-"+str(int(value*100))] = data[column].map(lambda x : GTE_prep_df(x, description[column].values[i]))
        booleanDF[column+"-LTE-"+str(int(value*100))] = data[column].map(lambda x : LTE_prep_df(x, description[column].values[i]))
# Out:
# CPU times: user 6.95 s, sys: 78.1 ms, total: 7.03 s
# Wall time: 7.03 s

# %%
booleanDF["approval"] = data["approval"].map({' true': True, ' false': False})
booleanDF
# Out:
#        loanAmount-GT-814085.5  loanAmount-LTE-814085.5  \
# 0                       False                     True
# 1                        True                    False
# 2                        True                    False
# 3                        True                    False
# 4                        True                    False
# ...                       ...                      ...
# 99995                    True                    False
# 99996                    True                    False
# 99997                    True                    False
# 99998                    True                    False
# 99999                   False                     True
#
#        yearlyReimbursement-GT-66274.0  yearlyReimbursement-LTE-66274.0  \
# 0                                True                            False
# 1                                True                            False
# 2                                True                            False
# 3                                True                            False
# 4                                True                            False
# ...                               ...                              ...
# 99995                            True                            False
# 99996                            True                            False
# 99997                            True                            False
# 99998                            True                            False
# 99999                           False                             True
#
#        income/yearlyReimbursement-GT-3.33  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 99995                               False
# 99996                               False
# 99997                               False
# 99998                               False
# 99999                               False
#
#        income/yearlyReimbursement-LTE-3.33  income/loanAmount-GT-0.25  \
# 0                                     True                      False
# 1                                     True                      False
# 2                                     True                      False
# 3                                     True                      False
# 4                                     True                      False
# ...                                    ...                        ...
# 99995                                 True                      False
# 99996                                 True                      False
# 99997                                 True                      False
# 99998                                 True                      False
# 99999                                 True                      False
#
#        income/loanAmount-LTE-0.25  loanAmount/rate-GT-17942690.0  \
# 0                            True                           True
# 1                            True                           True
# 2                            True                           True
# 3                            True                           True
# 4                            True                           True
# ...                           ...                            ...
# 99995                        True                           True
# 99996                        True                           True
# 99997                        True                           True
# 99998                        True                           True
# 99999                        True                          False
#
#        loanAmount/rate-LTE-17942690.0  ...  monthDuration-LTE-50  \
# 0                               False  ...                  True
# 1                               False  ...                 False
# 2                               False  ...                  True
# 3                               False  ...                  True
# 4                               False  ...                  True
# ...                               ...  ...                   ...
# 99995                           False  ...                  True
# 99996                           False  ...                  True
# 99997                           False  ...                 False
# 99998                           False  ...                 False
# 99999                            True  ...                 False
#
#        monthDuration-GTE-75  monthDuration-LTE-75  rate-GTE-25  rate-LTE-25  \
# 0                     False                  True        False         True
# 1                     False                  True         True        False
# 2                     False                  True         True        False
# 3                     False                  True         True        False
# 4                     False                  True         True        False
# ...                     ...                   ...          ...          ...
# 99995                 False                  True         True        False
# 99996                 False                  True         True        False
# 99997                 False                  True         True        False
# 99998                 False                  True         True        False
# 99999                 False                  True         True        False
#
#        rate-GTE-50  rate-LTE-50  rate-GTE-75  rate-LTE-75  approval
# 0            False         True        False         True     False
# 1             True        False         True        False     False
# 2             True        False         True        False     False
# 3            False         True        False         True     False
# 4            False         True        False         True     False
# ...            ...          ...          ...          ...       ...
# 99995         True        False         True        False     False
# 99996        False         True        False         True     False
# 99997        False         True        False         True     False
# 99998         True        False        False         True     False
# 99999         True        False         True        False     False
#
# [100000 rows x 35 columns]

# %% [markdown]
# Create the folder where the data will be stored.

# %%
if not path.isdir(root):
    os.mkdir(root)
    os.mkdir(root+"/Save_raw")
else : 
    shutil.rmtree(root)
    os.mkdir(root)
    os.mkdir(root+"/Save_raw")

# %%
booleanDF.to_csv(root+"dfSave.csv")

# %% [markdown]
# # 4° Save the best data

# %% [markdown]
# We store the data in the Amie format.

# %%
save_all_data(root, booleanDF)

# %% [markdown]
# ## Save in cross validation

# %%
save_CV(root, booleanDF, cv)
# Out:
# Train repartition :
#  False    52004
# True     14662
# Name: approval, dtype: int64
# Train repartition :
#  False    52007
# True     14660
# Name: approval, dtype: int64
# Train repartition :
#  False    52081
# True     14586
# Name: approval, dtype: int64

# %% [markdown]
# # 5° Launch Amie

# %% [markdown]
# Describe the parameters.

# %%
atom_LIST = [2]#, 3]
minc_LIST = [0, 0.4]#, 0.8]
minhc_LIST = [0, 0.4]#, 0.8]

# %% [markdown]
# Launch Amie.

# %%
# %%time

res_rules_raw = run_amie(atom_LIST, root, cv, const=True)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°3 : FinishedProcess n°4 : Launched
#
# Process n°4 : FinishedProcess n°5 : Launched
#
# Process n°6 : LaunchedProcess n°5 : Finished
# Process n°7 : LaunchedProcess n°6 : Finished
#
#
# Process n°7 : FinishedProcess n°8 : Launched
#
# Process n°8 : FinishedProcess n°9 : Launched
#
# Process n°10 : Launched
# Process n°10 : FinishedProcess n°9 : FinishedProcess n°11 : Launched
#
#
# Process n°12 : Launched
# Process n°11 : FinishedProcess n°12 : Finished

# %% [markdown]
# ### Save raw results

# %%
for i in res_rules_raw:
    f = open(root+"Save_raw/"+i+".txt", "w")
    f.write(res_rules_raw[i].decode())
    f.close()

# %% [markdown]
# ### Read raw results

# %%
res_rules_raw = {}
for a in atom_LIST:
    for i in range(cv):
        f = open(root+"Save_raw/"+f"CV={i}-A={a}"+".txt", "r")
        res_rules_raw[f"CV={i}-A={a}"] = f.read().encode()
        f.close()

# %% [markdown]
# Transform the raw output into sets of rules.

# %%
rules_per_cv = parse_amie(res_rules_raw)

# %% [markdown]
# Retrieve the indexes for each CV.

# %%
indexes = retrieve_indexes(root, cv)
df = pd.read_csv(root+"dfSave.csv")

# %% [markdown]
# # 5° Precision

# %%
# %%time

rules_per_para = run_precision(root, indexes, rules_per_cv)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 100)
# Process n°4 : Finished
# Process n°8 : Finished
# Process n°0 : Finished
# Process n°5 : Finished
# Process n°2 : Finished
# Process n°1 : Finished
# Process n°10 : Finished
# Process n°3 : Finished
# Process n°12 : Finished
# Process n°11 : Finished
# Process n°6 : Finished
# Process n°7 : Finished
# Process n°9 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 100)
# Process n°0 : Finished
# Process n°4 : Finished
# Process n°8 : Finished
# Process n°7 : Finished
# Process n°1 : Finished
# Process n°6 : Finished
# Process n°2 : Finished
# Process n°9 : Finished
# Process n°3 : Finished
# Process n°12 : Finished
# Process n°5 : Finished
# Process n°10 : Finished
# Process n°11 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : LaunchedProcess n°5 : Launched
#
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Value('d', 100)
# Process n°0 : Finished
# Process n°4 : Finished
# Process n°8 : Finished
# Process n°1 : Finished
# Process n°3 : Finished
# Process n°6 : Finished
# Process n°5 : Finished
# Process n°2 : Finished
# Process n°12 : Finished
# Process n°9 : Finished
# Process n°10 : Finished
# Process n°7 : Finished
# Process n°11 : Finished
# CPU times: user 266 ms, sys: 1.55 s, total: 1.81 s
# Wall time: 3min 51s

# %% [markdown]
# ### Add parameters

# %% [markdown]
# Describe the combinaison of these new parameters.

# %%
new_parameters = []
for minc in minc_LIST:
    for minhc in minhc_LIST:
        new_parameters.append([("stdConfidence", minc), ("headCoverage", minhc)])
print(new_parameters)
# Out:
# [[('stdConfidence', 0), ('headCoverage', 0)], [('stdConfidence', 0), ('headCoverage', 0.4)], [('stdConfidence', 0.4), ('headCoverage', 0)], [('stdConfidence', 0.4), ('headCoverage', 0.4)]]

# %% [markdown]
# Create the DataFrames corresponding to these parameters.

# %%
new_dfs = add_parameters(rules_per_para, new_parameters)

# %% [markdown]
# Print the precision for each parameters.

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 
to_print, to_print_std = mean_and_std_precision(new_dfs, cv)

to_print.plot.bar(ax=_axs, rot=0, yerr=to_print_std, ylim=[0,1])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Save sets

# %%
save_sets_rule(root, new_dfs)

# %% [markdown]
# # 6° Prediction

# %%
to_print_save =  []
to_print_std_save = []

# %%
# %%time

# prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy_proportional, indexes, True)
prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy, indexes, True)

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "Demo")
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

max_possible = bestScorePossible(prediction_per_rules_count)
print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : LaunchedProcess n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°5 : Finished
# Process n°6 : Finished
# Process n°1 : Finished
# Process n°12 : Finished
# Process n°8 : Finished
# Process n°3 : Finished
# Process n°10 : Finished
# Process n°2 : Finished
# Process n°7 : Finished
# Process n°11 : Finished
# Value('d', 10)
# Process n°4 : Finished
# Process n°0 : Finished
# Process n°9 : Finished
# 12
# CPU times: user 2.86 s, sys: 2.2 s, total: 5.06 s
# Wall time: 3min 49s

# %%
# %%time

# prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy, indexes, True)
prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, safe, indexes, True)

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "Safe")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°3 : Finished
# Process n°1 : Finished
# Process n°7 : Finished
# Process n°5 : Finished
# Process n°6 : Finished
# Process n°11 : Finished
# Process n°2 : Finished
# Process n°10 : Finished
# Process n°9 : Finished
# Value('d', 10)
# Process n°4 : Finished
# Process n°0 : Finished
# Process n°8 : Finished
# 12
# CPU times: user 2.88 s, sys: 781 ms, total: 3.66 s
# Wall time: 17.6 s

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["precision_train", "precision_test"], [False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-precision")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°1 : Finished
# Process n°0 : Finished
# Process n°2 : Finished
# Process n°3 : Finished
# Process n°4 : Finished
# Process n°5 : Finished
# Process n°7 : Finished
# Process n°10 : Finished
# Process n°9 : Finished
# Value('d', 10)
# Process n°6 : Finished
# Process n°8 : Finished
# Process n°11 : Finished
# 12
# CPU times: user 3 s, sys: 750 ms, total: 3.75 s
# Wall time: 22.4 s

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["headCoverage", "precision_train", "precision_test"], [True, False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-coverage")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : LaunchedProcess n°3 : Launched
#
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°1 : Finished
# Process n°5 : Finished
# Process n°0 : Finished
# Process n°4 : Finished
# Process n°3 : Finished
# Process n°6 : Finished
# Process n°9 : Finished
# Value('d', 10)
# Process n°10 : FinishedProcess n°7 : Finished
#
# Process n°8 : Finished
# Process n°2 : Finished
# Process n°11 : Finished
# 12
# CPU times: user 2.84 s, sys: 719 ms, total: 3.56 s
# Wall time: 22 s

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["size_hypothese", "precision_train", "precision_test"], [False, False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-length")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°12 : Finished
# Process n°2 : Finished
# Process n°6 : Finished
# Process n°4 : Finished
# Process n°0 : Finished
# Process n°3 : Finished
# Process n°1 : Finished
# Process n°8 : Finished
# Process n°9 : Finished
# Value('d', 10)
# Process n°7 : Finished
# Process n°10 : Finished
# Process n°11 : Finished
# Process n°5 : Finished
# 12
# CPU times: user 2.88 s, sys: 703 ms, total: 3.58 s
# Wall time: 21.9 s

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 153 entries, ?a income-LTE-50 True => ?a approval False to ?a creditScore-GTE-25 True => ?a approval False
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   hypotheses       153 non-null    object
#  1   conclusion       153 non-null    object
#  2   size_hypothese   153 non-null    int64
#  3   headCoverage     153 non-null    float64
#  4   stdConfidence    153 non-null    float64
#  5   pcaConfidence    153 non-null    float64
#  6   precision_train  153 non-null    float64
#  7   precision_test   153 non-null    float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 10.8+ KB

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0'].describe()
# Out:
#        size_hypothese  headCoverage  stdConfidence  pcaConfidence  \
# count           153.0    153.000000     153.000000     153.000000
# mean              1.0      0.331988       0.552012       0.552012
# std               0.0      0.223722       0.274101       0.274101
# min               1.0      0.052636       0.101281       0.101281
# 25%               1.0      0.161432       0.274309       0.274309
# 50%               1.0      0.219857       0.577086       0.577086
# 75%               1.0      0.550341       0.780281       0.780281
# max               1.0      0.989845       0.999903       0.999903
#
#        precision_train  precision_test
# count       153.000000      153.000000
# mean          0.502959        0.502980
# std           0.209069        0.210086
# min           0.010155        0.011100
# 25%           0.359569        0.359273
# 50%           0.500255        0.502400
# 75%           0.639831        0.644657
# max           0.989845        0.988900

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0']
# Out:
#                                                                                     hypotheses  \
# ?a income-LTE-50 True => ?a approval False                            (?a income-LTE-50 True,)
# ?a creditScore-LTE-75 True => ?a approval False                  (?a creditScore-LTE-75 True,)
# ?a income-LTE-25 True => ?a approval False                            (?a income-LTE-25 True,)
# ?a yearlyReimbursement-LTE-66647.5 True => ?a a...  (?a yearlyReimbursement-LTE-66647.5 True,)
# ?a loanAmount/rate-LTE-16889491.0 True => ?a ap...   (?a loanAmount/rate-LTE-16889491.0 True,)
# ...                                                                                        ...
# ?a creditScore-LTE-75 False => ?a approval False                (?a creditScore-LTE-75 False,)
# ?a monthDuration-GTE-75 True => ?a approval False              (?a monthDuration-GTE-75 True,)
# ?a monthDuration-LTE-75 True => ?a approval True               (?a monthDuration-LTE-75 True,)
# ?a yearlyReimbursement-GT-66647.5 ?b => ?a appr...     (?a yearlyReimbursement-GT-66647.5 ?b,)
# ?a creditScore-GTE-25 True => ?a approval False                  (?a creditScore-GTE-25 True,)
#
#                                                            conclusion  \
# ?a income-LTE-50 True => ?a approval False          ?a approval False
# ?a creditScore-LTE-75 True => ?a approval False     ?a approval False
# ?a income-LTE-25 True => ?a approval False          ?a approval False
# ?a yearlyReimbursement-LTE-66647.5 True => ?a a...  ?a approval False
# ?a loanAmount/rate-LTE-16889491.0 True => ?a ap...  ?a approval False
# ...                                                               ...
# ?a creditScore-LTE-75 False => ?a approval False    ?a approval False
# ?a monthDuration-GTE-75 True => ?a approval False   ?a approval False
# ?a monthDuration-LTE-75 True => ?a approval True     ?a approval True
# ?a yearlyReimbursement-GT-66647.5 ?b => ?a appr...     ?a approval ?b
# ?a creditScore-GTE-25 True => ?a approval False     ?a approval False
#
#                                                     size_hypothese  \
# ?a income-LTE-50 True => ?a approval False                       1
# ?a creditScore-LTE-75 True => ?a approval False                  1
# ?a income-LTE-25 True => ?a approval False                       1
# ?a yearlyReimbursement-LTE-66647.5 True => ?a a...               1
# ?a loanAmount/rate-LTE-16889491.0 True => ?a ap...               1
# ...                                                            ...
# ?a creditScore-LTE-75 False => ?a approval False                 1
# ?a monthDuration-GTE-75 True => ?a approval False                1
# ?a monthDuration-LTE-75 True => ?a approval True                 1
# ?a yearlyReimbursement-GT-66647.5 ?b => ?a appr...               1
# ?a creditScore-GTE-25 True => ?a approval False                  1
#
#                                                     headCoverage  \
# ?a income-LTE-50 True => ?a approval False              0.442969
# ?a creditScore-LTE-75 True => ?a approval False         0.585351
# ?a income-LTE-25 True => ?a approval False              0.235892
# ?a yearlyReimbursement-LTE-66647.5 True => ?a a...      0.128581
# ?a loanAmount/rate-LTE-16889491.0 True => ?a ap...      0.185612
# ...                                                          ...
# ?a creditScore-LTE-75 False => ?a approval False        0.194717
# ?a monthDuration-GTE-75 True => ?a approval False       0.172532
# ?a monthDuration-LTE-75 True => ?a approval True        0.142096
# ?a yearlyReimbursement-GT-66647.5 ?b => ?a appr...      0.137101
# ?a creditScore-GTE-25 True => ?a approval False         0.586086
#
#                                                     stdConfidence  \
# ?a income-LTE-50 True => ?a approval False               0.885540
# ?a creditScore-LTE-75 True => ?a approval False          0.780257
# ?a income-LTE-25 True => ?a approval False               0.943088
# ?a yearlyReimbursement-LTE-66647.5 True => ?a a...       0.378188
# ?a loanAmount/rate-LTE-16889491.0 True => ?a ap...       0.486246
# ...                                                           ...
# ?a creditScore-LTE-75 False => ?a approval False         0.779499
# ?a monthDuration-GTE-75 True => ?a approval False        0.686892
# ?a monthDuration-LTE-75 True => ?a approval True         0.189040
# ?a yearlyReimbursement-GT-66647.5 ?b => ?a appr...       0.137101
# ?a creditScore-GTE-25 True => ?a approval False          0.780301
#
#                                                     pcaConfidence  \
# ?a income-LTE-50 True => ?a approval False               0.885540
# ?a creditScore-LTE-75 True => ?a approval False          0.780257
# ?a income-LTE-25 True => ?a approval False               0.943088
# ?a yearlyReimbursement-LTE-66647.5 True => ?a a...       0.378188
# ?a loanAmount/rate-LTE-16889491.0 True => ?a ap...       0.486246
# ...                                                           ...
# ?a creditScore-LTE-75 False => ?a approval False         0.779499
# ?a monthDuration-GTE-75 True => ?a approval False        0.686892
# ?a monthDuration-LTE-75 True => ?a approval True         0.189040
# ?a yearlyReimbursement-GT-66647.5 ?b => ?a appr...       0.137101
# ?a creditScore-GTE-25 True => ?a approval False          0.780301
#
#                                                     precision_train  \
# ?a income-LTE-50 True => ?a approval False                 0.394354
# ?a creditScore-LTE-75 True => ?a approval False            0.359569
# ?a income-LTE-25 True => ?a approval False                 0.558411
# ?a yearlyReimbursement-LTE-66647.5 True => ?a a...         0.862899
# ?a loanAmount/rate-LTE-16889491.0 True => ?a ap...         0.790568
# ...                                                             ...
# ?a creditScore-LTE-75 False => ?a approval False           0.359569
# ?a monthDuration-GTE-75 True => ?a approval False          0.686182
# ?a monthDuration-LTE-75 True => ?a approval True           0.312588
# ?a yearlyReimbursement-GT-66647.5 ?b => ?a appr...         0.137101
# ?a creditScore-GTE-25 True => ?a approval False            0.358999
#
#                                                     precision_test
# ?a income-LTE-50 True => ?a approval False                0.397852
# ?a creditScore-LTE-75 True => ?a approval False           0.354383
# ?a income-LTE-25 True => ?a approval False                0.561439
# ?a yearlyReimbursement-LTE-66647.5 True => ?a a...        0.866143
# ?a loanAmount/rate-LTE-16889491.0 True => ?a ap...        0.793994
# ...                                                            ...
# ?a creditScore-LTE-75 False => ?a approval False          0.354383
# ?a monthDuration-GTE-75 True => ?a approval False         0.688396
# ?a monthDuration-LTE-75 True => ?a approval True          0.310764
# ?a yearlyReimbursement-GT-66647.5 ?b => ?a appr...        0.133857
# ?a creditScore-GTE-25 True => ?a approval False           0.359273
#
# [153 rows x 8 columns]
