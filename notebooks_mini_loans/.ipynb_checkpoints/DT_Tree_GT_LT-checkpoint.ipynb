# %%
import pandas as pd
import numpy as np
import sklearn.tree as tree
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os.path
from os import path
from sklearn.model_selection import KFold
from multiprocessing import Process, Manager, SimpleQueue
import multiprocessing
import shutil
from sklearn.metrics import accuracy_score
from rules import *
from vote import *
from save_amie_data import *
from precision import *
from amie import *

root = "./../../DT_Tree_GT_LT/"
cv = 3

colors_to_print = ["red",  "blue", "orange",  "violet", "darkgrey", "darkred", "darkblue", "darkorange", "darkviolet", "grey"]

# %% [markdown]
# # 1° Load data

# %%
data = pd.read_csv("./../Data/miniloan-decisions-100K.csv")

# %%
data
# Out:
#            name  creditScore  income  loanAmount  monthDuration      rate  \
# 0      John Doe          736  113243      783440            162  0.030005
# 1      John Doe          527  224186     1787385            183  0.054819
# 2      John Doe          460   39954     1733494             75  0.055183
# 3      John Doe          751  219998     1350004             72  0.043400
# 4      John Doe          684   72470     1210944            160  0.037772
# ...         ...          ...     ...         ...            ...       ...
# 99995  John Doe          366   83851     1718571            168  0.053737
# 99996  John Doe          395  184259     1599473             90  0.040564
# 99997  John Doe          674  242620     1099790            260  0.040825
# 99998  John Doe          420  180957     1645870            203  0.049558
# 99999  John Doe          699  102769      665190            244  0.058460
#
#       approval  yearlyReimbursement
# 0        false                70648
# 1        false               173197
# 2        false               328563
# 3        false               255970
# 4        false               115742
# ...        ...                  ...
# 99995    false               174928
# 99996    false               247703
# 99997    false                76557
# 99998    false               143897
# 99999    false                55993
#
# [100000 rows x 8 columns]

# %% [markdown]
# # Ratios

# %%
ratio_names = [("income","yearlyReimbursement"), ("income","loanAmount"), ("loanAmount","rate")]

# %%
# Takes two features and will create the ratio f_0/f_1
def create_features_ratio(data):
    if data[data.index[1]] == 0:
        return 2147483647
    return np.round(data[data.index[0]]/data[data.index[1]], decimals=2)

# %%
for ratio_name in ratio_names:
    data[f"{ratio_name[0]}/{ratio_name[1]}"] = data[[ratio_name[0], ratio_name[1]]].apply(create_features_ratio, axis=1)

# %%
data
# Out:
#            name  creditScore  income  loanAmount  monthDuration      rate  \
# 0      John Doe          736  113243      783440            162  0.030005
# 1      John Doe          527  224186     1787385            183  0.054819
# 2      John Doe          460   39954     1733494             75  0.055183
# 3      John Doe          751  219998     1350004             72  0.043400
# 4      John Doe          684   72470     1210944            160  0.037772
# ...         ...          ...     ...         ...            ...       ...
# 99995  John Doe          366   83851     1718571            168  0.053737
# 99996  John Doe          395  184259     1599473             90  0.040564
# 99997  John Doe          674  242620     1099790            260  0.040825
# 99998  John Doe          420  180957     1645870            203  0.049558
# 99999  John Doe          699  102769      665190            244  0.058460
#
#       approval  yearlyReimbursement  income/yearlyReimbursement  \
# 0        false                70648                        1.60
# 1        false               173197                        1.29
# 2        false               328563                        0.12
# 3        false               255970                        0.86
# 4        false               115742                        0.63
# ...        ...                  ...                         ...
# 99995    false               174928                        0.48
# 99996    false               247703                        0.74
# 99997    false                76557                        3.17
# 99998    false               143897                        1.26
# 99999    false                55993                        1.84
#
#        income/loanAmount  loanAmount/rate
# 0                   0.14      26110372.80
# 1                   0.13      32605003.59
# 2                   0.02      31413368.70
# 3                   0.16      31106073.81
# 4                   0.06      32059172.14
# ...                  ...              ...
# 99995               0.05      31981153.44
# 99996               0.12      39430859.20
# 99997               0.22      26938940.88
# 99998               0.11      33211031.24
# 99999               0.15      11378481.46
#
# [100000 rows x 11 columns]

# %% [markdown]
# # 2° Find the best thresholds

# %%
data_raw = data.drop(columns=["name"])
false_data = data_raw[data_raw["approval"] == " false"]
true_data = data_raw[data_raw["approval"] == " true"]
data_equilibrium = true_data.append(false_data.sample(n=len(true_data)))

# %%
# %%time

def returnSplitValue(stringToSplit):
    res = []
    tp = ""
    spliters = [("lt", "< "), ("lte", "<= "), ("gt", "> "), ("gte", ">= ")]
    i=0
    
    while i < len(spliters):
        splited = stringToSplit.split(spliters[i][1]) 
        if len(splited) == 2:
            return  spliters[i][0], float(splited[1])
        i += 1
    print("C'est casse")
    return None 


best_threshold = []
for key in data_equilibrium.keys():
    if key != "approval":
        print("\t\t"+key)
        X = data_equilibrium[[key]]

        Y = data_equilibrium["approval"]

        X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)
        
        model = tree.DecisionTreeClassifier(max_depth=1)
        model.fit(X_train, y_train)    

        print(f"Train Score : {accuracy_score(y_train, model.predict(X_train))}")
        print(f"Test Score : {accuracy_score(y_test, model.predict(X_test))}")
        
        if accuracy_score(y_train, model.predict(X_train)) > 0.8 and accuracy_score(y_test, model.predict(X_test)) > 0.8:
            best_threshold.append((key,)+ returnSplitValue(tree.export_text(model, spacing=1, feature_names=[key]).split("\n")[0]))
print(best_threshold)
# Out:
# 		creditScore
# Train Score : 0.5050989190291658
# Test Score : 0.4968944099378882
# 		income
# Train Score : 0.64678088245292
# Test Score : 0.6516908212560386
# 		loanAmount
# Train Score : 0.8404718199741654
# Test Score : 0.847688060731539
# 		monthDuration
# Train Score : 0.6085389897341763
# Test Score : 0.6046928916494134
# 		rate
# Train Score : 0.5081922632401931
# Test Score : 0.5064182194616977
# 		yearlyReimbursement
# Train Score : 0.8963899653273506
# Test Score : 0.9041407867494824
# 		income/yearlyReimbursement
# Train Score : 0.9930994629138623
# Test Score : 0.9937888198757764
# 		income/loanAmount
# Train Score : 0.9254877965871235
# Test Score : 0.9225672877846791
# 		loanAmount/rate
# Train Score : 0.8256509619960568
# Test Score : 0.8284334023464458
# [('loanAmount', 'lte', 820907.0), ('yearlyReimbursement', 'lte', 66625.5), ('income/yearlyReimbursement', 'lte', 3.33), ('income/loanAmount', 'lte', 0.24), ('loanAmount/rate', 'lte', 17679080.0)]
# CPU times: user 1.28 s, sys: 31.2 ms, total: 1.31 s
# Wall time: 1.29 s

# %% [markdown]
# # 3° Create the thresholds

# %% [markdown]
# Define the thresholds

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
# Takes a dataframe and return the values per percents for each feature
def description_per_thresholds(data, percents):
    thresholds_Dic =  {}
    for column in data.columns:
        serie = data[column]
        thresholds_Dic[column] = serie.quantile(percents)
        
    return pd.DataFrame.from_dict(thresholds_Dic)

# %%
def GTE_prep_df(value, valueToCompareTo):
    return value >= valueToCompareTo

def LTE_prep_df(value, valueToCompareTo):
    return value <= valueToCompareTo

def GT_prep_df(value, valueToCompareTo):
    return value > valueToCompareTo

def LT_prep_df(value, valueToCompareTo):
    return value < valueToCompareTo

# %%
columns = list(data.drop(columns=["name", "approval"]).columns)

booleanDF = pd.DataFrame()

for column, comparator, value in best_threshold:
    if comparator == "lte" or comparator == "gt":
        booleanDF[column+"-GT-"+str(value)] = data[column].map(lambda x : GT_prep_df(x, value))
        booleanDF[column+"-LTE-"+str(value)] = data[column].map(lambda x : LTE_prep_df(x, value))
    else:
        booleanDF[column+"-GTE-"+str(value)] = data[column].map(lambda x : GTE_prep_df(x, value))
        booleanDF[column+"-LT-"+str(value)] = data[column].map(lambda x : LT_prep_df(x, value))
    columns.remove(column)

# %%
description = description_per_thresholds(data[columns], thresholds)

# %% [markdown]
# Transform the data from integer values to boolean values corresponding to GTE or LTE with the different percents.

# %%
# %%time

for column in columns:
    for i, value in enumerate(thresholds):
        booleanDF[column+"-GTE-"+str(int(value*100))] = data[column].map(lambda x : GTE_prep_df(x, description[column].values[i]))
        booleanDF[column+"-LTE-"+str(int(value*100))] = data[column].map(lambda x : LTE_prep_df(x, description[column].values[i]))
# Out:
# CPU times: user 7.17 s, sys: 15.6 ms, total: 7.19 s
# Wall time: 7.19 s

# %%
booleanDF["approval"] = data["approval"].map({' true': True, ' false': False})
booleanDF
# Out:
#        loanAmount-GT-820907.0  loanAmount-LTE-820907.0  \
# 0                       False                     True
# 1                        True                    False
# 2                        True                    False
# 3                        True                    False
# 4                        True                    False
# ...                       ...                      ...
# 99995                    True                    False
# 99996                    True                    False
# 99997                    True                    False
# 99998                    True                    False
# 99999                   False                     True
#
#        yearlyReimbursement-GT-66625.5  yearlyReimbursement-LTE-66625.5  \
# 0                                True                            False
# 1                                True                            False
# 2                                True                            False
# 3                                True                            False
# 4                                True                            False
# ...                               ...                              ...
# 99995                            True                            False
# 99996                            True                            False
# 99997                            True                            False
# 99998                            True                            False
# 99999                           False                             True
#
#        income/yearlyReimbursement-GT-3.33  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 99995                               False
# 99996                               False
# 99997                               False
# 99998                               False
# 99999                               False
#
#        income/yearlyReimbursement-LTE-3.33  income/loanAmount-GT-0.24  \
# 0                                     True                      False
# 1                                     True                      False
# 2                                     True                      False
# 3                                     True                      False
# 4                                     True                      False
# ...                                    ...                        ...
# 99995                                 True                      False
# 99996                                 True                      False
# 99997                                 True                      False
# 99998                                 True                      False
# 99999                                 True                      False
#
#        income/loanAmount-LTE-0.24  loanAmount/rate-GT-17679080.0  \
# 0                            True                           True
# 1                            True                           True
# 2                            True                           True
# 3                            True                           True
# 4                            True                           True
# ...                           ...                            ...
# 99995                        True                           True
# 99996                        True                           True
# 99997                        True                           True
# 99998                        True                           True
# 99999                        True                          False
#
#        loanAmount/rate-LTE-17679080.0  ...  monthDuration-LTE-50  \
# 0                               False  ...                  True
# 1                               False  ...                 False
# 2                               False  ...                  True
# 3                               False  ...                  True
# 4                               False  ...                  True
# ...                               ...  ...                   ...
# 99995                           False  ...                  True
# 99996                           False  ...                  True
# 99997                           False  ...                 False
# 99998                           False  ...                 False
# 99999                            True  ...                 False
#
#        monthDuration-GTE-75  monthDuration-LTE-75  rate-GTE-25  rate-LTE-25  \
# 0                     False                  True        False         True
# 1                     False                  True         True        False
# 2                     False                  True         True        False
# 3                     False                  True         True        False
# 4                     False                  True         True        False
# ...                     ...                   ...          ...          ...
# 99995                 False                  True         True        False
# 99996                 False                  True         True        False
# 99997                 False                  True         True        False
# 99998                 False                  True         True        False
# 99999                 False                  True         True        False
#
#        rate-GTE-50  rate-LTE-50  rate-GTE-75  rate-LTE-75  approval
# 0            False         True        False         True     False
# 1             True        False         True        False     False
# 2             True        False         True        False     False
# 3            False         True        False         True     False
# 4            False         True        False         True     False
# ...            ...          ...          ...          ...       ...
# 99995         True        False         True        False     False
# 99996        False         True        False         True     False
# 99997        False         True        False         True     False
# 99998         True        False        False         True     False
# 99999         True        False         True        False     False
#
# [100000 rows x 35 columns]

# %% [markdown]
# Create the folder where the data will be stored.

# %%
if not path.isdir(root):
    os.mkdir(root)
    os.mkdir(root+"/Save_raw")
else : 
    shutil.rmtree(root)
    os.mkdir(root)
    os.mkdir(root+"/Save_raw")

# %%
booleanDF.to_csv(root+"dfSave.csv")

# %% [markdown]
# # 4° Save the best data

# %% [markdown]
# We store the data in the Amie format.

# %%
save_all_data(root, booleanDF)

# %% [markdown]
# ## Save in cross validation

# %%
save_CV(root, booleanDF, cv)
# Out:
# Train repartition :
#  False    52004
# True     14662
# Name: approval, dtype: int64
# Train repartition :
#  False    52007
# True     14660
# Name: approval, dtype: int64
# Train repartition :
#  False    52081
# True     14586
# Name: approval, dtype: int64

# %% [markdown]
# # 5° Launch Amie

# %% [markdown]
# Describe the parameters.

# %%
atom_LIST = [2]
minc_LIST = [0, 0.4, 0.8]
minhc_LIST = [0, 0.4, 0.8]

# %% [markdown]
# Launch Amie.

# %%
# %%time

res_rules_raw = run_amie(atom_LIST, root, cv, const=False)
# Out:
# 2
# 2
# 2
# CPU times: user 0 ns, sys: 93.8 ms, total: 93.8 ms
# Wall time: 21.4 s

# %% [markdown]
# ### Save raw results

# %%
for i in res_rules_raw:
    f = open(root+"Save_raw/"+i+".txt", "w")
    f.write(res_rules_raw[i].decode())
    f.close()

# %% [markdown]
# ### Read raw results

# %%
res_rules_raw = {}
for a in atom_LIST:
    for i in range(cv):
        f = open(root+"Save_raw/"+f"CV={i}-A={a}"+".txt", "r")
        res_rules_raw[f"CV={i}-A={a}"] = f.read().encode()
        f.close()

# %% [markdown]
# Transform the raw output into sets of rules.

# %%
rules_per_cv = parse_amie(res_rules_raw)

# %% [markdown]
# Retrieve the indexes for each CV.

# %%
indexes = retrieve_indexes(root, cv)
df = pd.read_csv(root+"dfSave.csv")

# %% [markdown]
# # 5° Precision

# %%
# %%time

rules_per_para = run_precision(root, indexes, rules_per_cv)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°2 : Finished
# Process n°0 : Finished
# Process n°6 : Finished
# Process n°4 : Finished
# Process n°8 : Finished
# Process n°10 : Finished
# Process n°1 : Finished
# Process n°3 : Finished
# Process n°5 : Finished
# Process n°7 : Finished
# Process n°12 : Finished
# Process n°9 : Finished
# Process n°11 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : LaunchedProcess n°5 : Launched
#
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°0 : Finished
# Process n°2 : Finished
# Process n°4 : Finished
# Process n°6 : Finished
# Process n°8 : Finished
# Process n°10 : Finished
# Process n°1 : Finished
# Process n°5 : Finished
# Process n°7 : Finished
# Process n°11 : Finished
# Process n°3 : Finished
# Process n°9 : Finished
# Process n°12 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : LaunchedProcess n°5 : Launched
#
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°0 : Finished
# Process n°2 : Finished
# Process n°4 : Finished
# Process n°6 : Finished
# Process n°8 : Finished
# Process n°10 : Finished
# Process n°3 : Finished
# Process n°1 : Finished
# Process n°9 : Finished
# Process n°5 : Finished
# Process n°12 : Finished
# Process n°7 : Finished
# Process n°11 : Finished
# CPU times: user 328 ms, sys: 1.41 s, total: 1.73 s
# Wall time: 27.7 s

# %% [markdown]
# ### Add parameters

# %% [markdown]
# Describe the combinaison of these new parameters.

# %%
new_parameters = []
for minc in minc_LIST:
    for minhc in minhc_LIST:
        new_parameters.append([("stdConfidence", minc), ("headCoverage", minhc)])
print(new_parameters)
# Out:
# [[('stdConfidence', 0), ('headCoverage', 0)], [('stdConfidence', 0), ('headCoverage', 0.4)], [('stdConfidence', 0), ('headCoverage', 0.8)], [('stdConfidence', 0.4), ('headCoverage', 0)], [('stdConfidence', 0.4), ('headCoverage', 0.4)], [('stdConfidence', 0.4), ('headCoverage', 0.8)], [('stdConfidence', 0.8), ('headCoverage', 0)], [('stdConfidence', 0.8), ('headCoverage', 0.4)], [('stdConfidence', 0.8), ('headCoverage', 0.8)]]

# %% [markdown]
# Create the DataFrames corresponding to these parameters.

# %%
new_dfs = add_parameters(rules_per_para, new_parameters)

# %% [markdown]
# Print the precision for each parameters.

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 
to_print, to_print_std = mean_and_std_precision(new_dfs, cv)

to_print.plot.bar(ax=_axs, rot=0, yerr=to_print_std, ylim=[0,1])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 6° Prediction

# %%
to_print_save =  []
to_print_std_save = []

# %%
# %%time

# prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy_proportional, indexes, True)
prediction_per_rules_count, prediction_per_rules_raw, rules_used = prediction_test(root, cv, new_dfs, democracy, indexes, True)

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "Demo", cv)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

max_possible = bestScorePossible(prediction_per_rules_count)
print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)

# %%
# %%time

# prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy, indexes, True)
prediction_per_rules_count, prediction_per_rules_raw, rules_used = prediction_test(root, cv, new_dfs, safe, indexes, True)

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "Safe", cv)
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw, rules_used = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["precision_train", "precision_test"], [False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-precision", cv)
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw, rules_used = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["headCoverage", "precision_train", "precision_test"], [True, False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-coverage", cv)
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw, rules_used = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["size_hypothese", "precision_train", "precision_test"], [False, False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-length", cv)
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <timed exec> in <module>
#
# /mnt/c/Users/Thibaut/Desktop/FAC/M1 - DS/Stage/Stage/notebooks_mini_loans/vote.py in prediction_test(root, cv, new_dfs, vote, indexes, baseline, ranking)
#     281     rules_used = {}
#     282
# --> 283     df = pd.read_csv(root+"dfSave.csv", index_col=0)
#     284
#     285     q = SimpleQueue()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1055     def read(self, nrows=None):
#    1056         nrows = validate_integer("nrows", nrows)
# -> 1057         index, columns, col_dict = self._engine.read(nrows)
#    1058
#    1059         if index is None:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2059     def read(self, nrows=None):
#    2060         try:
# -> 2061             data = self._reader.read(nrows)
#    2062         except StopIteration:
#    2063             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
new_dfs['CV=0-A=2\nstdC=0\npcaC=0\nhC=0'].info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-f142721a1048> in <module>
# ----> 1 new_dfs['CV=0-A=2\nstdC=0\npcaC=0\nhC=0'].info()
#
# KeyError: 'CV=0-A=2\nstdC=0\npcaC=0\nhC=0'

# %%
new_dfs['CV=0-A=2\nstdC=0\npcaC=0\nhC=0'].describe()
# Out:
#        size_hypothese  headCoverage  stdConfidence  pcaConfidence  \
# count            60.0     60.000000      60.000000      60.000000
# mean              1.0      0.560321       0.281686       0.560321
# std               0.0      0.257146       0.198940       0.257146
# min               1.0      0.120914       0.052636       0.120914
# 25%               1.0      0.284934       0.140308       0.284934
# 50%               1.0      0.532434       0.199487       0.532434
# 75%               1.0      0.749744       0.401310       0.749744
# max               1.0      0.999659       0.769988       0.999659
#
#        precision_train  precision_test
# count        60.000000       60.000000
# mean          0.562369        0.562340
# std           0.288951        0.289424
# min           0.114460        0.116262
# 25%           0.231869        0.229313
# 50%           0.653690        0.656999
# 75%           0.781410        0.783913
# max           0.999903        0.999766

# %%
new_dfs['CV=0-A=2\nstdC=0\npcaC=0.4\nhC=0'].describe()
# Out:
#        size_hypothese  headCoverage  stdConfidence  pcaConfidence  \
# count            41.0     41.000000      41.000000      41.000000
# mean              1.0      0.703516       0.348003       0.703516
# std               0.0      0.173125       0.205050       0.173125
# min               1.0      0.419452       0.092251       0.419452
# 25%               1.0      0.517255       0.164852       0.517255
# 50%               1.0      0.739667       0.337098       0.739667
# 75%               1.0      0.796131       0.574401       0.796131
# max               1.0      0.999659       0.769988       0.999659
#
#        precision_train  precision_test
# count        41.000000       41.000000
# mean          0.592742        0.592746
# std           0.291586        0.292400
# min           0.170533        0.170693
# 25%           0.265045        0.265239
# 50%           0.701596        0.705536
# 75%           0.787173        0.787374
# max           0.999903        0.999766

# %%
new_dfs['CV=0-A=2\nstdC=0\npcaC=0\nhC=0.4'].describe()
# Out:
#        size_hypothese  headCoverage  stdConfidence  pcaConfidence  \
# count            41.0     41.000000      41.000000      41.000000
# mean              1.0      0.703516       0.348003       0.703516
# std               0.0      0.173125       0.205050       0.173125
# min               1.0      0.419452       0.092251       0.419452
# 25%               1.0      0.517255       0.164852       0.517255
# 50%               1.0      0.739667       0.337098       0.739667
# 75%               1.0      0.796131       0.574401       0.796131
# max               1.0      0.999659       0.769988       0.999659
#
#        precision_train  precision_test
# count        41.000000       41.000000
# mean          0.592742        0.592746
# std           0.291586        0.292400
# min           0.170533        0.170693
# 25%           0.265045        0.265239
# 50%           0.701596        0.705536
# 75%           0.787173        0.787374
# max           0.999903        0.999766
