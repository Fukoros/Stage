# %%
import pandas as pd
import numpy as np
import sklearn.tree as tree
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os.path
from os import path
from sklearn.model_selection import KFold
from multiprocessing import Process, Manager, SimpleQueue
import multiprocessing
import shutil
import sys
import time
from sklearn.metrics import accuracy_score
from rules import *
from vote import *
from save_amie_data import *
from precision import *
from amie import *

root = "./../../DT_constant_GT/"
cv = 3

colors_to_print = ["red",  "blue", "orange",  "violet", "darkgrey", "darkred", "darkblue", "darkorange", "darkviolet", "grey"]

# %% [markdown]
# # 1° Load data

# %%
data = pd.read_csv("./../Data/miniloan-decisions-100K.csv")

# %%
data
# Out:
#            name  creditScore  income  loanAmount  monthDuration      rate  \
# 0      John Doe          736  113243      783440            162  0.030005
# 1      John Doe          527  224186     1787385            183  0.054819
# 2      John Doe          460   39954     1733494             75  0.055183
# 3      John Doe          751  219998     1350004             72  0.043400
# 4      John Doe          684   72470     1210944            160  0.037772
# ...         ...          ...     ...         ...            ...       ...
# 99995  John Doe          366   83851     1718571            168  0.053737
# 99996  John Doe          395  184259     1599473             90  0.040564
# 99997  John Doe          674  242620     1099790            260  0.040825
# 99998  John Doe          420  180957     1645870            203  0.049558
# 99999  John Doe          699  102769      665190            244  0.058460
#
#       approval  yearlyReimbursement
# 0        false                70648
# 1        false               173197
# 2        false               328563
# 3        false               255970
# 4        false               115742
# ...        ...                  ...
# 99995    false               174928
# 99996    false               247703
# 99997    false                76557
# 99998    false               143897
# 99999    false                55993
#
# [100000 rows x 8 columns]

# %% [markdown]
# # Ratios

# %%
ratio_names = [("income","yearlyReimbursement"), ("income","loanAmount"), ("loanAmount","rate")]

# %%
# Takes two features and will create the ratio f_0/f_1
def create_features_ratio(data):
    if data[data.index[1]] == 0:
        return 2147483647
    return np.round(data[data.index[0]]/data[data.index[1]], decimals=2)

# %%
for ratio_name in ratio_names:
    data[f"{ratio_name[0]}/{ratio_name[1]}"] = data[[ratio_name[0], ratio_name[1]]].apply(create_features_ratio, axis=1)

# %%
data
# Out:
#            name  creditScore  income  loanAmount  monthDuration      rate  \
# 0      John Doe          736  113243      783440            162  0.030005
# 1      John Doe          527  224186     1787385            183  0.054819
# 2      John Doe          460   39954     1733494             75  0.055183
# 3      John Doe          751  219998     1350004             72  0.043400
# 4      John Doe          684   72470     1210944            160  0.037772
# ...         ...          ...     ...         ...            ...       ...
# 99995  John Doe          366   83851     1718571            168  0.053737
# 99996  John Doe          395  184259     1599473             90  0.040564
# 99997  John Doe          674  242620     1099790            260  0.040825
# 99998  John Doe          420  180957     1645870            203  0.049558
# 99999  John Doe          699  102769      665190            244  0.058460
#
#       approval  yearlyReimbursement  income/yearlyReimbursement  \
# 0        false                70648                        1.60
# 1        false               173197                        1.29
# 2        false               328563                        0.12
# 3        false               255970                        0.86
# 4        false               115742                        0.63
# ...        ...                  ...                         ...
# 99995    false               174928                        0.48
# 99996    false               247703                        0.74
# 99997    false                76557                        3.17
# 99998    false               143897                        1.26
# 99999    false                55993                        1.84
#
#        income/loanAmount  loanAmount/rate
# 0                   0.14      26110372.80
# 1                   0.13      32605003.59
# 2                   0.02      31413368.70
# 3                   0.16      31106073.81
# 4                   0.06      32059172.14
# ...                  ...              ...
# 99995               0.05      31981153.44
# 99996               0.12      39430859.20
# 99997               0.22      26938940.88
# 99998               0.11      33211031.24
# 99999               0.15      11378481.46
#
# [100000 rows x 11 columns]

# %% [markdown]
# # 3° Create the thresholds

# %% [markdown]
# Define the thresholds

# %%
thresholds = np.arange(0.25,1,0.25) #[0.25, 0.50, 0.75]
thresholds_str = ["-"+(str(int(i*100))) for i in thresholds]

# %%
# Takes a dataframe and return the values per percents for each feature
def description_per_thresholds(data, percents):
    thresholds_Dic =  {}
    for column in data.columns:
        serie = data[column]
        thresholds_Dic[column] = serie.quantile(percents)
        
    return pd.DataFrame.from_dict(thresholds_Dic)

# %%
def GTE_prep_df(value, valueToCompareTo):
    return value >= valueToCompareTo

def LTE_prep_df(value, valueToCompareTo):
    return value <= valueToCompareTo

def GT_prep_df(value, valueToCompareTo):
    return value > valueToCompareTo

def LT_prep_df(value, valueToCompareTo):
    return value < valueToCompareTo

# %%
columns_to_compare = ['creditScore', 'income', 'loanAmount', 'monthDuration', 'rate', 'yearlyReimbursement', 'income/yearlyReimbursement']

description = description_per_thresholds(data[columns_to_compare], thresholds)

# %% [markdown]
# Transform the data from integer values to boolean values corresponding to GTE or LTE with the different percents.

# %%
# %%time

booleanDF = pd.DataFrame()

for column in columns_to_compare:
    for i, value in enumerate(thresholds):
        booleanDF[column+"-GTE-"+str(int(value*100))] = data[column].map(lambda x : GTE_prep_df(x, description[column].values[i]))
#         booleanDF[column+"-LTE-"+str(int(value*100))] = data[column].map(lambda x : LTE_prep_df(x, description[column].values[i]))
# Out:
# CPU times: user 6.23 s, sys: 15.6 ms, total: 6.25 s
# Wall time: 6.24 s

# %%
booleanDF["approval"] = data["approval"].map({' true': True, ' false': False})
booleanDF
# Out:
#        creditScore-GTE-25  creditScore-GTE-50  creditScore-GTE-75  \
# 0                    True                True                True
# 1                    True               False               False
# 2                    True               False               False
# 3                    True                True                True
# 4                    True                True               False
# ...                   ...                 ...                 ...
# 99995               False               False               False
# 99996               False               False               False
# 99997                True                True               False
# 99998               False               False               False
# 99999                True                True               False
#
#        income-GTE-25  income-GTE-50  income-GTE-75  loanAmount-GTE-25  \
# 0               True          False          False               True
# 1               True           True          False               True
# 2              False          False          False               True
# 3               True           True          False               True
# 4              False          False          False               True
# ...              ...            ...            ...                ...
# 99995           True          False          False               True
# 99996           True           True          False               True
# 99997           True           True           True               True
# 99998           True           True          False               True
# 99999           True          False          False               True
#
#        loanAmount-GTE-50  loanAmount-GTE-75  monthDuration-GTE-25  ...  \
# 0                  False              False                  True  ...
# 1                   True               True                  True  ...
# 2                   True               True                 False  ...
# 3                   True              False                 False  ...
# 4                   True              False                  True  ...
# ...                  ...                ...                   ...  ...
# 99995               True               True                  True  ...
# 99996               True               True                  True  ...
# 99997               True              False                  True  ...
# 99998               True               True                  True  ...
# 99999              False              False                  True  ...
#
#        rate-GTE-25  rate-GTE-50  rate-GTE-75  yearlyReimbursement-GTE-25  \
# 0            False        False        False                        True
# 1             True         True         True                        True
# 2             True         True         True                        True
# 3             True        False        False                        True
# 4             True        False        False                        True
# ...            ...          ...          ...                         ...
# 99995         True         True         True                        True
# 99996         True        False        False                        True
# 99997         True        False        False                        True
# 99998         True         True        False                        True
# 99999         True         True         True                        True
#
#        yearlyReimbursement-GTE-50  yearlyReimbursement-GTE-75  \
# 0                           False                       False
# 1                            True                        True
# 2                            True                        True
# 3                            True                        True
# 4                            True                       False
# ...                           ...                         ...
# 99995                        True                        True
# 99996                        True                        True
# 99997                       False                       False
# 99998                        True                       False
# 99999                       False                       False
#
#        income/yearlyReimbursement-GTE-25  income/yearlyReimbursement-GTE-50  \
# 0                                   True                               True
# 1                                   True                              False
# 2                                  False                              False
# 3                                   True                              False
# 4                                   True                              False
# ...                                  ...                                ...
# 99995                              False                              False
# 99996                               True                              False
# 99997                               True                               True
# 99998                               True                              False
# 99999                               True                               True
#
#        income/yearlyReimbursement-GTE-75  approval
# 0                                  False     False
# 1                                  False     False
# 2                                  False     False
# 3                                  False     False
# 4                                  False     False
# ...                                  ...       ...
# 99995                              False     False
# 99996                              False     False
# 99997                               True     False
# 99998                              False     False
# 99999                              False     False
#
# [100000 rows x 22 columns]

# %% [markdown]
# Create the folder where the data will be stored.

# %%
if not path.isdir(root):
    os.mkdir(root)
else : 
    shutil.rmtree(root)
    os.mkdir(root)

# %%
booleanDF.to_csv(root+"dfSave.csv")

# %% [markdown]
# # 4° Save the best data

# %% [markdown]
# We store the data in the Amie format.

# %%
save_all_data(root, booleanDF)

# %% [markdown]
# ## Save in cross validation

# %%
save_CV(root, booleanDF, cv)
# Out:
# Train repartition :
#  False    52004
# True     14662
# Name: approval, dtype: int64
# Train repartition :
#  False    52007
# True     14660
# Name: approval, dtype: int64
# Train repartition :
#  False    52081
# True     14586
# Name: approval, dtype: int64

# %% [markdown]
# # 5° Launch Amie

# %% [markdown]
# Describe the parameters.

# %%
atom_LIST = [2]#, 3]
minc_LIST = [0, 0.4]#, 0.8]
minhc_LIST = [0, 0.4]#, 0.8]

# %% [markdown]
# Launch Amie.

# %%
# %%time

res_rules_raw = run_amie(atom_LIST, root, cv, const=True)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°3 : FinishedProcess n°4 : Launched
#
# Process n°4 : FinishedProcess n°5 : Launched
#
# Process n°5 : FinishedProcess n°6 : Launched
#
# Process n°6 : FinishedProcess n°7 : Launched
#
# Process n°7 : FinishedProcess n°8 : Launched
#
# Process n°8 : FinishedProcess n°9 : Launched
#
# Process n°10 : Launched
# Process n°9 : FinishedProcess n°11 : LaunchedProcess n°10 : Finished
#
#
# Process n°12 : LaunchedProcess n°11 : Finished
# Process n°12 : Finished
#
# Process n°2 : Finished
# Process n°1 : Finished
# Process n°0 : Finished
# CPU times: user 0 ns, sys: 500 ms, total: 500 ms
# Wall time: 18min 9s

# %% [markdown]
# Transform the raw output into sets of rules.

# %%
rules_per_cv = parse_amie(res_rules_raw)

# %% [markdown]
# Retrieve the indexes for each CV.

# %%
indexes = retrieve_indexes(root, cv)
df = pd.read_csv(root+"dfSave.csv")

# %% [markdown]
# # 5° Precision

# %%
# %%time

rules_per_para = run_precision(root, indexes, rules_per_cv)
# Out:
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°2 : Finished
# Process n°1 : Finished
# Process n°0 : Finished
# Process n°3 : Finished
# Process n°5 : Finished
# Process n°6 : Finished
# Process n°7 : Finished
# Process n°9 : Finished
# Process n°11 : Finished
# Process n°10 : Finished
# Process n°8 : Finished
# Process n°12 : Finished
# Process n°4 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
#
# Process n°5 : LaunchedProcess n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°3 : Finished
# Process n°2 : Finished
# Process n°0 : Finished
# Process n°1 : Finished
# Process n°6 : Finished
# Process n°10 : Finished
# Process n°5 : Finished
# Process n°9 : Finished
# Process n°7 : Finished
# Process n°11 : Finished
# Process n°4 : Finished
# Process n°12 : Finished
# Process n°8 : Finished
# Process n°0 : Launched
# Process n°1 : Launched
# Process n°2 : Launched
# Process n°3 : Launched
# Process n°4 : Launched
# Process n°5 : Launched
# Process n°6 : Launched
# Process n°7 : Launched
# Process n°8 : Launched
# Process n°9 : Launched
# Process n°10 : Launched
# Process n°11 : Launched
# Process n°12 : Launched
# Process n°0 : Finished
# Process n°1 : Finished
# Process n°2 : Finished
# Process n°3 : Finished
# Process n°5 : Finished
# Process n°11 : Finished
# Process n°6 : Finished
# Process n°7 : Finished
# Process n°9 : Finished
# Process n°10 : Finished
# Process n°8 : Finished
# Process n°12 : Finished
# Process n°4 : Finished
# CPU times: user 297 ms, sys: 1.41 s, total: 1.7 s
# Wall time: 2min 36s

# %% [markdown]
# ### Add parameters

# %% [markdown]
# Describe the combinaison of these new parameters.

# %%
new_parameters = []
for minc in minc_LIST:
    for minhc in minhc_LIST:
        new_parameters.append([("stdConfidence", minc), ("headCoverage", minhc)])
print(new_parameters)
# Out:
# [[('stdConfidence', 0), ('headCoverage', 0)], [('stdConfidence', 0), ('headCoverage', 0.4)], [('stdConfidence', 0.4), ('headCoverage', 0)], [('stdConfidence', 0.4), ('headCoverage', 0.4)]]

# %% [markdown]
# Create the DataFrames corresponding to these parameters.

# %%
new_dfs = add_parameters(rules_per_para, new_parameters)

# %% [markdown]
# Print the precision for each parameters.

# %%
fig, _axs = plt.subplots(nrows=1, ncols=1, figsize=(30,10)) 
to_print, to_print_std = mean_and_std_precision(new_dfs, cv)

to_print.plot.bar(ax=_axs, rot=0, yerr=to_print_std, yerr=[0,1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-5daf29584309> in <module>
#       2 to_print, to_print_std = mean_and_std_precision(new_dfs, cv)
#       3
# ----> 4 to_print.plot.bar(ax=_axs, rot=0, yerr=to_print_std, ylimit=[0,1])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1111         other axis represents a measured value.
#    1112         """
# -> 1113         return self(kind="bar", x=x, y=y, **kwargs)
#    1114
#    1115     @Appender(
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     278         self._compute_plot_data()
#     279         self._setup_subplots()
# --> 280         self._make_plot()
#     281         self._add_table()
#     282         self._make_legend()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1473             else:
#    1474                 w = self.bar_width / K
# -> 1475                 rect = self._plot(
#    1476                     ax,
#    1477                     self.ax_pos + (i + 0.5) * w,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1404     @classmethod
#    1405     def _plot(cls, ax: "Axes", x, y, w, start=0, log=False, **kwds):
# -> 1406         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1407
#    1408     @property
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2486                 label='_nolegend_',
#    2487                 )
# -> 2488             r.update(kwargs)
#    2489             r.get_path()._interpolation_steps = 100
#    2490             if orientation == 'vertical':
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'ylimit'

# %% [markdown]
# ### Save sets

# %%
save_sets_rule(root, new_dfs)

# %% [markdown]
# # 6° Prediction

# %%
to_print_save =  []
to_print_std_save = []

# %%
# %%time

# prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy_proportional, indexes, True)
prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy, indexes, True)

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "Demo")
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

max_possible = bestScorePossible(prediction_per_rules_count)
print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)

# %%
# %%time

# prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, democracy, indexes, True)
prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, safe, indexes, True)

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "Safe")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["precision_train", "precision_test"], [False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-precision")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["headCoverage", "precision_train", "precision_test"], [True, False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-coverage")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)

# %%
# %%time

prediction_per_rules_count, prediction_per_rules_raw = prediction_test(root, cv, new_dfs, expert, indexes, True, ranking=(["size_hypothese", "precision_train", "precision_test"], [False, False, False]))

accuracy_prediction = compute_accuracy_prediction(prediction_per_rules_raw, df, indexes)

to_print, to_print_std = mean_and_std_vote(accuracy_prediction, "expert-length")
to_print, to_print_std = merge(to_print_save[-1], to_print, to_print_std_save[-1], to_print_std)
to_print_save.append(to_print)
to_print_std_save.append(to_print_std)

print_accuracy(to_print_save[-1], to_print_std_save[-1], max_possible, colors_to_print)

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0'].info()

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0'].describe()
# Out:
#        size_hypothese  headCoverage  stdConfidence  pcaConfidence  \
# count            94.0     94.000000      94.000000      94.000000
# mean              1.0      0.333341       0.555288       0.555288
# std               0.0      0.212447       0.275487       0.275487
# min               1.0      0.031185       0.106471       0.106471
# 25%               1.0      0.163097       0.284455       0.284455
# 50%               1.0      0.265338       0.569720       0.569720
# 75%               1.0      0.522995       0.779601       0.779601
# max               1.0      0.968815       1.000000       1.000000
#
#        precision_train  precision_test
# count        94.000000       94.000000
# mean          0.504457        0.504064
# std           0.193933        0.194693
# min           0.106471        0.105118
# 25%           0.358999        0.359273
# 50%           0.498740        0.502400
# 75%           0.635916        0.635147
# max           0.968815        0.968441

# %%
new_dfs['CV=0-A=2\nstdC=0\nhC=0']
# Out:
#                                                                                 hypotheses  \
# ?a rate-GTE-50 True => ?a approval True                             (?a rate-GTE-50 True,)
# ?a loanAmount-GTE-75 True => ?a approval False                (?a loanAmount-GTE-75 True,)
# ?a rate-GTE-25 True => ?a approval False                            (?a rate-GTE-25 True,)
# ?a creditScore-GTE-25 True => ?a approval False              (?a creditScore-GTE-25 True,)
# ?a rate-GTE-75 ?b => ?a approval ?b                                   (?a rate-GTE-75 ?b,)
# ...                                                                                    ...
# ?a income-GTE-50 True => ?a approval False                        (?a income-GTE-50 True,)
# ?a creditScore-GTE-50 ?b => ?a approval ?b                     (?a creditScore-GTE-50 ?b,)
# ?a yearlyReimbursement-GTE-25 False => ?a appro...  (?a yearlyReimbursement-GTE-25 False,)
# ?a rate-GTE-50 False => ?a approval True                           (?a rate-GTE-50 False,)
# ?a creditScore-GTE-25 True => ?a approval True               (?a creditScore-GTE-25 True,)
#
#                                                            conclusion  \
# ?a rate-GTE-50 True => ?a approval True              ?a approval True
# ?a loanAmount-GTE-75 True => ?a approval False      ?a approval False
# ?a rate-GTE-25 True => ?a approval False            ?a approval False
# ?a creditScore-GTE-25 True => ?a approval False     ?a approval False
# ?a rate-GTE-75 ?b => ?a approval ?b                    ?a approval ?b
# ...                                                               ...
# ?a income-GTE-50 True => ?a approval False          ?a approval False
# ?a creditScore-GTE-50 ?b => ?a approval ?b             ?a approval ?b
# ?a yearlyReimbursement-GTE-25 False => ?a appro...  ?a approval False
# ?a rate-GTE-50 False => ?a approval True             ?a approval True
# ?a creditScore-GTE-25 True => ?a approval True       ?a approval True
#
#                                                     size_hypothese  \
# ?a rate-GTE-50 True => ?a approval True                          1
# ?a loanAmount-GTE-75 True => ?a approval False                   1
# ?a rate-GTE-25 True => ?a approval False                         1
# ?a creditScore-GTE-25 True => ?a approval False                  1
# ?a rate-GTE-75 ?b => ?a approval ?b                              1
# ...                                                            ...
# ?a income-GTE-50 True => ?a approval False                       1
# ?a creditScore-GTE-50 ?b => ?a approval ?b                       1
# ?a yearlyReimbursement-GTE-25 False => ?a appro...               1
# ?a rate-GTE-50 False => ?a approval True                         1
# ?a creditScore-GTE-25 True => ?a approval True                   1
#
#                                                     headCoverage  \
# ?a rate-GTE-50 True => ?a approval True                 0.106171
# ?a loanAmount-GTE-75 True => ?a approval False          0.248522
# ?a rate-GTE-25 True => ?a approval False                0.588021
# ?a creditScore-GTE-25 True => ?a approval False         0.586086
# ?a rate-GTE-75 ?b => ?a approval ?b                     0.635916
# ...                                                          ...
# ?a income-GTE-50 True => ?a approval False              0.337098
# ?a creditScore-GTE-50 ?b => ?a approval ?b              0.498740
# ?a yearlyReimbursement-GTE-25 False => ?a appro...      0.068986
# ?a rate-GTE-50 False => ?a approval True                0.113761
# ?a creditScore-GTE-25 True => ?a approval True          0.165017
#
#                                                     stdConfidence  \
# ?a rate-GTE-50 True => ?a approval True                  0.212827
# ?a loanAmount-GTE-75 True => ?a approval False           1.000000
# ?a rate-GTE-25 True => ?a approval False                 0.784601
# ?a creditScore-GTE-25 True => ?a approval False          0.780301
# ?a rate-GTE-75 ?b => ?a approval ?b                      0.635916
# ...                                                           ...
# ?a income-GTE-50 True => ?a approval False               0.674500
# ?a creditScore-GTE-50 ?b => ?a approval ?b               0.498740
# ?a yearlyReimbursement-GTE-25 False => ?a appro...       0.274371
# ?a rate-GTE-50 False => ?a approval True                 0.227005
# ?a creditScore-GTE-25 True => ?a approval True           0.219699
#
#                                                     pcaConfidence  \
# ?a rate-GTE-50 True => ?a approval True                  0.212827
# ?a loanAmount-GTE-75 True => ?a approval False           1.000000
# ?a rate-GTE-25 True => ?a approval False                 0.784601
# ?a creditScore-GTE-25 True => ?a approval False          0.780301
# ?a rate-GTE-75 ?b => ?a approval ?b                      0.635916
# ...                                                           ...
# ?a income-GTE-50 True => ?a approval False               0.674500
# ?a creditScore-GTE-50 ?b => ?a approval ?b               0.498740
# ?a yearlyReimbursement-GTE-25 False => ?a appro...       0.274371
# ?a rate-GTE-50 False => ?a approval True                 0.227005
# ?a creditScore-GTE-25 True => ?a approval True           0.219699
#
#                                                     precision_train  \
# ?a rate-GTE-50 True => ?a approval True                    0.493550
# ?a loanAmount-GTE-75 True => ?a approval False             0.531545
# ?a rate-GTE-25 True => ?a approval False                   0.353479
# ?a creditScore-GTE-25 True => ?a approval False            0.358999
# ?a rate-GTE-75 ?b => ?a approval ?b                        0.635916
# ...                                                             ...
# ?a income-GTE-50 True => ?a approval False                 0.605646
# ?a creditScore-GTE-50 ?b => ?a approval ?b                 0.498740
# ?a yearlyReimbursement-GTE-25 False => ?a appro...         0.106471
# ?a rate-GTE-50 False => ?a approval True                   0.493550
# ?a creditScore-GTE-25 True => ?a approval True             0.358999
#
#                                                     precision_test
# ?a rate-GTE-50 True => ?a approval True                   0.492560
# ?a loanAmount-GTE-75 True => ?a approval False            0.528289
# ?a rate-GTE-25 True => ?a approval False                  0.352883
# ?a creditScore-GTE-25 True => ?a approval False           0.359273
# ?a rate-GTE-75 ?b => ?a approval ?b                       0.635147
# ...                                                            ...
# ?a income-GTE-50 True => ?a approval False                0.602148
# ?a creditScore-GTE-50 ?b => ?a approval ?b                0.502400
# ?a yearlyReimbursement-GTE-25 False => ?a appro...        0.105118
# ?a rate-GTE-50 False => ?a approval True                  0.492560
# ?a creditScore-GTE-25 True => ?a approval True            0.359273
#
# [94 rows x 8 columns]
